# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Variables Description
#
# - **flight_id**: A unique identifier assigned to each flight.
# - **date**: The date when the flight took place.
# - **callsign**: The encrypted callsign associated with the flight.
# - **adep**: The code of the departure airport.
# - **name_adep**: The name of the departure airport.
# - **country_code_adep**: The country code of the departure airport.
# - **ades**: The code of the destination airport.
# - **name_ades**: The name of the destination airport.
# - **country_code_ades**: The country code of the destination airport.
# - **actual_offblock_time**: The time when the aircraft started to move from its parking position.
# - **arrival_time**: The time of arrival at the destination airport.
# - **aircraft_type**: The type of aircraft used for the flight.
# - **wtc**: The wake turbulence category of the aircraft.
# - **airline**: The encrypted identifier of the airline operating the flight.
# - **flight_duration**: The duration of the flight in minutes.
# - **taxiout_time**: The time spent taxiing out from the departure airport.
# - **flown_distance**: The distance flown during the flight in kilometers.
# - **tow**: The target variable representing the actual TakeOff Weight (TOW) of the aircraft.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# %% [raw]
# import pandas as pd
#
# # Loading the dataset
# traj = pd.read_csv('./data/trajectory_features.csv')
#
# # Checking for missing values in each column and displaying the result as a DataFrame
# missing_values = traj.isnull().sum()
# missing_values_df = pd.DataFrame(missing_values, columns=['Missing Values'])
# missing_values_df['Percentage'] = (missing_values_df['Missing Values'] / len(traj)) * 100
# missing_values_df

# %%
# Load the datasets
challenge_set_original = pd.read_csv('./data/challenge_set.csv')
submission_set_original = pd.read_csv('./data/submission_set.csv')
trajectories_set = pd.read_csv('./data/trajectory_features.csv')

# Display the first few rows of the datasets to understand their structure
# challenge_set.T

print('number of samples in the challenge set:', challenge_set_original.shape)
print('number of samples in the submission set:', submission_set_original.shape)
print('total number of samples:', challenge_set_original.shape[0] + submission_set_original.shape[0])

print('number of trajectories:', trajectories_set.shape)

challenge_set = trajectories_set[trajectories_set['flight_id'].isin(challenge_set_original['flight_id'])]
submission_set = trajectories_set[trajectories_set['flight_id'].isin(submission_set_original['flight_id'])]

print('number of samples in the challenge set (with trajectories):', challenge_set.shape)
print('number of samples in the submission set (with trajectories):', submission_set.shape)

challenge_set.T
# Out:
# number of samples in the challenge set: (369013, 18)
# number of samples in the submission set: (105959, 18)
# total number of samples: 474972
# number of trajectories: (474972, 46)
# number of samples in the challenge set (with trajectories): (369013, 46)
# number of samples in the submission set (with trajectories): (105959, 46)
#                                                          0       \
# flight_id                                             248763780
# date                                                 2022-01-01
# callsign                       3840d84f25d3f5fcc0a1be3076bb4039
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       EICK
# name_ades                                                  Cork
# country_code_ades                                            IE
# actual_offblock_time                       2022-01-01T13:46:00Z
# arrival_time                               2022-01-01T15:04:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              61
# taxiout_time                                                 18
# flown_distance                                              321
# tow                                                     54748.0
# track_variation_ARR_100                              124.339907
# track_variation_DEP_100                               39.704139
# track_variation_ENR                                    2.102124
# average_vertical_rate_ARR_100                      -1276.005427
# average_vertical_rate_DEP_100                       1683.211169
# average_vertical_rate_ENR                             -1.995976
# average_airspeed_ARR_100                             142.772028
# average_airspeed_DEP_100                             168.840816
# average_airspeed_ENR                                 235.921296
# groundspeed_ARR_100                                   143.81467
# groundspeed_DEP_100                                  165.621789
# groundspeed_ENR                                      189.015731
# wind_distance_ARR_100                                1567.84086
# wind_distance_DEP_100                              -1920.854367
# wind_distance_ENR                                  -46602.77926
# average_temperature_ARR_100                           254.55627
# average_temperature_DEP_100                          250.873132
# average_temperature_ENR                              223.724129
# average_humidity_ARR_100                               0.002407
# average_humidity_DEP_100                               0.001703
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                             5179.747171
# specific_energy_DEP_100                           140619.201674
# specific_energy_ENR                               144961.839766
# flown_distance_ARR_100                            211353.030545
# flown_distance_DEP_100                            188976.310447
# flown_distance_ENR                                186972.278435
# specific_energy                                    29211.247288
#
#                                                          1       \
# flight_id                                             248760618
# date                                                 2022-01-01
# callsign                       f6f610e73002b8892a239a81321f7f1d
# adep                                                       LEBL
# name_adep                                             Barcelona
# country_code_adep                                            ES
# ades                                                       KMIA
# name_ades                                                 Miami
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:55:00Z
# arrival_time                               2022-01-01T19:37:56Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             570
# taxiout_time                                                 13
# flown_distance                                             4193
# tow                                                    185441.0
# track_variation_ARR_100                               179.31889
# track_variation_DEP_100                                8.910306
# track_variation_ENR                                   76.029652
# average_vertical_rate_ARR_100                       -858.158167
# average_vertical_rate_DEP_100                       1682.557205
# average_vertical_rate_ENR                              6.553055
# average_airspeed_ARR_100                             123.061357
# average_airspeed_DEP_100                             185.710785
# average_airspeed_ENR                                  227.76135
# groundspeed_ARR_100                                   108.77848
# groundspeed_DEP_100                                  187.149785
# groundspeed_ENR                                      237.554856
# wind_distance_ARR_100                               -666.121285
# wind_distance_DEP_100                                4500.54389
# wind_distance_ENR                                -716980.775254
# average_temperature_ARR_100                          285.745817
# average_temperature_DEP_100                          259.884927
# average_temperature_ENR                              217.787401
# average_humidity_ARR_100                               0.004877
# average_humidity_DEP_100                               0.000757
# average_humidity_ENR                                   0.000043
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                                     NaN
# specific_energy_ENR                                162541.91571
# flown_distance_ARR_100                            127622.214114
# flown_distance_DEP_100                            213544.607732
# flown_distance_ENR                               6169683.647343
# specific_energy                                    30410.449851
#
#                                                          2       \
# flight_id                                             248753824
# date                                                 2022-01-01
# callsign                       139670936660762c230ca92556ba842b
# adep                                                       ESSA
# name_adep                                     Stockholm Arlanda
# country_code_adep                                            SE
# ades                                                       KORD
# name_ades                                        Chicago O'Hare
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:39:00Z
# arrival_time                               2022-01-01T19:08:13Z
# aircraft_type                                              A333
# wtc                                                           H
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             554
# taxiout_time                                                 15
# flown_distance                                             3770
# tow                                                    230396.0
# track_variation_ARR_100                              179.638848
# track_variation_DEP_100                               32.391881
# track_variation_ENR                                   85.115541
# average_vertical_rate_ARR_100                       -791.849866
# average_vertical_rate_DEP_100                        840.240481
# average_vertical_rate_ENR                            -41.609514
# average_airspeed_ARR_100                             123.297495
# average_airspeed_DEP_100                             167.315256
# average_airspeed_ENR                                 198.747653
# groundspeed_ARR_100                                   121.55452
# groundspeed_DEP_100                                  119.406937
# groundspeed_ENR                                      202.119847
# wind_distance_ARR_100                              -3900.645575
# wind_distance_DEP_100                               3490.863228
# wind_distance_ENR                                -828173.942204
# average_temperature_ARR_100                          263.376852
# average_temperature_DEP_100                          249.523926
# average_temperature_ENR                              213.785647
# average_humidity_ARR_100                                0.00236
# average_humidity_DEP_100                               0.000507
# average_humidity_ENR                                   0.000042
# specific_energy_ARR_100                             7685.579077
# specific_energy_DEP_100                           139285.174766
# specific_energy_ENR                                96028.817505
# flown_distance_ARR_100                            244485.485197
# flown_distance_DEP_100                            200421.211208
# flown_distance_ENR                               6576808.430733
# specific_energy                                    29343.480734
#
#                                                          3       \
# flight_id                                             248753852
# date                                                 2022-01-01
# callsign                       509dc61bb54fbab0e5406067c95603e2
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       KPHL
# name_ades                                          Philadelphia
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T11:04:00Z
# arrival_time                               2022-01-01T19:32:13Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             497
# taxiout_time                                                 11
# flown_distance                                             3607
# tow                                                    157615.0
# track_variation_ARR_100                                0.208347
# track_variation_DEP_100                               36.998783
# track_variation_ENR                                  101.712676
# average_vertical_rate_ARR_100                       -690.489814
# average_vertical_rate_DEP_100                       1851.136442
# average_vertical_rate_ENR                            -91.982416
# average_airspeed_ARR_100                             133.834251
# average_airspeed_DEP_100                             185.641205
# average_airspeed_ENR                                 215.660291
# groundspeed_ARR_100                                  131.727768
# groundspeed_DEP_100                                  183.495244
# groundspeed_ENR                                       225.86334
# wind_distance_ARR_100                              -4825.621679
# wind_distance_DEP_100                              -2484.248921
# wind_distance_ENR                                 491073.402159
# average_temperature_ARR_100                           275.85643
# average_temperature_DEP_100                           252.51522
# average_temperature_ENR                              215.317206
# average_humidity_ARR_100                               0.005906
# average_humidity_DEP_100                               0.001007
# average_humidity_ENR                                   0.000057
# specific_energy_ARR_100                             7374.774863
# specific_energy_DEP_100                           167995.235621
# specific_energy_ENR                               114033.745667
# flown_distance_ARR_100                            281179.256823
# flown_distance_DEP_100                            211652.180677
# flown_distance_ENR                               6213393.828258
# specific_energy                                     26606.90037
#
#                                                          4       \
# flight_id                                             248755934
# date                                                 2022-01-01
# callsign                       d0610d000dcf26b1d7bba8103ecc393d
# adep                                                       EIDW
# name_adep                                                Dublin
# country_code_adep                                            IE
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T12:36:00Z
# arrival_time                               2022-01-01T13:44:32Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              55
# taxiout_time                                                 14
# flown_distance                                              305
# tow                                                70318.447226
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                              174.878799
# track_variation_ENR                                         NaN
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       2754.662045
# average_vertical_rate_ENR                                   NaN
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                             180.572798
# average_airspeed_ENR                                        NaN
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  182.613355
# groundspeed_ENR                                             NaN
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                               1180.975329
# wind_distance_ENR                                           NaN
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                          255.205584
# average_temperature_ENR                                     NaN
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.001545
# average_humidity_ENR                                        NaN
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           137882.496272
# specific_energy_ENR                                         NaN
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            105355.234482
# flown_distance_ENR                                          NaN
# specific_energy                                    44309.014946
#
#                                                          5       \
# flight_id                                             248762583
# date                                                 2022-01-01
# callsign                       e6d5d070016d21108f8bd2bd643202ac
# adep                                                       ENGM
# name_adep                                                  Oslo
# country_code_adep                                            NO
# ades                                                       LEAL
# name_ades                                              Alicante
# country_code_ades                                            ES
# actual_offblock_time                       2022-01-01T10:24:52Z
# arrival_time                               2022-01-01T14:25:33Z
# aircraft_type                                              A20N
# wtc                                                           M
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             214
# taxiout_time                                                 27
# flown_distance                                             1434
# tow                                                     57721.0
# track_variation_ARR_100                              129.426353
# track_variation_DEP_100                               22.836441
# track_variation_ENR                                   14.447133
# average_vertical_rate_ARR_100                      -1147.657274
# average_vertical_rate_DEP_100                       1554.628143
# average_vertical_rate_ENR                              -6.54153
# average_airspeed_ARR_100                             156.904584
# average_airspeed_DEP_100                             219.885009
# average_airspeed_ENR                                 218.179626
# groundspeed_ARR_100                                  140.432858
# groundspeed_DEP_100                                  206.418935
# groundspeed_ENR                                      215.285914
# wind_distance_ARR_100                               2251.531005
# wind_distance_DEP_100                             -15672.969932
# wind_distance_ENR                                  10679.948199
# average_temperature_ARR_100                          274.099473
# average_temperature_DEP_100                          225.158834
# average_temperature_ENR                              208.825542
# average_humidity_ARR_100                               0.001318
# average_humidity_DEP_100                               0.000292
# average_humidity_ENR                                    0.00002
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           148566.454011
# specific_energy_ENR                               117382.882797
# flown_distance_ARR_100                            222352.123129
# flown_distance_DEP_100                            231013.156743
# flown_distance_ENR                               2202190.361213
# specific_energy                                    47657.454385
#
#                                                          6       \
# flight_id                                             248758528
# date                                                 2022-01-01
# callsign                       1f51e76bb1001c4f9de991288aacb326
# adep                                                       EGAC
# name_adep                                          Belfast City
# country_code_adep                                            GB
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T07:41:00Z
# arrival_time                               2022-01-01T08:48:19Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              57
# taxiout_time                                                 10
# flown_distance                                              295
# tow                                                     56818.0
# track_variation_ARR_100                              156.984462
# track_variation_DEP_100                               86.126276
# track_variation_ENR                                   35.653151
# average_vertical_rate_ARR_100                      -1146.074756
# average_vertical_rate_DEP_100                       1695.454545
# average_vertical_rate_ENR                              1.806835
# average_airspeed_ARR_100                             158.054538
# average_airspeed_DEP_100                             188.216844
# average_airspeed_ENR                                 198.990325
# groundspeed_ARR_100                                  137.234667
# groundspeed_DEP_100                                   175.35233
# groundspeed_ENR                                      206.068074
# wind_distance_ARR_100                                456.412934
# wind_distance_DEP_100                             -13529.002525
# wind_distance_ENR                                   4758.704146
# average_temperature_ARR_100                          259.257967
# average_temperature_DEP_100                          242.994114
# average_temperature_ENR                              221.114306
# average_humidity_ARR_100                               0.001969
# average_humidity_DEP_100                               0.000931
# average_humidity_ENR                                   0.000039
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           138551.415547
# specific_energy_ENR                               148839.887667
# flown_distance_ARR_100                            233653.725473
# flown_distance_DEP_100                            186329.014969
# flown_distance_ENR                                138047.172922
# specific_energy                                    51712.505536
#
#                                                          7       \
# flight_id                                             248752667
# date                                                 2022-01-01
# callsign                       52d1b50f92590b36489a929375be10f6
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LYBE
# name_ades                                              Belgrade
# country_code_ades                                            RS
# actual_offblock_time                       2022-01-01T05:21:00Z
# arrival_time                               2022-01-01T07:05:28Z
# aircraft_type                                              B738
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                              79
# taxiout_time                                                 25
# flown_distance                                              458
# tow                                                     60678.0
# track_variation_ARR_100                               17.706362
# track_variation_DEP_100                              178.849514
# track_variation_ENR                                    5.485476
# average_vertical_rate_ARR_100                      -1241.185882
# average_vertical_rate_DEP_100                       1689.102107
# average_vertical_rate_ENR                           -141.099415
# average_airspeed_ARR_100                             121.419076
# average_airspeed_DEP_100                             186.145523
# average_airspeed_ENR                                 216.591814
# groundspeed_ARR_100                                  121.879046
# groundspeed_DEP_100                                  184.123843
# groundspeed_ENR                                      206.011256
# wind_distance_ARR_100                              17484.737342
# wind_distance_DEP_100                              -2503.711019
# wind_distance_ENR                                 -21696.210238
# average_temperature_ARR_100                          256.753553
# average_temperature_DEP_100                          240.886871
# average_temperature_ENR                               217.56515
# average_humidity_ARR_100                               0.002688
# average_humidity_DEP_100                               0.001552
# average_humidity_ENR                                   0.000011
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           156089.001028
# specific_energy_ENR                               127799.326482
# flown_distance_ARR_100                            184008.971819
# flown_distance_DEP_100                            230811.252066
# flown_distance_ENR                                421459.524346
# specific_energy                                    40402.236552
#
#                                                          8       \
# flight_id                                             248762188
# date                                                 2022-01-01
# callsign                       256265f000acb4a06cd680b3df7c9897
# adep                                                       KLAX
# name_adep                                           Los Angeles
# country_code_adep                                            US
# ades                                                       LTFM
# name_ades                                          iGA Istanbul
# country_code_ades                                            TR
# actual_offblock_time                       2022-01-01T21:26:00Z
# arrival_time                               2022-01-02T09:55:00Z
# aircraft_type                                              B789
# wtc                                                           H
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             739
# taxiout_time                                                 10
# flown_distance                                             6354
# tow                                                    235632.0
# track_variation_ARR_100                               23.829551
# track_variation_DEP_100                                     NaN
# track_variation_ENR                                   99.558897
# average_vertical_rate_ARR_100                      12773.719008
# average_vertical_rate_DEP_100                               NaN
# average_vertical_rate_ENR                            -47.111015
# average_airspeed_ARR_100                              336.38239
# average_airspeed_DEP_100                                    NaN
# average_airspeed_ENR                                 282.767584
# groundspeed_ARR_100                                  340.799221
# groundspeed_DEP_100                                         NaN
# groundspeed_ENR                                      278.505289
# wind_distance_ARR_100                               8522.729263
# wind_distance_DEP_100                                       NaN
# wind_distance_ENR                                -213346.488345
# average_temperature_ARR_100                          262.078614
# average_temperature_DEP_100                                 NaN
# average_temperature_ENR                              216.352822
# average_humidity_ARR_100                               0.002507
# average_humidity_DEP_100                                    NaN
# average_humidity_ENR                                   0.000013
# specific_energy_ARR_100                            303185.89023
# specific_energy_DEP_100                                     NaN
# specific_energy_ENR                               135551.837481
# flown_distance_ARR_100                            245174.718293
# flown_distance_DEP_100                                      NaN
# flown_distance_ENR                              10180076.619312
# specific_energy                                   185741.730238
#
#                                                          9       ...  \
# flight_id                                             248753189  ...
# date                                                 2022-01-01  ...
# callsign                       8191fa049d6f1a6cb432a98d97bf960c  ...
# adep                                                       LTFM  ...
# name_adep                                          iGA Istanbul  ...
# country_code_adep                                            TR  ...
# ades                                                       LTAC  ...
# name_ades                                                Ankara  ...
# country_code_ades                                            TR  ...
# actual_offblock_time                       2022-01-01T15:00:00Z  ...
# arrival_time                               2022-01-01T16:09:00Z  ...
# aircraft_type                                              A321  ...
# wtc                                                           M  ...
# airline                        6351ec1b849adacc0cbb3b1313d8d39b  ...
# flight_duration                                              44  ...
# taxiout_time                                                 25  ...
# flown_distance                                              257  ...
# tow                                                     73571.0  ...
# track_variation_ARR_100                              119.350942  ...
# track_variation_DEP_100                                     NaN  ...
# track_variation_ENR                                         NaN  ...
# average_vertical_rate_ARR_100                       -654.951792  ...
# average_vertical_rate_DEP_100                               NaN  ...
# average_vertical_rate_ENR                                   NaN  ...
# average_airspeed_ARR_100                             101.215431  ...
# average_airspeed_DEP_100                                    NaN  ...
# average_airspeed_ENR                                        NaN  ...
# groundspeed_ARR_100                                  100.549956  ...
# groundspeed_DEP_100                                         NaN  ...
# groundspeed_ENR                                             NaN  ...
# wind_distance_ARR_100                                -540.74267  ...
# wind_distance_DEP_100                                       NaN  ...
# wind_distance_ENR                                           NaN  ...
# average_temperature_ARR_100                          274.784833  ...
# average_temperature_DEP_100                                 NaN  ...
# average_temperature_ENR                                     NaN  ...
# average_humidity_ARR_100                               0.004571  ...
# average_humidity_DEP_100                                    NaN  ...
# average_humidity_ENR                                        NaN  ...
# specific_energy_ARR_100                            15977.826605  ...
# specific_energy_DEP_100                                     NaN  ...
# specific_energy_ENR                                         NaN  ...
# flown_distance_ARR_100                             53914.394348  ...
# flown_distance_DEP_100                                      NaN  ...
# flown_distance_ENR                                          NaN  ...
# specific_energy                                    38213.580804  ...
#
#                                                          369003  \
# flight_id                                             258072846
# date                                                 2022-12-31
# callsign                       5ea802e68573752dc98d7623d897a915
# adep                                                       LIRF
# name_adep                                        Rome Fiumicino
# country_code_adep                                            IT
# ades                                                       EBBR
# name_ades                                              Brussels
# country_code_ades                                            BE
# actual_offblock_time                       2022-12-31T09:47:00Z
# arrival_time                               2022-12-31T11:58:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        bdeeef3a675587d530de70a25d7118d2
# flight_duration                                             114
# taxiout_time                                                 18
# flown_distance                                              726
# tow                                                61804.035897
# track_variation_ARR_100                               41.225296
# track_variation_DEP_100                              107.075354
# track_variation_ENR                                   86.102977
# average_vertical_rate_ARR_100                       -937.275362
# average_vertical_rate_DEP_100                       1676.220472
# average_vertical_rate_ENR                            -88.939373
# average_airspeed_ARR_100                             122.967444
# average_airspeed_DEP_100                               192.6238
# average_airspeed_ENR                                 216.760272
# groundspeed_ARR_100                                  135.792899
# groundspeed_DEP_100                                  188.189286
# groundspeed_ENR                                      211.361468
# wind_distance_ARR_100                              20658.403766
# wind_distance_DEP_100                              -3260.130151
# wind_distance_ENR                                 -23949.577571
# average_temperature_ARR_100                          269.844926
# average_temperature_DEP_100                          260.141793
# average_temperature_ENR                              217.026673
# average_humidity_ARR_100                               0.004583
# average_humidity_DEP_100                               0.002107
# average_humidity_ENR                                   0.000067
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                            133622.07443
# specific_energy_ENR                               112667.709633
# flown_distance_ARR_100                            186465.144745
# flown_distance_DEP_100                            190585.110323
# flown_distance_ENR                                936996.011575
# specific_energy                                    36237.665336
#
#                                                          369004  \
# flight_id                                             258057853
# date                                                 2022-12-31
# callsign                       b1de87e85987c58b0d29fa4e72e3f961
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       LSZH
# name_ades                                                Zurich
# country_code_ades                                            CH
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:14:52Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                              64
# taxiout_time                                                 19
# flown_distance                                              449
# tow                                                     72756.0
# track_variation_ARR_100                               64.982306
# track_variation_DEP_100                              174.543182
# track_variation_ENR                                   28.889307
# average_vertical_rate_ARR_100                      -1244.352645
# average_vertical_rate_DEP_100                       1642.811229
# average_vertical_rate_ENR                            156.761134
# average_airspeed_ARR_100                             137.852703
# average_airspeed_DEP_100                             220.263878
# average_airspeed_ENR                                 261.739939
# groundspeed_ARR_100                                  139.808418
# groundspeed_DEP_100                                  201.780574
# groundspeed_ENR                                      254.731008
# wind_distance_ARR_100                               3089.913657
# wind_distance_DEP_100                             -10280.268619
# wind_distance_ENR                                 -12093.078585
# average_temperature_ARR_100                          271.899846
# average_temperature_DEP_100                          259.683036
# average_temperature_ENR                              213.283719
# average_humidity_ARR_100                               0.004154
# average_humidity_DEP_100                               0.002833
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                             6407.360512
# specific_energy_DEP_100                           168893.023994
# specific_energy_ENR                               149197.949384
# flown_distance_ARR_100                            195675.977376
# flown_distance_DEP_100                            208022.688022
# flown_distance_ENR                                 438174.77535
# specific_energy                                    47447.649396
#
#                                                          369005  \
# flight_id                                             258071492
# date                                                 2022-12-31
# callsign                       49c815d2ca2e8c50b01473b12fd30119
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LIMC
# name_ades                                        Milan Malpensa
# country_code_ades                                            IT
# actual_offblock_time                       2022-12-31T09:34:00Z
# arrival_time                               2022-12-31T12:28:54Z
# aircraft_type                                              A321
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             150
# taxiout_time                                                 25
# flown_distance                                              975
# tow                                                     73571.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                                0.397226
# track_variation_ENR                                   17.529504
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       1758.369973
# average_vertical_rate_ENR                            -61.803143
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                              184.23032
# average_airspeed_ENR                                 219.668121
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  189.124142
# groundspeed_ENR                                      218.613382
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                               5480.149218
# wind_distance_ENR                                 -10901.238429
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                          245.451426
# average_temperature_ENR                              212.674614
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.000797
# average_humidity_ENR                                   0.000018
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           140053.115499
# specific_energy_ENR                               128044.533554
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            211067.430547
# flown_distance_ENR                               1326787.673125
# specific_energy                                    39340.477809
#
#                                                          369006  \
# flight_id                                             258060782
# date                                                 2022-12-31
# callsign                       92eba53fed3c3914105be1de666ca203
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       LGTS
# name_ades                                          Thessaloniki
# country_code_ades                                            GR
# actual_offblock_time                       2022-12-31T09:39:00Z
# arrival_time                               2022-12-31T11:36:58Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                             109
# taxiout_time                                                  9
# flown_distance                                              782
# tow                                                     64826.0
# track_variation_ARR_100                                38.67806
# track_variation_DEP_100                                0.815619
# track_variation_ENR                                   27.643538
# average_vertical_rate_ARR_100                       -1123.18552
# average_vertical_rate_DEP_100                           1163.52
# average_vertical_rate_ENR                            101.229917
# average_airspeed_ARR_100                             162.150949
# average_airspeed_DEP_100                             240.347377
# average_airspeed_ENR                                 248.697208
# groundspeed_ARR_100                                   132.82044
# groundspeed_DEP_100                                  241.131662
# groundspeed_ENR                                      244.375309
# wind_distance_ARR_100                              -1881.251514
# wind_distance_DEP_100                                266.267818
# wind_distance_ENR                                 -14033.188611
# average_temperature_ARR_100                          266.685247
# average_temperature_DEP_100                          237.221544
# average_temperature_ENR                              215.278241
# average_humidity_ARR_100                               0.002165
# average_humidity_DEP_100                               0.000248
# average_humidity_ENR                                   0.000027
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           156832.921001
# specific_energy_ENR                               155190.109141
# flown_distance_ARR_100                            155792.786993
# flown_distance_DEP_100                             84359.995118
# flown_distance_ENR                                789819.013017
# specific_energy                                   125289.758093
#
#                                                          369007  \
# flight_id                                             258067496
# date                                                 2022-12-31
# callsign                       80e0832fdc79cbba84dff5e9e06bb883
# adep                                                       EDDV
# name_adep                                               Hanover
# country_code_adep                                            DE
# ades                                                       LOWW
# name_ades                                                Vienna
# country_code_ades                                            AT
# actual_offblock_time                       2022-12-31T09:42:00Z
# arrival_time                               2022-12-31T10:49:00Z
# aircraft_type                                              E195
# wtc                                                           M
# airline                        5d407cb11cc29578cc3e292e743f5393
# flight_duration                                              59
# taxiout_time                                                  8
# flown_distance                                              416
# tow                                                     40868.0
# track_variation_ARR_100                               70.340447
# track_variation_DEP_100                               11.825033
# track_variation_ENR                                   19.299673
# average_vertical_rate_ARR_100                      -1531.761945
# average_vertical_rate_DEP_100                       1448.228571
# average_vertical_rate_ENR                            -73.789954
# average_airspeed_ARR_100                             180.948167
# average_airspeed_DEP_100                             242.288838
# average_airspeed_ENR                                 274.921886
# groundspeed_ARR_100                                  166.813103
# groundspeed_DEP_100                                   246.84073
# groundspeed_ENR                                      256.956948
# wind_distance_ARR_100                              -7472.241704
# wind_distance_DEP_100                               2231.413793
# wind_distance_ENR                                 -23584.897289
# average_temperature_ARR_100                          264.535833
# average_temperature_DEP_100                          236.754581
# average_temperature_ENR                              216.257414
# average_humidity_ARR_100                               0.003192
# average_humidity_DEP_100                               0.000321
# average_humidity_ENR                                   0.000038
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           172184.797047
# specific_energy_ENR                               168157.099762
# flown_distance_ARR_100                            197285.719862
# flown_distance_DEP_100                            119293.235695
# flown_distance_ENR                                336700.327007
# specific_energy                                   117497.769762
#
#                                                          369008  \
# flight_id                                             258058361
# date                                                 2022-12-31
# callsign                       85ee68e5b7b5acf24ba00d1318eca1e8
# adep                                                       LFPG
# name_adep                               Paris Charles de Gaulle
# country_code_adep                                            FR
# ades                                                       KMIA
# name_ades                                                 Miami
# country_code_ades                                            US
# actual_offblock_time                       2022-12-31T09:38:00Z
# arrival_time                               2022-12-31T19:03:48Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             545
# taxiout_time                                                 21
# flown_distance                                             4046
# tow                                                    163438.0
# track_variation_ARR_100                              174.768738
# track_variation_DEP_100                                9.528459
# track_variation_ENR                                    4.913511
# average_vertical_rate_ARR_100                        -957.19801
# average_vertical_rate_DEP_100                       1774.056075
# average_vertical_rate_ENR                            -36.004752
# average_airspeed_ARR_100                             120.477436
# average_airspeed_DEP_100                             157.386762
# average_airspeed_ENR                                 164.933554
# groundspeed_ARR_100                                   104.43162
# groundspeed_DEP_100                                  173.364743
# groundspeed_ENR                                      198.567031
# wind_distance_ARR_100                              -1128.929527
# wind_distance_DEP_100                              17086.799783
# wind_distance_ENR                                  99433.106553
# average_temperature_ARR_100                          287.071524
# average_temperature_DEP_100                          252.922497
# average_temperature_ENR                               217.79789
# average_humidity_ARR_100                               0.007733
# average_humidity_DEP_100                               0.002061
# average_humidity_ENR                                   0.000049
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           163105.039682
# specific_energy_ENR                               116846.850647
# flown_distance_ARR_100                             82920.116565
# flown_distance_DEP_100                            184272.114936
# flown_distance_ENR                                694149.603464
# specific_energy                                    37501.849179
#
#                                                          369009  \
# flight_id                                             258071247
# date                                                 2022-12-31
# callsign                       570cf7d5ebbd691bcba63e7466607da7
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       EDDB
# name_ades                                    Berlin Brandenburg
# country_code_ades                                            DE
# actual_offblock_time                       2022-12-31T09:27:00Z
# arrival_time                               2022-12-31T12:29:41Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             158
# taxiout_time                                                 25
# flown_distance                                              946
# tow                                                     78707.0
# track_variation_ARR_100                                62.54495
# track_variation_DEP_100                               22.872438
# track_variation_ENR                                   26.244336
# average_vertical_rate_ARR_100                       -986.942529
# average_vertical_rate_DEP_100                       1383.676768
# average_vertical_rate_ENR                             -1.009936
# average_airspeed_ARR_100                              130.21441
# average_airspeed_DEP_100                             207.311831
# average_airspeed_ENR                                 194.553687
# groundspeed_ARR_100                                  108.757847
# groundspeed_DEP_100                                  207.700919
# groundspeed_ENR                                      198.132349
# wind_distance_ARR_100                             -43244.289956
# wind_distance_DEP_100                                313.727621
# wind_distance_ENR                                  18337.913758
# average_temperature_ARR_100                           247.62106
# average_temperature_DEP_100                          232.875133
# average_temperature_ENR                              216.211231
# average_humidity_ARR_100                               0.002573
# average_humidity_DEP_100                                0.00013
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                           112914.102878
# specific_energy_DEP_100                           152199.894604
# specific_energy_ENR                               140217.805342
# flown_distance_ARR_100                            195902.336116
# flown_distance_DEP_100                            164082.472986
# flown_distance_ENR                               1329071.627906
# specific_energy                                    95013.649249
#
#                                                          369010  \
# flight_id                                             258059152
# date                                                 2022-12-31
# callsign                       5a7e43e4f981539ae3d3b1cb31591b7c
# adep                                                       EDDL
# name_adep                                            Dusseldorf
# country_code_adep                                            DE
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:41:51Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              99
# taxiout_time                                                 11
# flown_distance                                              522
# tow                                                    62942.75
# track_variation_ARR_100                               43.910303
# track_variation_DEP_100                               18.479277
# track_variation_ENR                                   19.499181
# average_vertical_rate_ARR_100                      -1514.788833
# average_vertical_rate_DEP_100                       1601.896296
# average_vertical_rate_ENR                             42.385714
# average_airspeed_ARR_100                             144.290228
# average_airspeed_DEP_100                             150.107396
# average_airspeed_ENR                                  212.79558
# groundspeed_ARR_100                                  139.525167
# groundspeed_DEP_100                                  160.518383
# groundspeed_ENR                                      167.741471
# wind_distance_ARR_100                              -6635.758627
# wind_distance_DEP_100                              14371.561186
# wind_distance_ENR                                -139780.366779
# average_temperature_ARR_100                          250.957833
# average_temperature_DEP_100                          251.493722
# average_temperature_ENR                              210.436025
# average_humidity_ARR_100                               0.002369
# average_humidity_DEP_100                               0.002126
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                             5362.951317
# specific_energy_DEP_100                           128466.552218
# specific_energy_ENR                               141243.406835
# flown_distance_ARR_100                            193167.686072
# flown_distance_DEP_100                            202633.765315
# flown_distance_ENR                                563061.094877
# specific_energy                                    30173.184666
#
#                                                          369011  \
# flight_id                                             258072276
# date                                                 2022-12-31
# callsign                       a1c078516f9f9e90cacec61854cad45b
# adep                                                       LFPG
# name_adep                               Paris Charles de Gaulle
# country_code_adep                                            FR
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:37:00Z
# arrival_time                               2022-12-31T11:13:10Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              84
# taxiout_time                                                 12
# flown_distance                                              466
# tow                                                72611.161024
# track_variation_ARR_100                               48.439184
# track_variation_DEP_100                               28.660678
# track_variation_ENR                                   35.779227
# average_vertical_rate_ARR_100                       -969.698872
# average_vertical_rate_DEP_100                       1378.429501
# average_vertical_rate_ENR                            -15.938319
# average_airspeed_ARR_100                              122.45483
# average_airspeed_DEP_100                             218.799521
# average_airspeed_ENR                                 191.069715
# groundspeed_ARR_100                                  112.449788
# groundspeed_DEP_100                                  226.096464
# groundspeed_ENR                                      176.568029
# wind_distance_ARR_100                             -20473.150862
# wind_distance_DEP_100                               3343.973845
# wind_distance_ENR                                 -34904.954795
# average_temperature_ARR_100                          242.858756
# average_temperature_DEP_100                          227.767796
# average_temperature_ENR                              211.729633
# average_humidity_ARR_100                               0.001674
# average_humidity_DEP_100                                0.00017
# average_humidity_ENR                                   0.000024
# specific_energy_ARR_100                           112926.042185
# specific_energy_DEP_100                           154852.097243
# specific_energy_ENR                               119424.098697
# flown_distance_ARR_100                            193489.008569
# flown_distance_DEP_100                            104213.234971
# flown_distance_ENR                                456310.057481
# specific_energy                                   126267.698202
#
#                                                          369012
# flight_id                                             258069969
# date                                                 2022-12-31
# callsign                       6c98fcaa191dec632b87b46511f1d2da
# adep                                                       LEMD
# name_adep                                        Madrid Barajas
# country_code_adep                                            ES
# ades                                                       KJFK
# name_ades                                          New York JFK
# country_code_ades                                            US
# actual_offblock_time                       2022-12-31T09:38:00Z
# arrival_time                               2022-12-31T17:26:35Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             453
# taxiout_time                                                 16
# flown_distance                                             3213
# tow                                                    195373.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                               23.802205
# track_variation_ENR                                   20.291439
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       1704.796434
# average_vertical_rate_ENR                             95.725934
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                             218.235814
# average_airspeed_ENR                                 223.393846
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  219.230349
# groundspeed_ENR                                       235.17158
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                                678.016139
# wind_distance_ENR                                  34396.167672
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                           247.96788
# average_temperature_ENR                              216.129046
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.000119
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           167056.041395
# specific_energy_ENR                               147639.900205
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            146406.180959
# flown_distance_ENR                                615701.069171
# specific_energy                                    91461.232681
#
# [46 rows x 369013 columns]

# %%
# Summary statistics of the challenge set
challenge_summary = challenge_set.describe()

# Check for missing values
missing_values = challenge_set.isnull().sum()

# Correlation matrix to check relationships between numerical features
correlation_matrix = challenge_set.corr(numeric_only=True)

# Plotting the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Challenge Set')
plt.show()

# Display the summary statistics and missing values
challenge_summary, missing_values
# Out:
# /home/mmaximo/ita/prc-challenge-ita/env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/mmaximo/ita/prc-challenge-ita/env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/mmaximo/ita/prc-challenge-ita/env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# (          flight_id  flight_duration   taxiout_time  flown_distance  \
#  count  3.690130e+05    369013.000000  369013.000000   369013.000000
#  mean   2.535220e+08       145.876779      13.489709     1021.728581
#  std    2.688565e+06       139.337587       5.779555     1128.171163
#  min    2.487506e+08         8.000000       0.000000       19.000000
#  25%    2.512296e+08        59.000000      10.000000      338.000000
#  50%    2.536200e+08       100.000000      12.000000      647.000000
#  75%    2.559059e+08       164.000000      16.000000     1113.000000
#  max    2.580745e+08      1013.000000      90.000000     7272.000000
#
#                   tow  track_variation_ARR_100  track_variation_DEP_100  \
#  count  369013.000000             3.454850e+05             3.140470e+05
#  mean    79482.257229                      inf                      inf
#  std     53250.919631                      NaN                      NaN
#  min     14944.000000             0.000000e+00             0.000000e+00
#  25%     55836.000000             2.419634e+01             2.483615e+01
#  50%     63852.000000             5.985446e+01             5.776161e+01
#  75%     73756.000000             1.241850e+02             1.152746e+02
#  max    351327.000000                      inf                      inf
#
#         track_variation_ENR  average_vertical_rate_ARR_100  \
#  count         3.181650e+05                  345285.000000
#  mean                   inf                   -1146.123157
#  std                    NaN                    1169.574909
#  min           0.000000e+00                 -116470.787234
#  25%           7.988137e+00                   -1327.845517
#  50%           2.260343e+01                   -1126.001198
#  75%           4.039071e+01                    -917.041096
#  max                    inf                   30854.554661
#
#         average_vertical_rate_DEP_100  ...  average_humidity_ARR_100  \
#  count                  313601.000000  ...             345181.000000
#  mean                     1709.595340  ...                  0.002797
#  std                      1445.136558  ...                  0.001656
#  min                    -22391.562095  ...                  0.000002
#  25%                      1501.858951  ...                  0.001595
#  50%                      1696.961924  ...                  0.002542
#  75%                      1871.023474  ...                  0.003669
#  max                    116479.925455  ...                  0.018347
#
#         average_humidity_DEP_100  average_humidity_ENR  \
#  count             313785.000000         318163.000000
#  mean                   0.001655              0.000056
#  std                    0.001160              0.000126
#  min                    0.000003             -0.000033
#  25%                    0.000851              0.000016
#  50%                    0.001417              0.000032
#  75%                    0.002156              0.000059
#  max                    0.017179              0.008716
#
#         specific_energy_ARR_100  specific_energy_DEP_100  specific_energy_ENR  \
#  count            215279.000000             3.126340e+05         3.172490e+05
#  mean              34473.816781             1.437247e+05         1.416313e+05
#  std               42000.263286             2.437356e+04         2.136825e+04
#  min                1120.180528             2.688469e+03         5.321438e+03
#  25%                6349.237924             1.367559e+05         1.297054e+05
#  50%                9181.897984             1.475955e+05         1.430344e+05
#  75%               55594.764767             1.570932e+05         1.549349e+05
#  max              578911.211053             1.499284e+06         2.600022e+06
#
#         flown_distance_ARR_100  flown_distance_DEP_100  flown_distance_ENR  \
#  count            3.454850e+05            3.140470e+05        3.181650e+05
#  mean             2.120027e+05            1.876483e+05        1.446262e+06
#  std              5.481208e+04            5.437659e+04        1.994361e+06
#  min              0.000000e+00            0.000000e+00        0.000000e+00
#  25%              1.931727e+05            1.859291e+05        2.883293e+05
#  50%              2.138608e+05            1.951121e+05        7.817550e+05
#  75%              2.377972e+05            2.078512e+05        1.542406e+06
#  max              3.583737e+06            1.878169e+07        7.217777e+07
#
#         specific_energy
#  count    364684.000000
#  mean      55720.648643
#  std       40597.851463
#  min        1217.957542
#  25%       36580.259475
#  50%       41074.575131
#  75%       48239.457456
#  max      677610.196801
#
#  [8 rows x 33 columns],
#  flight_id                             0
#  date                                  0
#  callsign                              0
#  adep                                  0
#  name_adep                             0
#  country_code_adep                     0
#  ades                                  0
#  name_ades                             0
#  country_code_ades                     0
#  actual_offblock_time                  0
#  arrival_time                          0
#  aircraft_type                         0
#  wtc                                   0
#  airline                               0
#  flight_duration                       0
#  taxiout_time                          0
#  flown_distance                        0
#  tow                                   0
#  track_variation_ARR_100           23528
#  track_variation_DEP_100           54966
#  track_variation_ENR               50848
#  average_vertical_rate_ARR_100     23728
#  average_vertical_rate_DEP_100     55412
#  average_vertical_rate_ENR         50852
#  average_airspeed_ARR_100          23996
#  average_airspeed_DEP_100          55471
#  average_airspeed_ENR              50852
#  groundspeed_ARR_100               23725
#  groundspeed_DEP_100               55409
#  groundspeed_ENR                   50850
#  wind_distance_ARR_100             23528
#  wind_distance_DEP_100             54966
#  wind_distance_ENR                 50848
#  average_temperature_ARR_100       23832
#  average_temperature_DEP_100       55228
#  average_temperature_ENR           50850
#  average_humidity_ARR_100          23832
#  average_humidity_DEP_100          55228
#  average_humidity_ENR              50850
#  specific_energy_ARR_100          153734
#  specific_energy_DEP_100           56379
#  specific_energy_ENR               51764
#  flown_distance_ARR_100            23528
#  flown_distance_DEP_100            54966
#  flown_distance_ENR                50848
#  specific_energy                    4329
#  dtype: int64)

# %%
# Checking for outliers in numerical features using box plots
numerical_features = ['flight_duration', 'taxiout_time', 'flown_distance', 'tow']

plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=challenge_set[feature])
    plt.title(f'Box Plot of {feature}')
plt.tight_layout()
plt.show()

# Identifying outliers using the Interquartile Range (IQR) method
outliers_info = {}
for feature in numerical_features:
    Q1 = challenge_set[feature].quantile(0.25)
    Q3 = challenge_set[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identifying outliers
    outliers = challenge_set[(challenge_set[feature] < lower_bound) | (challenge_set[feature] > upper_bound)]
    outliers_info[feature] = len(outliers)

# Displaying the count of outliers for each feature
outliers_info

# # Removing outliers using the IQR threshold
# def remove_outliers(df, features):
#     for feature in features:
#         Q1 = df[feature].quantile(0.25)
#         Q3 = df[feature].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         df = df[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]
#     return df

# # Remove outliers from the challenge set
# cleaned_challenge_set = remove_outliers(challenge_set, numerical_features)

# # Checking the shape of the dataset after outlier removal
# initial_count = len(challenge_set)
# cleaned_count = len(cleaned_challenge_set)

# initial_count, cleaned_count, cleaned_challenge_set.describe()
# Out:
# {'flight_duration': 40817,
#  'taxiout_time': 10512,
#  'flown_distance': 41047,
#  'tow': 61165}

# %%
challenge_set.T
# Out:
#                                                          0       \
# flight_id                                             248763780
# date                                                 2022-01-01
# callsign                       3840d84f25d3f5fcc0a1be3076bb4039
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       EICK
# name_ades                                                  Cork
# country_code_ades                                            IE
# actual_offblock_time                       2022-01-01T13:46:00Z
# arrival_time                               2022-01-01T15:04:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              61
# taxiout_time                                                 18
# flown_distance                                              321
# tow                                                     54748.0
# track_variation_ARR_100                              124.339907
# track_variation_DEP_100                               39.704139
# track_variation_ENR                                    2.102124
# average_vertical_rate_ARR_100                      -1276.005427
# average_vertical_rate_DEP_100                       1683.211169
# average_vertical_rate_ENR                             -1.995976
# average_airspeed_ARR_100                             142.772028
# average_airspeed_DEP_100                             168.840816
# average_airspeed_ENR                                 235.921296
# groundspeed_ARR_100                                   143.81467
# groundspeed_DEP_100                                  165.621789
# groundspeed_ENR                                      189.015731
# wind_distance_ARR_100                                1567.84086
# wind_distance_DEP_100                              -1920.854367
# wind_distance_ENR                                  -46602.77926
# average_temperature_ARR_100                           254.55627
# average_temperature_DEP_100                          250.873132
# average_temperature_ENR                              223.724129
# average_humidity_ARR_100                               0.002407
# average_humidity_DEP_100                               0.001703
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                             5179.747171
# specific_energy_DEP_100                           140619.201674
# specific_energy_ENR                               144961.839766
# flown_distance_ARR_100                            211353.030545
# flown_distance_DEP_100                            188976.310447
# flown_distance_ENR                                186972.278435
# specific_energy                                    29211.247288
#
#                                                          1       \
# flight_id                                             248760618
# date                                                 2022-01-01
# callsign                       f6f610e73002b8892a239a81321f7f1d
# adep                                                       LEBL
# name_adep                                             Barcelona
# country_code_adep                                            ES
# ades                                                       KMIA
# name_ades                                                 Miami
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:55:00Z
# arrival_time                               2022-01-01T19:37:56Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             570
# taxiout_time                                                 13
# flown_distance                                             4193
# tow                                                    185441.0
# track_variation_ARR_100                               179.31889
# track_variation_DEP_100                                8.910306
# track_variation_ENR                                   76.029652
# average_vertical_rate_ARR_100                       -858.158167
# average_vertical_rate_DEP_100                       1682.557205
# average_vertical_rate_ENR                              6.553055
# average_airspeed_ARR_100                             123.061357
# average_airspeed_DEP_100                             185.710785
# average_airspeed_ENR                                  227.76135
# groundspeed_ARR_100                                   108.77848
# groundspeed_DEP_100                                  187.149785
# groundspeed_ENR                                      237.554856
# wind_distance_ARR_100                               -666.121285
# wind_distance_DEP_100                                4500.54389
# wind_distance_ENR                                -716980.775254
# average_temperature_ARR_100                          285.745817
# average_temperature_DEP_100                          259.884927
# average_temperature_ENR                              217.787401
# average_humidity_ARR_100                               0.004877
# average_humidity_DEP_100                               0.000757
# average_humidity_ENR                                   0.000043
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                                     NaN
# specific_energy_ENR                                162541.91571
# flown_distance_ARR_100                            127622.214114
# flown_distance_DEP_100                            213544.607732
# flown_distance_ENR                               6169683.647343
# specific_energy                                    30410.449851
#
#                                                          2       \
# flight_id                                             248753824
# date                                                 2022-01-01
# callsign                       139670936660762c230ca92556ba842b
# adep                                                       ESSA
# name_adep                                     Stockholm Arlanda
# country_code_adep                                            SE
# ades                                                       KORD
# name_ades                                        Chicago O'Hare
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:39:00Z
# arrival_time                               2022-01-01T19:08:13Z
# aircraft_type                                              A333
# wtc                                                           H
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             554
# taxiout_time                                                 15
# flown_distance                                             3770
# tow                                                    230396.0
# track_variation_ARR_100                              179.638848
# track_variation_DEP_100                               32.391881
# track_variation_ENR                                   85.115541
# average_vertical_rate_ARR_100                       -791.849866
# average_vertical_rate_DEP_100                        840.240481
# average_vertical_rate_ENR                            -41.609514
# average_airspeed_ARR_100                             123.297495
# average_airspeed_DEP_100                             167.315256
# average_airspeed_ENR                                 198.747653
# groundspeed_ARR_100                                   121.55452
# groundspeed_DEP_100                                  119.406937
# groundspeed_ENR                                      202.119847
# wind_distance_ARR_100                              -3900.645575
# wind_distance_DEP_100                               3490.863228
# wind_distance_ENR                                -828173.942204
# average_temperature_ARR_100                          263.376852
# average_temperature_DEP_100                          249.523926
# average_temperature_ENR                              213.785647
# average_humidity_ARR_100                                0.00236
# average_humidity_DEP_100                               0.000507
# average_humidity_ENR                                   0.000042
# specific_energy_ARR_100                             7685.579077
# specific_energy_DEP_100                           139285.174766
# specific_energy_ENR                                96028.817505
# flown_distance_ARR_100                            244485.485197
# flown_distance_DEP_100                            200421.211208
# flown_distance_ENR                               6576808.430733
# specific_energy                                    29343.480734
#
#                                                          3       \
# flight_id                                             248753852
# date                                                 2022-01-01
# callsign                       509dc61bb54fbab0e5406067c95603e2
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       KPHL
# name_ades                                          Philadelphia
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T11:04:00Z
# arrival_time                               2022-01-01T19:32:13Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             497
# taxiout_time                                                 11
# flown_distance                                             3607
# tow                                                    157615.0
# track_variation_ARR_100                                0.208347
# track_variation_DEP_100                               36.998783
# track_variation_ENR                                  101.712676
# average_vertical_rate_ARR_100                       -690.489814
# average_vertical_rate_DEP_100                       1851.136442
# average_vertical_rate_ENR                            -91.982416
# average_airspeed_ARR_100                             133.834251
# average_airspeed_DEP_100                             185.641205
# average_airspeed_ENR                                 215.660291
# groundspeed_ARR_100                                  131.727768
# groundspeed_DEP_100                                  183.495244
# groundspeed_ENR                                       225.86334
# wind_distance_ARR_100                              -4825.621679
# wind_distance_DEP_100                              -2484.248921
# wind_distance_ENR                                 491073.402159
# average_temperature_ARR_100                           275.85643
# average_temperature_DEP_100                           252.51522
# average_temperature_ENR                              215.317206
# average_humidity_ARR_100                               0.005906
# average_humidity_DEP_100                               0.001007
# average_humidity_ENR                                   0.000057
# specific_energy_ARR_100                             7374.774863
# specific_energy_DEP_100                           167995.235621
# specific_energy_ENR                               114033.745667
# flown_distance_ARR_100                            281179.256823
# flown_distance_DEP_100                            211652.180677
# flown_distance_ENR                               6213393.828258
# specific_energy                                     26606.90037
#
#                                                          4       \
# flight_id                                             248755934
# date                                                 2022-01-01
# callsign                       d0610d000dcf26b1d7bba8103ecc393d
# adep                                                       EIDW
# name_adep                                                Dublin
# country_code_adep                                            IE
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T12:36:00Z
# arrival_time                               2022-01-01T13:44:32Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              55
# taxiout_time                                                 14
# flown_distance                                              305
# tow                                                70318.447226
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                              174.878799
# track_variation_ENR                                         NaN
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       2754.662045
# average_vertical_rate_ENR                                   NaN
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                             180.572798
# average_airspeed_ENR                                        NaN
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  182.613355
# groundspeed_ENR                                             NaN
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                               1180.975329
# wind_distance_ENR                                           NaN
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                          255.205584
# average_temperature_ENR                                     NaN
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.001545
# average_humidity_ENR                                        NaN
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           137882.496272
# specific_energy_ENR                                         NaN
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            105355.234482
# flown_distance_ENR                                          NaN
# specific_energy                                    44309.014946
#
#                                                          5       \
# flight_id                                             248762583
# date                                                 2022-01-01
# callsign                       e6d5d070016d21108f8bd2bd643202ac
# adep                                                       ENGM
# name_adep                                                  Oslo
# country_code_adep                                            NO
# ades                                                       LEAL
# name_ades                                              Alicante
# country_code_ades                                            ES
# actual_offblock_time                       2022-01-01T10:24:52Z
# arrival_time                               2022-01-01T14:25:33Z
# aircraft_type                                              A20N
# wtc                                                           M
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             214
# taxiout_time                                                 27
# flown_distance                                             1434
# tow                                                     57721.0
# track_variation_ARR_100                              129.426353
# track_variation_DEP_100                               22.836441
# track_variation_ENR                                   14.447133
# average_vertical_rate_ARR_100                      -1147.657274
# average_vertical_rate_DEP_100                       1554.628143
# average_vertical_rate_ENR                              -6.54153
# average_airspeed_ARR_100                             156.904584
# average_airspeed_DEP_100                             219.885009
# average_airspeed_ENR                                 218.179626
# groundspeed_ARR_100                                  140.432858
# groundspeed_DEP_100                                  206.418935
# groundspeed_ENR                                      215.285914
# wind_distance_ARR_100                               2251.531005
# wind_distance_DEP_100                             -15672.969932
# wind_distance_ENR                                  10679.948199
# average_temperature_ARR_100                          274.099473
# average_temperature_DEP_100                          225.158834
# average_temperature_ENR                              208.825542
# average_humidity_ARR_100                               0.001318
# average_humidity_DEP_100                               0.000292
# average_humidity_ENR                                    0.00002
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           148566.454011
# specific_energy_ENR                               117382.882797
# flown_distance_ARR_100                            222352.123129
# flown_distance_DEP_100                            231013.156743
# flown_distance_ENR                               2202190.361213
# specific_energy                                    47657.454385
#
#                                                          6       \
# flight_id                                             248758528
# date                                                 2022-01-01
# callsign                       1f51e76bb1001c4f9de991288aacb326
# adep                                                       EGAC
# name_adep                                          Belfast City
# country_code_adep                                            GB
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T07:41:00Z
# arrival_time                               2022-01-01T08:48:19Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              57
# taxiout_time                                                 10
# flown_distance                                              295
# tow                                                     56818.0
# track_variation_ARR_100                              156.984462
# track_variation_DEP_100                               86.126276
# track_variation_ENR                                   35.653151
# average_vertical_rate_ARR_100                      -1146.074756
# average_vertical_rate_DEP_100                       1695.454545
# average_vertical_rate_ENR                              1.806835
# average_airspeed_ARR_100                             158.054538
# average_airspeed_DEP_100                             188.216844
# average_airspeed_ENR                                 198.990325
# groundspeed_ARR_100                                  137.234667
# groundspeed_DEP_100                                   175.35233
# groundspeed_ENR                                      206.068074
# wind_distance_ARR_100                                456.412934
# wind_distance_DEP_100                             -13529.002525
# wind_distance_ENR                                   4758.704146
# average_temperature_ARR_100                          259.257967
# average_temperature_DEP_100                          242.994114
# average_temperature_ENR                              221.114306
# average_humidity_ARR_100                               0.001969
# average_humidity_DEP_100                               0.000931
# average_humidity_ENR                                   0.000039
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           138551.415547
# specific_energy_ENR                               148839.887667
# flown_distance_ARR_100                            233653.725473
# flown_distance_DEP_100                            186329.014969
# flown_distance_ENR                                138047.172922
# specific_energy                                    51712.505536
#
#                                                          7       \
# flight_id                                             248752667
# date                                                 2022-01-01
# callsign                       52d1b50f92590b36489a929375be10f6
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LYBE
# name_ades                                              Belgrade
# country_code_ades                                            RS
# actual_offblock_time                       2022-01-01T05:21:00Z
# arrival_time                               2022-01-01T07:05:28Z
# aircraft_type                                              B738
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                              79
# taxiout_time                                                 25
# flown_distance                                              458
# tow                                                     60678.0
# track_variation_ARR_100                               17.706362
# track_variation_DEP_100                              178.849514
# track_variation_ENR                                    5.485476
# average_vertical_rate_ARR_100                      -1241.185882
# average_vertical_rate_DEP_100                       1689.102107
# average_vertical_rate_ENR                           -141.099415
# average_airspeed_ARR_100                             121.419076
# average_airspeed_DEP_100                             186.145523
# average_airspeed_ENR                                 216.591814
# groundspeed_ARR_100                                  121.879046
# groundspeed_DEP_100                                  184.123843
# groundspeed_ENR                                      206.011256
# wind_distance_ARR_100                              17484.737342
# wind_distance_DEP_100                              -2503.711019
# wind_distance_ENR                                 -21696.210238
# average_temperature_ARR_100                          256.753553
# average_temperature_DEP_100                          240.886871
# average_temperature_ENR                               217.56515
# average_humidity_ARR_100                               0.002688
# average_humidity_DEP_100                               0.001552
# average_humidity_ENR                                   0.000011
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           156089.001028
# specific_energy_ENR                               127799.326482
# flown_distance_ARR_100                            184008.971819
# flown_distance_DEP_100                            230811.252066
# flown_distance_ENR                                421459.524346
# specific_energy                                    40402.236552
#
#                                                          8       \
# flight_id                                             248762188
# date                                                 2022-01-01
# callsign                       256265f000acb4a06cd680b3df7c9897
# adep                                                       KLAX
# name_adep                                           Los Angeles
# country_code_adep                                            US
# ades                                                       LTFM
# name_ades                                          iGA Istanbul
# country_code_ades                                            TR
# actual_offblock_time                       2022-01-01T21:26:00Z
# arrival_time                               2022-01-02T09:55:00Z
# aircraft_type                                              B789
# wtc                                                           H
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             739
# taxiout_time                                                 10
# flown_distance                                             6354
# tow                                                    235632.0
# track_variation_ARR_100                               23.829551
# track_variation_DEP_100                                     NaN
# track_variation_ENR                                   99.558897
# average_vertical_rate_ARR_100                      12773.719008
# average_vertical_rate_DEP_100                               NaN
# average_vertical_rate_ENR                            -47.111015
# average_airspeed_ARR_100                              336.38239
# average_airspeed_DEP_100                                    NaN
# average_airspeed_ENR                                 282.767584
# groundspeed_ARR_100                                  340.799221
# groundspeed_DEP_100                                         NaN
# groundspeed_ENR                                      278.505289
# wind_distance_ARR_100                               8522.729263
# wind_distance_DEP_100                                       NaN
# wind_distance_ENR                                -213346.488345
# average_temperature_ARR_100                          262.078614
# average_temperature_DEP_100                                 NaN
# average_temperature_ENR                              216.352822
# average_humidity_ARR_100                               0.002507
# average_humidity_DEP_100                                    NaN
# average_humidity_ENR                                   0.000013
# specific_energy_ARR_100                            303185.89023
# specific_energy_DEP_100                                     NaN
# specific_energy_ENR                               135551.837481
# flown_distance_ARR_100                            245174.718293
# flown_distance_DEP_100                                      NaN
# flown_distance_ENR                              10180076.619312
# specific_energy                                   185741.730238
#
#                                                          9       ...  \
# flight_id                                             248753189  ...
# date                                                 2022-01-01  ...
# callsign                       8191fa049d6f1a6cb432a98d97bf960c  ...
# adep                                                       LTFM  ...
# name_adep                                          iGA Istanbul  ...
# country_code_adep                                            TR  ...
# ades                                                       LTAC  ...
# name_ades                                                Ankara  ...
# country_code_ades                                            TR  ...
# actual_offblock_time                       2022-01-01T15:00:00Z  ...
# arrival_time                               2022-01-01T16:09:00Z  ...
# aircraft_type                                              A321  ...
# wtc                                                           M  ...
# airline                        6351ec1b849adacc0cbb3b1313d8d39b  ...
# flight_duration                                              44  ...
# taxiout_time                                                 25  ...
# flown_distance                                              257  ...
# tow                                                     73571.0  ...
# track_variation_ARR_100                              119.350942  ...
# track_variation_DEP_100                                     NaN  ...
# track_variation_ENR                                         NaN  ...
# average_vertical_rate_ARR_100                       -654.951792  ...
# average_vertical_rate_DEP_100                               NaN  ...
# average_vertical_rate_ENR                                   NaN  ...
# average_airspeed_ARR_100                             101.215431  ...
# average_airspeed_DEP_100                                    NaN  ...
# average_airspeed_ENR                                        NaN  ...
# groundspeed_ARR_100                                  100.549956  ...
# groundspeed_DEP_100                                         NaN  ...
# groundspeed_ENR                                             NaN  ...
# wind_distance_ARR_100                                -540.74267  ...
# wind_distance_DEP_100                                       NaN  ...
# wind_distance_ENR                                           NaN  ...
# average_temperature_ARR_100                          274.784833  ...
# average_temperature_DEP_100                                 NaN  ...
# average_temperature_ENR                                     NaN  ...
# average_humidity_ARR_100                               0.004571  ...
# average_humidity_DEP_100                                    NaN  ...
# average_humidity_ENR                                        NaN  ...
# specific_energy_ARR_100                            15977.826605  ...
# specific_energy_DEP_100                                     NaN  ...
# specific_energy_ENR                                         NaN  ...
# flown_distance_ARR_100                             53914.394348  ...
# flown_distance_DEP_100                                      NaN  ...
# flown_distance_ENR                                          NaN  ...
# specific_energy                                    38213.580804  ...
#
#                                                          369003  \
# flight_id                                             258072846
# date                                                 2022-12-31
# callsign                       5ea802e68573752dc98d7623d897a915
# adep                                                       LIRF
# name_adep                                        Rome Fiumicino
# country_code_adep                                            IT
# ades                                                       EBBR
# name_ades                                              Brussels
# country_code_ades                                            BE
# actual_offblock_time                       2022-12-31T09:47:00Z
# arrival_time                               2022-12-31T11:58:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        bdeeef3a675587d530de70a25d7118d2
# flight_duration                                             114
# taxiout_time                                                 18
# flown_distance                                              726
# tow                                                61804.035897
# track_variation_ARR_100                               41.225296
# track_variation_DEP_100                              107.075354
# track_variation_ENR                                   86.102977
# average_vertical_rate_ARR_100                       -937.275362
# average_vertical_rate_DEP_100                       1676.220472
# average_vertical_rate_ENR                            -88.939373
# average_airspeed_ARR_100                             122.967444
# average_airspeed_DEP_100                               192.6238
# average_airspeed_ENR                                 216.760272
# groundspeed_ARR_100                                  135.792899
# groundspeed_DEP_100                                  188.189286
# groundspeed_ENR                                      211.361468
# wind_distance_ARR_100                              20658.403766
# wind_distance_DEP_100                              -3260.130151
# wind_distance_ENR                                 -23949.577571
# average_temperature_ARR_100                          269.844926
# average_temperature_DEP_100                          260.141793
# average_temperature_ENR                              217.026673
# average_humidity_ARR_100                               0.004583
# average_humidity_DEP_100                               0.002107
# average_humidity_ENR                                   0.000067
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                            133622.07443
# specific_energy_ENR                               112667.709633
# flown_distance_ARR_100                            186465.144745
# flown_distance_DEP_100                            190585.110323
# flown_distance_ENR                                936996.011575
# specific_energy                                    36237.665336
#
#                                                          369004  \
# flight_id                                             258057853
# date                                                 2022-12-31
# callsign                       b1de87e85987c58b0d29fa4e72e3f961
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       LSZH
# name_ades                                                Zurich
# country_code_ades                                            CH
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:14:52Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                              64
# taxiout_time                                                 19
# flown_distance                                              449
# tow                                                     72756.0
# track_variation_ARR_100                               64.982306
# track_variation_DEP_100                              174.543182
# track_variation_ENR                                   28.889307
# average_vertical_rate_ARR_100                      -1244.352645
# average_vertical_rate_DEP_100                       1642.811229
# average_vertical_rate_ENR                            156.761134
# average_airspeed_ARR_100                             137.852703
# average_airspeed_DEP_100                             220.263878
# average_airspeed_ENR                                 261.739939
# groundspeed_ARR_100                                  139.808418
# groundspeed_DEP_100                                  201.780574
# groundspeed_ENR                                      254.731008
# wind_distance_ARR_100                               3089.913657
# wind_distance_DEP_100                             -10280.268619
# wind_distance_ENR                                 -12093.078585
# average_temperature_ARR_100                          271.899846
# average_temperature_DEP_100                          259.683036
# average_temperature_ENR                              213.283719
# average_humidity_ARR_100                               0.004154
# average_humidity_DEP_100                               0.002833
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                             6407.360512
# specific_energy_DEP_100                           168893.023994
# specific_energy_ENR                               149197.949384
# flown_distance_ARR_100                            195675.977376
# flown_distance_DEP_100                            208022.688022
# flown_distance_ENR                                 438174.77535
# specific_energy                                    47447.649396
#
#                                                          369005  \
# flight_id                                             258071492
# date                                                 2022-12-31
# callsign                       49c815d2ca2e8c50b01473b12fd30119
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LIMC
# name_ades                                        Milan Malpensa
# country_code_ades                                            IT
# actual_offblock_time                       2022-12-31T09:34:00Z
# arrival_time                               2022-12-31T12:28:54Z
# aircraft_type                                              A321
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             150
# taxiout_time                                                 25
# flown_distance                                              975
# tow                                                     73571.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                                0.397226
# track_variation_ENR                                   17.529504
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       1758.369973
# average_vertical_rate_ENR                            -61.803143
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                              184.23032
# average_airspeed_ENR                                 219.668121
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  189.124142
# groundspeed_ENR                                      218.613382
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                               5480.149218
# wind_distance_ENR                                 -10901.238429
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                          245.451426
# average_temperature_ENR                              212.674614
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.000797
# average_humidity_ENR                                   0.000018
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           140053.115499
# specific_energy_ENR                               128044.533554
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            211067.430547
# flown_distance_ENR                               1326787.673125
# specific_energy                                    39340.477809
#
#                                                          369006  \
# flight_id                                             258060782
# date                                                 2022-12-31
# callsign                       92eba53fed3c3914105be1de666ca203
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       LGTS
# name_ades                                          Thessaloniki
# country_code_ades                                            GR
# actual_offblock_time                       2022-12-31T09:39:00Z
# arrival_time                               2022-12-31T11:36:58Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                             109
# taxiout_time                                                  9
# flown_distance                                              782
# tow                                                     64826.0
# track_variation_ARR_100                                38.67806
# track_variation_DEP_100                                0.815619
# track_variation_ENR                                   27.643538
# average_vertical_rate_ARR_100                       -1123.18552
# average_vertical_rate_DEP_100                           1163.52
# average_vertical_rate_ENR                            101.229917
# average_airspeed_ARR_100                             162.150949
# average_airspeed_DEP_100                             240.347377
# average_airspeed_ENR                                 248.697208
# groundspeed_ARR_100                                   132.82044
# groundspeed_DEP_100                                  241.131662
# groundspeed_ENR                                      244.375309
# wind_distance_ARR_100                              -1881.251514
# wind_distance_DEP_100                                266.267818
# wind_distance_ENR                                 -14033.188611
# average_temperature_ARR_100                          266.685247
# average_temperature_DEP_100                          237.221544
# average_temperature_ENR                              215.278241
# average_humidity_ARR_100                               0.002165
# average_humidity_DEP_100                               0.000248
# average_humidity_ENR                                   0.000027
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           156832.921001
# specific_energy_ENR                               155190.109141
# flown_distance_ARR_100                            155792.786993
# flown_distance_DEP_100                             84359.995118
# flown_distance_ENR                                789819.013017
# specific_energy                                   125289.758093
#
#                                                          369007  \
# flight_id                                             258067496
# date                                                 2022-12-31
# callsign                       80e0832fdc79cbba84dff5e9e06bb883
# adep                                                       EDDV
# name_adep                                               Hanover
# country_code_adep                                            DE
# ades                                                       LOWW
# name_ades                                                Vienna
# country_code_ades                                            AT
# actual_offblock_time                       2022-12-31T09:42:00Z
# arrival_time                               2022-12-31T10:49:00Z
# aircraft_type                                              E195
# wtc                                                           M
# airline                        5d407cb11cc29578cc3e292e743f5393
# flight_duration                                              59
# taxiout_time                                                  8
# flown_distance                                              416
# tow                                                     40868.0
# track_variation_ARR_100                               70.340447
# track_variation_DEP_100                               11.825033
# track_variation_ENR                                   19.299673
# average_vertical_rate_ARR_100                      -1531.761945
# average_vertical_rate_DEP_100                       1448.228571
# average_vertical_rate_ENR                            -73.789954
# average_airspeed_ARR_100                             180.948167
# average_airspeed_DEP_100                             242.288838
# average_airspeed_ENR                                 274.921886
# groundspeed_ARR_100                                  166.813103
# groundspeed_DEP_100                                   246.84073
# groundspeed_ENR                                      256.956948
# wind_distance_ARR_100                              -7472.241704
# wind_distance_DEP_100                               2231.413793
# wind_distance_ENR                                 -23584.897289
# average_temperature_ARR_100                          264.535833
# average_temperature_DEP_100                          236.754581
# average_temperature_ENR                              216.257414
# average_humidity_ARR_100                               0.003192
# average_humidity_DEP_100                               0.000321
# average_humidity_ENR                                   0.000038
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           172184.797047
# specific_energy_ENR                               168157.099762
# flown_distance_ARR_100                            197285.719862
# flown_distance_DEP_100                            119293.235695
# flown_distance_ENR                                336700.327007
# specific_energy                                   117497.769762
#
#                                                          369008  \
# flight_id                                             258058361
# date                                                 2022-12-31
# callsign                       85ee68e5b7b5acf24ba00d1318eca1e8
# adep                                                       LFPG
# name_adep                               Paris Charles de Gaulle
# country_code_adep                                            FR
# ades                                                       KMIA
# name_ades                                                 Miami
# country_code_ades                                            US
# actual_offblock_time                       2022-12-31T09:38:00Z
# arrival_time                               2022-12-31T19:03:48Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             545
# taxiout_time                                                 21
# flown_distance                                             4046
# tow                                                    163438.0
# track_variation_ARR_100                              174.768738
# track_variation_DEP_100                                9.528459
# track_variation_ENR                                    4.913511
# average_vertical_rate_ARR_100                        -957.19801
# average_vertical_rate_DEP_100                       1774.056075
# average_vertical_rate_ENR                            -36.004752
# average_airspeed_ARR_100                             120.477436
# average_airspeed_DEP_100                             157.386762
# average_airspeed_ENR                                 164.933554
# groundspeed_ARR_100                                   104.43162
# groundspeed_DEP_100                                  173.364743
# groundspeed_ENR                                      198.567031
# wind_distance_ARR_100                              -1128.929527
# wind_distance_DEP_100                              17086.799783
# wind_distance_ENR                                  99433.106553
# average_temperature_ARR_100                          287.071524
# average_temperature_DEP_100                          252.922497
# average_temperature_ENR                               217.79789
# average_humidity_ARR_100                               0.007733
# average_humidity_DEP_100                               0.002061
# average_humidity_ENR                                   0.000049
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           163105.039682
# specific_energy_ENR                               116846.850647
# flown_distance_ARR_100                             82920.116565
# flown_distance_DEP_100                            184272.114936
# flown_distance_ENR                                694149.603464
# specific_energy                                    37501.849179
#
#                                                          369009  \
# flight_id                                             258071247
# date                                                 2022-12-31
# callsign                       570cf7d5ebbd691bcba63e7466607da7
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       EDDB
# name_ades                                    Berlin Brandenburg
# country_code_ades                                            DE
# actual_offblock_time                       2022-12-31T09:27:00Z
# arrival_time                               2022-12-31T12:29:41Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             158
# taxiout_time                                                 25
# flown_distance                                              946
# tow                                                     78707.0
# track_variation_ARR_100                                62.54495
# track_variation_DEP_100                               22.872438
# track_variation_ENR                                   26.244336
# average_vertical_rate_ARR_100                       -986.942529
# average_vertical_rate_DEP_100                       1383.676768
# average_vertical_rate_ENR                             -1.009936
# average_airspeed_ARR_100                              130.21441
# average_airspeed_DEP_100                             207.311831
# average_airspeed_ENR                                 194.553687
# groundspeed_ARR_100                                  108.757847
# groundspeed_DEP_100                                  207.700919
# groundspeed_ENR                                      198.132349
# wind_distance_ARR_100                             -43244.289956
# wind_distance_DEP_100                                313.727621
# wind_distance_ENR                                  18337.913758
# average_temperature_ARR_100                           247.62106
# average_temperature_DEP_100                          232.875133
# average_temperature_ENR                              216.211231
# average_humidity_ARR_100                               0.002573
# average_humidity_DEP_100                                0.00013
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                           112914.102878
# specific_energy_DEP_100                           152199.894604
# specific_energy_ENR                               140217.805342
# flown_distance_ARR_100                            195902.336116
# flown_distance_DEP_100                            164082.472986
# flown_distance_ENR                               1329071.627906
# specific_energy                                    95013.649249
#
#                                                          369010  \
# flight_id                                             258059152
# date                                                 2022-12-31
# callsign                       5a7e43e4f981539ae3d3b1cb31591b7c
# adep                                                       EDDL
# name_adep                                            Dusseldorf
# country_code_adep                                            DE
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:41:51Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              99
# taxiout_time                                                 11
# flown_distance                                              522
# tow                                                    62942.75
# track_variation_ARR_100                               43.910303
# track_variation_DEP_100                               18.479277
# track_variation_ENR                                   19.499181
# average_vertical_rate_ARR_100                      -1514.788833
# average_vertical_rate_DEP_100                       1601.896296
# average_vertical_rate_ENR                             42.385714
# average_airspeed_ARR_100                             144.290228
# average_airspeed_DEP_100                             150.107396
# average_airspeed_ENR                                  212.79558
# groundspeed_ARR_100                                  139.525167
# groundspeed_DEP_100                                  160.518383
# groundspeed_ENR                                      167.741471
# wind_distance_ARR_100                              -6635.758627
# wind_distance_DEP_100                              14371.561186
# wind_distance_ENR                                -139780.366779
# average_temperature_ARR_100                          250.957833
# average_temperature_DEP_100                          251.493722
# average_temperature_ENR                              210.436025
# average_humidity_ARR_100                               0.002369
# average_humidity_DEP_100                               0.002126
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                             5362.951317
# specific_energy_DEP_100                           128466.552218
# specific_energy_ENR                               141243.406835
# flown_distance_ARR_100                            193167.686072
# flown_distance_DEP_100                            202633.765315
# flown_distance_ENR                                563061.094877
# specific_energy                                    30173.184666
#
#                                                          369011  \
# flight_id                                             258072276
# date                                                 2022-12-31
# callsign                       a1c078516f9f9e90cacec61854cad45b
# adep                                                       LFPG
# name_adep                               Paris Charles de Gaulle
# country_code_adep                                            FR
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:37:00Z
# arrival_time                               2022-12-31T11:13:10Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              84
# taxiout_time                                                 12
# flown_distance                                              466
# tow                                                72611.161024
# track_variation_ARR_100                               48.439184
# track_variation_DEP_100                               28.660678
# track_variation_ENR                                   35.779227
# average_vertical_rate_ARR_100                       -969.698872
# average_vertical_rate_DEP_100                       1378.429501
# average_vertical_rate_ENR                            -15.938319
# average_airspeed_ARR_100                              122.45483
# average_airspeed_DEP_100                             218.799521
# average_airspeed_ENR                                 191.069715
# groundspeed_ARR_100                                  112.449788
# groundspeed_DEP_100                                  226.096464
# groundspeed_ENR                                      176.568029
# wind_distance_ARR_100                             -20473.150862
# wind_distance_DEP_100                               3343.973845
# wind_distance_ENR                                 -34904.954795
# average_temperature_ARR_100                          242.858756
# average_temperature_DEP_100                          227.767796
# average_temperature_ENR                              211.729633
# average_humidity_ARR_100                               0.001674
# average_humidity_DEP_100                                0.00017
# average_humidity_ENR                                   0.000024
# specific_energy_ARR_100                           112926.042185
# specific_energy_DEP_100                           154852.097243
# specific_energy_ENR                               119424.098697
# flown_distance_ARR_100                            193489.008569
# flown_distance_DEP_100                            104213.234971
# flown_distance_ENR                                456310.057481
# specific_energy                                   126267.698202
#
#                                                          369012
# flight_id                                             258069969
# date                                                 2022-12-31
# callsign                       6c98fcaa191dec632b87b46511f1d2da
# adep                                                       LEMD
# name_adep                                        Madrid Barajas
# country_code_adep                                            ES
# ades                                                       KJFK
# name_ades                                          New York JFK
# country_code_ades                                            US
# actual_offblock_time                       2022-12-31T09:38:00Z
# arrival_time                               2022-12-31T17:26:35Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             453
# taxiout_time                                                 16
# flown_distance                                             3213
# tow                                                    195373.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                               23.802205
# track_variation_ENR                                   20.291439
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       1704.796434
# average_vertical_rate_ENR                             95.725934
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                             218.235814
# average_airspeed_ENR                                 223.393846
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  219.230349
# groundspeed_ENR                                       235.17158
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                                678.016139
# wind_distance_ENR                                  34396.167672
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                           247.96788
# average_temperature_ENR                              216.129046
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.000119
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           167056.041395
# specific_energy_ENR                               147639.900205
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            146406.180959
# flown_distance_ENR                                615701.069171
# specific_energy                                    91461.232681
#
# [46 rows x 369013 columns]

# %%
# Check unique countries in the 'adep' and 'ades' columns
adep_countries = challenge_set['country_code_adep'].unique()
ades_countries = challenge_set['country_code_ades'].unique()

# Combine both lists to get a unique set of countries
all_countries = set(adep_countries).union(set(ades_countries))

# Display the unique countries
print("Unique countries in cleaned_challenge_set:")
print(sorted(all_countries))
# Out:
# Unique countries in cleaned_challenge_set:
# ['##', 'AE', 'AL', 'AM', 'AN', 'AO', 'AT', 'AW', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BG', 'BH', 'BJ', 'BR', 'BY', 'CA', 'CD', 'CG', 'CH', 'CI', 'CR', 'CU', 'CV', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EE', 'EG', 'ES', 'ET', 'FI', 'FR', 'GB', 'GE', 'GH', 'GI', 'GR', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IR', 'IS', 'IT', 'JM', 'JO', 'JP', 'KG', 'KR', 'KZ', 'LB', 'LC', 'LR', 'LT', 'LU', 'LV', 'MA', 'MD', 'ME', 'MK', 'MN', 'MT', 'MU', 'MX', 'MY', 'NG', 'NL', 'NO', 'NP', 'OM', 'PA', 'PH', 'PK', 'PL', 'PT', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SD', 'SE', 'SI', 'SK', 'SL', 'SN', 'SO', 'TH', 'TM', 'TN', 'TR', 'TZ', 'UA', 'US', 'UZ', 'VE', 'VN', 'XK', 'ZA']

# %%
# Check unique countries in the 'adep' and 'ades' columns
adep_countries = submission_set['country_code_adep'].unique()
ades_countries = submission_set['country_code_ades'].unique()

# Combine both lists to get a unique set of countries
all_countries_sub = set(adep_countries).union(set(ades_countries))

# Display the unique countries
print("Unique countries in cleaned_challenge_set:")
print(sorted(all_countries_sub))
# Out:
# Unique countries in cleaned_challenge_set:
# ['##', 'AE', 'AL', 'AM', 'AN', 'AT', 'AZ', 'BA', 'BE', 'BG', 'BH', 'BY', 'CA', 'CH', 'CI', 'CR', 'CU', 'CV', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EE', 'EG', 'ER', 'ES', 'FI', 'FR', 'GB', 'GE', 'GR', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IR', 'IS', 'IT', 'JM', 'JO', 'JP', 'KG', 'KZ', 'LB', 'LC', 'LR', 'LT', 'LU', 'LV', 'MA', 'MD', 'ME', 'MK', 'MN', 'MT', 'MX', 'NL', 'NO', 'OM', 'PA', 'PK', 'PL', 'PT', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SI', 'SK', 'SL', 'SN', 'TH', 'TM', 'TN', 'TR', 'TZ', 'UA', 'US', 'UZ', 'XK', 'ZA']

# %%
set(all_countries_sub) - set(all_countries)
# Out:
# {'ER'}

# %%
def extract_time_features(df):
    # Converting datetime strings to datetime objects
    df['actual_offblock_time'] = pd.to_datetime(df['actual_offblock_time'])
    df['arrival_time'] = pd.to_datetime(df['arrival_time'])
    
    # Extracting basic time features
    df['offblock_hour'] = df['actual_offblock_time'].dt.hour
    df['offblock_minute'] = df['actual_offblock_time'].dt.minute
    df['offblock_day_of_week'] = df['actual_offblock_time'].dt.dayofweek
    df['offblock_month'] = df['actual_offblock_time'].dt.month
    # df['offblock_day_of_year'] = df['actual_offblock_time'].dt.dayofyear
    df['offblock_week_of_year'] = df['actual_offblock_time'].dt.isocalendar().week
    df['offblock_season'] = df['offblock_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else 
                                                       'Spring' if x in [3, 4, 5] else
                                                       'Summer' if x in [6, 7, 8] else 'Fall')
    
    df['arrival_hour'] = df['arrival_time'].dt.hour
    df['arrival_minute'] = df['arrival_time'].dt.minute

    # Calculating the duration in minutes between offblock and arrival
    df['offblock_to_arrival_duration'] = (df['arrival_time'] - df['actual_offblock_time']).dt.total_seconds() / 60
    
    # Adding boolean flags for weekends and rush hours
    df['is_offblock_weekend'] = df['offblock_day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
    df['is_offblock_rush_hour'] = df['offblock_hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 18 else 0)
    
    return df

# Creating additional duration-based features
def create_duration_features(df):
    # Replace zero or negative values in flight_duration to avoid division errors
    df['flight_duration'] = df['flight_duration'].replace(0, np.nan)
    df['taxiout_time'] = df['taxiout_time'].replace(0, np.nan)
    
    # Fill NaN values in taxiout_time with the median or a reasonable default
    df['taxiout_time'] = df['taxiout_time'].fillna(df['taxiout_time'].median())
    
    # Calculating the ratio of taxiout time to flight duration with error handling
    df['taxi_ratio'] = df.apply(lambda row: row['taxiout_time'] / row['flight_duration'] 
                                if pd.notnull(row['flight_duration']) else np.nan, axis=1)
    
    # Fill NaN values in taxi_ratio with 0 or a reasonable default (e.g., the median of taxi_ratio)
    df['taxi_ratio'] = df['taxi_ratio'].fillna(df['taxi_ratio'].median())
    
    # Calculating the average flight speed (distance per minute) with error handling
    df['flight_speed'] = df.apply(lambda row: row['flown_distance'] / row['flight_duration'] 
                                  if pd.notnull(row['flown_distance']) and pd.notnull(row['flight_duration']) else np.nan, axis=1)
    
    # Fill NaN values in flight_speed with the median value or a reasonable default
    df['flight_speed'] = df['flight_speed'].fillna(df['flight_speed'].median())
    
    # Normalizing taxi_ratio by the median value to control for large values
    df['normalized_taxi_ratio'] = df['taxi_ratio'] / df['taxi_ratio'].median()
    
    # Categorical features for flight duration buckets
    df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=[0, 60, 180, 300, np.inf], 
                                            labels=['Very Short', 'Short', 'Medium', 'Long'], right=False)
    
    # Speed per distance feature for more detailed analysis
    df['speed_per_distance'] = df.apply(lambda row: row['flight_speed'] / row['flown_distance'] 
                                        if pd.notnull(row['flight_speed']) and pd.notnull(row['flown_distance']) else np.nan, axis=1)
    
    # Fill NaN values in speed_per_distance with the median value or a reasonable default
    df['speed_per_distance'] = df['speed_per_distance'].fillna(df['speed_per_distance'].median())
    
    # Cumulative mean of flight speed to capture trends over time (if data is ordered by time)
    df['cumulative_avg_speed'] = df['flight_speed'].expanding().mean()
    
    # Handling edge cases and setting up conditions for further analysis
    df['taxi_ratio'] = df['taxi_ratio'].replace([np.inf, -np.inf], np.nan)
    df['flight_speed'] = df['flight_speed'].replace([np.inf, -np.inf], np.nan)
    
    return df


# Grouping airports by region based on country codes
def group_airports_by_region(df):
    # Define country groups for regions
    europe_countries = ['GB', 'FR', 'DE', 'ES', 'IT', 'SE', 'CH', 'NL', 'AT', 'IE', 'BE', 'DK', 'FI', 'GR', 'HU', 
                        'IS', 'LT', 'LU', 'LV', 'MT', 'NO', 'PL', 'PT', 'RO', 'SI', 'SK', 'CZ', 'EE', 'BG', 'CY']
    north_america_countries = ['US', 'CA', 'MX']
    south_america_countries = ['BR', 'AR', 'CL', 'CO', 'PE', 'VE', 'UY', 'PY', 'BO', 'EC', 'GY', 'SR']
    middle_east_countries = ['AE', 'SA', 'IL', 'IR', 'IQ', 'JO', 'KW', 'OM', 'QA', 'BH', 'LB', 'SY', 'YE']
    asia_countries = ['JP', 'CN', 'KR', 'IN', 'PK', 'BD', 'VN', 'PH', 'TH', 'MY', 'ID', 'SG', 'MN', 'KZ', 'TM', 'UZ', 'KG']
    africa_countries = ['ZA', 'NG', 'EG', 'DZ', 'MA', 'KE', 'TZ', 'GH', 'ET', 'CI', 'SN', 'SD', 'AO', 'LR', 'RW', 'ER']
    other_countries = set(df['country_code_adep'].unique()).union(set(df['country_code_ades'].unique())) - set(europe_countries + 
                       north_america_countries + south_america_countries + middle_east_countries + asia_countries + africa_countries)

    # Apply region categorization based on country codes
    def categorize_region(code):
        if code in europe_countries:
            return 'Europe'
        elif code in north_america_countries:
            return 'North America'
        elif code in south_america_countries:
            return 'South America'
        elif code in middle_east_countries:
            return 'Middle East'
        elif code in asia_countries:
            return 'Asia'
        elif code in africa_countries:
            return 'Africa'
        elif code in other_countries:
            return 'Other'
        else:
            return 'Unknown'

    # Apply region classification for adep and ades
    df['adep_region'] = df['country_code_adep'].apply(categorize_region)
    df['ades_region'] = df['country_code_ades'].apply(categorize_region)

    return df

# Update functions to remove original columns where applicable
def extract_country_features(df):
    # Basic feature indicating if the flight is within the same country
    df['same_country_flight'] = (df['country_code_adep'] == df['country_code_ades']).astype(int)

    # Feature indicating if the flight is within the same region
    df['same_region_flight'] = (df['adep_region'] == df['ades_region']).astype(int)

    # Flight direction based on regions: North-South, East-West, or Other
    df['flight_direction'] = df.apply(lambda row: 'North-South' if row['adep_region'] in ['North America', 'Europe'] and
                                                      row['ades_region'] in ['South America', 'Africa'] else
                                                      'East-West' if row['adep_region'] in ['Europe', 'Asia'] and 
                                                      row['ades_region'] in ['North America'] else 'Other', axis=1)

    # Create a feature indicating if the flight is intercontinental
    intercontinental_regions = ['Europe', 'North America', 'South America', 'Middle East', 'Asia', 'Africa']
    df['is_intercontinental'] = df.apply(
        lambda row: 1 if row['adep_region'] in intercontinental_regions and 
                         row['ades_region'] in intercontinental_regions and 
                         row['adep_region'] != row['ades_region'] else 0, axis=1)
    return df

# Function to remove original columns after feature extraction
def remove_columns(df, columns_to_remove):
    # Removing original datetime columns since features have been extracted
    df = df.drop(columns_to_remove, axis=1)
    return df

# List of columns to remove after feature extraction
columns_to_remove = ['name_adep', 'name_ades', 'country_code_adep', 'country_code_ades', 'flight_id', 'callsign', 'date', 'actual_offblock_time', 'arrival_time', 'flight_duration']

# Applying functions to the challenge set
cleaned_challenge_set = extract_time_features(challenge_set)
cleaned_challenge_set = create_duration_features(cleaned_challenge_set)
cleaned_challenge_set = group_airports_by_region(cleaned_challenge_set)
cleaned_challenge_set = extract_country_features(cleaned_challenge_set)
cleaned_challenge_set = remove_columns(cleaned_challenge_set, columns_to_remove)

# Applying functions to the submission set
cleaned_submission_set = extract_time_features(submission_set)
cleaned_submission_set = create_duration_features(cleaned_submission_set)
cleaned_submission_set = group_airports_by_region(cleaned_submission_set)
cleaned_submission_set = extract_country_features(cleaned_submission_set)
cleaned_submission_set = remove_columns(cleaned_submission_set, columns_to_remove)

# Display the transposed first few rows of the updated challenge set for review
cleaned_challenge_set.T
# Out:
# /tmp/ipykernel_127923/1767009025.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actual_offblock_time'] = pd.to_datetime(df['actual_offblock_time'])
# /tmp/ipykernel_127923/1767009025.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_time'] = pd.to_datetime(df['arrival_time'])
# /tmp/ipykernel_127923/1767009025.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_hour'] = df['actual_offblock_time'].dt.hour
# /tmp/ipykernel_127923/1767009025.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_minute'] = df['actual_offblock_time'].dt.minute
# /tmp/ipykernel_127923/1767009025.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_day_of_week'] = df['actual_offblock_time'].dt.dayofweek
# /tmp/ipykernel_127923/1767009025.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_month'] = df['actual_offblock_time'].dt.month
# /tmp/ipykernel_127923/1767009025.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_week_of_year'] = df['actual_offblock_time'].dt.isocalendar().week
# /tmp/ipykernel_127923/1767009025.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_season'] = df['offblock_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else
# /tmp/ipykernel_127923/1767009025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_hour'] = df['arrival_time'].dt.hour
# /tmp/ipykernel_127923/1767009025.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_minute'] = df['arrival_time'].dt.minute
# /tmp/ipykernel_127923/1767009025.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_to_arrival_duration'] = (df['arrival_time'] - df['actual_offblock_time']).dt.total_seconds() / 60
# /tmp/ipykernel_127923/1767009025.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_weekend'] = df['offblock_day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
# /tmp/ipykernel_127923/1767009025.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_rush_hour'] = df['offblock_hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 18 else 0)
# /tmp/ipykernel_127923/1767009025.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration'] = df['flight_duration'].replace(0, np.nan)
# /tmp/ipykernel_127923/1767009025.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].replace(0, np.nan)
# /tmp/ipykernel_127923/1767009025.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].fillna(df['taxiout_time'].median())
# /tmp/ipykernel_127923/1767009025.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df.apply(lambda row: row['taxiout_time'] / row['flight_duration']
# /tmp/ipykernel_127923/1767009025.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].fillna(df['taxi_ratio'].median())
# /tmp/ipykernel_127923/1767009025.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df.apply(lambda row: row['flown_distance'] / row['flight_duration']
# /tmp/ipykernel_127923/1767009025.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].fillna(df['flight_speed'].median())
# /tmp/ipykernel_127923/1767009025.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_taxi_ratio'] = df['taxi_ratio'] / df['taxi_ratio'].median()
# /tmp/ipykernel_127923/1767009025.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=[0, 60, 180, 300, np.inf],
# /tmp/ipykernel_127923/1767009025.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df.apply(lambda row: row['flight_speed'] / row['flown_distance']
# /tmp/ipykernel_127923/1767009025.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df['speed_per_distance'].fillna(df['speed_per_distance'].median())
# /tmp/ipykernel_127923/1767009025.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_avg_speed'] = df['flight_speed'].expanding().mean()
# /tmp/ipykernel_127923/1767009025.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_127923/1767009025.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_127923/1767009025.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adep_region'] = df['country_code_adep'].apply(categorize_region)
# /tmp/ipykernel_127923/1767009025.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ades_region'] = df['country_code_ades'].apply(categorize_region)
# /tmp/ipykernel_127923/1767009025.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_country_flight'] = (df['country_code_adep'] == df['country_code_ades']).astype(int)
# /tmp/ipykernel_127923/1767009025.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_region_flight'] = (df['adep_region'] == df['ades_region']).astype(int)
# /tmp/ipykernel_127923/1767009025.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_direction'] = df.apply(lambda row: 'North-South' if row['adep_region'] in ['North America', 'Europe'] and
# /tmp/ipykernel_127923/1767009025.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_intercontinental'] = df.apply(
# /tmp/ipykernel_127923/1767009025.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actual_offblock_time'] = pd.to_datetime(df['actual_offblock_time'])
# /tmp/ipykernel_127923/1767009025.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_time'] = pd.to_datetime(df['arrival_time'])
# /tmp/ipykernel_127923/1767009025.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_hour'] = df['actual_offblock_time'].dt.hour
# /tmp/ipykernel_127923/1767009025.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_minute'] = df['actual_offblock_time'].dt.minute
# /tmp/ipykernel_127923/1767009025.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_day_of_week'] = df['actual_offblock_time'].dt.dayofweek
# /tmp/ipykernel_127923/1767009025.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_month'] = df['actual_offblock_time'].dt.month
# /tmp/ipykernel_127923/1767009025.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_week_of_year'] = df['actual_offblock_time'].dt.isocalendar().week
# /tmp/ipykernel_127923/1767009025.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_season'] = df['offblock_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else
# /tmp/ipykernel_127923/1767009025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_hour'] = df['arrival_time'].dt.hour
# /tmp/ipykernel_127923/1767009025.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_minute'] = df['arrival_time'].dt.minute
# /tmp/ipykernel_127923/1767009025.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_to_arrival_duration'] = (df['arrival_time'] - df['actual_offblock_time']).dt.total_seconds() / 60
# /tmp/ipykernel_127923/1767009025.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_weekend'] = df['offblock_day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
# /tmp/ipykernel_127923/1767009025.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_rush_hour'] = df['offblock_hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 18 else 0)
# /tmp/ipykernel_127923/1767009025.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration'] = df['flight_duration'].replace(0, np.nan)
# /tmp/ipykernel_127923/1767009025.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].replace(0, np.nan)
# /tmp/ipykernel_127923/1767009025.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].fillna(df['taxiout_time'].median())
# /tmp/ipykernel_127923/1767009025.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df.apply(lambda row: row['taxiout_time'] / row['flight_duration']
# /tmp/ipykernel_127923/1767009025.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].fillna(df['taxi_ratio'].median())
# /tmp/ipykernel_127923/1767009025.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df.apply(lambda row: row['flown_distance'] / row['flight_duration']
# /tmp/ipykernel_127923/1767009025.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].fillna(df['flight_speed'].median())
# /tmp/ipykernel_127923/1767009025.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_taxi_ratio'] = df['taxi_ratio'] / df['taxi_ratio'].median()
# /tmp/ipykernel_127923/1767009025.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=[0, 60, 180, 300, np.inf],
# /tmp/ipykernel_127923/1767009025.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df.apply(lambda row: row['flight_speed'] / row['flown_distance']
# /tmp/ipykernel_127923/1767009025.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df['speed_per_distance'].fillna(df['speed_per_distance'].median())
# /tmp/ipykernel_127923/1767009025.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_avg_speed'] = df['flight_speed'].expanding().mean()
# /tmp/ipykernel_127923/1767009025.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_127923/1767009025.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_127923/1767009025.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adep_region'] = df['country_code_adep'].apply(categorize_region)
# /tmp/ipykernel_127923/1767009025.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ades_region'] = df['country_code_ades'].apply(categorize_region)
# /tmp/ipykernel_127923/1767009025.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_country_flight'] = (df['country_code_adep'] == df['country_code_ades']).astype(int)
# /tmp/ipykernel_127923/1767009025.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_region_flight'] = (df['adep_region'] == df['ades_region']).astype(int)
# /tmp/ipykernel_127923/1767009025.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_direction'] = df.apply(lambda row: 'North-South' if row['adep_region'] in ['North America', 'Europe'] and
# /tmp/ipykernel_127923/1767009025.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_intercontinental'] = df.apply(
#                                                          0       \
# adep                                                       EGLL
# ades                                                       EICK
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# taxiout_time                                               18.0
# flown_distance                                              321
# tow                                                     54748.0
# track_variation_ARR_100                              124.339907
# track_variation_DEP_100                               39.704139
# track_variation_ENR                                    2.102124
# average_vertical_rate_ARR_100                      -1276.005427
# average_vertical_rate_DEP_100                       1683.211169
# average_vertical_rate_ENR                             -1.995976
# average_airspeed_ARR_100                             142.772028
# average_airspeed_DEP_100                             168.840816
# average_airspeed_ENR                                 235.921296
# groundspeed_ARR_100                                   143.81467
# groundspeed_DEP_100                                  165.621789
# groundspeed_ENR                                      189.015731
# wind_distance_ARR_100                                1567.84086
# wind_distance_DEP_100                              -1920.854367
# wind_distance_ENR                                  -46602.77926
# average_temperature_ARR_100                           254.55627
# average_temperature_DEP_100                          250.873132
# average_temperature_ENR                              223.724129
# average_humidity_ARR_100                               0.002407
# average_humidity_DEP_100                               0.001703
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                             5179.747171
# specific_energy_DEP_100                           140619.201674
# specific_energy_ENR                               144961.839766
# flown_distance_ARR_100                            211353.030545
# flown_distance_DEP_100                            188976.310447
# flown_distance_ENR                                186972.278435
# specific_energy                                    29211.247288
# offblock_hour                                                13
# offblock_minute                                              46
# offblock_day_of_week                                          5
# offblock_month                                                1
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 15
# arrival_minute                                                4
# offblock_to_arrival_duration                          78.933333
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         0
# taxi_ratio                                             0.295082
# flight_speed                                           5.262295
# normalized_taxi_ratio                                  2.423888
# flight_duration_category                                  Short
# speed_per_distance                                     0.016393
# cumulative_avg_speed                                   5.262295
# adep_region                                              Europe
# ades_region                                              Europe
# same_country_flight                                           0
# same_region_flight                                            1
# flight_direction                                          Other
# is_intercontinental                                           0
#
#                                                          1       \
# adep                                                       LEBL
# ades                                                       KMIA
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# taxiout_time                                               13.0
# flown_distance                                             4193
# tow                                                    185441.0
# track_variation_ARR_100                               179.31889
# track_variation_DEP_100                                8.910306
# track_variation_ENR                                   76.029652
# average_vertical_rate_ARR_100                       -858.158167
# average_vertical_rate_DEP_100                       1682.557205
# average_vertical_rate_ENR                              6.553055
# average_airspeed_ARR_100                             123.061357
# average_airspeed_DEP_100                             185.710785
# average_airspeed_ENR                                  227.76135
# groundspeed_ARR_100                                   108.77848
# groundspeed_DEP_100                                  187.149785
# groundspeed_ENR                                      237.554856
# wind_distance_ARR_100                               -666.121285
# wind_distance_DEP_100                                4500.54389
# wind_distance_ENR                                -716980.775254
# average_temperature_ARR_100                          285.745817
# average_temperature_DEP_100                          259.884927
# average_temperature_ENR                              217.787401
# average_humidity_ARR_100                               0.004877
# average_humidity_DEP_100                               0.000757
# average_humidity_ENR                                   0.000043
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                                     NaN
# specific_energy_ENR                                162541.91571
# flown_distance_ARR_100                            127622.214114
# flown_distance_DEP_100                            213544.607732
# flown_distance_ENR                               6169683.647343
# specific_energy                                    30410.449851
# offblock_hour                                                 9
# offblock_minute                                              55
# offblock_day_of_week                                          5
# offblock_month                                                1
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 19
# arrival_minute                                               37
# offblock_to_arrival_duration                         582.933333
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         1
# taxi_ratio                                             0.022807
# flight_speed                                            7.35614
# normalized_taxi_ratio                                  0.187343
# flight_duration_category                                   Long
# speed_per_distance                                     0.001754
# cumulative_avg_speed                                   6.309218
# adep_region                                              Europe
# ades_region                                       North America
# same_country_flight                                           0
# same_region_flight                                            0
# flight_direction                                      East-West
# is_intercontinental                                           1
#
#                                                          2       \
# adep                                                       ESSA
# ades                                                       KORD
# aircraft_type                                              A333
# wtc                                                           H
# airline                        8be5c854fd664bcb97fb543339f74770
# taxiout_time                                               15.0
# flown_distance                                             3770
# tow                                                    230396.0
# track_variation_ARR_100                              179.638848
# track_variation_DEP_100                               32.391881
# track_variation_ENR                                   85.115541
# average_vertical_rate_ARR_100                       -791.849866
# average_vertical_rate_DEP_100                        840.240481
# average_vertical_rate_ENR                            -41.609514
# average_airspeed_ARR_100                             123.297495
# average_airspeed_DEP_100                             167.315256
# average_airspeed_ENR                                 198.747653
# groundspeed_ARR_100                                   121.55452
# groundspeed_DEP_100                                  119.406937
# groundspeed_ENR                                      202.119847
# wind_distance_ARR_100                              -3900.645575
# wind_distance_DEP_100                               3490.863228
# wind_distance_ENR                                -828173.942204
# average_temperature_ARR_100                          263.376852
# average_temperature_DEP_100                          249.523926
# average_temperature_ENR                              213.785647
# average_humidity_ARR_100                                0.00236
# average_humidity_DEP_100                               0.000507
# average_humidity_ENR                                   0.000042
# specific_energy_ARR_100                             7685.579077
# specific_energy_DEP_100                           139285.174766
# specific_energy_ENR                                96028.817505
# flown_distance_ARR_100                            244485.485197
# flown_distance_DEP_100                            200421.211208
# flown_distance_ENR                               6576808.430733
# specific_energy                                    29343.480734
# offblock_hour                                                 9
# offblock_minute                                              39
# offblock_day_of_week                                          5
# offblock_month                                                1
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 19
# arrival_minute                                                8
# offblock_to_arrival_duration                         569.216667
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         1
# taxi_ratio                                             0.027076
# flight_speed                                           6.805054
# normalized_taxi_ratio                                  0.222408
# flight_duration_category                                   Long
# speed_per_distance                                     0.001805
# cumulative_avg_speed                                   6.474497
# adep_region                                              Europe
# ades_region                                       North America
# same_country_flight                                           0
# same_region_flight                                            0
# flight_direction                                      East-West
# is_intercontinental                                           1
#
#                                                          3       \
# adep                                                       LSZH
# ades                                                       KPHL
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# taxiout_time                                               11.0
# flown_distance                                             3607
# tow                                                    157615.0
# track_variation_ARR_100                                0.208347
# track_variation_DEP_100                               36.998783
# track_variation_ENR                                  101.712676
# average_vertical_rate_ARR_100                       -690.489814
# average_vertical_rate_DEP_100                       1851.136442
# average_vertical_rate_ENR                            -91.982416
# average_airspeed_ARR_100                             133.834251
# average_airspeed_DEP_100                             185.641205
# average_airspeed_ENR                                 215.660291
# groundspeed_ARR_100                                  131.727768
# groundspeed_DEP_100                                  183.495244
# groundspeed_ENR                                       225.86334
# wind_distance_ARR_100                              -4825.621679
# wind_distance_DEP_100                              -2484.248921
# wind_distance_ENR                                 491073.402159
# average_temperature_ARR_100                           275.85643
# average_temperature_DEP_100                           252.51522
# average_temperature_ENR                              215.317206
# average_humidity_ARR_100                               0.005906
# average_humidity_DEP_100                               0.001007
# average_humidity_ENR                                   0.000057
# specific_energy_ARR_100                             7374.774863
# specific_energy_DEP_100                           167995.235621
# specific_energy_ENR                               114033.745667
# flown_distance_ARR_100                            281179.256823
# flown_distance_DEP_100                            211652.180677
# flown_distance_ENR                               6213393.828258
# specific_energy                                     26606.90037
# offblock_hour                                                11
# offblock_minute                                               4
# offblock_day_of_week                                          5
# offblock_month                                                1
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 19
# arrival_minute                                               32
# offblock_to_arrival_duration                         508.216667
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         0
# taxi_ratio                                             0.022133
# flight_speed                                           7.257545
# normalized_taxi_ratio                                  0.181805
# flight_duration_category                                   Long
# speed_per_distance                                     0.002012
# cumulative_avg_speed                                   6.670259
# adep_region                                              Europe
# ades_region                                       North America
# same_country_flight                                           0
# same_region_flight                                            0
# flight_direction                                      East-West
# is_intercontinental                                           1
#
#                                                          4       \
# adep                                                       EIDW
# ades                                                       EGLL
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# taxiout_time                                               14.0
# flown_distance                                              305
# tow                                                70318.447226
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                              174.878799
# track_variation_ENR                                         NaN
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       2754.662045
# average_vertical_rate_ENR                                   NaN
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                             180.572798
# average_airspeed_ENR                                        NaN
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  182.613355
# groundspeed_ENR                                             NaN
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                               1180.975329
# wind_distance_ENR                                           NaN
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                          255.205584
# average_temperature_ENR                                     NaN
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.001545
# average_humidity_ENR                                        NaN
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           137882.496272
# specific_energy_ENR                                         NaN
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            105355.234482
# flown_distance_ENR                                          NaN
# specific_energy                                    44309.014946
# offblock_hour                                                12
# offblock_minute                                              36
# offblock_day_of_week                                          5
# offblock_month                                                1
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 13
# arrival_minute                                               44
# offblock_to_arrival_duration                          68.533333
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         0
# taxi_ratio                                             0.254545
# flight_speed                                           5.545455
# normalized_taxi_ratio                                  2.090909
# flight_duration_category                             Very Short
# speed_per_distance                                     0.018182
# cumulative_avg_speed                                   6.445298
# adep_region                                              Europe
# ades_region                                              Europe
# same_country_flight                                           0
# same_region_flight                                            1
# flight_direction                                          Other
# is_intercontinental                                           0
#
#                                                          5       \
# adep                                                       ENGM
# ades                                                       LEAL
# aircraft_type                                              A20N
# wtc                                                           M
# airline                        8be5c854fd664bcb97fb543339f74770
# taxiout_time                                               27.0
# flown_distance                                             1434
# tow                                                     57721.0
# track_variation_ARR_100                              129.426353
# track_variation_DEP_100                               22.836441
# track_variation_ENR                                   14.447133
# average_vertical_rate_ARR_100                      -1147.657274
# average_vertical_rate_DEP_100                       1554.628143
# average_vertical_rate_ENR                              -6.54153
# average_airspeed_ARR_100                             156.904584
# ...
# adep                                                       LTFM
# ades                                                       EDDB
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# taxiout_time                                               25.0
# flown_distance                                              946
# tow                                                     78707.0
# track_variation_ARR_100                                62.54495
# track_variation_DEP_100                               22.872438
# track_variation_ENR                                   26.244336
# average_vertical_rate_ARR_100                       -986.942529
# average_vertical_rate_DEP_100                       1383.676768
# average_vertical_rate_ENR                             -1.009936
# average_airspeed_ARR_100                              130.21441
# average_airspeed_DEP_100                             207.311831
# average_airspeed_ENR                                 194.553687
# groundspeed_ARR_100                                  108.757847
# groundspeed_DEP_100                                  207.700919
# groundspeed_ENR                                      198.132349
# wind_distance_ARR_100                             -43244.289956
# wind_distance_DEP_100                                313.727621
# wind_distance_ENR                                  18337.913758
# average_temperature_ARR_100                           247.62106
# average_temperature_DEP_100                          232.875133
# average_temperature_ENR                              216.211231
# average_humidity_ARR_100                               0.002573
# average_humidity_DEP_100                                0.00013
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                           112914.102878
# specific_energy_DEP_100                           152199.894604
# specific_energy_ENR                               140217.805342
# flown_distance_ARR_100                            195902.336116
# flown_distance_DEP_100                            164082.472986
# flown_distance_ENR                               1329071.627906
# specific_energy                                    95013.649249
# offblock_hour                                                 9
# offblock_minute                                              27
# offblock_day_of_week                                          5
# offblock_month                                               12
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 12
# arrival_minute                                               29
# offblock_to_arrival_duration                         182.683333
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         1
# taxi_ratio                                             0.158228
# flight_speed                                           5.987342
# normalized_taxi_ratio                                  1.299729
# flight_duration_category                                  Short
# speed_per_distance                                     0.006329
# cumulative_avg_speed                                   6.368781
# adep_region                                               Other
# ades_region                                              Europe
# same_country_flight                                           0
# same_region_flight                                            0
# flight_direction                                          Other
# is_intercontinental                                           0
#
#                                                          369010  \
# adep                                                       EDDL
# ades                                                       EIDW
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# taxiout_time                                               11.0
# flown_distance                                              522
# tow                                                    62942.75
# track_variation_ARR_100                               43.910303
# track_variation_DEP_100                               18.479277
# track_variation_ENR                                   19.499181
# average_vertical_rate_ARR_100                      -1514.788833
# average_vertical_rate_DEP_100                       1601.896296
# average_vertical_rate_ENR                             42.385714
# average_airspeed_ARR_100                             144.290228
# average_airspeed_DEP_100                             150.107396
# average_airspeed_ENR                                  212.79558
# groundspeed_ARR_100                                  139.525167
# groundspeed_DEP_100                                  160.518383
# groundspeed_ENR                                      167.741471
# wind_distance_ARR_100                              -6635.758627
# wind_distance_DEP_100                              14371.561186
# wind_distance_ENR                                -139780.366779
# average_temperature_ARR_100                          250.957833
# average_temperature_DEP_100                          251.493722
# average_temperature_ENR                              210.436025
# average_humidity_ARR_100                               0.002369
# average_humidity_DEP_100                               0.002126
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                             5362.951317
# specific_energy_DEP_100                           128466.552218
# specific_energy_ENR                               141243.406835
# flown_distance_ARR_100                            193167.686072
# flown_distance_DEP_100                            202633.765315
# flown_distance_ENR                                563061.094877
# specific_energy                                    30173.184666
# offblock_hour                                                 9
# offblock_minute                                              52
# offblock_day_of_week                                          5
# offblock_month                                               12
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 11
# arrival_minute                                               41
# offblock_to_arrival_duration                             109.85
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         1
# taxi_ratio                                             0.111111
# flight_speed                                           5.272727
# normalized_taxi_ratio                                  0.912698
# flight_duration_category                                  Short
# speed_per_distance                                     0.010101
# cumulative_avg_speed                                   6.368778
# adep_region                                              Europe
# ades_region                                              Europe
# same_country_flight                                           0
# same_region_flight                                            1
# flight_direction                                          Other
# is_intercontinental                                           0
#
#                                                          369011  \
# adep                                                       LFPG
# ades                                                       EIDW
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# taxiout_time                                               12.0
# flown_distance                                              466
# tow                                                72611.161024
# track_variation_ARR_100                               48.439184
# track_variation_DEP_100                               28.660678
# track_variation_ENR                                   35.779227
# average_vertical_rate_ARR_100                       -969.698872
# average_vertical_rate_DEP_100                       1378.429501
# average_vertical_rate_ENR                            -15.938319
# average_airspeed_ARR_100                              122.45483
# average_airspeed_DEP_100                             218.799521
# average_airspeed_ENR                                 191.069715
# groundspeed_ARR_100                                  112.449788
# groundspeed_DEP_100                                  226.096464
# groundspeed_ENR                                      176.568029
# wind_distance_ARR_100                             -20473.150862
# wind_distance_DEP_100                               3343.973845
# wind_distance_ENR                                 -34904.954795
# average_temperature_ARR_100                          242.858756
# average_temperature_DEP_100                          227.767796
# average_temperature_ENR                              211.729633
# average_humidity_ARR_100                               0.001674
# average_humidity_DEP_100                                0.00017
# average_humidity_ENR                                   0.000024
# specific_energy_ARR_100                           112926.042185
# specific_energy_DEP_100                           154852.097243
# specific_energy_ENR                               119424.098697
# flown_distance_ARR_100                            193489.008569
# flown_distance_DEP_100                            104213.234971
# flown_distance_ENR                                456310.057481
# specific_energy                                   126267.698202
# offblock_hour                                                 9
# offblock_minute                                              37
# offblock_day_of_week                                          5
# offblock_month                                               12
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 11
# arrival_minute                                               13
# offblock_to_arrival_duration                          96.166667
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         1
# taxi_ratio                                             0.142857
# flight_speed                                           5.547619
# normalized_taxi_ratio                                  1.173469
# flight_duration_category                                  Short
# speed_per_distance                                     0.011905
# cumulative_avg_speed                                   6.368776
# adep_region                                              Europe
# ades_region                                              Europe
# same_country_flight                                           0
# same_region_flight                                            1
# flight_direction                                          Other
# is_intercontinental                                           0
#
#                                                          369012
# adep                                                       LEMD
# ades                                                       KJFK
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# taxiout_time                                               16.0
# flown_distance                                             3213
# tow                                                    195373.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_100                               23.802205
# track_variation_ENR                                   20.291439
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_100                       1704.796434
# average_vertical_rate_ENR                             95.725934
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_100                             218.235814
# average_airspeed_ENR                                 223.393846
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_100                                  219.230349
# groundspeed_ENR                                       235.17158
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_100                                678.016139
# wind_distance_ENR                                  34396.167672
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_100                           247.96788
# average_temperature_ENR                              216.129046
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_100                               0.000119
# average_humidity_ENR                                   0.000035
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_100                           167056.041395
# specific_energy_ENR                               147639.900205
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_100                            146406.180959
# flown_distance_ENR                                615701.069171
# specific_energy                                    91461.232681
# offblock_hour                                                 9
# offblock_minute                                              38
# offblock_day_of_week                                          5
# offblock_month                                               12
# offblock_week_of_year                                        52
# offblock_season                                          Winter
# arrival_hour                                                 17
# arrival_minute                                               26
# offblock_to_arrival_duration                         468.583333
# is_offblock_weekend                                           1
# is_offblock_rush_hour                                         1
# taxi_ratio                                              0.03532
# flight_speed                                           7.092715
# normalized_taxi_ratio                                  0.290129
# flight_duration_category                                   Long
# speed_per_distance                                     0.002208
# cumulative_avg_speed                                   6.368778
# adep_region                                              Europe
# ades_region                                       North America
# same_country_flight                                           0
# same_region_flight                                            0
# flight_direction                                      East-West
# is_intercontinental                                           1
#
# [59 rows x 369013 columns]

# %%
challenge_set['aircraft_type'].value_counts()
# Out:
# aircraft_type
# A320    79761
# A20N    37944
# B738    37495
# A321    29423
# E195    24914
# A21N    23257
# CRJ9    22926
# A319    17578
# A333    17011
# B38M    12330
# BCS3    11936
# B77W     9162
# B772     8322
# AT76     6897
# B788     5960
# B789     5734
# BCS1     4649
# B737     3627
# A332     2241
# E190     2105
# B739     1793
# A359     1725
# B763     1190
# B39M      542
# A343      480
# B752        6
# A310        2
# B773        1
# C56X        1
# E290        1
# Name: count, dtype: int64

# %%
# Extracting unique aircraft types from each set
challenge_aircraft_types = set(challenge_set['aircraft_type'].unique())
submission_aircraft_types = set(submission_set['aircraft_type'].unique())

# Aircraft types in challenge_set but not in submission_set
only_in_challenge = challenge_aircraft_types - submission_aircraft_types
print("Aircraft types only in challenge_set:", only_in_challenge)

# Aircraft types in submission_set but not in challenge_set
only_in_submission = submission_aircraft_types - challenge_aircraft_types
print("Aircraft types only in submission_set:", only_in_submission)
# Out:
# Aircraft types only in challenge_set: {'C56X', 'A310'}
# Aircraft types only in submission_set: set()

# %%
# Load the FAA Aircraft Characteristics Database from the uploaded Excel file
file_path = "./extra_data/FAA-Aircraft-Char-DB-AC-150-5300-13B-App-2023-09-07.xlsx"

# Load the FAA dataset and select relevant columns
faa_data = pd.read_excel(file_path, sheet_name='ACD_Data')

# Select relevant columns for merging
faa_relevant_columns = [
    'FAA_Designator', 'MTOW_lb', 'MALW_lb', 'Manufacturer', 'Model_FAA',
    'Physical_Class_Engine', 'Num_Engines', 'Approach_Speed_knot', 
    'FAA_Weight'
]

# Prepare the FAA data for merging
faa_clean = faa_data[faa_relevant_columns].dropna()

# Convert MTOW and MALW from pounds to kilograms for consistency
faa_clean['MTOW_kg'] = faa_clean['MTOW_lb'] * 0.453592
faa_clean['MALW_kg'] = faa_clean['MALW_lb'] * 0.453592

# Merge the cleaned_challenge_set with FAA data on aircraft_type and FAA_Designator
cleaned_challenge_set = cleaned_challenge_set.merge(
    faa_clean, how='left', left_on='aircraft_type', right_on='FAA_Designator'
)

# Merge the cleaned_submission_set with FAA data on aircraft_type and FAA_Designator
cleaned_submission_set = cleaned_submission_set.merge(
    faa_clean, how='left', left_on='aircraft_type', right_on='FAA_Designator'
)
cleaned_challenge_set.T
# Out:
#                                                0       \
# adep                                             EGLL
# ades                                             EICK
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                1       \
# adep                                             LEBL
# ades                                             KMIA
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             140.0
# FAA_Weight                                      Heavy
# MTOW_kg                                    297556.352
# MALW_kg                                     213188.24
#
#                                                2       \
# adep                                             ESSA
# ades                                             KORD
# aircraft_type                                    A333
# wtc                                                 H
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             137.0
# FAA_Weight                                      Heavy
# MTOW_kg                                 241999.950248
# MALW_kg                                 186999.652288
#
#                                                3       \
# adep                                             LSZH
# ades                                             KPHL
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Heavy
# MTOW_kg                                     227929.98
# MALW_kg                                     172364.96
#
#                                                4       \
# adep                                             EIDW
# ades                                             EGLL
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                5       \
# adep                                             ENGM
# ades                                             LEAL
# aircraft_type                                    A20N
# wtc                                                 M
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             137.0
# FAA_Weight                                      Large
# MTOW_kg                                   78999.85068
# MALW_kg                                  67399.688872
#
#                                                6       \
# adep                                             EGAC
# ades                                             EGLL
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                7       \
# adep                                             LTFM
# ades                                             LYBE
# aircraft_type                                    B738
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Large
# MTOW_kg                                    79015.7264
# MALW_kg                                    66349.1698
#
#                                                8       \
# adep                                             KLAX
# ades                                             LTFM
# aircraft_type                                    B789
# wtc                                                 H
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Heavy
# MTOW_kg                                     254011.52
# MALW_kg                                      192776.6
#
#                                                9       ...  \
# adep                                             LTFM  ...
# ades                                             LTAC  ...
# aircraft_type                                    A321  ...
# wtc                                                 M  ...
# airline              6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                               ...  ...
# Num_Engines                                         2  ...
# Approach_Speed_knot                             142.0  ...
# FAA_Weight                                      Large  ...
# MTOW_kg                                  91000.080632  ...
# MALW_kg                                   77800.09984  ...
#
#                                                369003  \
# adep                                             LIRF
# ades                                             EBBR
# aircraft_type                                    A320
# wtc                                                 M
# airline              bdeeef3a675587d530de70a25d7118d2
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                369004  \
# adep                                             EGLL
# ades                                             LSZH
# aircraft_type                                    A21N
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                369005  \
# adep                                             LTFM
# ades                                             LIMC
# aircraft_type                                    A321
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             142.0
# FAA_Weight                                      Large
# MTOW_kg                                  91000.080632
# MALW_kg                                   77800.09984
#
#                                                369006  \
# adep                                             LSZH
# ades                                             LGTS
# aircraft_type                                    A320
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                369007  \
# adep                                             EDDV
# ades                                             LOWW
# aircraft_type                                    E195
# wtc                                                 M
# airline              5d407cb11cc29578cc3e292e743f5393
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             135.0
# FAA_Weight                                      Large
# MTOW_kg                                   52290.08576
# MALW_kg                                  45800.091424
#
#                                                369008  \
# adep                                             LFPG
# ades                                             KMIA
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Heavy
# MTOW_kg                                     227929.98
# MALW_kg                                     172364.96
#
#                                                369009  \
# adep                                             LTFM
# ades                                             EDDB
# aircraft_type                                    A21N
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                369010  \
# adep                                             EDDL
# ades                                             EIDW
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                369011  \
# adep                                             LFPG
# ades                                             EIDW
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                369012
# adep                                             LEMD
# ades                                             KJFK
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             140.0
# FAA_Weight                                      Heavy
# MTOW_kg                                    297556.352
# MALW_kg                                     213188.24
#
# [70 rows x 369013 columns]

# %%
cleaned_challenge_set.drop(["FAA_Designator", "MTOW_lb", "MALW_lb"], axis=1, inplace=True)
cleaned_submission_set.drop(["FAA_Designator", "MTOW_lb", "MALW_lb"], axis=1, inplace=True)

# %%
# Check for unique aircraft types in the cleaned challenge set
unique_aircraft_types = cleaned_challenge_set['aircraft_type'].unique()

# Check which aircraft types from the challenge set are not present in the FAA data
missing_aircraft_types = [atype for atype in unique_aircraft_types if atype not in faa_data['FAA_Designator'].unique()]

missing_aircraft_types
# Out:
# []

# %% [raw]
# # Updated dictionary with estimated features for aircraft types
# aircraft_features = {
#     'A320': {'passenger_capacity': 150, 'mtow': 73500, 'range_km': 6100, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'A20N': {'passenger_capacity': 180, 'mtow': 79000, 'range_km': 6850, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'B738': {'passenger_capacity': 160, 'mtow': 79015, 'range_km': 5765, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A321': {'passenger_capacity': 200, 'mtow': 93000, 'range_km': 5950, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'E195': {'passenger_capacity': 120, 'mtow': 52290, 'range_km': 4260, 'category': 'regional', 'manufacturer': 'Embraer'},
#     'A21N': {'passenger_capacity': 206, 'mtow': 97000, 'range_km': 7400, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'CRJ9': {'passenger_capacity': 90, 'mtow': 38430, 'range_km': 2945, 'category': 'regional', 'manufacturer': 'Bombardier'},
#     'A319': {'passenger_capacity': 140, 'mtow': 64000, 'range_km': 6850, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'A333': {'passenger_capacity': 277, 'mtow': 242000, 'range_km': 11750, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B38M': {'passenger_capacity': 180, 'mtow': 82019, 'range_km': 6570, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'BCS3': {'passenger_capacity': 145, 'mtow': 67132, 'range_km': 6297, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'B77W': {'passenger_capacity': 396, 'mtow': 351535, 'range_km': 15690, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'B772': {'passenger_capacity': 314, 'mtow': 299370, 'range_km': 15600, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'AT76': {'passenger_capacity': 70, 'mtow': 23000, 'range_km': 1523, 'category': 'turboprop', 'manufacturer': 'ATR'},
#     'B788': {'passenger_capacity': 242, 'mtow': 227930, 'range_km': 13620, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'B789': {'passenger_capacity': 296, 'mtow': 254011, 'range_km': 14140, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'BCS1': {'passenger_capacity': 130, 'mtow': 60350, 'range_km': 5920, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'B737': {'passenger_capacity': 124, 'mtow': 62831, 'range_km': 4700, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A332': {'passenger_capacity': 278, 'mtow': 233000, 'range_km': 13450, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'E190': {'passenger_capacity': 100, 'mtow': 51800, 'range_km': 4445, 'category': 'regional', 'manufacturer': 'Embraer'},
#     'B739': {'passenger_capacity': 177, 'mtow': 79015, 'range_km': 5950, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A359': {'passenger_capacity': 325, 'mtow': 280000, 'range_km': 15000, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B763': {'passenger_capacity': 218, 'mtow': 186880, 'range_km': 11400, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'B39M': {'passenger_capacity': 210, 'mtow': 82019, 'range_km': 6570, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A343': {'passenger_capacity': 300, 'mtow': 276500, 'range_km': 13270, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B752': {'passenger_capacity': 200, 'mtow': 115680, 'range_km': 7222, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A310': {'passenger_capacity': 220, 'mtow': 164000, 'range_km': 8050, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B773': {'passenger_capacity': 365, 'mtow': 299370, 'range_km': 13750, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'C56X': {'passenger_capacity': 9, 'mtow': 9220, 'range_km': 3889, 'category': 'business', 'manufacturer': 'Cessna'},
#     'E290': {'passenger_capacity': 100, 'mtow': 57300, 'range_km': 4620, 'category': 'regional', 'manufacturer': 'Embraer'}
# }
#
# # Function to extract aircraft-specific features
# def extract_aircraft_features(df):
#     # Mapping the features from the dictionary based on aircraft_type
#     df['passenger_capacity'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('passenger_capacity', np.nan))
#     # passenger_capacity: Estimated number of passengers that the aircraft can carry.
#
#     df['mtow'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('mtow', np.nan))
#     # mtow: Maximum TakeOff Weight (MTOW) in kilograms, representing the heaviest weight at which the aircraft is certified to take off.
#
#     df['range_km'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('range_km', np.nan))
#     # range_km: The maximum range in kilometers that the aircraft can fly with a full load of fuel.
#
#     df['aircraft_category'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('category', 'unknown'))
#     # aircraft_category: The category of the aircraft (e.g., narrow-body, wide-body, regional), indicating its size and typical use.
#
#     df['aircraft_manufacturer'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('manufacturer', 'unknown'))
#     # aircraft_manufacturer: The manufacturer of the aircraft (e.g., Airbus, Boeing, Embraer).
#
#     # Creating new features based on these mappings
#     df['estimated_payload'] = df['mtow'] - (df['passenger_capacity'] * 100)  # Simplified payload estimate
#     # estimated_payload: A simplified estimate of the payload capacity, calculated as MTOW minus an average weight per passenger (assumed to be 100 kg per passenger).
#
#     # Additional features
#     df['range_to_mtow_ratio'] = df['range_km'] / df['mtow']  # Range-to-MTOW Ratio
#     # range_to_mtow_ratio: Ratio of the aircraft's range to its MTOW, indicating the efficiency of the aircraft in terms of distance per unit of weight.
#
#     df['passenger_density'] = df['passenger_capacity'] / df['mtow']  # Passenger Density
#     # passenger_density: The number of passengers per unit of MTOW, showing how optimized the aircraft is for passenger transport versus other uses (like cargo).
#
#     df['range_efficiency'] = df['range_km'] / (df['mtow'] / 1000)  # Range Efficiency
#     # range_efficiency: The efficiency of the aircraft’s range per tonne of MTOW, highlighting how far the aircraft can fly per unit of its weight.
#
#     df['is_high_range'] = df['range_km'].apply(lambda x: 1 if x > 10000 else 0)  # Binary high range indicator
#     # is_high_range: A binary feature indicating if the aircraft is considered long-range (1 if the range is greater than 10,000 km).
#
#     df['is_high_capacity'] = df['passenger_capacity'].apply(lambda x: 1 if x > 300 else 0)  # Binary high capacity indicator
#     # is_high_capacity: A binary feature indicating if the aircraft is high-capacity (1 if it can carry more than 300 passengers).
#
#     return df
#
# # Applying the function to enhance challenge and submission sets
# cleaned_challenge_set = extract_aircraft_features(cleaned_challenge_set)
# cleaned_submission_set = extract_aircraft_features(cleaned_submission_set)
#
# # Display the first few rows of the updated challenge set for review
# cleaned_challenge_set.T

# %%
# Load the GlobalAirportDatabase.txt into a DataFrame
columns_global = ['ICAO', 'IATA', 'Airport Name', 'City/Town', 'Country', 
                  'Latitude Degrees', 'Latitude Minutes', 'Latitude Seconds', 'Latitude Direction',
                  'Longitude Degrees', 'Longitude Minutes', 'Longitude Seconds', 'Longitude Direction',
                  'Altitude', 'Latitude Decimal Degrees', 'Longitude Decimal Degrees']
global_airports = pd.read_csv('./extra_data/GlobalAirportDatabase.txt', sep=':', header=None, names=columns_global)

# Select relevant columns including Altitude (ICAO, Latitude Decimal Degrees, Longitude Decimal Degrees, Altitude)
global_airports = global_airports[['ICAO', 'Latitude Decimal Degrees', 'Longitude Decimal Degrees', 'Altitude']]

# Load the airports.dat file (assuming previous naming and structure)
columns_openflights = ['Airport ID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 
                       'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 
                       'Type', 'Source']
openflights_airports = pd.read_csv('./extra_data/airports.dat', header=None, names=columns_openflights)

# Select relevant columns including Altitude (ICAO, Latitude Decimal Degrees, Longitude Decimal Degrees, Altitude)
openflights_airports = openflights_airports[['ICAO', 'Latitude', 'Longitude', 'Altitude']]
openflights_airports.rename(columns={'Latitude': 'Latitude Decimal Degrees', 
                                     'Longitude': 'Longitude Decimal Degrees'}, inplace=True)

# Concatenate both datasets, removing duplicates based on ICAO codes
airports = pd.concat([global_airports, openflights_airports]).drop_duplicates(subset=['ICAO'])

# Display the combined dataset to verify the merge
airports.head()
# Out:
#    ICAO  Latitude Decimal Degrees  Longitude Decimal Degrees  Altitude
# 0  AYGA                    -6.082                    145.392      1610
# 1  AYLA                     0.000                      0.000         0
# 2  AYMD                    -5.207                    145.789         7
# 3  AYMH                    -5.826                    144.296      1643
# 4  AYNZ                    -6.570                    146.726        73

# %%
# Backup
backup_challenge_set = cleaned_challenge_set.copy()

# Merge airports data to cleaned_challenge_set for both departure (adep) and arrival (ades) airports

# Merge for adep (departure airport)
cleaned_challenge_set = pd.merge(
    cleaned_challenge_set, airports, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
cleaned_challenge_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
cleaned_challenge_set = pd.merge(
    cleaned_challenge_set, airports, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
cleaned_challenge_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True
)

# Display the transposed DataFrame to confirm the correct columns are retained
cleaned_challenge_set.T
# Out:
#                                           0       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                              154.0
#
#                                           1       \
# adep                                        LEBL
# ades                                        KMIA
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           2       \
# adep                                        ESSA
# ades                                        KORD
# aircraft_type                               A333
# wtc                                            H
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                               38.0
# ICAO_ades                                   KORD
# Latitude_ades                             41.979
# Longitude_ades                           -87.904
# Altitude_ades                              204.0
#
#                                           3       \
# adep                                        LSZH
# ades                                        KPHL
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   KPHL
# Latitude_ades                             39.872
# Longitude_ades                           -75.241
# Altitude_ades                               12.0
#
#                                           4       \
# adep                                        EIDW
# ades                                        EGLL
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               74.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           5       \
# adep                                        ENGM
# ades                                        LEAL
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                              208.0
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                               44.0
#
#                                           6       \
# adep                                        EGAC
# ades                                        EGLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                5.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           7       \
# adep                                        LTFM
# ades                                        LYBE
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LYBE
# Latitude_ades                             44.818
# Longitude_ades                            20.309
# Altitude_ades                              103.0
#
#                                           8       \
# adep                                        KLAX
# ades                                        LTFM
# aircraft_type                               B789
# wtc                                            H
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                               39.0
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                              325.0
#
#                                           9       ...  \
# adep                                        LTFM  ...
# ades                                        LTAC  ...
# aircraft_type                               A321  ...
# wtc                                            M  ...
# airline         6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                          ...  ...
# Altitude_adep                              325.0  ...
# ICAO_ades                                   LTAC  ...
# Latitude_ades                             40.128  ...
# Longitude_ades                            32.995  ...
# Altitude_ades                              953.0  ...
#
#                                           369003  \
# adep                                        LIRF
# ades                                        EBBR
# aircraft_type                               A320
# wtc                                            M
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   EBBR
# Latitude_ades                             50.902
# Longitude_ades                             4.499
# Altitude_ades                               57.0
#
#                                           369004  \
# adep                                        EGLL
# ades                                        LSZH
# aircraft_type                               A21N
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                              432.0
#
#                                           369005  \
# adep                                        LTFM
# ades                                        LIMC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LIMC
# Latitude_ades                             45.631
# Longitude_ades                             8.728
# Altitude_ades                              234.0
#
#                                           369006  \
# adep                                        LSZH
# ades                                        LGTS
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   LGTS
# Latitude_ades                              40.52
# Longitude_ades                            22.971
# Altitude_ades                                7.0
#
#                                           369007  \
# adep                                        EDDV
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                               56.0
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                              183.0
#
#                                           369008  \
# adep                                        LFPG
# ades                                        KMIA
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           369009  \
# adep                                        LTFM
# ades                                        EDDB
# aircraft_type                               A21N
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   EDDB
# Latitude_ades                              52.38
# Longitude_ades                            13.523
# Altitude_ades                               48.0
#
#                                           369010  \
# adep                                        EDDL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               45.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           369011  \
# adep                                        LFPG
# ades                                        EIDW
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           369012
# adep                                        LEMD
# ades                                        KJFK
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              610.0
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                4.0
#
# [75 rows x 369013 columns]

# %%
# Count missing values for each column in the cleaned_challenge_set DataFrame
missing_values = cleaned_challenge_set.isnull().sum()

# Identify columns with missing values
columns_with_missing = missing_values[missing_values > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
# Assuming 'adep' and 'ades' are the columns where ICAO codes are merged
missing_icaos_adep = cleaned_challenge_set[cleaned_challenge_set['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades = cleaned_challenge_set[cleaned_challenge_set['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos = set(missing_icaos_adep).union(set(missing_icaos_ades))

# Count the number of unique ICAO codes missing
unique_missing_count = len(unique_missing_icaos)

unique_missing_count, unique_missing_icaos
# Out:
# (9, {'HSSK', 'LFTM', 'LTFG', 'LTFO', 'UCFM', 'UTFF', 'VGHS', 'VOGO', 'ZMCK'})

# %%
challenge_set['taxiout_time'].iloc[827]
# Out:
# 12.0

# %%
cleaned_challenge_set['taxiout_time'].iloc[827]
# Out:
# 12.0

# %%
# Display rows in the DataFrame that have missing values in any column
rows_with_missing_values = cleaned_challenge_set[cleaned_challenge_set.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_values.T
# Out:
#                                           1       \
# adep                                        LEBL
# ades                                        KMIA
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           4       \
# adep                                        EIDW
# ades                                        EGLL
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               74.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           5       \
# adep                                        ENGM
# ades                                        LEAL
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                              208.0
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                               44.0
#
#                                           6       \
# adep                                        EGAC
# ades                                        EGLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                5.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           7       \
# adep                                        LTFM
# ades                                        LYBE
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LYBE
# Latitude_ades                             44.818
# Longitude_ades                            20.309
# Altitude_ades                              103.0
#
#                                           8       \
# adep                                        KLAX
# ades                                        LTFM
# aircraft_type                               B789
# wtc                                            H
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                               39.0
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                              325.0
#
#                                           9       \
# adep                                        LTFM
# ades                                        LTAC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LTAC
# Latitude_ades                             40.128
# Longitude_ades                            32.995
# Altitude_ades                              953.0
#
#                                           10      \
# adep                                        LOWW
# ades                                        EDDM
# aircraft_type                               A320
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                              183.0
# ICAO_ades                                   EDDM
# Latitude_ades                             48.354
# Longitude_ades                            11.786
# Altitude_ades                              454.0
#
#                                           12      \
# adep                                        ESSA
# ades                                        ESMS
# aircraft_type                               CRJ9
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                               38.0
# ICAO_ades                                   ESMS
# Latitude_ades                              55.53
# Longitude_ades                            13.371
# Altitude_ades                               72.0
#
#                                           14      ...  \
# adep                                        LTAT  ...
# ades                                        LTAC  ...
# aircraft_type                               B738  ...
# wtc                                            M  ...
# airline         6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                          ...  ...
# Altitude_adep                              862.0  ...
# ICAO_ades                                   LTAC  ...
# Latitude_ades                             40.128  ...
# Longitude_ades                            32.995  ...
# Altitude_ades                              953.0  ...
#
#                                           368997  \
# adep                                        KMIA
# ades                                        LLBG
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                3.0
# ICAO_ades                                   LLBG
# Latitude_ades                             32.009
# Longitude_ades                            34.877
# Altitude_ades                               42.0
#
#                                           368999  \
# adep                                        EPWA
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                              111.0
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                              183.0
#
#                                           369000  \
# adep                                        LTFM
# ades                                        LEBL
# aircraft_type                               A21N
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LEBL
# Latitude_ades                             41.297
# Longitude_ades                             2.078
# Altitude_ades                                4.0
#
#                                           369001  \
# adep                                        LSGG
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                              431.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           369003  \
# adep                                        LIRF
# ades                                        EBBR
# aircraft_type                               A320
# wtc                                            M
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   EBBR
# Latitude_ades                             50.902
# Longitude_ades                             4.499
# Altitude_ades                               57.0
#
#                                           369005  \
# adep                                        LTFM
# ades                                        LIMC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LIMC
# Latitude_ades                             45.631
# Longitude_ades                             8.728
# Altitude_ades                              234.0
#
#                                           369006  \
# adep                                        LSZH
# ades                                        LGTS
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   LGTS
# Latitude_ades                              40.52
# Longitude_ades                            22.971
# Altitude_ades                                7.0
#
#                                           369007  \
# adep                                        EDDV
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                               56.0
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                              183.0
#
#                                           369008  \
# adep                                        LFPG
# ades                                        KMIA
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           369012
# adep                                        LEMD
# ades                                        KJFK
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              610.0
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                4.0
#
# [75 rows x 210255 columns]

# %%
# Applying the same transformations for submission_set as described for challenge_set

# Backup
backup_submission_set = cleaned_submission_set.copy()

# Filter updated_airports to include only ICAO codes present in cleaned_submission_set (adep and ades)
relevant_icaos_submission = cleaned_submission_set['adep'].unique().tolist() + cleaned_submission_set['ades'].unique().tolist()
filtered_airports_submission = airports[airports['ICAO'].isin(relevant_icaos_submission)]

# Merge airports data to submission_set for both departure (adep) and arrival (ades) airports
# Merge for adep (departure airport)
cleaned_submission_set = pd.merge(
    cleaned_submission_set, filtered_airports_submission, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
cleaned_submission_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
cleaned_submission_set = pd.merge(
    cleaned_submission_set, filtered_airports_submission, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
cleaned_submission_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True
)

cleaned_submission_set.T
# Out:
#                                           0       \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                              251.0
#
#                                           1       \
# adep                                        EBBR
# ades                                        KJFK
# aircraft_type                               A333
# wtc                                            H
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                               57.0
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                4.0
#
#                                           2       \
# adep                                        KMIA
# ades                                        EGLL
# aircraft_type                               B77W
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                3.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           3       \
# adep                                        EGCN
# ades                                        LEAL
# aircraft_type                               B38M
# wtc                                            M
# airline         3922524069809ac4326134429751e26f
# ...                                          ...
# Altitude_adep                               55.0
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                               44.0
#
#                                           4       \
# adep                                        EIDW
# ades                                        LFLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               74.0
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                              251.0
#
#                                           5       \
# adep                                        LTFJ
# ades                                        LTAC
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   LTAC
# Latitude_ades                             40.128
# Longitude_ades                            32.995
# Altitude_ades                              953.0
#
#                                           6       \
# adep                                        EGLL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           7       \
# adep                                        LSZH
# ades                                        EDDH
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   EDDH
# Latitude_ades                              53.63
# Longitude_ades                             9.988
# Altitude_ades                               17.0
#
#                                           8       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                              154.0
#
#                                           9       ...  \
# adep                                        LEMD  ...
# ades                                        EIDW  ...
# aircraft_type                               A320  ...
# wtc                                            M  ...
# airline         a73f82288988b79be490c6322f4c32ed  ...
# ...                                          ...  ...
# Altitude_adep                              610.0  ...
# ICAO_ades                                   EIDW  ...
# Latitude_ades                             53.421  ...
# Longitude_ades                             -6.27  ...
# Altitude_ades                               74.0  ...
#
#                                           105949  \
# adep                                        BKPR
# ades                                        LSGG
# aircraft_type                               BCS3
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                             1789.0
# ICAO_ades                                   LSGG
# Latitude_ades                             46.238
# Longitude_ades                             6.109
# Altitude_ades                              431.0
#
#                                           105950  \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                              251.0
#
#                                           105951  \
# adep                                        KORD
# ades                                        EGLL
# aircraft_type                               B789
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              204.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           105952  \
# adep                                        KJFK
# ades                                        LEBL
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   LEBL
# Latitude_ades                             41.297
# Longitude_ades                             2.078
# Altitude_ades                                4.0
#
#                                           105953  \
# adep                                        KSFO
# ades                                        EIDW
# aircraft_type                               A333
# wtc                                            H
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           105954  \
# adep                                        LTFJ
# ades                                        EKCH
# aircraft_type                               B38M
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   EKCH
# Latitude_ades                             55.618
# Longitude_ades                            12.656
# Altitude_ades                                6.0
#
#                                           105955  \
# adep                                        LOWW
# ades                                        KIAD
# aircraft_type                               B763
# wtc                                            H
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                              183.0
# ICAO_ades                                   KIAD
# Latitude_ades                             38.944
# Longitude_ades                           -77.456
# Altitude_ades                               96.0
#
#                                           105956  \
# adep                                        LTFM
# ades                                        LSZH
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                              432.0
#
#                                           105957  \
# adep                                        EHAM
# ades                                        EDDF
# aircraft_type                               A320
# wtc                                            M
# airline         f502877cab405652cf0dd70c2213e730
# ...                                          ...
# Altitude_adep                               -3.0
# ICAO_ades                                   EDDF
# Latitude_ades                             50.026
# Longitude_ades                             8.543
# Altitude_ades                              111.0
#
#                                           105958
# adep                                        UBBB
# ades                                        LTFM
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                              325.0
#
# [75 rows x 105959 columns]

# %%
# Count missing values for each column in the submission_set_updated DataFrame
missing_values_submission = cleaned_submission_set.isnull().sum()

# Identify columns with missing values
columns_with_missing_submission = missing_values_submission[missing_values_submission > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
missing_icaos_adep_submission = cleaned_submission_set[cleaned_submission_set['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades_submission = cleaned_submission_set[cleaned_submission_set['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos_submission = set(missing_icaos_adep_submission).union(set(missing_icaos_ades_submission))

# Count the number of unique ICAO codes missing
unique_missing_count_submission = len(unique_missing_icaos_submission)

unique_missing_count_submission, unique_missing_icaos_submission
# Out:
# (6, {'LTFG', 'LTFO', 'UCFM', 'UTFF', 'VOGO', 'ZMCK'})

# %%
# Coordinates for the given ICAO codes

new_airports = {
    'ICAO': ['CYHZ', 'EDDE', 'KDAB', 'KRFD', 'LIPO', 'LTAP', 'HSSK', 'LFTM', 'LTFG', 
             'LTFO', 'UCFM', 'UTFF', 'VGHS', 'VOGO', 'ZMCK'],
    'Latitude Decimal Degrees': [44.8800, 50.9798, 29.1799, 42.1954, 45.4289, 40.0714, 
                                 15.5895, 40.9769, 36.2994, 38.7262, 43.0613, 40.3581, 
                                 23.8433, 15.3808, 48.1357],
    'Longitude Decimal Degrees': [-63.5086, 10.9581, -81.0581, -89.0972, 10.3306, 32.5644, 
                                  32.5532, 28.8146, 32.3006, 30.6015, 74.4776, 71.7450, 
                                  90.3978, 73.8314, 114.6460],
    'Altitude': [145, 316, 11, 224, 109, 535, 386, 35, 28, 1003, 627, 577, 8, 56, 751]
}

# Convert new airports data to DataFrame
new_airports_df = pd.DataFrame(new_airports)

# Append the new rows to the existing DataFrame
updated_airports = pd.concat([airports, new_airports_df], ignore_index=True)

updated_airports = updated_airports.drop_duplicates(subset=['ICAO'])

# %%
# Filter updated_airports to include only ICAO codes present in df (adep and ades)
relevant_icaos_challenge = backup_challenge_set['adep'].unique().tolist() + backup_challenge_set['ades'].unique().tolist()
filtered_airports_challenge = updated_airports[updated_airports['ICAO'].isin(relevant_icaos_challenge)]

# Merge airports data to cleaned_challenge_set for both departure (adep) and arrival (ades) airports
# Merge for adep (departure airport)
challenge_set_updated = pd.merge(
    backup_challenge_set, filtered_airports_challenge, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
challenge_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
challenge_set_updated = pd.merge(
    challenge_set_updated, filtered_airports_challenge, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
challenge_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True)


# Display the transposed DataFrame to confirm the correct columns are retained
challenge_set_updated.T
# Out:
#                                           0       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                                154
#
#                                           1       \
# adep                                        LEBL
# ades                                        KMIA
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                  3
#
#                                           2       \
# adep                                        ESSA
# ades                                        KORD
# aircraft_type                               A333
# wtc                                            H
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                                 38
# ICAO_ades                                   KORD
# Latitude_ades                             41.979
# Longitude_ades                           -87.904
# Altitude_ades                                204
#
#                                           3       \
# adep                                        LSZH
# ades                                        KPHL
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                432
# ICAO_ades                                   KPHL
# Latitude_ades                             39.872
# Longitude_ades                           -75.241
# Altitude_ades                                 12
#
#                                           4       \
# adep                                        EIDW
# ades                                        EGLL
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 74
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           5       \
# adep                                        ENGM
# ades                                        LEAL
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                                208
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                                 44
#
#                                           6       \
# adep                                        EGAC
# ades                                        EGLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                  5
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           7       \
# adep                                        LTFM
# ades                                        LYBE
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   LYBE
# Latitude_ades                             44.818
# Longitude_ades                            20.309
# Altitude_ades                                103
#
#                                           8       \
# adep                                        KLAX
# ades                                        LTFM
# aircraft_type                               B789
# wtc                                            H
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                 39
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                                325
#
#                                           9       ...  \
# adep                                        LTFM  ...
# ades                                        LTAC  ...
# aircraft_type                               A321  ...
# wtc                                            M  ...
# airline         6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                          ...  ...
# Altitude_adep                                325  ...
# ICAO_ades                                   LTAC  ...
# Latitude_ades                             40.128  ...
# Longitude_ades                            32.995  ...
# Altitude_ades                                953  ...
#
#                                           369003  \
# adep                                        LIRF
# ades                                        EBBR
# aircraft_type                               A320
# wtc                                            M
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   EBBR
# Latitude_ades                             50.902
# Longitude_ades                             4.499
# Altitude_ades                                 57
#
#                                           369004  \
# adep                                        EGLL
# ades                                        LSZH
# aircraft_type                               A21N
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                                432
#
#                                           369005  \
# adep                                        LTFM
# ades                                        LIMC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   LIMC
# Latitude_ades                             45.631
# Longitude_ades                             8.728
# Altitude_ades                                234
#
#                                           369006  \
# adep                                        LSZH
# ades                                        LGTS
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                                432
# ICAO_ades                                   LGTS
# Latitude_ades                              40.52
# Longitude_ades                            22.971
# Altitude_ades                                  7
#
#                                           369007  \
# adep                                        EDDV
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                                 56
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                                183
#
#                                           369008  \
# adep                                        LFPG
# ades                                        KMIA
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                120
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                  3
#
#                                           369009  \
# adep                                        LTFM
# ades                                        EDDB
# aircraft_type                               A21N
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   EDDB
# Latitude_ades                              52.38
# Longitude_ades                            13.523
# Altitude_ades                                 48
#
#                                           369010  \
# adep                                        EDDL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 45
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           369011  \
# adep                                        LFPG
# ades                                        EIDW
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                120
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           369012
# adep                                        LEMD
# ades                                        KJFK
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                610
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                  4
#
# [75 rows x 369013 columns]

# %%
# Count missing values for each column in the cleaned_challenge_set DataFrame
missing_values = challenge_set_updated.isnull().sum()

# Identify columns with missing values
columns_with_missing = missing_values[missing_values > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
# Assuming 'adep' and 'ades' are the columns where ICAO codes are merged
missing_icaos_adep = challenge_set_updated[challenge_set_updated['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades = challenge_set_updated[challenge_set_updated['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos = set(missing_icaos_adep).union(set(missing_icaos_ades))

# Count the number of unique ICAO codes missing
unique_missing_count = len(unique_missing_icaos)

unique_missing_count, unique_missing_icaos
# Out:
# (0, set())

# %%
# Display rows in the DataFrame that have missing values in any column
rows_with_missing_values = challenge_set_updated[challenge_set_updated.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_values
# Out:
#         adep  ades aircraft_type wtc                           airline  \
# 1       LEBL  KMIA          B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 4       EIDW  EGLL          A21N   M  a73f82288988b79be490c6322f4c32ed
# 5       ENGM  LEAL          A20N   M  8be5c854fd664bcb97fb543339f74770
# 6       EGAC  EGLL          A320   M  a73f82288988b79be490c6322f4c32ed
# 7       LTFM  LYBE          B738   M  6351ec1b849adacc0cbb3b1313d8d39b
# ...      ...   ...           ...  ..                               ...
# 369005  LTFM  LIMC          A321   M  6351ec1b849adacc0cbb3b1313d8d39b
# 369006  LSZH  LGTS          A320   M  2d5def0a5a844b343ba1b7cc9cb28fa9
# 369007  EDDV  LOWW          E195   M  5d407cb11cc29578cc3e292e743f5393
# 369008  LFPG  KMIA          B788   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 369012  LEMD  KJFK          B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1
#
#         taxiout_time  flown_distance            tow  track_variation_ARR_100  \
# 1               13.0            4193  185441.000000               179.318890
# 4               14.0             305   70318.447226                      NaN
# 5               27.0            1434   57721.000000               129.426353
# 6               10.0             295   56818.000000               156.984462
# 7               25.0             458   60678.000000                17.706362
# ...              ...             ...            ...                      ...
# 369005          25.0             975   73571.000000                      NaN
# 369006           9.0             782   64826.000000                38.678060
# 369007           8.0             416   40868.000000                70.340447
# 369008          21.0            4046  163438.000000               174.768738
# 369012          16.0            3213  195373.000000                      NaN
#
#         track_variation_DEP_100  ...        MTOW_kg        MALW_kg  ICAO  \
# 1                      8.910306  ...  297556.352000  213188.240000  LEBL
# 4                    174.878799  ...   94999.854888   79199.884752  EIDW
# 5                     22.836441  ...   78999.850680   67399.688872  ENGM
# 6                     86.126276  ...   78000.133912   65999.903960  EGAC
# 7                    178.849514  ...   79015.726400   66349.169800  LTFM
# ...                         ...  ...            ...            ...   ...
# 369005                 0.397226  ...   91000.080632   77800.099840  LTFM
# 369006                 0.815619  ...   78000.133912   65999.903960  LSZH
# 369007                11.825033  ...   52290.085760   45800.091424  EDDV
# 369008                 9.528459  ...  227929.980000  172364.960000  LFPG
# 369012                23.802205  ...  297556.352000  213188.240000  LEMD
#
#         Latitude_adep  Longitude_adep  Altitude_adep  ICAO_ades  \
# 1           41.297000        2.078000              4       KMIA
# 4           53.421000       -6.270000             74       EGLL
# 5           60.194000       11.100000            208       LEAL
# 6           54.618000       -5.873000              5       EGLL
# 7           41.275278       28.751944            325       LYBE
# ...               ...             ...            ...        ...
# 369005      41.275278       28.751944            325       LIMC
# 369006      47.465000        8.549000            432       LGTS
# 369007      52.461000        9.685000             56       LOWW
# 369008      49.013000        2.550000            120       KMIA
# 369012      40.472000       -3.561000            610       KJFK
#
#         Latitude_ades  Longitude_ades  Altitude_ades
# 1              25.793         -80.291              3
# 4              51.477          -0.461             25
# 5              38.282          -0.558             44
# 6              51.477          -0.461             25
# 7              44.818          20.309            103
# ...               ...             ...            ...
# 369005         45.631           8.728            234
# 369006         40.520          22.971              7
# 369007         48.110          16.570            183
# 369008         25.793         -80.291              3
# 369012         40.640         -73.779              4
#
# [210200 rows x 75 columns]

# %%
# Applying the same transformations for submission_set as described for challenge_set

# Filter updated_airports to include only ICAO codes present in df (adep and ades)
relevant_icaos_submission = backup_submission_set['adep'].unique().tolist() + backup_submission_set['ades'].unique().tolist()
filtered_airports_submission = updated_airports[updated_airports['ICAO'].isin(relevant_icaos_submission)]

# Merge airports data to submission_set for both departure (adep) and arrival (ades) airports
# Merge for adep (departure airport)
submission_set_updated = pd.merge(
    backup_submission_set, filtered_airports_submission, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
submission_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
submission_set_updated = pd.merge(
    submission_set_updated, filtered_airports_submission, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
submission_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True
)

submission_set_updated.T
# Out:
#                                           0       \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                                251
#
#                                           1       \
# adep                                        EBBR
# ades                                        KJFK
# aircraft_type                               A333
# wtc                                            H
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                 57
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                  4
#
#                                           2       \
# adep                                        KMIA
# ades                                        EGLL
# aircraft_type                               B77W
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                  3
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           3       \
# adep                                        EGCN
# ades                                        LEAL
# aircraft_type                               B38M
# wtc                                            M
# airline         3922524069809ac4326134429751e26f
# ...                                          ...
# Altitude_adep                                 55
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                                 44
#
#                                           4       \
# adep                                        EIDW
# ades                                        LFLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 74
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                                251
#
#                                           5       \
# adep                                        LTFJ
# ades                                        LTAC
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   LTAC
# Latitude_ades                             40.128
# Longitude_ades                            32.995
# Altitude_ades                                953
#
#                                           6       \
# adep                                        EGLL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           7       \
# adep                                        LSZH
# ades                                        EDDH
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                                432
# ICAO_ades                                   EDDH
# Latitude_ades                              53.63
# Longitude_ades                             9.988
# Altitude_ades                                 17
#
#                                           8       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                                154
#
#                                           9       ...  \
# adep                                        LEMD  ...
# ades                                        EIDW  ...
# aircraft_type                               A320  ...
# wtc                                            M  ...
# airline         a73f82288988b79be490c6322f4c32ed  ...
# ...                                          ...  ...
# Altitude_adep                                610  ...
# ICAO_ades                                   EIDW  ...
# Latitude_ades                             53.421  ...
# Longitude_ades                             -6.27  ...
# Altitude_ades                                 74  ...
#
#                                           105949  \
# adep                                        BKPR
# ades                                        LSGG
# aircraft_type                               BCS3
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                               1789
# ICAO_ades                                   LSGG
# Latitude_ades                             46.238
# Longitude_ades                             6.109
# Altitude_ades                                431
#
#                                           105950  \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                                251
#
#                                           105951  \
# adep                                        KORD
# ades                                        EGLL
# aircraft_type                               B789
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                204
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           105952  \
# adep                                        KJFK
# ades                                        LEBL
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   LEBL
# Latitude_ades                             41.297
# Longitude_ades                             2.078
# Altitude_ades                                  4
#
#                                           105953  \
# adep                                        KSFO
# ades                                        EIDW
# aircraft_type                               A333
# wtc                                            H
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           105954  \
# adep                                        LTFJ
# ades                                        EKCH
# aircraft_type                               B38M
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   EKCH
# Latitude_ades                             55.618
# Longitude_ades                            12.656
# Altitude_ades                                  6
#
#                                           105955  \
# adep                                        LOWW
# ades                                        KIAD
# aircraft_type                               B763
# wtc                                            H
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                                183
# ICAO_ades                                   KIAD
# Latitude_ades                             38.944
# Longitude_ades                           -77.456
# Altitude_ades                                 96
#
#                                           105956  \
# adep                                        LTFM
# ades                                        LSZH
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                                432
#
#                                           105957  \
# adep                                        EHAM
# ades                                        EDDF
# aircraft_type                               A320
# wtc                                            M
# airline         f502877cab405652cf0dd70c2213e730
# ...                                          ...
# Altitude_adep                                 -3
# ICAO_ades                                   EDDF
# Latitude_ades                             50.026
# Longitude_ades                             8.543
# Altitude_ades                                111
#
#                                           105958
# adep                                        UBBB
# ades                                        LTFM
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                                325
#
# [75 rows x 105959 columns]

# %%
# Count missing values for each column in the submission_set_updated DataFrame
missing_values_submission = submission_set_updated.isnull().sum()

# Identify columns with missing values
columns_with_missing_submission = missing_values_submission[missing_values_submission > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
missing_icaos_adep_submission = submission_set_updated[submission_set_updated['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades_submission = submission_set_updated[submission_set_updated['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos_submission = set(missing_icaos_adep_submission).union(set(missing_icaos_ades_submission))

# Count the number of unique ICAO codes missing
unique_missing_count_submission = len(unique_missing_icaos_submission)

unique_missing_count_submission, unique_missing_icaos_submission
# Out:
# (0, set())

# %%
# Function to calculate actual distance between airports using Haversine formula
def calculate_actual_distance(df):
    # Convert degrees to radians
    lat1 = np.radians(df['Latitude_adep'])
    lon1 = np.radians(df['Longitude_adep'])
    lat2 = np.radians(df['Latitude_ades'])
    lon2 = np.radians(df['Longitude_ades'])
    
    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    radius_earth_km = 6371  # Earth radius in kilometers
    df['actual_distance'] = radius_earth_km * c
    
    # Additional features
    df['altitude_difference'] = df['Altitude_ades'] - df['Altitude_adep']  # Vertical distance
    df['bearing'] = np.degrees(np.arctan2(np.sin(dlon) * np.cos(lat2), 
                                           np.cos(lat1) * np.sin(lat2) - 
                                           np.sin(lat1) * np.cos(lat2) * np.cos(dlon)))  # Bearing
    
    df['bearing'] = (df['bearing'] + 360) % 360  # Normalize bearing to 0-360 degrees
    df['elevation_gradient'] = df['altitude_difference'] / df['actual_distance']  # Altitude change per km
    
    return df

# Apply the actual distance calculation and additional features to the challenge set
challenge_set_updated = calculate_actual_distance(challenge_set_updated)
challenge_set_updated = challenge_set_updated.drop(['ICAO', 'ICAO_ades'], axis=1)

# Apply the actual distance calculation and additional features to the submission set
submission_set_updated = calculate_actual_distance(submission_set_updated)
submission_set_updated = submission_set_updated.drop(['ICAO', 'ICAO_ades'], axis=1)

# %%
challenge_set_updated.T
# Out:
#                                                0       \
# adep                                             EGLL
# ades                                             EICK
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                     154
# actual_distance                            555.164898
# altitude_difference                               129
# bearing                                    277.346455
# elevation_gradient                           0.232363
#
#                                                1       \
# adep                                             LEBL
# ades                                             KMIA
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                       3
# actual_distance                           7544.863035
# altitude_difference                                -1
# bearing                                    285.530704
# elevation_gradient                          -0.000133
#
#                                                2       \
# adep                                             ESSA
# ades                                             KORD
# aircraft_type                                    A333
# wtc                                                 H
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Altitude_ades                                     204
# actual_distance                           6855.624802
# altitude_difference                               166
# bearing                                    305.643136
# elevation_gradient                           0.024214
#
#                                                3       \
# adep                                             LSZH
# ades                                             KPHL
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                      12
# actual_distance                           6459.885397
# altitude_difference                              -420
# bearing                                    296.005451
# elevation_gradient                          -0.065017
#
#                                                4       \
# adep                                             EIDW
# ades                                             EGLL
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      25
# actual_distance                            448.923048
# altitude_difference                               -49
# bearing                                    116.445141
# elevation_gradient                           -0.10915
#
#                                                5       \
# adep                                             ENGM
# ades                                             LEAL
# aircraft_type                                    A20N
# wtc                                                 M
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Altitude_ades                                      44
# actual_distance                           2570.426742
# altitude_difference                              -164
# bearing                                    203.829766
# elevation_gradient                          -0.063803
#
#                                                6       \
# adep                                             EGAC
# ades                                             EGLL
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      25
# actual_distance                            502.584003
# altitude_difference                                20
# bearing                                    131.803893
# elevation_gradient                           0.039794
#
#                                                7       \
# adep                                             LTFM
# ades                                             LYBE
# aircraft_type                                    B738
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                     103
# actual_distance                            790.539429
# altitude_difference                              -222
# bearing                                    302.700411
# elevation_gradient                          -0.280821
#
#                                                8       \
# adep                                             KLAX
# ades                                             LTFM
# aircraft_type                                    B789
# wtc                                                 H
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                     325
# actual_distance                          11002.355884
# altitude_difference                               286
# bearing                                     24.367089
# elevation_gradient                           0.025994
#
#                                                9       ...  \
# adep                                             LTFM  ...
# ades                                             LTAC  ...
# aircraft_type                                    A321  ...
# wtc                                                 M  ...
# airline              6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                               ...  ...
# Altitude_ades                                     953  ...
# actual_distance                            379.701883  ...
# altitude_difference                               628  ...
# bearing                                    108.236772  ...
# elevation_gradient                           1.653929  ...
#
#                                                369003  \
# adep                                             LIRF
# ades                                             EBBR
# aircraft_type                                    A320
# wtc                                                 M
# airline              bdeeef3a675587d530de70a25d7118d2
# ...                                               ...
# Altitude_ades                                      57
# actual_distance                           1171.335841
# altitude_difference                                53
# bearing                                    332.262955
# elevation_gradient                           0.045247
#
#                                                369004  \
# adep                                             EGLL
# ades                                             LSZH
# aircraft_type                                    A21N
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Altitude_ades                                     432
# actual_distance                            788.345953
# altitude_difference                               407
# bearing                                    120.930202
# elevation_gradient                           0.516271
#
#                                                369005  \
# adep                                             LTFM
# ades                                             LIMC
# aircraft_type                                    A321
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                     234
# actual_distance                            1682.22032
# altitude_difference                               -91
# bearing                                    293.444038
# elevation_gradient                          -0.054095
#
#                                                369006  \
# adep                                             LSZH
# ades                                             LGTS
# aircraft_type                                    A320
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Altitude_ades                                       7
# actual_distance                           1384.862343
# altitude_difference                              -425
# bearing                                    118.608849
# elevation_gradient                           -0.30689
#
#                                                369007  \
# adep                                             EDDV
# ades                                             LOWW
# aircraft_type                                    E195
# wtc                                                 M
# airline              5d407cb11cc29578cc3e292e743f5393
# ...                                               ...
# Altitude_ades                                     183
# actual_distance                            687.443083
# altitude_difference                               127
# bearing                                    131.991329
# elevation_gradient                           0.184743
#
#                                                369008  \
# adep                                             LFPG
# ades                                             KMIA
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                       3
# actual_distance                           7371.510894
# altitude_difference                              -117
# bearing                                    282.661191
# elevation_gradient                          -0.015872
#
#                                                369009  \
# adep                                             LTFM
# ades                                             EDDB
# aircraft_type                                    A21N
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                      48
# actual_distance                           1686.504718
# altitude_difference                              -277
# bearing                                    322.204001
# elevation_gradient                          -0.164245
#
#                                                369010  \
# adep                                             EDDL
# ades                                             EIDW
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      74
# actual_distance                             915.12942
# altitude_difference                                29
# bearing                                    290.097453
# elevation_gradient                            0.03169
#
#                                                369011  \
# adep                                             LFPG
# ades                                             EIDW
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      74
# actual_distance                             784.92987
# altitude_difference                               -46
# bearing                                    311.966635
# elevation_gradient                          -0.058604
#
#                                                369012
# adep                                             LEMD
# ades                                             KJFK
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                       4
# actual_distance                           5762.301327
# altitude_difference                              -606
# bearing                                    294.723106
# elevation_gradient                          -0.105166
#
# [77 rows x 369013 columns]

# %%
# List of categorical columns to analyze
categorical_columns = ['aircraft_type', 
                       'wtc', 
                       'airline',
                       'offblock_hour',
                       'offblock_minute', 
                       'offblock_day_of_week',
                       'offblock_month',
                       'offblock_week_of_year', 
                       'offblock_season', 
                       'arrival_hour',
                       'arrival_minute',
                       'is_offblock_weekend',
                       'is_offblock_rush_hour',
                       'flight_duration_category',                       
                       'adep_region', 
                       'ades_region', 
                       'same_country_flight',
                       'same_region_flight',                        
                       'flight_direction',
                       'is_intercontinental',
                       'Manufacturer',
                       'Model_FAA',
                       'Physical_Class_Engine',
                       'FAA_Weight']

# Calculate the number of unique values for each categorical column efficiently
unique_variations = challenge_set_updated[categorical_columns].nunique()

# Display the number of variations for each categorical variable
unique_variations
# Out:
# aircraft_type               30
# wtc                          2
# airline                     29
# offblock_hour               24
# offblock_minute             60
# offblock_day_of_week         7
# offblock_month              12
# offblock_week_of_year       52
# offblock_season              4
# arrival_hour                24
# arrival_minute              60
# is_offblock_weekend          2
# is_offblock_rush_hour        2
# flight_duration_category     4
# adep_region                  7
# ades_region                  7
# same_country_flight          2
# same_region_flight           2
# flight_direction             3
# is_intercontinental          2
# Manufacturer                 7
# Model_FAA                   30
# Physical_Class_Engine        2
# FAA_Weight                   3
# dtype: int64

# %%
# Extract airports from both datasets
challenge_airports = set(challenge_set_updated['adep']).union(set(challenge_set_updated['ades']))
submission_airports = set(submission_set_updated['adep']).union(set(submission_set_updated['ades']))

# Find airports in challenge_set_updated that are not in submission_set_updated
airports_only_in_challenge = challenge_airports - submission_airports

# Find airports in submission_set_updated that are not in challenge_set_updated
airports_only_in_submission = submission_airports - challenge_airports

# Display the results
print("Airports in challenge_set_updated that are not in submission_set_updated:")
print(airports_only_in_challenge)

print("\nAirports in submission_set_updated that are not in challenge_set_updated:")
print(airports_only_in_submission)
# Out:
# Airports in challenge_set_updated that are not in submission_set_updated:
# {'DGAA', 'OMAA', 'VVTS', 'GMTA', 'RKSI', 'EFIV', 'OMDW', 'FNLU', 'EDLW', 'UTNU', 'KOMA', 'LIEA', 'UTTT', 'CYYT', 'FZAA', 'LFTW', 'LECH', 'OPKC', 'LDRI', 'LRBS', 'LFCR', 'DNMM', 'KNYL', 'EDSB', 'VNKT', 'EPKT', 'FIMP', 'OPIS', 'LFTM', 'GCXO', 'EDFH', 'EFKI', 'EFOU', 'EGHL', 'UKHH', 'KTUL', 'HRYR', 'CYFB', 'LPAZ', 'SBGR', 'VGHS', 'EDLV', 'WADD', 'USSS', 'TNCA', 'TBPB', 'LIMJ', 'KFLL', 'LJMB', 'UGSB', 'LEGR', 'LEZG', 'EGJJ', 'HAAB', 'EYKA', 'UTSB', 'FCPP', 'GMFK', 'KPAE', 'DBBB', 'LGBL', 'LTCU', 'KGSP', 'CYUL', 'RPLL', 'HSSK', 'LXGB', 'HCMM', 'EPMO', 'LTFC', 'VTBS', 'LFRH', 'FAOR', 'LTAS', 'WMKK', 'SVMI', 'LCRA'}
#
# Airports in submission_set_updated that are not in challenge_set_updated:
# {'KDAB', 'LTCM', 'DAOO', 'RJTT', 'HHAS', 'LFBH', 'KRFD', 'ESKN', 'LKMT', 'MMPR', 'LKTB', 'LEAB', 'EFET'}

# %%
# Clustering based on geographical coordinates for challenge_set_updated

# Extract coordinates for adep and ades
adep_coords = challenge_set_updated[['Latitude_adep', 'Longitude_adep']].values
ades_coords = challenge_set_updated[['Latitude_ades', 'Longitude_ades']].values

# Combine all coordinates for clustering
combined_coords = np.vstack((adep_coords, ades_coords))

# Calculate inertia for each k value in the specified range
inertia = []
k_range = range(1, 50)  # Testing cluster sizes from 1 to 50

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(combined_coords)
    inertia.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.figure(figsize=(10, 6))
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia (Sum of Squared Distances)')
plt.title('Elbow Method for Optimal k')
plt.grid(True)
plt.show()
        
# Automatically determining the optimal k using the "elbow" point
# Finding the point where the reduction in inertia slows down significantly
optimal_k = 1  # Default to 1 cluster if no elbow is detected
threshold_ratio = 0.01  # Define a threshold for identifying the elbow point

# Checking for the point where inertia reduction starts to slow down
for i in range(1, len(inertia) - 1):
    if (inertia[i - 1] - inertia[i]) > (inertia[i] - inertia[i + 1]) * threshold_ratio:
        optimal_k = i + 1
        break

# %%
# Apply K-means clustering on combined coordinates
kmeans_geo = KMeans(n_clusters=20, random_state=42)  
kmeans_geo.fit(combined_coords)

# Assign cluster labels back to adep and ades separately
adep_geo_labels = kmeans_geo.predict(adep_coords)
ades_geo_labels = kmeans_geo.predict(ades_coords)

# Map cluster labels to the original dataframe
challenge_set_updated['adep_geo_cluster'] = adep_geo_labels
challenge_set_updated['ades_geo_cluster'] = ades_geo_labels

# %%
# Clustering based on geographical coordinates for submission_set_updated

# Extract coordinates for adep and ades from submission_set_updated
adep_coords_submission = submission_set_updated[['Latitude_adep', 'Longitude_adep']].values
ades_coords_submission = submission_set_updated[['Latitude_ades', 'Longitude_ades']].values

# Assign cluster labels back to adep and ades separately for submission_set_updated
adep_geo_labels_submission = kmeans_geo.predict(adep_coords_submission)
ades_geo_labels_submission = kmeans_geo.predict(ades_coords_submission)

# Map cluster labels to the submission_set_updated dataframe
submission_set_updated['adep_geo_cluster'] = adep_geo_labels_submission
submission_set_updated['ades_geo_cluster'] = ades_geo_labels_submission

# %%
# Automatically identify categorical variables in the DataFrame
categorical_columns_auto = challenge_set_updated.select_dtypes(include=['object', 'category']).columns.tolist()

# Calculate the number of unique values for each automatically identified categorical column
unique_variations_auto = challenge_set_updated[categorical_columns_auto].nunique()

# Display the identified categorical variables and their number of unique variations
unique_variations_auto
# Out:
# adep                        460
# ades                        367
# aircraft_type                30
# wtc                           2
# airline                      29
# offblock_season               4
# flight_duration_category      4
# adep_region                   7
# ades_region                   7
# flight_direction              3
# Manufacturer                  7
# Model_FAA                    30
# Physical_Class_Engine         2
# FAA_Weight                    3
# dtype: int64

# %%
# Calculate the number of unique values for each categorical column efficiently
unique_variations = challenge_set_updated[categorical_columns].nunique()

# Display the number of variations for each categorical variable
unique_variations
# Out:
# aircraft_type               30
# wtc                          2
# airline                     29
# offblock_hour               24
# offblock_minute             60
# offblock_day_of_week         7
# offblock_month              12
# offblock_week_of_year       52
# offblock_season              4
# arrival_hour                24
# arrival_minute              60
# is_offblock_weekend          2
# is_offblock_rush_hour        2
# flight_duration_category     4
# adep_region                  7
# ades_region                  7
# same_country_flight          2
# same_region_flight           2
# flight_direction             3
# is_intercontinental          2
# Manufacturer                 7
# Model_FAA                   30
# Physical_Class_Engine        2
# FAA_Weight                   3
# dtype: int64

# %%
# Summary statistics of the challenge set
challenge_summary = challenge_set_updated.describe()

# Check for missing values
missing_values = challenge_set_updated.isnull().sum()

# Correlation matrix to check relationships between numerical features
correlation_matrix = challenge_set_updated.corr(numeric_only=True)

# Plotting the correlation matrix
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Challenge Set')
plt.show()

# Display the summary statistics and missing values
challenge_summary, missing_values
# Out:
# /home/mmaximo/ita/prc-challenge-ita/env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/mmaximo/ita/prc-challenge-ita/env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/mmaximo/ita/prc-challenge-ita/env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# (        taxiout_time  flown_distance            tow  track_variation_ARR_100  \
#  count  369013.000000   369013.000000  369013.000000             3.454850e+05
#  mean       13.507952     1021.728581   79482.257229                      inf
#  std         5.755837     1128.171163   53250.919631                      NaN
#  min         1.000000       19.000000   14944.000000             0.000000e+00
#  25%        10.000000      338.000000   55836.000000             2.419634e+01
#  50%        12.000000      647.000000   63852.000000             5.985446e+01
#  75%        16.000000     1113.000000   73756.000000             1.241850e+02
#  max        90.000000     7272.000000  351327.000000                      inf
#
#         track_variation_DEP_100  track_variation_ENR  \
#  count             3.140470e+05         3.181650e+05
#  mean                       inf                  inf
#  std                        NaN                  NaN
#  min               0.000000e+00         0.000000e+00
#  25%               2.483615e+01         7.988137e+00
#  50%               5.776161e+01         2.260343e+01
#  75%               1.152746e+02         4.039071e+01
#  max                        inf                  inf
#
#         average_vertical_rate_ARR_100  average_vertical_rate_DEP_100  \
#  count                  345285.000000                  313601.000000
#  mean                    -1146.123157                    1709.595340
#  std                      1169.574909                    1445.136558
#  min                   -116470.787234                  -22391.562095
#  25%                     -1327.845517                    1501.858951
#  50%                     -1126.001198                    1696.961924
#  75%                      -917.041096                    1871.023474
#  max                     30854.554661                  116479.925455
#
#         average_vertical_rate_ENR  average_airspeed_ARR_100  ...  \
#  count              318161.000000             345017.000000  ...
#  mean                  -77.742268                147.054990  ...
#  std                   542.994884                 22.672059  ...
#  min               -100246.382353                -16.118496  ...
#  25%                   -99.099132                135.237784  ...
#  50%                   -26.170453                147.998790  ...
#  75%                     8.279958                159.831574  ...
#  max                 35616.966270                922.343740  ...
#
#         Altitude_adep  Latitude_ades  Longitude_ades  Altitude_ades  \
#  count  369013.000000  369013.000000   369013.000000  369013.000000
#  mean      155.889275      48.629936        5.786672     148.487343
#  std       192.741494       7.271459       24.159908     166.775645
#  min        -4.000000     -23.432000     -122.375000      -4.000000
#  25%        25.000000      41.297000        2.550000      25.000000
#  50%        74.000000      49.013000        9.222000      74.000000
#  75%       234.000000      53.421000       16.570000     208.000000
#  max      6400.000000      69.725000      140.386000    2835.000000
#
#         actual_distance  altitude_difference        bearing  \
#  count    369013.000000        369013.000000  369013.000000
#  mean       1791.114860            -7.401932     185.758299
#  std        2037.158776           249.104527     108.710509
#  min          32.122875         -6075.000000       0.112606
#  25%         554.323655          -138.000000      96.124865
#  50%        1112.227042            -2.000000     188.997460
#  75%        1957.775162           129.000000     294.557833
#  max       12289.405460          2510.000000     359.913734
#
#         elevation_gradient  adep_geo_cluster  ades_geo_cluster
#  count       369013.000000     369013.000000     369013.000000
#  mean            -0.008213          8.675486          8.684767
#  std              0.376571          5.253997          5.270159
#  min             -7.182588          0.000000          0.000000
#  25%             -0.109150          5.000000          5.000000
#  50%             -0.001303          9.000000          9.000000
#  75%              0.099998         13.000000         13.000000
#  max              6.201988         19.000000         19.000000
#
#  [8 rows x 65 columns],
#  adep                   0
#  ades                   0
#  aircraft_type          0
#  wtc                    0
#  airline                0
#                        ..
#  altitude_difference    0
#  bearing                0
#  elevation_gradient     0
#  adep_geo_cluster       0
#  ades_geo_cluster       0
#  Length: 79, dtype: int64)

# %%
# Function to rearrange the dataframe so that the target variable 'tow' is the last column
def rearrange_columns(df):
    # Moving 'tow' to the last position
    columns = [col for col in df.columns if col != 'tow'] + ['tow']
    df = df[columns]
    return df

# Remove some categorical columns
# mmaximo: I am not removing 'adep' and 'ades' anymore so I can use them to imput missing values
new_columns_to_remove = ['actual_distance']
# new_columns_to_remove = ['adep', 'ades', 'actual_distance']
challenge_set_updated = remove_columns(challenge_set_updated, new_columns_to_remove)
submission_set_updated = remove_columns(submission_set_updated, new_columns_to_remove)

# Apply One-Hot Encoding to the training set
# challenge_set_updated = pd.get_dummies(challenge_set_updated, columns=categorical_columns, drop_first=True)

# Apply One-Hot Encoding to the test set
# submission_set_updated = pd.get_dummies(submission_set_updated, columns=categorical_columns, drop_first=True)

# Align the test set columns with the training set columns
# Identify missing columns and create a DataFrame with those columns set to zero
missing_cols = set(challenge_set_updated.columns) - set(submission_set_updated.columns)
missing_cols_df = pd.DataFrame(0, index=submission_set_updated.index, columns=list(missing_cols))

# Concatenate the missing columns DataFrame with the test set
submission_set_updated = pd.concat([submission_set_updated, missing_cols_df], axis=1)

# Drop extra columns in the test set that are not in the training set
extra_cols = set(submission_set_updated.columns) - set(challenge_set_updated.columns)
submission_set_updated.drop(columns=list(extra_cols), inplace=True)

# Reorder the columns of the test set to match the training set
submission_set_updated = submission_set_updated[challenge_set_updated.columns]

# Rearrange columns
challenge_set_updated = rearrange_columns(challenge_set_updated)
submission_set_updated = rearrange_columns(submission_set_updated)

# %%
missing_cols
# Out:
# set()

# %%
extra_cols
# Out:
# set()

# %%
challenge_set_updated.T
# Out:
#                                               0       \
# adep                                            EGLL
# ades                                            EICK
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   277.346455
# elevation_gradient                          0.232363
# adep_geo_cluster                                  13
# ades_geo_cluster                                   0
# tow                                          54748.0
#
#                                               1       \
# adep                                            LEBL
# ades                                            KMIA
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   285.530704
# elevation_gradient                         -0.000133
# adep_geo_cluster                                  19
# ades_geo_cluster                                  12
# tow                                         185441.0
#
#                                               2       \
# adep                                            ESSA
# ades                                            KORD
# aircraft_type                                   A333
# wtc                                                H
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   305.643136
# elevation_gradient                          0.024214
# adep_geo_cluster                                   8
# ades_geo_cluster                                  15
# tow                                         230396.0
#
#                                               3       \
# adep                                            LSZH
# ades                                            KPHL
# aircraft_type                                   B788
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   296.005451
# elevation_gradient                         -0.065017
# adep_geo_cluster                                   2
# ades_geo_cluster                                   1
# tow                                         157615.0
#
#                                               4       \
# adep                                            EIDW
# ades                                            EGLL
# aircraft_type                                   A21N
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   116.445141
# elevation_gradient                          -0.10915
# adep_geo_cluster                                   0
# ades_geo_cluster                                  13
# tow                                     70318.447226
#
#                                               5       \
# adep                                            ENGM
# ades                                            LEAL
# aircraft_type                                   A20N
# wtc                                                M
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   203.829766
# elevation_gradient                         -0.063803
# adep_geo_cluster                                   9
# ades_geo_cluster                                  19
# tow                                          57721.0
#
#                                               6       \
# adep                                            EGAC
# ades                                            EGLL
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   131.803893
# elevation_gradient                          0.039794
# adep_geo_cluster                                   0
# ades_geo_cluster                                  13
# tow                                          56818.0
#
#                                               7       \
# adep                                            LTFM
# ades                                            LYBE
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   302.700411
# elevation_gradient                         -0.280821
# adep_geo_cluster                                  11
# ades_geo_cluster                                  16
# tow                                          60678.0
#
#                                               8       \
# adep                                            KLAX
# ades                                            LTFM
# aircraft_type                                   B789
# wtc                                                H
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    24.367089
# elevation_gradient                          0.025994
# adep_geo_cluster                                   4
# ades_geo_cluster                                  11
# tow                                         235632.0
#
#                                               9       ...  \
# adep                                            LTFM  ...
# ades                                            LTAC  ...
# aircraft_type                                   A321  ...
# wtc                                                M  ...
# airline             6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                              ...  ...
# bearing                                   108.236772  ...
# elevation_gradient                          1.653929  ...
# adep_geo_cluster                                  11  ...
# ades_geo_cluster                                  11  ...
# tow                                          73571.0  ...
#
#                                               369003  \
# adep                                            LIRF
# ades                                            EBBR
# aircraft_type                                   A320
# wtc                                                M
# airline             bdeeef3a675587d530de70a25d7118d2
# ...                                              ...
# bearing                                   332.262955
# elevation_gradient                          0.045247
# adep_geo_cluster                                   2
# ades_geo_cluster                                   6
# tow                                     61804.035897
#
#                                               369004  \
# adep                                            EGLL
# ades                                            LSZH
# aircraft_type                                   A21N
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   120.930202
# elevation_gradient                          0.516271
# adep_geo_cluster                                  13
# ades_geo_cluster                                   2
# tow                                          72756.0
#
#                                               369005  \
# adep                                            LTFM
# ades                                            LIMC
# aircraft_type                                   A321
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.444038
# elevation_gradient                         -0.054095
# adep_geo_cluster                                  11
# ades_geo_cluster                                   2
# tow                                          73571.0
#
#                                               369006  \
# adep                                            LSZH
# ades                                            LGTS
# aircraft_type                                   A320
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   118.608849
# elevation_gradient                          -0.30689
# adep_geo_cluster                                   2
# ades_geo_cluster                                   3
# tow                                          64826.0
#
#                                               369007  \
# adep                                            EDDV
# ades                                            LOWW
# aircraft_type                                   E195
# wtc                                                M
# airline             5d407cb11cc29578cc3e292e743f5393
# ...                                              ...
# bearing                                   131.991329
# elevation_gradient                          0.184743
# adep_geo_cluster                                   9
# ades_geo_cluster                                  16
# tow                                          40868.0
#
#                                               369008  \
# adep                                            LFPG
# ades                                            KMIA
# aircraft_type                                   B788
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   282.661191
# elevation_gradient                         -0.015872
# adep_geo_cluster                                   6
# ades_geo_cluster                                  12
# tow                                         163438.0
#
#                                               369009  \
# adep                                            LTFM
# ades                                            EDDB
# aircraft_type                                   A21N
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   322.204001
# elevation_gradient                         -0.164245
# adep_geo_cluster                                  11
# ades_geo_cluster                                   9
# tow                                          78707.0
#
#                                               369010  \
# adep                                            EDDL
# ades                                            EIDW
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   290.097453
# elevation_gradient                           0.03169
# adep_geo_cluster                                   6
# ades_geo_cluster                                   0
# tow                                         62942.75
#
#                                               369011  \
# adep                                            LFPG
# ades                                            EIDW
# aircraft_type                                   A21N
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   311.966635
# elevation_gradient                         -0.058604
# adep_geo_cluster                                   6
# ades_geo_cluster                                   0
# tow                                     72611.161024
#
#                                               369012
# adep                                            LEMD
# ades                                            KJFK
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   294.723106
# elevation_gradient                         -0.105166
# adep_geo_cluster                                   7
# ades_geo_cluster                                   1
# tow                                         195373.0
#
# [78 rows x 369013 columns]

# %%
submission_set_updated.T
# Out:
#                                               0       \
# adep                                            LTFJ
# ades                                            LFLL
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.477205
# elevation_gradient                         -0.030154
# adep_geo_cluster                                  11
# ades_geo_cluster                                  17
# tow                                              NaN
#
#                                               1       \
# adep                                            EBBR
# ades                                            KJFK
# aircraft_type                                   A333
# wtc                                                H
# airline             bdeeef3a675587d530de70a25d7118d2
# ...                                              ...
# bearing                                   291.395141
# elevation_gradient                         -0.009004
# adep_geo_cluster                                   6
# ades_geo_cluster                                   1
# tow                                              NaN
#
#                                               2       \
# adep                                            KMIA
# ades                                            EGLL
# aircraft_type                                   B77W
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    43.036806
# elevation_gradient                          0.003095
# adep_geo_cluster                                  12
# ades_geo_cluster                                  13
# tow                                              NaN
#
#                                               3       \
# adep                                            EGCN
# ades                                            LEAL
# aircraft_type                                   B38M
# wtc                                                M
# airline             3922524069809ac4326134429751e26f
# ...                                              ...
# bearing                                   178.644825
# elevation_gradient                         -0.006508
# adep_geo_cluster                                  13
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               4       \
# adep                                            EIDW
# ades                                            LFLL
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   131.790949
# elevation_gradient                          0.149765
# adep_geo_cluster                                   0
# ades_geo_cluster                                  17
# tow                                              NaN
#
#                                               5       \
# adep                                            LTFJ
# ades                                            LTAC
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   104.173834
# elevation_gradient                          1.983765
# adep_geo_cluster                                  11
# ades_geo_cluster                                  11
# tow                                              NaN
#
#                                               6       \
# adep                                            EGLL
# ades                                            EIDW
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   301.052709
# elevation_gradient                           0.10915
# adep_geo_cluster                                  13
# ades_geo_cluster                                   0
# tow                                              NaN
#
#                                               7       \
# adep                                            LSZH
# ades                                            EDDH
# aircraft_type                                   A320
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                       7.8847
# elevation_gradient                         -0.598866
# adep_geo_cluster                                   2
# ades_geo_cluster                                   9
# tow                                              NaN
#
#                                               8       \
# adep                                            EGLL
# ades                                            EICK
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   277.346455
# elevation_gradient                          0.232363
# adep_geo_cluster                                  13
# ades_geo_cluster                                   0
# tow                                              NaN
#
#                                               9       ...  \
# adep                                            LEMD  ...
# ades                                            EIDW  ...
# aircraft_type                                   A320  ...
# wtc                                                M  ...
# airline             a73f82288988b79be490c6322f4c32ed  ...
# ...                                              ...  ...
# bearing                                   352.849559  ...
# elevation_gradient                         -0.368588  ...
# adep_geo_cluster                                   7  ...
# ades_geo_cluster                                   0  ...
# tow                                              NaN  ...
#
#                                               105949  \
# adep                                            BKPR
# ades                                            LSGG
# aircraft_type                                   BCS3
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   294.105445
# elevation_gradient                         -1.085058
# adep_geo_cluster                                   3
# ades_geo_cluster                                  17
# tow                                              NaN
#
#                                               105950  \
# adep                                            LTFJ
# ades                                            LFLL
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.477205
# elevation_gradient                         -0.030154
# adep_geo_cluster                                  11
# ades_geo_cluster                                  17
# tow                                              NaN
#
#                                               105951  \
# adep                                            KORD
# ades                                            EGLL
# aircraft_type                                   B789
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    47.859294
# elevation_gradient                         -0.028218
# adep_geo_cluster                                  15
# ades_geo_cluster                                  13
# tow                                              NaN
#
#                                               105952  \
# adep                                            KJFK
# ades                                            LEBL
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    62.377552
# elevation_gradient                               0.0
# adep_geo_cluster                                   1
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               105953  \
# adep                                            KSFO
# ades                                            EIDW
# aircraft_type                                   A333
# wtc                                                H
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                    33.907846
# elevation_gradient                          0.008554
# adep_geo_cluster                                   4
# ades_geo_cluster                                   0
# tow                                              NaN
#
#                                               105954  \
# adep                                            LTFJ
# ades                                            EKCH
# aircraft_type                                   B38M
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   329.024194
# elevation_gradient                         -0.150159
# adep_geo_cluster                                  11
# ades_geo_cluster                                   9
# tow                                              NaN
#
#                                               105955  \
# adep                                            LOWW
# ades                                            KIAD
# aircraft_type                                   B763
# wtc                                                H
# airline             5d407cb11cc29578cc3e292e743f5393
# ...                                              ...
# bearing                                   300.682568
# elevation_gradient                         -0.012142
# adep_geo_cluster                                  16
# ades_geo_cluster                                   1
# tow                                              NaN
#
#                                               105956  \
# adep                                            LTFM
# ades                                            LSZH
# aircraft_type                                   A321
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   300.085737
# elevation_gradient                          0.061473
# adep_geo_cluster                                  11
# ades_geo_cluster                                   2
# tow                                              NaN
#
#                                               105957  \
# adep                                            EHAM
# ades                                            EDDF
# aircraft_type                                   A320
# wtc                                                M
# airline             f502877cab405652cf0dd70c2213e730
# ...                                              ...
# bearing                                   132.448927
# elevation_gradient                          0.311654
# adep_geo_cluster                                   6
# ades_geo_cluster                                   2
# tow                                              NaN
#
#                                               105958
# adep                                            UBBB
# ades                                            LTFM
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    279.85055
# elevation_gradient                          0.179499
# adep_geo_cluster                                  10
# ades_geo_cluster                                  11
# tow                                              NaN
#
# [78 rows x 105959 columns]

# %%
total_dataset = pd.concat([challenge_set_updated, submission_set_updated])
total_dataset.T
# Out:
#                                               0       \
# adep                                            EGLL
# ades                                            EICK
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   277.346455
# elevation_gradient                          0.232363
# adep_geo_cluster                                  13
# ades_geo_cluster                                   0
# tow                                          54748.0
#
#                                               1       \
# adep                                            LEBL
# ades                                            KMIA
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   285.530704
# elevation_gradient                         -0.000133
# adep_geo_cluster                                  19
# ades_geo_cluster                                  12
# tow                                         185441.0
#
#                                               2       \
# adep                                            ESSA
# ades                                            KORD
# aircraft_type                                   A333
# wtc                                                H
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   305.643136
# elevation_gradient                          0.024214
# adep_geo_cluster                                   8
# ades_geo_cluster                                  15
# tow                                         230396.0
#
#                                               3       \
# adep                                            LSZH
# ades                                            KPHL
# aircraft_type                                   B788
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   296.005451
# elevation_gradient                         -0.065017
# adep_geo_cluster                                   2
# ades_geo_cluster                                   1
# tow                                         157615.0
#
#                                               4       \
# adep                                            EIDW
# ades                                            EGLL
# aircraft_type                                   A21N
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   116.445141
# elevation_gradient                          -0.10915
# adep_geo_cluster                                   0
# ades_geo_cluster                                  13
# tow                                     70318.447226
#
#                                               5       \
# adep                                            ENGM
# ades                                            LEAL
# aircraft_type                                   A20N
# wtc                                                M
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   203.829766
# elevation_gradient                         -0.063803
# adep_geo_cluster                                   9
# ades_geo_cluster                                  19
# tow                                          57721.0
#
#                                               6       \
# adep                                            EGAC
# ades                                            EGLL
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   131.803893
# elevation_gradient                          0.039794
# adep_geo_cluster                                   0
# ades_geo_cluster                                  13
# tow                                          56818.0
#
#                                               7       \
# adep                                            LTFM
# ades                                            LYBE
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   302.700411
# elevation_gradient                         -0.280821
# adep_geo_cluster                                  11
# ades_geo_cluster                                  16
# tow                                          60678.0
#
#                                               8       \
# adep                                            KLAX
# ades                                            LTFM
# aircraft_type                                   B789
# wtc                                                H
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    24.367089
# elevation_gradient                          0.025994
# adep_geo_cluster                                   4
# ades_geo_cluster                                  11
# tow                                         235632.0
#
#                                               9       ...  \
# adep                                            LTFM  ...
# ades                                            LTAC  ...
# aircraft_type                                   A321  ...
# wtc                                                M  ...
# airline             6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                              ...  ...
# bearing                                   108.236772  ...
# elevation_gradient                          1.653929  ...
# adep_geo_cluster                                  11  ...
# ades_geo_cluster                                  11  ...
# tow                                          73571.0  ...
#
#                                               105949  \
# adep                                            BKPR
# ades                                            LSGG
# aircraft_type                                   BCS3
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   294.105445
# elevation_gradient                         -1.085058
# adep_geo_cluster                                   3
# ades_geo_cluster                                  17
# tow                                              NaN
#
#                                               105950  \
# adep                                            LTFJ
# ades                                            LFLL
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.477205
# elevation_gradient                         -0.030154
# adep_geo_cluster                                  11
# ades_geo_cluster                                  17
# tow                                              NaN
#
#                                               105951  \
# adep                                            KORD
# ades                                            EGLL
# aircraft_type                                   B789
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    47.859294
# elevation_gradient                         -0.028218
# adep_geo_cluster                                  15
# ades_geo_cluster                                  13
# tow                                              NaN
#
#                                               105952  \
# adep                                            KJFK
# ades                                            LEBL
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    62.377552
# elevation_gradient                               0.0
# adep_geo_cluster                                   1
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               105953  \
# adep                                            KSFO
# ades                                            EIDW
# aircraft_type                                   A333
# wtc                                                H
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                    33.907846
# elevation_gradient                          0.008554
# adep_geo_cluster                                   4
# ades_geo_cluster                                   0
# tow                                              NaN
#
#                                               105954  \
# adep                                            LTFJ
# ades                                            EKCH
# aircraft_type                                   B38M
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   329.024194
# elevation_gradient                         -0.150159
# adep_geo_cluster                                  11
# ades_geo_cluster                                   9
# tow                                              NaN
#
#                                               105955  \
# adep                                            LOWW
# ades                                            KIAD
# aircraft_type                                   B763
# wtc                                                H
# airline             5d407cb11cc29578cc3e292e743f5393
# ...                                              ...
# bearing                                   300.682568
# elevation_gradient                         -0.012142
# adep_geo_cluster                                  16
# ades_geo_cluster                                   1
# tow                                              NaN
#
#                                               105956  \
# adep                                            LTFM
# ades                                            LSZH
# aircraft_type                                   A321
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   300.085737
# elevation_gradient                          0.061473
# adep_geo_cluster                                  11
# ades_geo_cluster                                   2
# tow                                              NaN
#
#                                               105957  \
# adep                                            EHAM
# ades                                            EDDF
# aircraft_type                                   A320
# wtc                                                M
# airline             f502877cab405652cf0dd70c2213e730
# ...                                              ...
# bearing                                   132.448927
# elevation_gradient                          0.311654
# adep_geo_cluster                                   6
# ades_geo_cluster                                   2
# tow                                              NaN
#
#                                               105958
# adep                                            UBBB
# ades                                            LTFM
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    279.85055
# elevation_gradient                          0.179499
# adep_geo_cluster                                  10
# ades_geo_cluster                                  11
# tow                                              NaN
#
# [78 rows x 474972 columns]

# %%
total_dataset.replace(np.inf, np.nan, inplace=True)

# %%
pd.set_option('display.max_rows', None)

print('Showing proportion of NaNs in the total dataset (challenge + submission):')
print(total_dataset.isna().sum()/total_dataset.shape[0])

pd.reset_option('display.max_rows')
# Out:
# Showing proportion of NaNs in the total dataset (challenge + submission):
# adep                             0.000000
# ades                             0.000000
# aircraft_type                    0.000000
# wtc                              0.000000
# airline                          0.000000
# taxiout_time                     0.000000
# flown_distance                   0.000000
# track_variation_ARR_100          0.064160
# track_variation_DEP_100          0.150224
# track_variation_ENR              0.137267
# average_vertical_rate_ARR_100    0.064166
# average_vertical_rate_DEP_100    0.150230
# average_vertical_rate_ENR        0.137271
# average_airspeed_ARR_100         0.064859
# average_airspeed_DEP_100         0.150409
# average_airspeed_ENR             0.137275
# groundspeed_ARR_100              0.064160
# groundspeed_DEP_100              0.150224
# groundspeed_ENR                  0.137267
# wind_distance_ARR_100            0.063616
# wind_distance_DEP_100            0.149042
# wind_distance_ENR                0.137263
# average_temperature_ARR_100      0.064421
# average_temperature_DEP_100      0.149773
# average_temperature_ENR          0.137271
# average_humidity_ARR_100         0.064421
# average_humidity_DEP_100         0.149773
# average_humidity_ENR             0.137271
# specific_energy_ARR_100          0.415911
# specific_energy_DEP_100          0.152874
# specific_energy_ENR              0.139756
# flown_distance_ARR_100           0.063616
# flown_distance_DEP_100           0.149042
# flown_distance_ENR               0.137263
# specific_energy                  0.011954
# offblock_hour                    0.000000
# offblock_minute                  0.000000
# offblock_day_of_week             0.000000
# offblock_month                   0.000000
# offblock_week_of_year            0.000000
# offblock_season                  0.000000
# arrival_hour                     0.000000
# arrival_minute                   0.000000
# offblock_to_arrival_duration     0.000000
# is_offblock_weekend              0.000000
# is_offblock_rush_hour            0.000000
# taxi_ratio                       0.000000
# flight_speed                     0.000000
# normalized_taxi_ratio            0.000000
# flight_duration_category         0.000000
# speed_per_distance               0.000000
# cumulative_avg_speed             0.000000
# adep_region                      0.000000
# ades_region                      0.000000
# same_country_flight              0.000000
# same_region_flight               0.000000
# flight_direction                 0.000000
# is_intercontinental              0.000000
# Manufacturer                     0.000000
# Model_FAA                        0.000000
# Physical_Class_Engine            0.000000
# Num_Engines                      0.000000
# Approach_Speed_knot              0.000000
# FAA_Weight                       0.000000
# MTOW_kg                          0.000000
# MALW_kg                          0.000000
# Latitude_adep                    0.000000
# Longitude_adep                   0.000000
# Altitude_adep                    0.000000
# Latitude_ades                    0.000000
# Longitude_ades                   0.000000
# Altitude_ades                    0.000000
# altitude_difference              0.000000
# bearing                          0.000000
# elevation_gradient               0.000000
# adep_geo_cluster                 0.000000
# ades_geo_cluster                 0.000000
# tow                              0.223085
# dtype: float64

# %%
num_nans = total_dataset.isna().sum().sum()
columns = total_dataset.columns[total_dataset.isna().sum() > 0]
columns = list(columns)
columns.remove('tow')

cropped_dataset = total_dataset[['adep', 'ades', 'aircraft_type'] + columns]
cropped_dataset.head()

mean_values = cropped_dataset[columns].mean()

print(mean_values)
# Out:
# track_variation_ARR_100          7.437340e+01
# track_variation_DEP_100          7.093348e+01
# track_variation_ENR              2.920475e+01
# average_vertical_rate_ARR_100   -1.147050e+03
# average_vertical_rate_DEP_100    1.712534e+03
# average_vertical_rate_ENR       -7.816254e+01
# average_airspeed_ARR_100         1.470796e+02
# average_airspeed_DEP_100         1.802952e+02
# average_airspeed_ENR             2.284382e+02
# groundspeed_ARR_100              1.424208e+02
# groundspeed_DEP_100              1.771598e+02
# groundspeed_ENR                  2.286949e+02
# wind_distance_ARR_100            3.591999e+02
# wind_distance_DEP_100            1.072722e+02
# wind_distance_ENR               -1.453936e+03
# average_temperature_ARR_100      2.637085e+02
# average_temperature_DEP_100      2.526542e+02
# average_temperature_ENR          2.210615e+02
# average_humidity_ARR_100         2.798654e-03
# average_humidity_DEP_100         1.652539e-03
# average_humidity_ENR             5.616125e-05
# specific_energy_ARR_100          3.447350e+04
# specific_energy_DEP_100          1.437589e+05
# specific_energy_ENR              1.416561e+05
# flown_distance_ARR_100           2.121313e+05
# flown_distance_DEP_100           1.877372e+05
# flown_distance_ENR               1.443580e+06
# specific_energy                  5.574508e+04
# dtype: float64

# %%
grouped_dataset = cropped_dataset.groupby(['adep', 'ades', 'aircraft_type']).median()
grouped_dataset.head()

# print(grouped_dataset.shape[0])
# total_dataset_imputted = total_dataset
# total_dataset_imputted[columns] = grouped_dataset[columns]
# Out:
#                          track_variation_ARR_100  track_variation_DEP_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                        106.962873                 0.381966
#           B738                         81.044395               115.288750
#      EGGD B38M                          2.626313                74.514518
#      EGKK B38M                         28.095888                41.296190
#           B738                         27.328421                45.469595
#
#                          track_variation_ENR  average_vertical_rate_ARR_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                     20.828562                   -1228.444444
#           B738                     36.450225                   -1197.714286
#      EGGD B38M                     37.243574                   -1011.200000
#      EGKK B38M                     45.072241                    -952.869912
#           B738                     35.535351                    -909.765388
#
#                          average_vertical_rate_DEP_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                             1155.678161
#           B738                             1252.128280
#      EGGD B38M                             1616.413604
#      EGKK B38M                             1547.992841
#           B738                             1298.923858
#
#                          average_vertical_rate_ENR  average_airspeed_ARR_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                          -39.561785                151.851590
#           B738                           98.024788                154.229611
#      EGGD B38M                            5.143417                157.472807
#      EGKK B38M                         -246.786773                166.848617
#           B738                         -108.118835                133.103852
#
#                          average_airspeed_DEP_100  average_airspeed_ENR  \
# adep ades aircraft_type
# BIKF EGCC B38M                         136.586061            219.046035
#           B738                         129.063777            246.121472
#      EGGD B38M                         167.187358            231.297811
#      EGKK B38M                         166.738882            243.445959
#           B738                         127.591985            232.133491
#
#                          groundspeed_ARR_100  ...  average_humidity_ARR_100  \
# adep ades aircraft_type                       ...
# BIKF EGCC B38M                    142.549574  ...                  0.000926
#           B738                    140.307362  ...                  0.001647
#      EGGD B38M                    154.977943  ...                  0.002021
#      EGKK B38M                    142.936505  ...                  0.001824
#           B738                    135.057922  ...                  0.001848
#
#                          average_humidity_DEP_100  average_humidity_ENR  \
# adep ades aircraft_type
# BIKF EGCC B38M                           0.000828              0.000009
#           B738                           0.001287              0.000009
#      EGGD B38M                           0.000713              0.000007
#      EGKK B38M                           0.000985              0.000021
#           B738                           0.001147              0.000012
#
#                          specific_energy_ARR_100  specific_energy_DEP_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                               NaN            158297.643120
#           B738                      36980.614374            178136.973595
#      EGGD B38M                       4767.057271            155743.447955
#      EGKK B38M                               NaN            185803.227544
#           B738                       6292.469906            159939.820662
#
#                          specific_energy_ENR  flown_distance_ARR_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                 142832.656678           200945.627525
#           B738                 159412.111818           164696.149215
#      EGGD B38M                 166074.447711             9582.945702
#      EGKK B38M                 126285.912989           243056.094561
#           B738                 140529.028668           210496.571200
#
#                          flown_distance_DEP_100  flown_distance_ENR  \
# adep ades aircraft_type
# BIKF EGCC B38M                    201132.875963        7.495917e+05
#           B738                    200906.900918        1.049839e+06
#      EGGD B38M                    186681.454334        1.169697e+06
#      EGKK B38M                    197342.053337        1.583096e+06
#           B738                    190393.048803        9.034633e+05
#
#                          specific_energy
# adep ades aircraft_type
# BIKF EGCC B38M             102956.842114
#           B738              37428.640143
#      EGGD B38M              38185.428272
#      EGKK B38M              39048.348661
#           B738              36355.669364
#
# [5 rows x 28 columns]

# %%
print('Number of NaNs:', total_dataset.isna().sum().sum())
# Out:
# Number of NaNs: 1782980

# %%
mask = (total_dataset['adep'] == 'BIKF') & (total_dataset['ades'] == 'EGCC') & (total_dataset['aircraft_type'] == 'B38M')
total_dataset.loc[mask]
# Out:
#         adep  ades aircraft_type wtc                           airline  \
# 15090   BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
# 105673  BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
#
#         taxiout_time  flown_distance  track_variation_ARR_100  \
# 15090           10.0             931               106.962873
# 105673          10.0             933                      NaN
#
#         track_variation_DEP_100  track_variation_ENR  ...  Altitude_adep  \
# 15090                       NaN             6.217697  ...             53
# 105673                 0.381966            35.439428  ...             53
#
#         Latitude_ades  Longitude_ades  Altitude_ades  altitude_difference  \
# 15090          53.354          -2.275             79                   26
# 105673         53.354          -2.275             79                   26
#
#            bearing  elevation_gradient  adep_geo_cluster  ades_geo_cluster  \
# 15090   126.071797            0.015728                 0                13
# 105673  126.071797            0.015728                 0                13
#
#             tow
# 15090   59835.0
# 105673      NaN
#
# [2 rows x 78 columns]

# %%
from tqdm import tqdm

num_elems = grouped_dataset.shape[0] * grouped_dataset.shape[1]
count = 0

# Uncomment to use the (adep, ades, aircraft_type) strategy!
# for group, row in tqdm(grouped_dataset.iterrows(), total=grouped_dataset.shape[0]):
#     adep = group[0]
#     ades = group[1]
#     aircraft_type = group[2]
#     mask = (total_dataset['adep'] == adep) & (total_dataset['ades'] == ades) & (total_dataset['aircraft_type'] == aircraft_type)
#     for col, value in row.items():
#         if not pd.isna(value):
#             total_dataset.loc[mask, col] = total_dataset.loc[mask, col].fillna(value)

# %%
mask = (total_dataset['adep'] == 'BIKF') & (total_dataset['ades'] == 'EGCC') & (total_dataset['aircraft_type'] == 'B38M')
total_dataset.loc[mask]
# Out:
#         adep  ades aircraft_type wtc                           airline  \
# 15090   BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
# 105673  BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
#
#         taxiout_time  flown_distance  track_variation_ARR_100  \
# 15090           10.0             931               106.962873
# 105673          10.0             933                      NaN
#
#         track_variation_DEP_100  track_variation_ENR  ...  Altitude_adep  \
# 15090                       NaN             6.217697  ...             53
# 105673                 0.381966            35.439428  ...             53
#
#         Latitude_ades  Longitude_ades  Altitude_ades  altitude_difference  \
# 15090          53.354          -2.275             79                   26
# 105673         53.354          -2.275             79                   26
#
#            bearing  elevation_gradient  adep_geo_cluster  ades_geo_cluster  \
# 15090   126.071797            0.015728                 0                13
# 105673  126.071797            0.015728                 0                13
#
#             tow
# 15090   59835.0
# 105673      NaN
#
# [2 rows x 78 columns]

# %%
print('Number of NaNs:', total_dataset.isna().sum().sum())
# Out:
# Number of NaNs: 1782980

# %%
pd.set_option('display.max_rows', None)

print('Showing proportion of NaNs in the total dataset (challenge + submission):')
print(total_dataset.isna().sum()/total_dataset.shape[0])

pd.reset_option('display.max_rows')

columns_with_nan = total_dataset.columns[total_dataset.isna().sum() > 0]
columns_with_nan = list(columns_with_nan)
columns_with_nan.remove('tow')
print(columns_with_nan)
# Out:
# Showing proportion of NaNs in the total dataset (challenge + submission):
# adep                             0.000000
# ades                             0.000000
# aircraft_type                    0.000000
# wtc                              0.000000
# airline                          0.000000
# taxiout_time                     0.000000
# flown_distance                   0.000000
# track_variation_ARR_100          0.064160
# track_variation_DEP_100          0.150224
# track_variation_ENR              0.137267
# average_vertical_rate_ARR_100    0.064166
# average_vertical_rate_DEP_100    0.150230
# average_vertical_rate_ENR        0.137271
# average_airspeed_ARR_100         0.064859
# average_airspeed_DEP_100         0.150409
# average_airspeed_ENR             0.137275
# groundspeed_ARR_100              0.064160
# groundspeed_DEP_100              0.150224
# groundspeed_ENR                  0.137267
# wind_distance_ARR_100            0.063616
# wind_distance_DEP_100            0.149042
# wind_distance_ENR                0.137263
# average_temperature_ARR_100      0.064421
# average_temperature_DEP_100      0.149773
# average_temperature_ENR          0.137271
# average_humidity_ARR_100         0.064421
# average_humidity_DEP_100         0.149773
# average_humidity_ENR             0.137271
# specific_energy_ARR_100          0.415911
# specific_energy_DEP_100          0.152874
# specific_energy_ENR              0.139756
# flown_distance_ARR_100           0.063616
# flown_distance_DEP_100           0.149042
# flown_distance_ENR               0.137263
# specific_energy                  0.011954
# offblock_hour                    0.000000
# offblock_minute                  0.000000
# offblock_day_of_week             0.000000
# offblock_month                   0.000000
# offblock_week_of_year            0.000000
# offblock_season                  0.000000
# arrival_hour                     0.000000
# arrival_minute                   0.000000
# offblock_to_arrival_duration     0.000000
# is_offblock_weekend              0.000000
# is_offblock_rush_hour            0.000000
# taxi_ratio                       0.000000
# flight_speed                     0.000000
# normalized_taxi_ratio            0.000000
# flight_duration_category         0.000000
# speed_per_distance               0.000000
# cumulative_avg_speed             0.000000
# adep_region                      0.000000
# ades_region                      0.000000
# same_country_flight              0.000000
# same_region_flight               0.000000
# flight_direction                 0.000000
# is_intercontinental              0.000000
# Manufacturer                     0.000000
# Model_FAA                        0.000000
# Physical_Class_Engine            0.000000
# Num_Engines                      0.000000
# Approach_Speed_knot              0.000000
# FAA_Weight                       0.000000
# MTOW_kg                          0.000000
# MALW_kg                          0.000000
# Latitude_adep                    0.000000
# Longitude_adep                   0.000000
# Altitude_adep                    0.000000
# Latitude_ades                    0.000000
# Longitude_ades                   0.000000
# Altitude_ades                    0.000000
# altitude_difference              0.000000
# bearing                          0.000000
# elevation_gradient               0.000000
# adep_geo_cluster                 0.000000
# ades_geo_cluster                 0.000000
# tow                              0.223085
# dtype: float64
# ['track_variation_ARR_100', 'track_variation_DEP_100', 'track_variation_ENR', 'average_vertical_rate_ARR_100', 'average_vertical_rate_DEP_100', 'average_vertical_rate_ENR', 'average_airspeed_ARR_100', 'average_airspeed_DEP_100', 'average_airspeed_ENR', 'groundspeed_ARR_100', 'groundspeed_DEP_100', 'groundspeed_ENR', 'wind_distance_ARR_100', 'wind_distance_DEP_100', 'wind_distance_ENR', 'average_temperature_ARR_100', 'average_temperature_DEP_100', 'average_temperature_ENR', 'average_humidity_ARR_100', 'average_humidity_DEP_100', 'average_humidity_ENR', 'specific_energy_ARR_100', 'specific_energy_DEP_100', 'specific_energy_ENR', 'flown_distance_ARR_100', 'flown_distance_DEP_100', 'flown_distance_ENR', 'specific_energy']

# %%
for col in columns_with_nan:
    total_dataset[col] = total_dataset[col].fillna(mean_values[col])

print('Number of NaNs (with tow):', total_dataset.isna().sum().sum())
print('Number of NaNs (in tow):', total_dataset['tow'].isna().sum())

challenge_set_updated = total_dataset[~total_dataset['tow'].isna()]
submission_set_updated = total_dataset[total_dataset['tow'].isna()]

print('Number of flights in challenge:', challenge_set_updated.shape[0])
print('Number of flights in submission:', submission_set_updated.shape[0])
# Out:
# Number of NaNs (with tow): 105959
# Number of NaNs (in tow): 105959
# Number of flights in challenge: 369013
# Number of flights in submission: 105959

# %%
challenge_set_updated.to_csv('./data/challenge_set_updated_v9_median.csv', index=False)
submission_set_updated.to_csv('./data/submission_set_updated_v9_median.csv', index=False)

# %% [raw]
# # Summary
# v1: sem ICAO
# v2: sem ICAO mas com lat e lon
# v3: com ICAO e lat e lon
# v4: sem ICAO e lat lon alt
# v5: correcao de alguns erros do v4
# v6: inclusao de features do aircraft type
# v7: correção das features de aircraft type
# v8: v7 plus trajectories
# v9: v8 plus imputation using the (adep, ades, aircraft_type) strategy
