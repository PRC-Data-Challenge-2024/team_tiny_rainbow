# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Variables Description
#
# - **flight_id**: A unique identifier assigned to each flight.
# - **date**: The date when the flight took place.
# - **callsign**: The encrypted callsign associated with the flight.
# - **adep**: The code of the departure airport.
# - **name_adep**: The name of the departure airport.
# - **country_code_adep**: The country code of the departure airport.
# - **ades**: The code of the destination airport.
# - **name_ades**: The name of the destination airport.
# - **country_code_ades**: The country code of the destination airport.
# - **actual_offblock_time**: The time when the aircraft started to move from its parking position.
# - **arrival_time**: The time of arrival at the destination airport.
# - **aircraft_type**: The type of aircraft used for the flight.
# - **wtc**: The wake turbulence category of the aircraft.
# - **airline**: The encrypted identifier of the airline operating the flight.
# - **flight_duration**: The duration of the flight in minutes.
# - **taxiout_time**: The time spent taxiing out from the departure airport.
# - **flown_distance**: The distance flown during the flight in kilometers.
# - **tow**: The target variable representing the actual TakeOff Weight (TOW) of the aircraft.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# %% [raw]
# import pandas as pd
#
# # Loading the dataset
# traj = pd.read_csv('./data/trajectory_features.csv')
#
# # Checking for missing values in each column and displaying the result as a DataFrame
# missing_values = traj.isnull().sum()
# missing_values_df = pd.DataFrame(missing_values, columns=['Missing Values'])
# missing_values_df['Percentage'] = (missing_values_df['Missing Values'] / len(traj)) * 100
# missing_values_df

# %%
# Load the datasets
challenge_set_original = pd.read_csv('./data/challenge_set.csv')
submission_set_original = pd.read_csv('./data/submission_set.csv')
trajectories_set = pd.read_csv('./data/trajectory_features.csv')

# Display the first few rows of the datasets to understand their structure
# challenge_set.T

print('number of samples in the challenge set:', challenge_set_original.shape)
print('number of samples in the submission set:', submission_set_original.shape)
print('total number of samples:', challenge_set_original.shape[0] + submission_set_original.shape[0])

print('number of trajectories:', trajectories_set.shape)

challenge_set = trajectories_set[trajectories_set['flight_id'].isin(challenge_set_original['flight_id'])]
submission_set = trajectories_set[trajectories_set['flight_id'].isin(submission_set_original['flight_id'])]

print('number of samples in the challenge set (with trajectories):', challenge_set.shape)
print('number of samples in the submission set (with trajectories):', submission_set.shape)

challenge_set.T
# Out:
# number of samples in the challenge set: (369013, 18)
# number of samples in the submission set: (105959, 18)
# total number of samples: 474972
# number of trajectories: (474162, 49)
# number of samples in the challenge set (with trajectories): (368371, 49)
# number of samples in the submission set (with trajectories): (105791, 49)
#                                                          105791  \
# flight_id                                             248763780
# date                                                 2022-01-01
# callsign                       3840d84f25d3f5fcc0a1be3076bb4039
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       EICK
# name_ades                                                  Cork
# country_code_ades                                            IE
# actual_offblock_time                       2022-01-01T13:46:00Z
# arrival_time                               2022-01-01T15:04:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              61
# taxiout_time                                                 18
# flown_distance                                              321
# tow                                                     54748.0
# track_variation_ARR_100                              124.339907
# track_variation_DEP_40                                39.704139
# track_variation_ENR                                   18.449496
# average_vertical_rate_ARR_100                      -1290.828729
# average_vertical_rate_DEP_40                        1794.412698
# average_vertical_rate_ENR                            577.924812
# average_airspeed_ARR_100                             144.183237
# average_airspeed_DEP_40                              152.698285
# average_airspeed_ENR                                 216.901773
# groundspeed_ARR_100                                  145.300942
# groundspeed_DEP_40                                   147.559687
# groundspeed_ENR                                      188.101807
# wind_distance_ARR_100                               1649.422621
# wind_distance_DEP_40                               -2579.698967
# wind_distance_ENR                                  -45960.80701
# average_temperature_ARR_100                          254.028168
# average_temperature_DEP_40                           271.189236
# average_temperature_ENR                               227.11362
# average_humidity_ARR_100                                0.00232
# average_humidity_DEP_40                                0.003253
# average_humidity_ENR                                   0.000087
# specific_energy_ARR_100                             7185.351086
# specific_energy_DEP_40                             84354.189095
# specific_energy_ENR                               144961.839766
# flown_distance_ARR_100                            209778.210671
# flown_distance_DEP_40                              74129.419615
# flown_distance_ENR                                298889.740138
# average_altitude_ARR_100                           15722.634669
# average_altitude_DEP_40                             9336.656746
# average_altitude_ENR                               30307.033208
# specific_energy                                    40764.557911
#
#                                                          105792  \
# flight_id                                             248760618
# date                                                 2022-01-01
# callsign                       f6f610e73002b8892a239a81321f7f1d
# adep                                                       LEBL
# name_adep                                             Barcelona
# country_code_adep                                            ES
# ades                                                       KMIA
# name_ades                                                 Miami
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:55:00Z
# arrival_time                               2022-01-01T19:37:56Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             570
# taxiout_time                                                 13
# flown_distance                                             4193
# tow                                                    185441.0
# track_variation_ARR_100                               179.31889
# track_variation_DEP_40                                 8.910306
# track_variation_ENR                                   76.492864
# average_vertical_rate_ARR_100                       -858.158167
# average_vertical_rate_DEP_40                        1921.115689
# average_vertical_rate_ENR                             72.139544
# average_airspeed_ARR_100                             123.061357
# average_airspeed_DEP_40                               157.02721
# average_airspeed_ENR                                 227.625592
# groundspeed_ARR_100                                   108.77848
# groundspeed_DEP_40                                   157.229088
# groundspeed_ENR                                      237.382576
# wind_distance_ARR_100                               -666.121285
# wind_distance_DEP_40                                 639.594655
# wind_distance_ENR                                -713130.601964
# average_temperature_ARR_100                          285.745817
# average_temperature_DEP_40                           275.889818
# average_temperature_ENR                              218.690973
# average_humidity_ARR_100                               0.004877
# average_humidity_DEP_40                                 0.00122
# average_humidity_ENR                                   0.000047
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            102511.724141
# specific_energy_ENR                                162541.91571
# flown_distance_ARR_100                            127622.214114
# flown_distance_DEP_40                              99060.878334
# flown_distance_ENR                               6282087.523503
# average_altitude_ARR_100                            5860.162602
# average_altitude_DEP_40                            10091.006339
# average_altitude_ENR                               34803.069293
# specific_energy                                    34908.979058
#
#                                                          105793  \
# flight_id                                             248753824
# date                                                 2022-01-01
# callsign                       139670936660762c230ca92556ba842b
# adep                                                       ESSA
# name_adep                                     Stockholm Arlanda
# country_code_adep                                            SE
# ades                                                       KORD
# name_ades                                        Chicago O'Hare
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:39:00Z
# arrival_time                               2022-01-01T19:08:13Z
# aircraft_type                                              A333
# wtc                                                           H
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             554
# taxiout_time                                                 15
# flown_distance                                             3770
# tow                                                    230396.0
# track_variation_ARR_100                              179.638848
# track_variation_DEP_40                                32.391881
# track_variation_ENR                                   86.835411
# average_vertical_rate_ARR_100                         -808.8576
# average_vertical_rate_DEP_40                        1854.188679
# average_vertical_rate_ENR                             22.304571
# average_airspeed_ARR_100                             132.986114
# average_airspeed_DEP_40                              143.187825
# average_airspeed_ENR                                 198.200087
# groundspeed_ARR_100                                   131.84116
# groundspeed_DEP_40                                   154.339995
# groundspeed_ENR                                       201.15097
# wind_distance_ARR_100                              -2146.656892
# wind_distance_DEP_40                                5921.445204
# wind_distance_ENR                                -830705.381757
# average_temperature_ARR_100                          261.535023
# average_temperature_DEP_40                           260.919502
# average_temperature_ENR                              215.239845
# average_humidity_ARR_100                               0.002227
# average_humidity_DEP_40                                0.000896
# average_humidity_ENR                                   0.000048
# specific_energy_ARR_100                              7645.38543
# specific_energy_DEP_40                             71893.805576
# specific_energy_ENR                                96028.817505
# flown_distance_ARR_100                            240489.668725
# flown_distance_DEP_40                              82036.725936
# flown_distance_ENR                               6688759.718174
# average_altitude_ARR_100                           11309.806667
# average_altitude_DEP_40                             8478.537736
# average_altitude_ENR                               35185.738992
# specific_energy                                    40234.369736
#
#                                                          105794  \
# flight_id                                             248753852
# date                                                 2022-01-01
# callsign                       509dc61bb54fbab0e5406067c95603e2
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       KPHL
# name_ades                                          Philadelphia
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T11:04:00Z
# arrival_time                               2022-01-01T19:32:13Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             497
# taxiout_time                                                 11
# flown_distance                                             3607
# tow                                                    157615.0
# track_variation_ARR_100                                0.208347
# track_variation_DEP_40                                36.998783
# track_variation_ENR                                  101.712676
# average_vertical_rate_ARR_100                       -690.489814
# average_vertical_rate_DEP_40                        2071.919192
# average_vertical_rate_ENR                             24.499965
# average_airspeed_ARR_100                             133.834251
# average_airspeed_DEP_40                              152.487226
# average_airspeed_ENR                                 217.133876
# groundspeed_ARR_100                                  131.727768
# groundspeed_DEP_40                                   154.813867
# groundspeed_ENR                                      226.088664
# wind_distance_ARR_100                              -4825.621679
# wind_distance_DEP_40                                1538.397185
# wind_distance_ENR                                 487198.220628
# average_temperature_ARR_100                           275.85643
# average_temperature_DEP_40                           269.667311
# average_temperature_ENR                              216.198831
# average_humidity_ARR_100                               0.005906
# average_humidity_DEP_40                                0.001463
# average_humidity_ENR                                   0.000061
# specific_energy_ARR_100                             7374.774863
# specific_energy_DEP_40                            110104.238115
# specific_energy_ENR                               114033.745667
# flown_distance_ARR_100                            281179.256823
# flown_distance_DEP_40                              95357.659908
# flown_distance_ENR                               6327140.950315
# average_altitude_ARR_100                            8454.269614
# average_altitude_DEP_40                            11889.225589
# average_altitude_ENR                               37196.623777
# specific_energy                                     26606.90037
#
#                                                          105795  \
# flight_id                                             248755934
# date                                                 2022-01-01
# callsign                       d0610d000dcf26b1d7bba8103ecc393d
# adep                                                       EIDW
# name_adep                                                Dublin
# country_code_adep                                            IE
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T12:36:00Z
# arrival_time                               2022-01-01T13:44:32Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              55
# taxiout_time                                                 14
# flown_distance                                              305
# tow                                                70318.447226
# track_variation_ARR_100                                     NaN
# track_variation_DEP_40                               174.928513
# track_variation_ENR                                    0.620176
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_40                        2796.986408
# average_vertical_rate_ENR                                2128.0
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_40                              178.359962
# average_airspeed_ENR                                 251.911658
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_40                                   181.408937
# groundspeed_ENR                                      239.391839
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_40                                1554.200641
# wind_distance_ENR                                   -526.618231
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_40                           256.327825
# average_temperature_ENR                              230.109324
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_40                                0.001504
# average_humidity_ENR                                   0.000062
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            146321.242136
# specific_energy_ENR                               137882.496272
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_40                              93452.616841
# flown_distance_ENR                                 10255.557891
# average_altitude_ARR_100                                    NaN
# average_altitude_DEP_40                            14424.708738
# average_altitude_ENR                               26051.136364
# specific_energy                                    47630.110708
#
#                                                          105796  \
# flight_id                                             248762583
# date                                                 2022-01-01
# callsign                       e6d5d070016d21108f8bd2bd643202ac
# adep                                                       ENGM
# name_adep                                                  Oslo
# country_code_adep                                            NO
# ades                                                       LEAL
# name_ades                                              Alicante
# country_code_ades                                            ES
# actual_offblock_time                       2022-01-01T10:24:52Z
# arrival_time                               2022-01-01T14:25:33Z
# aircraft_type                                              A20N
# wtc                                                           M
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             214
# taxiout_time                                                 27
# flown_distance                                             1434
# tow                                                     57721.0
# track_variation_ARR_100                              129.426353
# track_variation_DEP_40                                22.836441
# track_variation_ENR                                   16.791489
# average_vertical_rate_ARR_100                      -1240.150104
# average_vertical_rate_DEP_40                        2608.168816
# average_vertical_rate_ENR                             59.139008
# average_airspeed_ARR_100                             156.904584
# average_airspeed_DEP_40                               210.13651
# average_airspeed_ENR                                 219.139608
# groundspeed_ARR_100                                  155.874744
# groundspeed_DEP_40                                   187.612239
# groundspeed_ENR                                       215.95786
# wind_distance_ARR_100                               2251.531005
# wind_distance_DEP_40                               -12695.52564
# wind_distance_ENR                                   7761.574767
# average_temperature_ARR_100                          274.099473
# average_temperature_DEP_40                           243.269267
# average_temperature_ENR                              208.935069
# average_humidity_ARR_100                               0.001318
# average_humidity_DEP_40                                0.000613
# average_humidity_ENR                                    0.00002
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            166430.352523
# specific_energy_ENR                               117382.882797
# flown_distance_ARR_100                            221986.104932
# flown_distance_DEP_40                             118459.253246
# flown_distance_ENR                               2314731.640286
# average_altitude_ARR_100                           10659.398888
# average_altitude_DEP_40                            21073.065651
# average_altitude_ENR                               38100.819241
# specific_energy                                    47657.454385
#
#                                                          105797  \
# flight_id                                             248758528
# date                                                 2022-01-01
# callsign                       1f51e76bb1001c4f9de991288aacb326
# adep                                                       EGAC
# name_adep                                          Belfast City
# country_code_adep                                            GB
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T07:41:00Z
# arrival_time                               2022-01-01T08:48:19Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              57
# taxiout_time                                                 10
# flown_distance                                              295
# tow                                                     56818.0
# track_variation_ARR_100                              156.984462
# track_variation_DEP_40                                82.098135
# track_variation_ENR                                   35.653151
# average_vertical_rate_ARR_100                      -1205.424058
# average_vertical_rate_DEP_40                        2447.385859
# average_vertical_rate_ENR                            470.145867
# average_airspeed_ARR_100                             158.054538
# average_airspeed_DEP_40                              155.573864
# average_airspeed_ENR                                 207.186721
# groundspeed_ARR_100                                  141.498666
# groundspeed_DEP_40                                   146.338013
# groundspeed_ENR                                      203.742753
# wind_distance_ARR_100                                456.412934
# wind_distance_DEP_40                               -4574.243306
# wind_distance_ENR                                  -4308.278361
# average_temperature_ARR_100                          259.257967
# average_temperature_DEP_40                           262.121142
# average_temperature_ENR                              223.388774
# average_humidity_ARR_100                               0.001969
# average_humidity_DEP_40                                0.001869
# average_humidity_ENR                                   0.000068
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            100334.178098
# specific_energy_ENR                               148839.887667
# flown_distance_ARR_100                            232236.705752
# flown_distance_DEP_40                              73811.104041
# flown_distance_ENR                                249078.051733
# average_altitude_ARR_100                           12696.233293
# average_altitude_DEP_40                            13114.545455
# average_altitude_ENR                               31852.613452
# specific_energy                                    51712.505536
#
#                                                          105798  \
# flight_id                                             248752667
# date                                                 2022-01-01
# callsign                       52d1b50f92590b36489a929375be10f6
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LYBE
# name_ades                                              Belgrade
# country_code_ades                                            RS
# actual_offblock_time                       2022-01-01T05:21:00Z
# arrival_time                               2022-01-01T07:05:28Z
# aircraft_type                                              B738
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                              79
# taxiout_time                                                 25
# flown_distance                                              458
# tow                                                     60678.0
# track_variation_ARR_100                               17.706362
# track_variation_DEP_40                               178.849514
# track_variation_ENR                                   41.002189
# average_vertical_rate_ARR_100                      -1371.055794
# average_vertical_rate_DEP_40                        2397.353383
# average_vertical_rate_ENR                             76.526517
# average_airspeed_ARR_100                             121.419076
# average_airspeed_DEP_40                               161.07308
# average_airspeed_ENR                                 216.343525
# groundspeed_ARR_100                                  133.316065
# groundspeed_DEP_40                                   160.253561
# groundspeed_ENR                                      207.316025
# wind_distance_ARR_100                              17484.737342
# wind_distance_DEP_40                                -539.654081
# wind_distance_ENR                                 -23683.482565
# average_temperature_ARR_100                          256.753553
# average_temperature_DEP_40                           260.778654
# average_temperature_ENR                              217.581183
# average_humidity_ARR_100                               0.002688
# average_humidity_DEP_40                                0.002844
# average_humidity_ENR                                   0.000018
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            125930.812543
# specific_energy_ENR                               127799.326482
# flown_distance_ARR_100                            183634.551484
# flown_distance_DEP_40                             110188.415331
# flown_distance_ENR                                542222.441417
# average_altitude_ARR_100                           15043.848355
# average_altitude_DEP_40                            13378.233083
# average_altitude_ENR                               35283.422358
# specific_energy                                    40402.236552
#
#                                                          105799  \
# flight_id                                             248762188
# date                                                 2022-01-01
# callsign                       256265f000acb4a06cd680b3df7c9897
# adep                                                       KLAX
# name_adep                                           Los Angeles
# country_code_adep                                            US
# ades                                                       LTFM
# name_ades                                          iGA Istanbul
# country_code_ades                                            TR
# actual_offblock_time                       2022-01-01T21:26:00Z
# arrival_time                               2022-01-02T09:55:00Z
# aircraft_type                                              B789
# wtc                                                           H
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             739
# taxiout_time                                                 10
# flown_distance                                             6354
# tow                                                    235632.0
# track_variation_ARR_100                               23.829551
# track_variation_DEP_40                                      NaN
# track_variation_ENR                                   99.558897
# average_vertical_rate_ARR_100                      12773.719008
# average_vertical_rate_DEP_40                                NaN
# average_vertical_rate_ENR                            -47.111015
# average_airspeed_ARR_100                              336.38239
# average_airspeed_DEP_40                                     NaN
# average_airspeed_ENR                                 282.767584
# groundspeed_ARR_100                                  340.799221
# groundspeed_DEP_40                                          NaN
# groundspeed_ENR                                      278.505289
# wind_distance_ARR_100                               8522.729263
# wind_distance_DEP_40                                        NaN
# wind_distance_ENR                                -213346.488345
# average_temperature_ARR_100                          262.078614
# average_temperature_DEP_40                                  NaN
# average_temperature_ENR                              216.352822
# average_humidity_ARR_100                               0.002507
# average_humidity_DEP_40                                     NaN
# average_humidity_ENR                                   0.000013
# specific_energy_ARR_100                            303185.89023
# specific_energy_DEP_40                                      NaN
# specific_energy_ENR                               135551.837481
# flown_distance_ARR_100                            245174.718293
# flown_distance_DEP_40                                       NaN
# flown_distance_ENR                              10180076.619312
# average_altitude_ARR_100                           12134.090909
# average_altitude_DEP_40                                     NaN
# average_altitude_ENR                               37288.354273
# specific_energy                                             NaN
#
#                                                          105800  ...  \
# flight_id                                             248753189  ...
# date                                                 2022-01-01  ...
# callsign                       8191fa049d6f1a6cb432a98d97bf960c  ...
# adep                                                       LTFM  ...
# name_adep                                          iGA Istanbul  ...
# country_code_adep                                            TR  ...
# ades                                                       LTAC  ...
# name_ades                                                Ankara  ...
# country_code_ades                                            TR  ...
# actual_offblock_time                       2022-01-01T15:00:00Z  ...
# arrival_time                               2022-01-01T16:09:00Z  ...
# aircraft_type                                              A321  ...
# wtc                                                           M  ...
# airline                        6351ec1b849adacc0cbb3b1313d8d39b  ...
# flight_duration                                              44  ...
# taxiout_time                                                 25  ...
# flown_distance                                              257  ...
# tow                                                     73571.0  ...
# track_variation_ARR_100                              119.350942  ...
# track_variation_DEP_40                                      NaN  ...
# track_variation_ENR                                         NaN  ...
# average_vertical_rate_ARR_100                       -654.951792  ...
# average_vertical_rate_DEP_40                                NaN  ...
# average_vertical_rate_ENR                                   NaN  ...
# average_airspeed_ARR_100                             101.215431  ...
# average_airspeed_DEP_40                                     NaN  ...
# average_airspeed_ENR                                        NaN  ...
# groundspeed_ARR_100                                  100.549956  ...
# groundspeed_DEP_40                                          NaN  ...
# groundspeed_ENR                                             NaN  ...
# wind_distance_ARR_100                                -540.74267  ...
# wind_distance_DEP_40                                        NaN  ...
# wind_distance_ENR                                           NaN  ...
# average_temperature_ARR_100                          274.784833  ...
# average_temperature_DEP_40                                  NaN  ...
# average_temperature_ENR                                     NaN  ...
# average_humidity_ARR_100                               0.004571  ...
# average_humidity_DEP_40                                     NaN  ...
# average_humidity_ENR                                        NaN  ...
# specific_energy_ARR_100                            15977.826605  ...
# specific_energy_DEP_40                                      NaN  ...
# specific_energy_ENR                                         NaN  ...
# flown_distance_ARR_100                             53914.394348  ...
# flown_distance_DEP_40                                       NaN  ...
# flown_distance_ENR                                          NaN  ...
# average_altitude_ARR_100                            5252.163164  ...
# average_altitude_DEP_40                                     NaN  ...
# average_altitude_ENR                                        NaN  ...
# specific_energy                                             NaN  ...
#
#                                                          474152  \
# flight_id                                             258072846
# date                                                 2022-12-31
# callsign                       5ea802e68573752dc98d7623d897a915
# adep                                                       LIRF
# name_adep                                        Rome Fiumicino
# country_code_adep                                            IT
# ades                                                       EBBR
# name_ades                                              Brussels
# country_code_ades                                            BE
# actual_offblock_time                       2022-12-31T09:47:00Z
# arrival_time                               2022-12-31T11:58:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        bdeeef3a675587d530de70a25d7118d2
# flight_duration                                             114
# taxiout_time                                                 18
# flown_distance                                              726
# tow                                                61804.035897
# track_variation_ARR_100                               41.225296
# track_variation_DEP_40                               107.075354
# track_variation_ENR                                   86.102977
# average_vertical_rate_ARR_100                       -944.935673
# average_vertical_rate_DEP_40                        1910.291417
# average_vertical_rate_ENR                             58.349503
# average_airspeed_ARR_100                             122.967444
# average_airspeed_DEP_40                              156.178417
# average_airspeed_ENR                                 218.387572
# groundspeed_ARR_100                                  136.581686
# groundspeed_DEP_40                                    155.84162
# groundspeed_ENR                                      212.901819
# wind_distance_ARR_100                              20658.403766
# wind_distance_DEP_40                                -167.728228
# wind_distance_ENR                                 -27009.830839
# average_temperature_ARR_100                          269.844926
# average_temperature_DEP_40                           273.239045
# average_temperature_ENR                              219.907415
# average_humidity_ARR_100                               0.004583
# average_humidity_DEP_40                                0.003602
# average_humidity_ENR                                   0.000101
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                             99560.798708
# specific_energy_ENR                               112667.709633
# flown_distance_ARR_100                            185953.716431
# flown_distance_DEP_40                              78136.379016
# flown_distance_ENR                               1048177.464189
# average_altitude_ARR_100                           10151.461988
# average_altitude_DEP_40                             9292.065868
# average_altitude_ENR                               33406.129491
# specific_energy                                    39327.802637
#
#                                                          474153  \
# flight_id                                             258057853
# date                                                 2022-12-31
# callsign                       b1de87e85987c58b0d29fa4e72e3f961
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       LSZH
# name_ades                                                Zurich
# country_code_ades                                            CH
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:14:52Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                              64
# taxiout_time                                                 19
# flown_distance                                              449
# tow                                                     72756.0
# track_variation_ARR_100                               64.982306
# track_variation_DEP_40                               174.578445
# track_variation_ENR                                   59.919141
# average_vertical_rate_ARR_100                      -1914.656126
# average_vertical_rate_DEP_40                        1356.238596
# average_vertical_rate_ENR                            528.036782
# average_airspeed_ARR_100                             185.484428
# average_airspeed_DEP_40                              174.000327
# average_airspeed_ENR                                 263.703285
# groundspeed_ARR_100                                  189.635394
# groundspeed_DEP_40                                   160.740284
# groundspeed_ENR                                      255.580037
# wind_distance_ARR_100                               4185.016755
# wind_distance_DEP_40                               -4808.856518
# wind_distance_ENR                                 -17689.590424
# average_temperature_ARR_100                          262.471594
# average_temperature_DEP_40                           273.819874
# average_temperature_ENR                              219.745981
# average_humidity_ARR_100                               0.002745
# average_humidity_DEP_40                                0.004649
# average_humidity_ENR                                   0.000201
# specific_energy_ARR_100                             8661.139522
# specific_energy_DEP_40                             90255.057531
# specific_energy_ENR                               149197.949384
# flown_distance_ARR_100                            192268.438483
# flown_distance_DEP_40                              91577.807082
# flown_distance_ENR                                553274.231706
# average_altitude_ARR_100                           14556.311759
# average_altitude_DEP_40                             7840.087719
# average_altitude_ENR                                33185.45977
# specific_energy                                    48007.663607
#
#                                                          474154  \
# flight_id                                             258071492
# date                                                 2022-12-31
# callsign                       49c815d2ca2e8c50b01473b12fd30119
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LIMC
# name_ades                                        Milan Malpensa
# country_code_ades                                            IT
# actual_offblock_time                       2022-12-31T09:34:00Z
# arrival_time                               2022-12-31T12:28:54Z
# aircraft_type                                              A321
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             150
# taxiout_time                                                 25
# flown_distance                                              975
# tow                                                     73571.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_40                                 0.397226
# track_variation_ENR                                   25.211864
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_40                        2105.462932
# average_vertical_rate_ENR                              9.018068
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_40                              162.008747
# average_airspeed_ENR                                 219.210967
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_40                                   163.950845
# groundspeed_ENR                                      218.631224
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_40                                1182.816014
# wind_distance_ENR                                   -6586.94011
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_40                           261.892455
# average_temperature_ENR                              213.342527
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_40                                0.001391
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            109727.021482
# specific_energy_ENR                               128044.533554
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_40                              99073.086322
# flown_distance_ENR                                1438706.43647
# average_altitude_ARR_100                                    NaN
# average_altitude_DEP_40                            12195.057661
# average_altitude_ENR                               35357.420954
# specific_energy                                    39340.477809
#
#                                                          474155  \
# flight_id                                             258060782
# date                                                 2022-12-31
# callsign                       92eba53fed3c3914105be1de666ca203
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       LGTS
# name_ades                                          Thessaloniki
# country_code_ades                                            GR
# actual_offblock_time                       2022-12-31T09:39:00Z
# arrival_time                               2022-12-31T11:36:58Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                             109
# taxiout_time                                                  9
# flown_distance                                              782
# tow                                                     64826.0
# track_variation_ARR_100                               38.212132
# track_variation_DEP_40                                      NaN
# track_variation_ENR                                   28.434073
# average_vertical_rate_ARR_100                      -1419.209393
# average_vertical_rate_DEP_40                                NaN
# average_vertical_rate_ENR                            204.536816
# average_airspeed_ARR_100                             162.150949
# average_airspeed_DEP_40                                     NaN
# average_airspeed_ENR                                 247.885193
# groundspeed_ARR_100                                  154.424813
# groundspeed_DEP_40                                          NaN
# groundspeed_ENR                                      244.059867
# wind_distance_ARR_100                              -1881.251514
# wind_distance_DEP_40                                        NaN
# wind_distance_ENR                                 -13775.580985
# average_temperature_ARR_100                          266.685247
# average_temperature_DEP_40                                  NaN
# average_temperature_ENR                              217.412211
# average_humidity_ARR_100                               0.002165
# average_humidity_DEP_40                                     NaN
# average_humidity_ENR                                   0.000049
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                                      NaN
# specific_energy_ENR                               155190.109141
# flown_distance_ARR_100                            154850.236264
# flown_distance_DEP_40                                       NaN
# flown_distance_ENR                                874431.280266
# average_altitude_ARR_100                             9977.39726
# average_altitude_DEP_40                                     NaN
# average_altitude_ENR                               33976.069742
# specific_energy                                             NaN
#
#                                                          474156  \
# flight_id                                             258067496
# date                                                 2022-12-31
# callsign                       80e0832fdc79cbba84dff5e9e06bb883
# adep                                                       EDDV
# name_adep                                               Hanover
# country_code_adep                                            DE
# ...
# arrival_time                               2022-12-31T19:03:48Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             545
# taxiout_time                                                 21
# flown_distance                                             4046
# tow                                                    163438.0
# track_variation_ARR_100                              174.768738
# track_variation_DEP_40                                 5.640549
# track_variation_ENR                                    5.110034
# average_vertical_rate_ARR_100                        -957.19801
# average_vertical_rate_DEP_40                        2076.337711
# average_vertical_rate_ENR                            109.133345
# average_airspeed_ARR_100                             120.477436
# average_airspeed_DEP_40                              114.565121
# average_airspeed_ENR                                 168.347139
# groundspeed_ARR_100                                   104.43162
# groundspeed_DEP_40                                   138.455895
# groundspeed_ENR                                      199.474993
# wind_distance_ARR_100                              -1128.929527
# wind_distance_DEP_40                               12724.142049
# wind_distance_ENR                                 103721.478012
# average_temperature_ARR_100                          287.071524
# average_temperature_DEP_40                           269.632091
# average_temperature_ENR                              219.608346
# average_humidity_ARR_100                               0.007733
# average_humidity_DEP_40                                0.003773
# average_humidity_ENR                                   0.000079
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                             82051.456723
# specific_energy_ENR                               116846.850647
# flown_distance_ARR_100                             82920.116565
# flown_distance_DEP_40                              72874.882709
# flown_distance_ENR                                805578.573789
# average_altitude_ARR_100                            4303.880597
# average_altitude_DEP_40                            10943.949343
# average_altitude_ENR                               33277.819044
# specific_energy                                    37501.849179
#
#                                                          474158  \
# flight_id                                             258071247
# date                                                 2022-12-31
# callsign                       570cf7d5ebbd691bcba63e7466607da7
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       EDDB
# name_ades                                    Berlin Brandenburg
# country_code_ades                                            DE
# actual_offblock_time                       2022-12-31T09:27:00Z
# arrival_time                               2022-12-31T12:29:41Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             158
# taxiout_time                                                 25
# flown_distance                                              946
# tow                                                     78707.0
# track_variation_ARR_100                                62.54495
# track_variation_DEP_40                                 7.287586
# track_variation_ENR                                   26.244336
# average_vertical_rate_ARR_100                       -986.942529
# average_vertical_rate_DEP_40                        1687.940741
# average_vertical_rate_ENR                             58.375973
# average_airspeed_ARR_100                              130.21441
# average_airspeed_DEP_40                              198.594316
# average_airspeed_ENR                                 195.389197
# groundspeed_ARR_100                                  108.757847
# groundspeed_DEP_40                                   194.865671
# groundspeed_ENR                                      198.916582
# wind_distance_ARR_100                             -43244.289956
# wind_distance_DEP_40                               -1001.164596
# wind_distance_ENR                                  19637.741161
# average_temperature_ARR_100                           247.62106
# average_temperature_DEP_40                           246.646298
# average_temperature_ENR                              216.672887
# average_humidity_ARR_100                               0.002573
# average_humidity_DEP_40                                0.000193
# average_humidity_ENR                                   0.000038
# specific_energy_ARR_100                           112914.102878
# specific_energy_DEP_40                            113137.164423
# specific_energy_ENR                               140217.805342
# flown_distance_ARR_100                            195902.336116
# flown_distance_DEP_40                               52213.69603
# flown_distance_ENR                               1440900.848184
# average_altitude_ARR_100                           20225.634579
# average_altitude_DEP_40                            19776.296296
# average_altitude_ENR                               33741.142937
# specific_energy                                    95013.649249
#
#                                                          474159  \
# flight_id                                             258059152
# date                                                 2022-12-31
# callsign                       5a7e43e4f981539ae3d3b1cb31591b7c
# adep                                                       EDDL
# name_adep                                            Dusseldorf
# country_code_adep                                            DE
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:41:51Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              99
# taxiout_time                                                 11
# flown_distance                                              522
# tow                                                    62942.75
# track_variation_ARR_100                               43.910303
# track_variation_DEP_40                                18.479277
# track_variation_ENR                                   19.499181
# average_vertical_rate_ARR_100                      -1553.085546
# average_vertical_rate_DEP_40                        1887.600713
# average_vertical_rate_ENR                            199.908984
# average_airspeed_ARR_100                             146.688552
# average_airspeed_DEP_40                              149.765418
# average_airspeed_ENR                                 205.309589
# groundspeed_ARR_100                                  141.830997
# groundspeed_DEP_40                                   140.976913
# groundspeed_ENR                                      169.654912
# wind_distance_ARR_100                              -6565.814124
# wind_distance_DEP_40                               -4919.055085
# wind_distance_ENR                                -120485.552766
# average_temperature_ARR_100                          250.020435
# average_temperature_DEP_40                           267.916932
# average_temperature_ENR                              213.551798
# average_humidity_ARR_100                               0.002255
# average_humidity_DEP_40                                0.003832
# average_humidity_ENR                                    0.00007
# specific_energy_ARR_100                             8583.364417
# specific_energy_DEP_40                             73808.131433
# specific_energy_ENR                               141243.406835
# flown_distance_ARR_100                            191389.813534
# flown_distance_DEP_40                               87313.70912
# flown_distance_ENR                                676211.797334
# average_altitude_ARR_100                           17019.561209
# average_altitude_DEP_40                            11507.932264
# average_altitude_ENR                               34729.977442
# specific_energy                                    30173.184666
#
#                                                          474160  \
# flight_id                                             258072276
# date                                                 2022-12-31
# callsign                       a1c078516f9f9e90cacec61854cad45b
# adep                                                       LFPG
# name_adep                               Paris Charles de Gaulle
# country_code_adep                                            FR
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:37:00Z
# arrival_time                               2022-12-31T11:13:10Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              84
# taxiout_time                                                 12
# flown_distance                                              466
# tow                                                72611.161024
# track_variation_ARR_100                               48.439184
# track_variation_DEP_40                                      NaN
# track_variation_ENR                                   64.144324
# average_vertical_rate_ARR_100                      -1356.236589
# average_vertical_rate_DEP_40                                NaN
# average_vertical_rate_ENR                            194.472013
# average_airspeed_ARR_100                             139.084419
# average_airspeed_DEP_40                                     NaN
# average_airspeed_ENR                                 195.408968
# groundspeed_ARR_100                                  135.403147
# groundspeed_DEP_40                                          NaN
# groundspeed_ENR                                      184.041878
# wind_distance_ARR_100                             -17444.119009
# wind_distance_DEP_40                                        NaN
# wind_distance_ENR                                  -31588.15396
# average_temperature_ARR_100                          255.247801
# average_temperature_DEP_40                                  NaN
# average_temperature_ENR                              214.239339
# average_humidity_ARR_100                               0.002342
# average_humidity_DEP_40                                     NaN
# average_humidity_ENR                                   0.000047
# specific_energy_ARR_100                           112926.042185
# specific_energy_DEP_40                                      NaN
# specific_energy_ENR                               119424.098697
# flown_distance_ARR_100                            189059.726253
# flown_distance_DEP_40                                       NaN
# flown_distance_ENR                                560710.775683
# average_altitude_ARR_100                           15045.197753
# average_altitude_DEP_40                                     NaN
# average_altitude_ENR                               35017.422259
# specific_energy                                             NaN
#
#                                                          474161
# flight_id                                             258069969
# date                                                 2022-12-31
# callsign                       6c98fcaa191dec632b87b46511f1d2da
# adep                                                       LEMD
# name_adep                                        Madrid Barajas
# country_code_adep                                            ES
# ades                                                       KJFK
# name_ades                                          New York JFK
# country_code_ades                                            US
# actual_offblock_time                       2022-12-31T09:38:00Z
# arrival_time                               2022-12-31T17:26:35Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             453
# taxiout_time                                                 16
# flown_distance                                             3213
# tow                                                    195373.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_40                                 0.612683
# track_variation_ENR                                   23.802205
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_40                        2283.906977
# average_vertical_rate_ENR                            302.315789
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_40                                208.4603
# average_airspeed_ENR                                 223.129874
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_40                                   193.517682
# groundspeed_ENR                                      234.129481
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_40                                -2561.43598
# wind_distance_ENR                                  37636.609741
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_40                           264.101201
# average_temperature_ENR                              219.981772
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_40                                0.000264
# average_humidity_ENR                                    0.00004
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            103786.584976
# specific_energy_ENR                               147639.900205
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_40                              33133.293615
# flown_distance_ENR                                731187.010808
# average_altitude_ARR_100                                    NaN
# average_altitude_DEP_40                            15128.633721
# average_altitude_ENR                               33950.738304
# specific_energy                                    91461.232681
#
# [49 rows x 368371 columns]

# %%
# Summary statistics of the challenge set
challenge_summary = challenge_set.describe()

# Check for missing values
missing_values = challenge_set.isnull().sum()

# Correlation matrix to check relationships between numerical features
correlation_matrix = challenge_set.corr(numeric_only=True)

# Plotting the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Challenge Set')
plt.show()

# Display the summary statistics and missing values
challenge_summary, missing_values
# Out:
# (          flight_id  flight_duration   taxiout_time  flown_distance  \
#  count  3.683710e+05    368371.000000  368371.000000   368371.000000
#  mean   2.535221e+08       145.962049      13.490858     1022.422902
#  std    2.688971e+06       139.415997       5.780621     1128.832563
#  min    2.487506e+08         8.000000       0.000000       19.000000
#  25%    2.512290e+08        59.000000      10.000000      338.000000
#  50%    2.536200e+08       100.000000      12.000000      648.000000
#  75%    2.559066e+08       164.000000      16.000000     1114.000000
#  max    2.580745e+08      1013.000000      90.000000     7272.000000
#
#                   tow  track_variation_ARR_100  track_variation_DEP_40  \
#  count  368371.000000            344953.000000           308844.000000
#  mean    79511.807653                74.451965               70.607768
#  std     53280.808626                57.408515               53.305970
#  min     14944.000000                 0.000000                0.000000
#  25%     55836.000000                24.303922               25.523426
#  50%     63852.000000                59.945523               57.510864
#  75%     73756.000000               124.180948              114.296709
#  max    351327.000000               180.000000              180.000000
#
#         track_variation_ENR  average_vertical_rate_ARR_100  \
#  count        339923.000000                  344950.000000
#  mean             32.640811                   -1214.532871
#  std              28.915224                    1257.372074
#  min               0.000000                 -116470.787234
#  25%              10.098077                   -1393.579890
#  50%              27.069933                   -1197.617822
#  75%              46.032811                    -984.500952
#  max             179.925209                   31131.539229
#
#         average_vertical_rate_DEP_40  ...  specific_energy_ARR_100  \
#  count                 308843.000000  ...            213104.000000
#  mean                    2218.441553  ...             24832.879559
#  std                     1728.012090  ...             35081.593464
#  min                   -22391.562095  ...              1124.682402
#  25%                     1947.452687  ...              6587.776530
#  50%                     2173.308958  ...              8589.139183
#  75%                     2426.087868  ...             20707.212331
#  max                   154417.926724  ...            578911.211053
#
#         specific_energy_DEP_40  specific_energy_ENR  flown_distance_ARR_100  \
#  count           306514.000000         3.389960e+05            3.449960e+05
#  mean            103536.537442         1.400761e+05            2.113318e+05
#  std              17146.907123         2.226226e+04            5.402649e+04
#  min               2688.469483         3.924830e+03            0.000000e+00
#  25%              94054.668337         1.277284e+05            1.921849e+05
#  50%             103357.917100         1.418861e+05            2.128515e+05
#  75%             113580.545184         1.541288e+05            2.368049e+05
#  max             632328.487483         2.600022e+06            3.583737e+06
#
#         flown_distance_DEP_40  flown_distance_ENR  average_altitude_ARR_100  \
#  count           3.089150e+05        3.399240e+05             344996.000000
#  mean            8.307967e+04        1.461926e+06              12553.548910
#  std             3.659178e+04        1.972177e+06               3594.645250
#  min             0.000000e+00        0.000000e+00               -483.482143
#  25%             7.402635e+04        3.097275e+05              10727.788424
#  50%             8.138903e+04        7.810875e+05              12488.071742
#  75%             9.198451e+04        1.588639e+06              14161.428390
#  max             1.785795e+07        7.229291e+07              85290.185547
#
#         average_altitude_DEP_40  average_altitude_ENR  specific_energy
#  count            308915.000000         339924.000000    306101.000000
#  mean              11381.172613          33277.502060     43108.305905
#  std                2645.498994           4123.223160      9804.962483
#  min                -525.000000            156.777778      3654.440984
#  25%                9814.957264          31714.025192     37979.500581
#  50%               11179.516807          34092.765501     41757.399511
#  75%               12760.584484          36000.000000     46379.412739
#  max              106124.836957          67301.552548    312432.656009
#
#  [8 rows x 36 columns],
#  flight_id                             0
#  date                                  0
#  callsign                              0
#  adep                                  0
#  name_adep                             0
#  country_code_adep                     0
#  ades                                  0
#  name_ades                             0
#  country_code_ades                     0
#  actual_offblock_time                  0
#  arrival_time                          0
#  aircraft_type                         0
#  wtc                                   0
#  airline                               0
#  flight_duration                       0
#  taxiout_time                          0
#  flown_distance                        0
#  tow                                   0
#  track_variation_ARR_100           23418
#  track_variation_DEP_40            59527
#  track_variation_ENR               28448
#  average_vertical_rate_ARR_100     23421
#  average_vertical_rate_DEP_40      59528
#  average_vertical_rate_ENR         28450
#  average_airspeed_ARR_100          23604
#  average_airspeed_DEP_40           59593
#  average_airspeed_ENR              28456
#  groundspeed_ARR_100               23418
#  groundspeed_DEP_40                59527
#  groundspeed_ENR                   28448
#  wind_distance_ARR_100             23375
#  wind_distance_DEP_40              59456
#  wind_distance_ENR                 28447
#  average_temperature_ARR_100       23568
#  average_temperature_DEP_40        59558
#  average_temperature_ENR           28455
#  average_humidity_ARR_100          23568
#  average_humidity_DEP_40           59558
#  average_humidity_ENR              28455
#  specific_energy_ARR_100          155267
#  specific_energy_DEP_40            61857
#  specific_energy_ENR               29375
#  flown_distance_ARR_100            23375
#  flown_distance_DEP_40             59456
#  flown_distance_ENR                28447
#  average_altitude_ARR_100          23375
#  average_altitude_DEP_40           59456
#  average_altitude_ENR              28447
#  specific_energy                   62270
#  dtype: int64)

# %%
# Checking for outliers in numerical features using box plots
numerical_features = ['flight_duration', 'taxiout_time', 'flown_distance', 'tow']

plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=challenge_set[feature])
    plt.title(f'Box Plot of {feature}')
plt.tight_layout()
plt.show()

# Identifying outliers using the Interquartile Range (IQR) method
outliers_info = {}
for feature in numerical_features:
    Q1 = challenge_set[feature].quantile(0.25)
    Q3 = challenge_set[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identifying outliers
    outliers = challenge_set[(challenge_set[feature] < lower_bound) | (challenge_set[feature] > upper_bound)]
    outliers_info[feature] = len(outliers)

# Displaying the count of outliers for each feature
outliers_info

# # Removing outliers using the IQR threshold
# def remove_outliers(df, features):
#     for feature in features:
#         Q1 = df[feature].quantile(0.25)
#         Q3 = df[feature].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         df = df[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]
#     return df

# # Remove outliers from the challenge set
# cleaned_challenge_set = remove_outliers(challenge_set, numerical_features)

# # Checking the shape of the dataset after outlier removal
# initial_count = len(challenge_set)
# cleaned_count = len(cleaned_challenge_set)

# initial_count, cleaned_count, cleaned_challenge_set.describe()
# Out:
# {'flight_duration': 40809,
#  'taxiout_time': 10500,
#  'flown_distance': 41037,
#  'tow': 61119}

# %%
challenge_set.T
# Out:
#                                                          105791  \
# flight_id                                             248763780
# date                                                 2022-01-01
# callsign                       3840d84f25d3f5fcc0a1be3076bb4039
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       EICK
# name_ades                                                  Cork
# country_code_ades                                            IE
# actual_offblock_time                       2022-01-01T13:46:00Z
# arrival_time                               2022-01-01T15:04:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              61
# taxiout_time                                                 18
# flown_distance                                              321
# tow                                                     54748.0
# track_variation_ARR_100                              124.339907
# track_variation_DEP_40                                39.704139
# track_variation_ENR                                   18.449496
# average_vertical_rate_ARR_100                      -1290.828729
# average_vertical_rate_DEP_40                        1794.412698
# average_vertical_rate_ENR                            577.924812
# average_airspeed_ARR_100                             144.183237
# average_airspeed_DEP_40                              152.698285
# average_airspeed_ENR                                 216.901773
# groundspeed_ARR_100                                  145.300942
# groundspeed_DEP_40                                   147.559687
# groundspeed_ENR                                      188.101807
# wind_distance_ARR_100                               1649.422621
# wind_distance_DEP_40                               -2579.698967
# wind_distance_ENR                                  -45960.80701
# average_temperature_ARR_100                          254.028168
# average_temperature_DEP_40                           271.189236
# average_temperature_ENR                               227.11362
# average_humidity_ARR_100                                0.00232
# average_humidity_DEP_40                                0.003253
# average_humidity_ENR                                   0.000087
# specific_energy_ARR_100                             7185.351086
# specific_energy_DEP_40                             84354.189095
# specific_energy_ENR                               144961.839766
# flown_distance_ARR_100                            209778.210671
# flown_distance_DEP_40                              74129.419615
# flown_distance_ENR                                298889.740138
# average_altitude_ARR_100                           15722.634669
# average_altitude_DEP_40                             9336.656746
# average_altitude_ENR                               30307.033208
# specific_energy                                    40764.557911
#
#                                                          105792  \
# flight_id                                             248760618
# date                                                 2022-01-01
# callsign                       f6f610e73002b8892a239a81321f7f1d
# adep                                                       LEBL
# name_adep                                             Barcelona
# country_code_adep                                            ES
# ades                                                       KMIA
# name_ades                                                 Miami
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:55:00Z
# arrival_time                               2022-01-01T19:37:56Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             570
# taxiout_time                                                 13
# flown_distance                                             4193
# tow                                                    185441.0
# track_variation_ARR_100                               179.31889
# track_variation_DEP_40                                 8.910306
# track_variation_ENR                                   76.492864
# average_vertical_rate_ARR_100                       -858.158167
# average_vertical_rate_DEP_40                        1921.115689
# average_vertical_rate_ENR                             72.139544
# average_airspeed_ARR_100                             123.061357
# average_airspeed_DEP_40                               157.02721
# average_airspeed_ENR                                 227.625592
# groundspeed_ARR_100                                   108.77848
# groundspeed_DEP_40                                   157.229088
# groundspeed_ENR                                      237.382576
# wind_distance_ARR_100                               -666.121285
# wind_distance_DEP_40                                 639.594655
# wind_distance_ENR                                -713130.601964
# average_temperature_ARR_100                          285.745817
# average_temperature_DEP_40                           275.889818
# average_temperature_ENR                              218.690973
# average_humidity_ARR_100                               0.004877
# average_humidity_DEP_40                                 0.00122
# average_humidity_ENR                                   0.000047
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            102511.724141
# specific_energy_ENR                                162541.91571
# flown_distance_ARR_100                            127622.214114
# flown_distance_DEP_40                              99060.878334
# flown_distance_ENR                               6282087.523503
# average_altitude_ARR_100                            5860.162602
# average_altitude_DEP_40                            10091.006339
# average_altitude_ENR                               34803.069293
# specific_energy                                    34908.979058
#
#                                                          105793  \
# flight_id                                             248753824
# date                                                 2022-01-01
# callsign                       139670936660762c230ca92556ba842b
# adep                                                       ESSA
# name_adep                                     Stockholm Arlanda
# country_code_adep                                            SE
# ades                                                       KORD
# name_ades                                        Chicago O'Hare
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T09:39:00Z
# arrival_time                               2022-01-01T19:08:13Z
# aircraft_type                                              A333
# wtc                                                           H
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             554
# taxiout_time                                                 15
# flown_distance                                             3770
# tow                                                    230396.0
# track_variation_ARR_100                              179.638848
# track_variation_DEP_40                                32.391881
# track_variation_ENR                                   86.835411
# average_vertical_rate_ARR_100                         -808.8576
# average_vertical_rate_DEP_40                        1854.188679
# average_vertical_rate_ENR                             22.304571
# average_airspeed_ARR_100                             132.986114
# average_airspeed_DEP_40                              143.187825
# average_airspeed_ENR                                 198.200087
# groundspeed_ARR_100                                   131.84116
# groundspeed_DEP_40                                   154.339995
# groundspeed_ENR                                       201.15097
# wind_distance_ARR_100                              -2146.656892
# wind_distance_DEP_40                                5921.445204
# wind_distance_ENR                                -830705.381757
# average_temperature_ARR_100                          261.535023
# average_temperature_DEP_40                           260.919502
# average_temperature_ENR                              215.239845
# average_humidity_ARR_100                               0.002227
# average_humidity_DEP_40                                0.000896
# average_humidity_ENR                                   0.000048
# specific_energy_ARR_100                              7645.38543
# specific_energy_DEP_40                             71893.805576
# specific_energy_ENR                                96028.817505
# flown_distance_ARR_100                            240489.668725
# flown_distance_DEP_40                              82036.725936
# flown_distance_ENR                               6688759.718174
# average_altitude_ARR_100                           11309.806667
# average_altitude_DEP_40                             8478.537736
# average_altitude_ENR                               35185.738992
# specific_energy                                    40234.369736
#
#                                                          105794  \
# flight_id                                             248753852
# date                                                 2022-01-01
# callsign                       509dc61bb54fbab0e5406067c95603e2
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       KPHL
# name_ades                                          Philadelphia
# country_code_ades                                            US
# actual_offblock_time                       2022-01-01T11:04:00Z
# arrival_time                               2022-01-01T19:32:13Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             497
# taxiout_time                                                 11
# flown_distance                                             3607
# tow                                                    157615.0
# track_variation_ARR_100                                0.208347
# track_variation_DEP_40                                36.998783
# track_variation_ENR                                  101.712676
# average_vertical_rate_ARR_100                       -690.489814
# average_vertical_rate_DEP_40                        2071.919192
# average_vertical_rate_ENR                             24.499965
# average_airspeed_ARR_100                             133.834251
# average_airspeed_DEP_40                              152.487226
# average_airspeed_ENR                                 217.133876
# groundspeed_ARR_100                                  131.727768
# groundspeed_DEP_40                                   154.813867
# groundspeed_ENR                                      226.088664
# wind_distance_ARR_100                              -4825.621679
# wind_distance_DEP_40                                1538.397185
# wind_distance_ENR                                 487198.220628
# average_temperature_ARR_100                           275.85643
# average_temperature_DEP_40                           269.667311
# average_temperature_ENR                              216.198831
# average_humidity_ARR_100                               0.005906
# average_humidity_DEP_40                                0.001463
# average_humidity_ENR                                   0.000061
# specific_energy_ARR_100                             7374.774863
# specific_energy_DEP_40                            110104.238115
# specific_energy_ENR                               114033.745667
# flown_distance_ARR_100                            281179.256823
# flown_distance_DEP_40                              95357.659908
# flown_distance_ENR                               6327140.950315
# average_altitude_ARR_100                            8454.269614
# average_altitude_DEP_40                            11889.225589
# average_altitude_ENR                               37196.623777
# specific_energy                                     26606.90037
#
#                                                          105795  \
# flight_id                                             248755934
# date                                                 2022-01-01
# callsign                       d0610d000dcf26b1d7bba8103ecc393d
# adep                                                       EIDW
# name_adep                                                Dublin
# country_code_adep                                            IE
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T12:36:00Z
# arrival_time                               2022-01-01T13:44:32Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              55
# taxiout_time                                                 14
# flown_distance                                              305
# tow                                                70318.447226
# track_variation_ARR_100                                     NaN
# track_variation_DEP_40                               174.928513
# track_variation_ENR                                    0.620176
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_40                        2796.986408
# average_vertical_rate_ENR                                2128.0
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_40                              178.359962
# average_airspeed_ENR                                 251.911658
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_40                                   181.408937
# groundspeed_ENR                                      239.391839
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_40                                1554.200641
# wind_distance_ENR                                   -526.618231
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_40                           256.327825
# average_temperature_ENR                              230.109324
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_40                                0.001504
# average_humidity_ENR                                   0.000062
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            146321.242136
# specific_energy_ENR                               137882.496272
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_40                              93452.616841
# flown_distance_ENR                                 10255.557891
# average_altitude_ARR_100                                    NaN
# average_altitude_DEP_40                            14424.708738
# average_altitude_ENR                               26051.136364
# specific_energy                                    47630.110708
#
#                                                          105796  \
# flight_id                                             248762583
# date                                                 2022-01-01
# callsign                       e6d5d070016d21108f8bd2bd643202ac
# adep                                                       ENGM
# name_adep                                                  Oslo
# country_code_adep                                            NO
# ades                                                       LEAL
# name_ades                                              Alicante
# country_code_ades                                            ES
# actual_offblock_time                       2022-01-01T10:24:52Z
# arrival_time                               2022-01-01T14:25:33Z
# aircraft_type                                              A20N
# wtc                                                           M
# airline                        8be5c854fd664bcb97fb543339f74770
# flight_duration                                             214
# taxiout_time                                                 27
# flown_distance                                             1434
# tow                                                     57721.0
# track_variation_ARR_100                              129.426353
# track_variation_DEP_40                                22.836441
# track_variation_ENR                                   16.791489
# average_vertical_rate_ARR_100                      -1240.150104
# average_vertical_rate_DEP_40                        2608.168816
# average_vertical_rate_ENR                             59.139008
# average_airspeed_ARR_100                             156.904584
# average_airspeed_DEP_40                               210.13651
# average_airspeed_ENR                                 219.139608
# groundspeed_ARR_100                                  155.874744
# groundspeed_DEP_40                                   187.612239
# groundspeed_ENR                                       215.95786
# wind_distance_ARR_100                               2251.531005
# wind_distance_DEP_40                               -12695.52564
# wind_distance_ENR                                   7761.574767
# average_temperature_ARR_100                          274.099473
# average_temperature_DEP_40                           243.269267
# average_temperature_ENR                              208.935069
# average_humidity_ARR_100                               0.001318
# average_humidity_DEP_40                                0.000613
# average_humidity_ENR                                    0.00002
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            166430.352523
# specific_energy_ENR                               117382.882797
# flown_distance_ARR_100                            221986.104932
# flown_distance_DEP_40                             118459.253246
# flown_distance_ENR                               2314731.640286
# average_altitude_ARR_100                           10659.398888
# average_altitude_DEP_40                            21073.065651
# average_altitude_ENR                               38100.819241
# specific_energy                                    47657.454385
#
#                                                          105797  \
# flight_id                                             248758528
# date                                                 2022-01-01
# callsign                       1f51e76bb1001c4f9de991288aacb326
# adep                                                       EGAC
# name_adep                                          Belfast City
# country_code_adep                                            GB
# ades                                                       EGLL
# name_ades                                       London Heathrow
# country_code_ades                                            GB
# actual_offblock_time                       2022-01-01T07:41:00Z
# arrival_time                               2022-01-01T08:48:19Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              57
# taxiout_time                                                 10
# flown_distance                                              295
# tow                                                     56818.0
# track_variation_ARR_100                              156.984462
# track_variation_DEP_40                                82.098135
# track_variation_ENR                                   35.653151
# average_vertical_rate_ARR_100                      -1205.424058
# average_vertical_rate_DEP_40                        2447.385859
# average_vertical_rate_ENR                            470.145867
# average_airspeed_ARR_100                             158.054538
# average_airspeed_DEP_40                              155.573864
# average_airspeed_ENR                                 207.186721
# groundspeed_ARR_100                                  141.498666
# groundspeed_DEP_40                                   146.338013
# groundspeed_ENR                                      203.742753
# wind_distance_ARR_100                                456.412934
# wind_distance_DEP_40                               -4574.243306
# wind_distance_ENR                                  -4308.278361
# average_temperature_ARR_100                          259.257967
# average_temperature_DEP_40                           262.121142
# average_temperature_ENR                              223.388774
# average_humidity_ARR_100                               0.001969
# average_humidity_DEP_40                                0.001869
# average_humidity_ENR                                   0.000068
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            100334.178098
# specific_energy_ENR                               148839.887667
# flown_distance_ARR_100                            232236.705752
# flown_distance_DEP_40                              73811.104041
# flown_distance_ENR                                249078.051733
# average_altitude_ARR_100                           12696.233293
# average_altitude_DEP_40                            13114.545455
# average_altitude_ENR                               31852.613452
# specific_energy                                    51712.505536
#
#                                                          105798  \
# flight_id                                             248752667
# date                                                 2022-01-01
# callsign                       52d1b50f92590b36489a929375be10f6
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LYBE
# name_ades                                              Belgrade
# country_code_ades                                            RS
# actual_offblock_time                       2022-01-01T05:21:00Z
# arrival_time                               2022-01-01T07:05:28Z
# aircraft_type                                              B738
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                              79
# taxiout_time                                                 25
# flown_distance                                              458
# tow                                                     60678.0
# track_variation_ARR_100                               17.706362
# track_variation_DEP_40                               178.849514
# track_variation_ENR                                   41.002189
# average_vertical_rate_ARR_100                      -1371.055794
# average_vertical_rate_DEP_40                        2397.353383
# average_vertical_rate_ENR                             76.526517
# average_airspeed_ARR_100                             121.419076
# average_airspeed_DEP_40                               161.07308
# average_airspeed_ENR                                 216.343525
# groundspeed_ARR_100                                  133.316065
# groundspeed_DEP_40                                   160.253561
# groundspeed_ENR                                      207.316025
# wind_distance_ARR_100                              17484.737342
# wind_distance_DEP_40                                -539.654081
# wind_distance_ENR                                 -23683.482565
# average_temperature_ARR_100                          256.753553
# average_temperature_DEP_40                           260.778654
# average_temperature_ENR                              217.581183
# average_humidity_ARR_100                               0.002688
# average_humidity_DEP_40                                0.002844
# average_humidity_ENR                                   0.000018
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            125930.812543
# specific_energy_ENR                               127799.326482
# flown_distance_ARR_100                            183634.551484
# flown_distance_DEP_40                             110188.415331
# flown_distance_ENR                                542222.441417
# average_altitude_ARR_100                           15043.848355
# average_altitude_DEP_40                            13378.233083
# average_altitude_ENR                               35283.422358
# specific_energy                                    40402.236552
#
#                                                          105799  \
# flight_id                                             248762188
# date                                                 2022-01-01
# callsign                       256265f000acb4a06cd680b3df7c9897
# adep                                                       KLAX
# name_adep                                           Los Angeles
# country_code_adep                                            US
# ades                                                       LTFM
# name_ades                                          iGA Istanbul
# country_code_ades                                            TR
# actual_offblock_time                       2022-01-01T21:26:00Z
# arrival_time                               2022-01-02T09:55:00Z
# aircraft_type                                              B789
# wtc                                                           H
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             739
# taxiout_time                                                 10
# flown_distance                                             6354
# tow                                                    235632.0
# track_variation_ARR_100                               23.829551
# track_variation_DEP_40                                      NaN
# track_variation_ENR                                   99.558897
# average_vertical_rate_ARR_100                      12773.719008
# average_vertical_rate_DEP_40                                NaN
# average_vertical_rate_ENR                            -47.111015
# average_airspeed_ARR_100                              336.38239
# average_airspeed_DEP_40                                     NaN
# average_airspeed_ENR                                 282.767584
# groundspeed_ARR_100                                  340.799221
# groundspeed_DEP_40                                          NaN
# groundspeed_ENR                                      278.505289
# wind_distance_ARR_100                               8522.729263
# wind_distance_DEP_40                                        NaN
# wind_distance_ENR                                -213346.488345
# average_temperature_ARR_100                          262.078614
# average_temperature_DEP_40                                  NaN
# average_temperature_ENR                              216.352822
# average_humidity_ARR_100                               0.002507
# average_humidity_DEP_40                                     NaN
# average_humidity_ENR                                   0.000013
# specific_energy_ARR_100                            303185.89023
# specific_energy_DEP_40                                      NaN
# specific_energy_ENR                               135551.837481
# flown_distance_ARR_100                            245174.718293
# flown_distance_DEP_40                                       NaN
# flown_distance_ENR                              10180076.619312
# average_altitude_ARR_100                           12134.090909
# average_altitude_DEP_40                                     NaN
# average_altitude_ENR                               37288.354273
# specific_energy                                             NaN
#
#                                                          105800  ...  \
# flight_id                                             248753189  ...
# date                                                 2022-01-01  ...
# callsign                       8191fa049d6f1a6cb432a98d97bf960c  ...
# adep                                                       LTFM  ...
# name_adep                                          iGA Istanbul  ...
# country_code_adep                                            TR  ...
# ades                                                       LTAC  ...
# name_ades                                                Ankara  ...
# country_code_ades                                            TR  ...
# actual_offblock_time                       2022-01-01T15:00:00Z  ...
# arrival_time                               2022-01-01T16:09:00Z  ...
# aircraft_type                                              A321  ...
# wtc                                                           M  ...
# airline                        6351ec1b849adacc0cbb3b1313d8d39b  ...
# flight_duration                                              44  ...
# taxiout_time                                                 25  ...
# flown_distance                                              257  ...
# tow                                                     73571.0  ...
# track_variation_ARR_100                              119.350942  ...
# track_variation_DEP_40                                      NaN  ...
# track_variation_ENR                                         NaN  ...
# average_vertical_rate_ARR_100                       -654.951792  ...
# average_vertical_rate_DEP_40                                NaN  ...
# average_vertical_rate_ENR                                   NaN  ...
# average_airspeed_ARR_100                             101.215431  ...
# average_airspeed_DEP_40                                     NaN  ...
# average_airspeed_ENR                                        NaN  ...
# groundspeed_ARR_100                                  100.549956  ...
# groundspeed_DEP_40                                          NaN  ...
# groundspeed_ENR                                             NaN  ...
# wind_distance_ARR_100                                -540.74267  ...
# wind_distance_DEP_40                                        NaN  ...
# wind_distance_ENR                                           NaN  ...
# average_temperature_ARR_100                          274.784833  ...
# average_temperature_DEP_40                                  NaN  ...
# average_temperature_ENR                                     NaN  ...
# average_humidity_ARR_100                               0.004571  ...
# average_humidity_DEP_40                                     NaN  ...
# average_humidity_ENR                                        NaN  ...
# specific_energy_ARR_100                            15977.826605  ...
# specific_energy_DEP_40                                      NaN  ...
# specific_energy_ENR                                         NaN  ...
# flown_distance_ARR_100                             53914.394348  ...
# flown_distance_DEP_40                                       NaN  ...
# flown_distance_ENR                                          NaN  ...
# average_altitude_ARR_100                            5252.163164  ...
# average_altitude_DEP_40                                     NaN  ...
# average_altitude_ENR                                        NaN  ...
# specific_energy                                             NaN  ...
#
#                                                          474152  \
# flight_id                                             258072846
# date                                                 2022-12-31
# callsign                       5ea802e68573752dc98d7623d897a915
# adep                                                       LIRF
# name_adep                                        Rome Fiumicino
# country_code_adep                                            IT
# ades                                                       EBBR
# name_ades                                              Brussels
# country_code_ades                                            BE
# actual_offblock_time                       2022-12-31T09:47:00Z
# arrival_time                               2022-12-31T11:58:56Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        bdeeef3a675587d530de70a25d7118d2
# flight_duration                                             114
# taxiout_time                                                 18
# flown_distance                                              726
# tow                                                61804.035897
# track_variation_ARR_100                               41.225296
# track_variation_DEP_40                               107.075354
# track_variation_ENR                                   86.102977
# average_vertical_rate_ARR_100                       -944.935673
# average_vertical_rate_DEP_40                        1910.291417
# average_vertical_rate_ENR                             58.349503
# average_airspeed_ARR_100                             122.967444
# average_airspeed_DEP_40                              156.178417
# average_airspeed_ENR                                 218.387572
# groundspeed_ARR_100                                  136.581686
# groundspeed_DEP_40                                    155.84162
# groundspeed_ENR                                      212.901819
# wind_distance_ARR_100                              20658.403766
# wind_distance_DEP_40                                -167.728228
# wind_distance_ENR                                 -27009.830839
# average_temperature_ARR_100                          269.844926
# average_temperature_DEP_40                           273.239045
# average_temperature_ENR                              219.907415
# average_humidity_ARR_100                               0.004583
# average_humidity_DEP_40                                0.003602
# average_humidity_ENR                                   0.000101
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                             99560.798708
# specific_energy_ENR                               112667.709633
# flown_distance_ARR_100                            185953.716431
# flown_distance_DEP_40                              78136.379016
# flown_distance_ENR                               1048177.464189
# average_altitude_ARR_100                           10151.461988
# average_altitude_DEP_40                             9292.065868
# average_altitude_ENR                               33406.129491
# specific_energy                                    39327.802637
#
#                                                          474153  \
# flight_id                                             258057853
# date                                                 2022-12-31
# callsign                       b1de87e85987c58b0d29fa4e72e3f961
# adep                                                       EGLL
# name_adep                                       London Heathrow
# country_code_adep                                            GB
# ades                                                       LSZH
# name_ades                                                Zurich
# country_code_ades                                            CH
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:14:52Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                              64
# taxiout_time                                                 19
# flown_distance                                              449
# tow                                                     72756.0
# track_variation_ARR_100                               64.982306
# track_variation_DEP_40                               174.578445
# track_variation_ENR                                   59.919141
# average_vertical_rate_ARR_100                      -1914.656126
# average_vertical_rate_DEP_40                        1356.238596
# average_vertical_rate_ENR                            528.036782
# average_airspeed_ARR_100                             185.484428
# average_airspeed_DEP_40                              174.000327
# average_airspeed_ENR                                 263.703285
# groundspeed_ARR_100                                  189.635394
# groundspeed_DEP_40                                   160.740284
# groundspeed_ENR                                      255.580037
# wind_distance_ARR_100                               4185.016755
# wind_distance_DEP_40                               -4808.856518
# wind_distance_ENR                                 -17689.590424
# average_temperature_ARR_100                          262.471594
# average_temperature_DEP_40                           273.819874
# average_temperature_ENR                              219.745981
# average_humidity_ARR_100                               0.002745
# average_humidity_DEP_40                                0.004649
# average_humidity_ENR                                   0.000201
# specific_energy_ARR_100                             8661.139522
# specific_energy_DEP_40                             90255.057531
# specific_energy_ENR                               149197.949384
# flown_distance_ARR_100                            192268.438483
# flown_distance_DEP_40                              91577.807082
# flown_distance_ENR                                553274.231706
# average_altitude_ARR_100                           14556.311759
# average_altitude_DEP_40                             7840.087719
# average_altitude_ENR                                33185.45977
# specific_energy                                    48007.663607
#
#                                                          474154  \
# flight_id                                             258071492
# date                                                 2022-12-31
# callsign                       49c815d2ca2e8c50b01473b12fd30119
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       LIMC
# name_ades                                        Milan Malpensa
# country_code_ades                                            IT
# actual_offblock_time                       2022-12-31T09:34:00Z
# arrival_time                               2022-12-31T12:28:54Z
# aircraft_type                                              A321
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             150
# taxiout_time                                                 25
# flown_distance                                              975
# tow                                                     73571.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_40                                 0.397226
# track_variation_ENR                                   25.211864
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_40                        2105.462932
# average_vertical_rate_ENR                              9.018068
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_40                              162.008747
# average_airspeed_ENR                                 219.210967
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_40                                   163.950845
# groundspeed_ENR                                      218.631224
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_40                                1182.816014
# wind_distance_ENR                                   -6586.94011
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_40                           261.892455
# average_temperature_ENR                              213.342527
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_40                                0.001391
# average_humidity_ENR                                   0.000022
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            109727.021482
# specific_energy_ENR                               128044.533554
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_40                              99073.086322
# flown_distance_ENR                                1438706.43647
# average_altitude_ARR_100                                    NaN
# average_altitude_DEP_40                            12195.057661
# average_altitude_ENR                               35357.420954
# specific_energy                                    39340.477809
#
#                                                          474155  \
# flight_id                                             258060782
# date                                                 2022-12-31
# callsign                       92eba53fed3c3914105be1de666ca203
# adep                                                       LSZH
# name_adep                                                Zurich
# country_code_adep                                            CH
# ades                                                       LGTS
# name_ades                                          Thessaloniki
# country_code_ades                                            GR
# actual_offblock_time                       2022-12-31T09:39:00Z
# arrival_time                               2022-12-31T11:36:58Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        2d5def0a5a844b343ba1b7cc9cb28fa9
# flight_duration                                             109
# taxiout_time                                                  9
# flown_distance                                              782
# tow                                                     64826.0
# track_variation_ARR_100                               38.212132
# track_variation_DEP_40                                      NaN
# track_variation_ENR                                   28.434073
# average_vertical_rate_ARR_100                      -1419.209393
# average_vertical_rate_DEP_40                                NaN
# average_vertical_rate_ENR                            204.536816
# average_airspeed_ARR_100                             162.150949
# average_airspeed_DEP_40                                     NaN
# average_airspeed_ENR                                 247.885193
# groundspeed_ARR_100                                  154.424813
# groundspeed_DEP_40                                          NaN
# groundspeed_ENR                                      244.059867
# wind_distance_ARR_100                              -1881.251514
# wind_distance_DEP_40                                        NaN
# wind_distance_ENR                                 -13775.580985
# average_temperature_ARR_100                          266.685247
# average_temperature_DEP_40                                  NaN
# average_temperature_ENR                              217.412211
# average_humidity_ARR_100                               0.002165
# average_humidity_DEP_40                                     NaN
# average_humidity_ENR                                   0.000049
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                                      NaN
# specific_energy_ENR                               155190.109141
# flown_distance_ARR_100                            154850.236264
# flown_distance_DEP_40                                       NaN
# flown_distance_ENR                                874431.280266
# average_altitude_ARR_100                             9977.39726
# average_altitude_DEP_40                                     NaN
# average_altitude_ENR                               33976.069742
# specific_energy                                             NaN
#
#                                                          474156  \
# flight_id                                             258067496
# date                                                 2022-12-31
# callsign                       80e0832fdc79cbba84dff5e9e06bb883
# adep                                                       EDDV
# name_adep                                               Hanover
# country_code_adep                                            DE
# ades                                                       LOWW
# name_ades                                                Vienna
# country_code_ades                                            AT
# actual_offblock_time                       2022-12-31T09:42:00Z
# arrival_time                               2022-12-31T10:49:00Z
# ...
# arrival_time                               2022-12-31T19:03:48Z
# aircraft_type                                              B788
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             545
# taxiout_time                                                 21
# flown_distance                                             4046
# tow                                                    163438.0
# track_variation_ARR_100                              174.768738
# track_variation_DEP_40                                 5.640549
# track_variation_ENR                                    5.110034
# average_vertical_rate_ARR_100                        -957.19801
# average_vertical_rate_DEP_40                        2076.337711
# average_vertical_rate_ENR                            109.133345
# average_airspeed_ARR_100                             120.477436
# average_airspeed_DEP_40                              114.565121
# average_airspeed_ENR                                 168.347139
# groundspeed_ARR_100                                   104.43162
# groundspeed_DEP_40                                   138.455895
# groundspeed_ENR                                      199.474993
# wind_distance_ARR_100                              -1128.929527
# wind_distance_DEP_40                               12724.142049
# wind_distance_ENR                                 103721.478012
# average_temperature_ARR_100                          287.071524
# average_temperature_DEP_40                           269.632091
# average_temperature_ENR                              219.608346
# average_humidity_ARR_100                               0.007733
# average_humidity_DEP_40                                0.003773
# average_humidity_ENR                                   0.000079
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                             82051.456723
# specific_energy_ENR                               116846.850647
# flown_distance_ARR_100                             82920.116565
# flown_distance_DEP_40                              72874.882709
# flown_distance_ENR                                805578.573789
# average_altitude_ARR_100                            4303.880597
# average_altitude_DEP_40                            10943.949343
# average_altitude_ENR                               33277.819044
# specific_energy                                    37501.849179
#
#                                                          474158  \
# flight_id                                             258071247
# date                                                 2022-12-31
# callsign                       570cf7d5ebbd691bcba63e7466607da7
# adep                                                       LTFM
# name_adep                                          iGA Istanbul
# country_code_adep                                            TR
# ades                                                       EDDB
# name_ades                                    Berlin Brandenburg
# country_code_ades                                            DE
# actual_offblock_time                       2022-12-31T09:27:00Z
# arrival_time                               2022-12-31T12:29:41Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        6351ec1b849adacc0cbb3b1313d8d39b
# flight_duration                                             158
# taxiout_time                                                 25
# flown_distance                                              946
# tow                                                     78707.0
# track_variation_ARR_100                                62.54495
# track_variation_DEP_40                                 7.287586
# track_variation_ENR                                   26.244336
# average_vertical_rate_ARR_100                       -986.942529
# average_vertical_rate_DEP_40                        1687.940741
# average_vertical_rate_ENR                             58.375973
# average_airspeed_ARR_100                              130.21441
# average_airspeed_DEP_40                              198.594316
# average_airspeed_ENR                                 195.389197
# groundspeed_ARR_100                                  108.757847
# groundspeed_DEP_40                                   194.865671
# groundspeed_ENR                                      198.916582
# wind_distance_ARR_100                             -43244.289956
# wind_distance_DEP_40                               -1001.164596
# wind_distance_ENR                                  19637.741161
# average_temperature_ARR_100                           247.62106
# average_temperature_DEP_40                           246.646298
# average_temperature_ENR                              216.672887
# average_humidity_ARR_100                               0.002573
# average_humidity_DEP_40                                0.000193
# average_humidity_ENR                                   0.000038
# specific_energy_ARR_100                           112914.102878
# specific_energy_DEP_40                            113137.164423
# specific_energy_ENR                               140217.805342
# flown_distance_ARR_100                            195902.336116
# flown_distance_DEP_40                               52213.69603
# flown_distance_ENR                               1440900.848184
# average_altitude_ARR_100                           20225.634579
# average_altitude_DEP_40                            19776.296296
# average_altitude_ENR                               33741.142937
# specific_energy                                    95013.649249
#
#                                                          474159  \
# flight_id                                             258059152
# date                                                 2022-12-31
# callsign                       5a7e43e4f981539ae3d3b1cb31591b7c
# adep                                                       EDDL
# name_adep                                            Dusseldorf
# country_code_adep                                            DE
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:52:00Z
# arrival_time                               2022-12-31T11:41:51Z
# aircraft_type                                              A320
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              99
# taxiout_time                                                 11
# flown_distance                                              522
# tow                                                    62942.75
# track_variation_ARR_100                               43.910303
# track_variation_DEP_40                                18.479277
# track_variation_ENR                                   19.499181
# average_vertical_rate_ARR_100                      -1553.085546
# average_vertical_rate_DEP_40                        1887.600713
# average_vertical_rate_ENR                            199.908984
# average_airspeed_ARR_100                             146.688552
# average_airspeed_DEP_40                              149.765418
# average_airspeed_ENR                                 205.309589
# groundspeed_ARR_100                                  141.830997
# groundspeed_DEP_40                                   140.976913
# groundspeed_ENR                                      169.654912
# wind_distance_ARR_100                              -6565.814124
# wind_distance_DEP_40                               -4919.055085
# wind_distance_ENR                                -120485.552766
# average_temperature_ARR_100                          250.020435
# average_temperature_DEP_40                           267.916932
# average_temperature_ENR                              213.551798
# average_humidity_ARR_100                               0.002255
# average_humidity_DEP_40                                0.003832
# average_humidity_ENR                                    0.00007
# specific_energy_ARR_100                             8583.364417
# specific_energy_DEP_40                             73808.131433
# specific_energy_ENR                               141243.406835
# flown_distance_ARR_100                            191389.813534
# flown_distance_DEP_40                               87313.70912
# flown_distance_ENR                                676211.797334
# average_altitude_ARR_100                           17019.561209
# average_altitude_DEP_40                            11507.932264
# average_altitude_ENR                               34729.977442
# specific_energy                                    30173.184666
#
#                                                          474160  \
# flight_id                                             258072276
# date                                                 2022-12-31
# callsign                       a1c078516f9f9e90cacec61854cad45b
# adep                                                       LFPG
# name_adep                               Paris Charles de Gaulle
# country_code_adep                                            FR
# ades                                                       EIDW
# name_ades                                                Dublin
# country_code_ades                                            IE
# actual_offblock_time                       2022-12-31T09:37:00Z
# arrival_time                               2022-12-31T11:13:10Z
# aircraft_type                                              A21N
# wtc                                                           M
# airline                        a73f82288988b79be490c6322f4c32ed
# flight_duration                                              84
# taxiout_time                                                 12
# flown_distance                                              466
# tow                                                72611.161024
# track_variation_ARR_100                               48.439184
# track_variation_DEP_40                                      NaN
# track_variation_ENR                                   64.144324
# average_vertical_rate_ARR_100                      -1356.236589
# average_vertical_rate_DEP_40                                NaN
# average_vertical_rate_ENR                            194.472013
# average_airspeed_ARR_100                             139.084419
# average_airspeed_DEP_40                                     NaN
# average_airspeed_ENR                                 195.408968
# groundspeed_ARR_100                                  135.403147
# groundspeed_DEP_40                                          NaN
# groundspeed_ENR                                      184.041878
# wind_distance_ARR_100                             -17444.119009
# wind_distance_DEP_40                                        NaN
# wind_distance_ENR                                  -31588.15396
# average_temperature_ARR_100                          255.247801
# average_temperature_DEP_40                                  NaN
# average_temperature_ENR                              214.239339
# average_humidity_ARR_100                               0.002342
# average_humidity_DEP_40                                     NaN
# average_humidity_ENR                                   0.000047
# specific_energy_ARR_100                           112926.042185
# specific_energy_DEP_40                                      NaN
# specific_energy_ENR                               119424.098697
# flown_distance_ARR_100                            189059.726253
# flown_distance_DEP_40                                       NaN
# flown_distance_ENR                                560710.775683
# average_altitude_ARR_100                           15045.197753
# average_altitude_DEP_40                                     NaN
# average_altitude_ENR                               35017.422259
# specific_energy                                             NaN
#
#                                                          474161
# flight_id                                             258069969
# date                                                 2022-12-31
# callsign                       6c98fcaa191dec632b87b46511f1d2da
# adep                                                       LEMD
# name_adep                                        Madrid Barajas
# country_code_adep                                            ES
# ades                                                       KJFK
# name_ades                                          New York JFK
# country_code_ades                                            US
# actual_offblock_time                       2022-12-31T09:38:00Z
# arrival_time                               2022-12-31T17:26:35Z
# aircraft_type                                              B772
# wtc                                                           H
# airline                        5543e4dc327359ffaf5b9c0e6faaf0e1
# flight_duration                                             453
# taxiout_time                                                 16
# flown_distance                                             3213
# tow                                                    195373.0
# track_variation_ARR_100                                     NaN
# track_variation_DEP_40                                 0.612683
# track_variation_ENR                                   23.802205
# average_vertical_rate_ARR_100                               NaN
# average_vertical_rate_DEP_40                        2283.906977
# average_vertical_rate_ENR                            302.315789
# average_airspeed_ARR_100                                    NaN
# average_airspeed_DEP_40                                208.4603
# average_airspeed_ENR                                 223.129874
# groundspeed_ARR_100                                         NaN
# groundspeed_DEP_40                                   193.517682
# groundspeed_ENR                                      234.129481
# wind_distance_ARR_100                                       NaN
# wind_distance_DEP_40                                -2561.43598
# wind_distance_ENR                                  37636.609741
# average_temperature_ARR_100                                 NaN
# average_temperature_DEP_40                           264.101201
# average_temperature_ENR                              219.981772
# average_humidity_ARR_100                                    NaN
# average_humidity_DEP_40                                0.000264
# average_humidity_ENR                                    0.00004
# specific_energy_ARR_100                                     NaN
# specific_energy_DEP_40                            103786.584976
# specific_energy_ENR                               147639.900205
# flown_distance_ARR_100                                      NaN
# flown_distance_DEP_40                              33133.293615
# flown_distance_ENR                                731187.010808
# average_altitude_ARR_100                                    NaN
# average_altitude_DEP_40                            15128.633721
# average_altitude_ENR                               33950.738304
# specific_energy                                    91461.232681
#
# [49 rows x 368371 columns]

# %%
# Check unique countries in the 'adep' and 'ades' columns
adep_countries = challenge_set['country_code_adep'].unique()
ades_countries = challenge_set['country_code_ades'].unique()

# Combine both lists to get a unique set of countries
all_countries = set(adep_countries).union(set(ades_countries))

# Display the unique countries
print("Unique countries in cleaned_challenge_set:")
print(sorted(all_countries))
# Out:
# Unique countries in cleaned_challenge_set:
# ['##', 'AE', 'AL', 'AM', 'AN', 'AO', 'AT', 'AW', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BG', 'BH', 'BJ', 'BR', 'BY', 'CA', 'CD', 'CG', 'CH', 'CI', 'CR', 'CU', 'CV', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EE', 'EG', 'ES', 'ET', 'FI', 'FR', 'GB', 'GE', 'GH', 'GI', 'GR', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IR', 'IS', 'IT', 'JM', 'JO', 'JP', 'KG', 'KR', 'KZ', 'LB', 'LC', 'LR', 'LT', 'LU', 'LV', 'MA', 'MD', 'ME', 'MK', 'MN', 'MT', 'MU', 'MX', 'MY', 'NG', 'NL', 'NO', 'NP', 'OM', 'PA', 'PH', 'PK', 'PL', 'PT', 'QA', 'RO', 'RS', 'RU', 'SA', 'SD', 'SE', 'SI', 'SK', 'SL', 'SN', 'SO', 'TH', 'TM', 'TN', 'TR', 'TZ', 'UA', 'US', 'UZ', 'VE', 'VN', 'XK', 'ZA']

# %%
# Check unique countries in the 'adep' and 'ades' columns
adep_countries = submission_set['country_code_adep'].unique()
ades_countries = submission_set['country_code_ades'].unique()

# Combine both lists to get a unique set of countries
all_countries_sub = set(adep_countries).union(set(ades_countries))

# Display the unique countries
print("Unique countries in cleaned_challenge_set:")
print(sorted(all_countries_sub))
# Out:
# Unique countries in cleaned_challenge_set:
# ['##', 'AE', 'AL', 'AM', 'AN', 'AT', 'AZ', 'BA', 'BE', 'BG', 'BH', 'BY', 'CA', 'CH', 'CI', 'CR', 'CU', 'CV', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EE', 'EG', 'ER', 'ES', 'FI', 'FR', 'GB', 'GE', 'GR', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IR', 'IS', 'IT', 'JM', 'JO', 'JP', 'KG', 'KZ', 'LB', 'LC', 'LR', 'LT', 'LU', 'LV', 'MA', 'MD', 'ME', 'MK', 'MN', 'MT', 'MX', 'NL', 'NO', 'OM', 'PA', 'PK', 'PL', 'PT', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SI', 'SK', 'SL', 'SN', 'TH', 'TM', 'TN', 'TR', 'TZ', 'UA', 'US', 'UZ', 'XK', 'ZA']

# %%
set(all_countries_sub) - set(all_countries)
# Out:
# {'ER'}

# %%
def extract_time_features(df):
    # Converting datetime strings to datetime objects
    df['actual_offblock_time'] = pd.to_datetime(df['actual_offblock_time'])
    df['arrival_time'] = pd.to_datetime(df['arrival_time'])
    
    # Extracting basic time features
    df['offblock_hour'] = df['actual_offblock_time'].dt.hour
    df['offblock_minute'] = df['actual_offblock_time'].dt.minute
    df['offblock_day_of_week'] = df['actual_offblock_time'].dt.dayofweek
    df['offblock_month'] = df['actual_offblock_time'].dt.month
    # df['offblock_day_of_year'] = df['actual_offblock_time'].dt.dayofyear
    df['offblock_week_of_year'] = df['actual_offblock_time'].dt.isocalendar().week
    df['offblock_season'] = df['offblock_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else 
                                                       'Spring' if x in [3, 4, 5] else
                                                       'Summer' if x in [6, 7, 8] else 'Fall')
    
    df['arrival_hour'] = df['arrival_time'].dt.hour
    df['arrival_minute'] = df['arrival_time'].dt.minute

    # Calculating the duration in minutes between offblock and arrival
    df['offblock_to_arrival_duration'] = (df['arrival_time'] - df['actual_offblock_time']).dt.total_seconds() / 60
    
    # Adding boolean flags for weekends and rush hours
    df['is_offblock_weekend'] = df['offblock_day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
    df['is_offblock_rush_hour'] = df['offblock_hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 18 else 0)
    
    return df

# Creating additional duration-based features
def create_duration_features(df):
    # Replace zero or negative values in flight_duration to avoid division errors
    df['flight_duration'] = df['flight_duration'].replace(0, np.nan)
    df['taxiout_time'] = df['taxiout_time'].replace(0, np.nan)
    
    # Fill NaN values in taxiout_time with the median or a reasonable default
    df['taxiout_time'] = df['taxiout_time'].fillna(df['taxiout_time'].median())
    
    # Calculating the ratio of taxiout time to flight duration with error handling
    df['taxi_ratio'] = df.apply(lambda row: row['taxiout_time'] / row['flight_duration'] 
                                if pd.notnull(row['flight_duration']) else np.nan, axis=1)
    
    # Fill NaN values in taxi_ratio with 0 or a reasonable default (e.g., the median of taxi_ratio)
    df['taxi_ratio'] = df['taxi_ratio'].fillna(df['taxi_ratio'].median())
    
    # Calculating the average flight speed (distance per minute) with error handling
    df['flight_speed'] = df.apply(lambda row: row['flown_distance'] / row['flight_duration'] 
                                  if pd.notnull(row['flown_distance']) and pd.notnull(row['flight_duration']) else np.nan, axis=1)
    
    # Fill NaN values in flight_speed with the median value or a reasonable default
    df['flight_speed'] = df['flight_speed'].fillna(df['flight_speed'].median())
    
    # Normalizing taxi_ratio by the median value to control for large values
    df['normalized_taxi_ratio'] = df['taxi_ratio'] / df['taxi_ratio'].median()
    
    # Categorical features for flight duration buckets
    df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=[0, 60, 180, 300, np.inf], 
                                            labels=['Very Short', 'Short', 'Medium', 'Long'], right=False)
    
    # Speed per distance feature for more detailed analysis
    df['speed_per_distance'] = df.apply(lambda row: row['flight_speed'] / row['flown_distance'] 
                                        if pd.notnull(row['flight_speed']) and pd.notnull(row['flown_distance']) else np.nan, axis=1)
    
    # Fill NaN values in speed_per_distance with the median value or a reasonable default
    df['speed_per_distance'] = df['speed_per_distance'].fillna(df['speed_per_distance'].median())
    
    # Cumulative mean of flight speed to capture trends over time (if data is ordered by time)
    df['cumulative_avg_speed'] = df['flight_speed'].expanding().mean()
    
    # Handling edge cases and setting up conditions for further analysis
    df['taxi_ratio'] = df['taxi_ratio'].replace([np.inf, -np.inf], np.nan)
    df['flight_speed'] = df['flight_speed'].replace([np.inf, -np.inf], np.nan)
    
    return df


# Grouping airports by region based on country codes
def group_airports_by_region(df):
    # Define country groups for regions
    europe_countries = ['GB', 'FR', 'DE', 'ES', 'IT', 'SE', 'CH', 'NL', 'AT', 'IE', 'BE', 'DK', 'FI', 'GR', 'HU', 
                        'IS', 'LT', 'LU', 'LV', 'MT', 'NO', 'PL', 'PT', 'RO', 'SI', 'SK', 'CZ', 'EE', 'BG', 'CY']
    north_america_countries = ['US', 'CA', 'MX']
    south_america_countries = ['BR', 'AR', 'CL', 'CO', 'PE', 'VE', 'UY', 'PY', 'BO', 'EC', 'GY', 'SR']
    middle_east_countries = ['AE', 'SA', 'IL', 'IR', 'IQ', 'JO', 'KW', 'OM', 'QA', 'BH', 'LB', 'SY', 'YE']
    asia_countries = ['JP', 'CN', 'KR', 'IN', 'PK', 'BD', 'VN', 'PH', 'TH', 'MY', 'ID', 'SG', 'MN', 'KZ', 'TM', 'UZ', 'KG']
    africa_countries = ['ZA', 'NG', 'EG', 'DZ', 'MA', 'KE', 'TZ', 'GH', 'ET', 'CI', 'SN', 'SD', 'AO', 'LR', 'RW', 'ER']
    other_countries = set(df['country_code_adep'].unique()).union(set(df['country_code_ades'].unique())) - set(europe_countries + 
                       north_america_countries + south_america_countries + middle_east_countries + asia_countries + africa_countries)

    # Apply region categorization based on country codes
    def categorize_region(code):
        if code in europe_countries:
            return 'Europe'
        elif code in north_america_countries:
            return 'North America'
        elif code in south_america_countries:
            return 'South America'
        elif code in middle_east_countries:
            return 'Middle East'
        elif code in asia_countries:
            return 'Asia'
        elif code in africa_countries:
            return 'Africa'
        elif code in other_countries:
            return 'Other'
        else:
            return 'Unknown'

    # Apply region classification for adep and ades
    df['adep_region'] = df['country_code_adep'].apply(categorize_region)
    df['ades_region'] = df['country_code_ades'].apply(categorize_region)

    return df

# Update functions to remove original columns where applicable
def extract_country_features(df):
    # Basic feature indicating if the flight is within the same country
    df['same_country_flight'] = (df['country_code_adep'] == df['country_code_ades']).astype(int)

    # Feature indicating if the flight is within the same region
    df['same_region_flight'] = (df['adep_region'] == df['ades_region']).astype(int)

    # Flight direction based on regions: North-South, East-West, or Other
    df['flight_direction'] = df.apply(lambda row: 'North-South' if row['adep_region'] in ['North America', 'Europe'] and
                                                      row['ades_region'] in ['South America', 'Africa'] else
                                                      'East-West' if row['adep_region'] in ['Europe', 'Asia'] and 
                                                      row['ades_region'] in ['North America'] else 'Other', axis=1)

    # Create a feature indicating if the flight is intercontinental
    intercontinental_regions = ['Europe', 'North America', 'South America', 'Middle East', 'Asia', 'Africa']
    df['is_intercontinental'] = df.apply(
        lambda row: 1 if row['adep_region'] in intercontinental_regions and 
                         row['ades_region'] in intercontinental_regions and 
                         row['adep_region'] != row['ades_region'] else 0, axis=1)
    return df

# Function to remove original columns after feature extraction
def remove_columns(df, columns_to_remove):
    # Removing original datetime columns since features have been extracted
    df = df.drop(columns_to_remove, axis=1)
    return df

# List of columns to remove after feature extraction
columns_to_remove = ['name_adep', 'name_ades', 'country_code_adep', 'country_code_ades', 'flight_id', 'callsign', 'date', 'actual_offblock_time', 'arrival_time', 'flight_duration']

# Applying functions to the challenge set
cleaned_challenge_set = extract_time_features(challenge_set)
cleaned_challenge_set = create_duration_features(cleaned_challenge_set)
cleaned_challenge_set = group_airports_by_region(cleaned_challenge_set)
cleaned_challenge_set = extract_country_features(cleaned_challenge_set)
cleaned_challenge_set = remove_columns(cleaned_challenge_set, columns_to_remove)

# Applying functions to the submission set
cleaned_submission_set = extract_time_features(submission_set)
cleaned_submission_set = create_duration_features(cleaned_submission_set)
cleaned_submission_set = group_airports_by_region(cleaned_submission_set)
cleaned_submission_set = extract_country_features(cleaned_submission_set)
cleaned_submission_set = remove_columns(cleaned_submission_set, columns_to_remove)

# Display the transposed first few rows of the updated challenge set for review
cleaned_challenge_set.T
# Out:
# /tmp/ipykernel_711813/1767009025.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actual_offblock_time'] = pd.to_datetime(df['actual_offblock_time'])
# /tmp/ipykernel_711813/1767009025.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_time'] = pd.to_datetime(df['arrival_time'])
# /tmp/ipykernel_711813/1767009025.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_hour'] = df['actual_offblock_time'].dt.hour
# /tmp/ipykernel_711813/1767009025.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_minute'] = df['actual_offblock_time'].dt.minute
# /tmp/ipykernel_711813/1767009025.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_day_of_week'] = df['actual_offblock_time'].dt.dayofweek
# /tmp/ipykernel_711813/1767009025.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_month'] = df['actual_offblock_time'].dt.month
# /tmp/ipykernel_711813/1767009025.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_week_of_year'] = df['actual_offblock_time'].dt.isocalendar().week
# /tmp/ipykernel_711813/1767009025.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_season'] = df['offblock_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else
# /tmp/ipykernel_711813/1767009025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_hour'] = df['arrival_time'].dt.hour
# /tmp/ipykernel_711813/1767009025.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_minute'] = df['arrival_time'].dt.minute
# /tmp/ipykernel_711813/1767009025.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_to_arrival_duration'] = (df['arrival_time'] - df['actual_offblock_time']).dt.total_seconds() / 60
# /tmp/ipykernel_711813/1767009025.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_weekend'] = df['offblock_day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
# /tmp/ipykernel_711813/1767009025.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_rush_hour'] = df['offblock_hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 18 else 0)
# /tmp/ipykernel_711813/1767009025.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration'] = df['flight_duration'].replace(0, np.nan)
# /tmp/ipykernel_711813/1767009025.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].replace(0, np.nan)
# /tmp/ipykernel_711813/1767009025.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].fillna(df['taxiout_time'].median())
# /tmp/ipykernel_711813/1767009025.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df.apply(lambda row: row['taxiout_time'] / row['flight_duration']
# /tmp/ipykernel_711813/1767009025.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].fillna(df['taxi_ratio'].median())
# /tmp/ipykernel_711813/1767009025.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df.apply(lambda row: row['flown_distance'] / row['flight_duration']
# /tmp/ipykernel_711813/1767009025.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].fillna(df['flight_speed'].median())
# /tmp/ipykernel_711813/1767009025.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_taxi_ratio'] = df['taxi_ratio'] / df['taxi_ratio'].median()
# /tmp/ipykernel_711813/1767009025.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=[0, 60, 180, 300, np.inf],
# /tmp/ipykernel_711813/1767009025.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df.apply(lambda row: row['flight_speed'] / row['flown_distance']
# /tmp/ipykernel_711813/1767009025.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df['speed_per_distance'].fillna(df['speed_per_distance'].median())
# /tmp/ipykernel_711813/1767009025.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_avg_speed'] = df['flight_speed'].expanding().mean()
# /tmp/ipykernel_711813/1767009025.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_711813/1767009025.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_711813/1767009025.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adep_region'] = df['country_code_adep'].apply(categorize_region)
# /tmp/ipykernel_711813/1767009025.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ades_region'] = df['country_code_ades'].apply(categorize_region)
# /tmp/ipykernel_711813/1767009025.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_country_flight'] = (df['country_code_adep'] == df['country_code_ades']).astype(int)
# /tmp/ipykernel_711813/1767009025.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_region_flight'] = (df['adep_region'] == df['ades_region']).astype(int)
# /tmp/ipykernel_711813/1767009025.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_direction'] = df.apply(lambda row: 'North-South' if row['adep_region'] in ['North America', 'Europe'] and
# /tmp/ipykernel_711813/1767009025.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_intercontinental'] = df.apply(
# /tmp/ipykernel_711813/1767009025.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actual_offblock_time'] = pd.to_datetime(df['actual_offblock_time'])
# /tmp/ipykernel_711813/1767009025.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_time'] = pd.to_datetime(df['arrival_time'])
# /tmp/ipykernel_711813/1767009025.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_hour'] = df['actual_offblock_time'].dt.hour
# /tmp/ipykernel_711813/1767009025.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_minute'] = df['actual_offblock_time'].dt.minute
# /tmp/ipykernel_711813/1767009025.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_day_of_week'] = df['actual_offblock_time'].dt.dayofweek
# /tmp/ipykernel_711813/1767009025.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_month'] = df['actual_offblock_time'].dt.month
# /tmp/ipykernel_711813/1767009025.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_week_of_year'] = df['actual_offblock_time'].dt.isocalendar().week
# /tmp/ipykernel_711813/1767009025.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_season'] = df['offblock_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else
# /tmp/ipykernel_711813/1767009025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_hour'] = df['arrival_time'].dt.hour
# /tmp/ipykernel_711813/1767009025.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['arrival_minute'] = df['arrival_time'].dt.minute
# /tmp/ipykernel_711813/1767009025.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['offblock_to_arrival_duration'] = (df['arrival_time'] - df['actual_offblock_time']).dt.total_seconds() / 60
# /tmp/ipykernel_711813/1767009025.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_weekend'] = df['offblock_day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
# /tmp/ipykernel_711813/1767009025.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_offblock_rush_hour'] = df['offblock_hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 18 else 0)
# /tmp/ipykernel_711813/1767009025.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration'] = df['flight_duration'].replace(0, np.nan)
# /tmp/ipykernel_711813/1767009025.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].replace(0, np.nan)
# /tmp/ipykernel_711813/1767009025.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxiout_time'] = df['taxiout_time'].fillna(df['taxiout_time'].median())
# /tmp/ipykernel_711813/1767009025.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df.apply(lambda row: row['taxiout_time'] / row['flight_duration']
# /tmp/ipykernel_711813/1767009025.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].fillna(df['taxi_ratio'].median())
# /tmp/ipykernel_711813/1767009025.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df.apply(lambda row: row['flown_distance'] / row['flight_duration']
# /tmp/ipykernel_711813/1767009025.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].fillna(df['flight_speed'].median())
# /tmp/ipykernel_711813/1767009025.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_taxi_ratio'] = df['taxi_ratio'] / df['taxi_ratio'].median()
# /tmp/ipykernel_711813/1767009025.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=[0, 60, 180, 300, np.inf],
# /tmp/ipykernel_711813/1767009025.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df.apply(lambda row: row['flight_speed'] / row['flown_distance']
# /tmp/ipykernel_711813/1767009025.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['speed_per_distance'] = df['speed_per_distance'].fillna(df['speed_per_distance'].median())
# /tmp/ipykernel_711813/1767009025.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_avg_speed'] = df['flight_speed'].expanding().mean()
# /tmp/ipykernel_711813/1767009025.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['taxi_ratio'] = df['taxi_ratio'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_711813/1767009025.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_speed'] = df['flight_speed'].replace([np.inf, -np.inf], np.nan)
# /tmp/ipykernel_711813/1767009025.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adep_region'] = df['country_code_adep'].apply(categorize_region)
# /tmp/ipykernel_711813/1767009025.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ades_region'] = df['country_code_ades'].apply(categorize_region)
# /tmp/ipykernel_711813/1767009025.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_country_flight'] = (df['country_code_adep'] == df['country_code_ades']).astype(int)
# /tmp/ipykernel_711813/1767009025.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_region_flight'] = (df['adep_region'] == df['ades_region']).astype(int)
# /tmp/ipykernel_711813/1767009025.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flight_direction'] = df.apply(lambda row: 'North-South' if row['adep_region'] in ['North America', 'Europe'] and
# /tmp/ipykernel_711813/1767009025.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_intercontinental'] = df.apply(
#                                                105791  \
# adep                                             EGLL
# ades                                             EICK
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                105792  \
# adep                                             LEBL
# ades                                             KMIA
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# ades_region                             North America
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                            East-West
# is_intercontinental                                 1
#
#                                                105793  \
# adep                                             ESSA
# ades                                             KORD
# aircraft_type                                    A333
# wtc                                                 H
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# ades_region                             North America
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                            East-West
# is_intercontinental                                 1
#
#                                                105794  \
# adep                                             LSZH
# ades                                             KPHL
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# ades_region                             North America
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                            East-West
# is_intercontinental                                 1
#
#                                                105795  \
# adep                                             EIDW
# ades                                             EGLL
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                105796  \
# adep                                             ENGM
# ades                                             LEAL
# aircraft_type                                    A20N
# wtc                                                 M
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                105797  \
# adep                                             EGAC
# ades                                             EGLL
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 1
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                105798  \
# adep                                             LTFM
# ades                                             LYBE
# aircraft_type                                    B738
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# ades_region                                     Other
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                105799  \
# adep                                             KLAX
# ades                                             LTFM
# aircraft_type                                    B789
# wtc                                                 H
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# ades_region                                     Other
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                105800  ...  \
# adep                                             LTFM  ...
# ades                                             LTAC  ...
# aircraft_type                                    A321  ...
# wtc                                                 M  ...
# airline              6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                               ...  ...
# ades_region                                     Other  ...
# same_country_flight                                 1  ...
# same_region_flight                                  1  ...
# flight_direction                                Other  ...
# is_intercontinental                                 0  ...
#
#                                                474152  \
# adep                                             LIRF
# ades                                             EBBR
# aircraft_type                                    A320
# wtc                                                 M
# airline              bdeeef3a675587d530de70a25d7118d2
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474153  \
# adep                                             EGLL
# ades                                             LSZH
# aircraft_type                                    A21N
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474154  \
# adep                                             LTFM
# ades                                             LIMC
# aircraft_type                                    A321
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474155  \
# adep                                             LSZH
# ades                                             LGTS
# aircraft_type                                    A320
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474156  \
# adep                                             EDDV
# ades                                             LOWW
# aircraft_type                                    E195
# wtc                                                 M
# airline              5d407cb11cc29578cc3e292e743f5393
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474157  \
# adep                                             LFPG
# ades                                             KMIA
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# ades_region                             North America
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                            East-West
# is_intercontinental                                 1
#
#                                                474158  \
# adep                                             LTFM
# ades                                             EDDB
# aircraft_type                                    A21N
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474159  \
# adep                                             EDDL
# ades                                             EIDW
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474160  \
# adep                                             LFPG
# ades                                             EIDW
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# ades_region                                    Europe
# same_country_flight                                 0
# same_region_flight                                  1
# flight_direction                                Other
# is_intercontinental                                 0
#
#                                                474161
# adep                                             LEMD
# ades                                             KJFK
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# ades_region                             North America
# same_country_flight                                 0
# same_region_flight                                  0
# flight_direction                            East-West
# is_intercontinental                                 1
#
# [62 rows x 368371 columns]

# %%
challenge_set['aircraft_type'].value_counts()
# Out:
# aircraft_type
# A320    79562
# A20N    37863
# B738    37466
# A321    29389
# E195    24887
# A21N    23237
# CRJ9    22880
# A319    17494
# A333    16996
# B38M    12320
# BCS3    11881
# B77W     9162
# B772     8322
# AT76     6880
# B788     5959
# B789     5732
# BCS1     4632
# B737     3627
# A332     2240
# E190     2105
# B739     1791
# A359     1725
# B763     1189
# B39M      542
# A343      479
# B752        6
# A310        2
# B773        1
# C56X        1
# E290        1
# Name: count, dtype: int64

# %%
# Extracting unique aircraft types from each set
challenge_aircraft_types = set(challenge_set['aircraft_type'].unique())
submission_aircraft_types = set(submission_set['aircraft_type'].unique())

# Aircraft types in challenge_set but not in submission_set
only_in_challenge = challenge_aircraft_types - submission_aircraft_types
print("Aircraft types only in challenge_set:", only_in_challenge)

# Aircraft types in submission_set but not in challenge_set
only_in_submission = submission_aircraft_types - challenge_aircraft_types
print("Aircraft types only in submission_set:", only_in_submission)
# Out:
# Aircraft types only in challenge_set: {'A310', 'C56X'}
# Aircraft types only in submission_set: set()

# %%
# Load the FAA Aircraft Characteristics Database from the uploaded Excel file
file_path = "./extra_data/FAA-Aircraft-Char-DB-AC-150-5300-13B-App-2023-09-07.xlsx"

# Load the FAA dataset and select relevant columns
faa_data = pd.read_excel(file_path, sheet_name='ACD_Data')

# Select relevant columns for merging
faa_relevant_columns = [
    'FAA_Designator', 'MTOW_lb', 'MALW_lb', 'Manufacturer', 'Model_FAA',
    'Physical_Class_Engine', 'Num_Engines', 'Approach_Speed_knot', 
    'FAA_Weight'
]

# Prepare the FAA data for merging
faa_clean = faa_data[faa_relevant_columns].dropna()

# Convert MTOW and MALW from pounds to kilograms for consistency
faa_clean['MTOW_kg'] = faa_clean['MTOW_lb'] * 0.453592
faa_clean['MALW_kg'] = faa_clean['MALW_lb'] * 0.453592

# Merge the cleaned_challenge_set with FAA data on aircraft_type and FAA_Designator
cleaned_challenge_set = cleaned_challenge_set.merge(
    faa_clean, how='left', left_on='aircraft_type', right_on='FAA_Designator'
)

# Merge the cleaned_submission_set with FAA data on aircraft_type and FAA_Designator
cleaned_submission_set = cleaned_submission_set.merge(
    faa_clean, how='left', left_on='aircraft_type', right_on='FAA_Designator'
)
cleaned_challenge_set.T
# Out:
#                                                0       \
# adep                                             EGLL
# ades                                             EICK
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                1       \
# adep                                             LEBL
# ades                                             KMIA
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             140.0
# FAA_Weight                                      Heavy
# MTOW_kg                                    297556.352
# MALW_kg                                     213188.24
#
#                                                2       \
# adep                                             ESSA
# ades                                             KORD
# aircraft_type                                    A333
# wtc                                                 H
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             137.0
# FAA_Weight                                      Heavy
# MTOW_kg                                 241999.950248
# MALW_kg                                 186999.652288
#
#                                                3       \
# adep                                             LSZH
# ades                                             KPHL
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Heavy
# MTOW_kg                                     227929.98
# MALW_kg                                     172364.96
#
#                                                4       \
# adep                                             EIDW
# ades                                             EGLL
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                5       \
# adep                                             ENGM
# ades                                             LEAL
# aircraft_type                                    A20N
# wtc                                                 M
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             137.0
# FAA_Weight                                      Large
# MTOW_kg                                   78999.85068
# MALW_kg                                  67399.688872
#
#                                                6       \
# adep                                             EGAC
# ades                                             EGLL
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                7       \
# adep                                             LTFM
# ades                                             LYBE
# aircraft_type                                    B738
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Large
# MTOW_kg                                    79015.7264
# MALW_kg                                    66349.1698
#
#                                                8       \
# adep                                             KLAX
# ades                                             LTFM
# aircraft_type                                    B789
# wtc                                                 H
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Heavy
# MTOW_kg                                     254011.52
# MALW_kg                                      192776.6
#
#                                                9       ...  \
# adep                                             LTFM  ...
# ades                                             LTAC  ...
# aircraft_type                                    A321  ...
# wtc                                                 M  ...
# airline              6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                               ...  ...
# Num_Engines                                         2  ...
# Approach_Speed_knot                             142.0  ...
# FAA_Weight                                      Large  ...
# MTOW_kg                                  91000.080632  ...
# MALW_kg                                   77800.09984  ...
#
#                                                368361  \
# adep                                             LIRF
# ades                                             EBBR
# aircraft_type                                    A320
# wtc                                                 M
# airline              bdeeef3a675587d530de70a25d7118d2
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                368362  \
# adep                                             EGLL
# ades                                             LSZH
# aircraft_type                                    A21N
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                368363  \
# adep                                             LTFM
# ades                                             LIMC
# aircraft_type                                    A321
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             142.0
# FAA_Weight                                      Large
# MTOW_kg                                  91000.080632
# MALW_kg                                   77800.09984
#
#                                                368364  \
# adep                                             LSZH
# ades                                             LGTS
# aircraft_type                                    A320
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                368365  \
# adep                                             EDDV
# ades                                             LOWW
# aircraft_type                                    E195
# wtc                                                 M
# airline              5d407cb11cc29578cc3e292e743f5393
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             135.0
# FAA_Weight                                      Large
# MTOW_kg                                   52290.08576
# MALW_kg                                  45800.091424
#
#                                                368366  \
# adep                                             LFPG
# ades                                             KMIA
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             144.0
# FAA_Weight                                      Heavy
# MTOW_kg                                     227929.98
# MALW_kg                                     172364.96
#
#                                                368367  \
# adep                                             LTFM
# ades                                             EDDB
# aircraft_type                                    A21N
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                368368  \
# adep                                             EDDL
# ades                                             EIDW
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  78000.133912
# MALW_kg                                   65999.90396
#
#                                                368369  \
# adep                                             LFPG
# ades                                             EIDW
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             136.0
# FAA_Weight                                      Large
# MTOW_kg                                  94999.854888
# MALW_kg                                  79199.884752
#
#                                                368370
# adep                                             LEMD
# ades                                             KJFK
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Num_Engines                                         2
# Approach_Speed_knot                             140.0
# FAA_Weight                                      Heavy
# MTOW_kg                                    297556.352
# MALW_kg                                     213188.24
#
# [73 rows x 368371 columns]

# %%
cleaned_challenge_set.drop(["FAA_Designator", "MTOW_lb", "MALW_lb"], axis=1, inplace=True)
cleaned_submission_set.drop(["FAA_Designator", "MTOW_lb", "MALW_lb"], axis=1, inplace=True)

# %%
# Check for unique aircraft types in the cleaned challenge set
unique_aircraft_types = cleaned_challenge_set['aircraft_type'].unique()

# Check which aircraft types from the challenge set are not present in the FAA data
missing_aircraft_types = [atype for atype in unique_aircraft_types if atype not in faa_data['FAA_Designator'].unique()]

missing_aircraft_types
# Out:
# []

# %% [raw]
# # Updated dictionary with estimated features for aircraft types
# aircraft_features = {
#     'A320': {'passenger_capacity': 150, 'mtow': 73500, 'range_km': 6100, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'A20N': {'passenger_capacity': 180, 'mtow': 79000, 'range_km': 6850, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'B738': {'passenger_capacity': 160, 'mtow': 79015, 'range_km': 5765, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A321': {'passenger_capacity': 200, 'mtow': 93000, 'range_km': 5950, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'E195': {'passenger_capacity': 120, 'mtow': 52290, 'range_km': 4260, 'category': 'regional', 'manufacturer': 'Embraer'},
#     'A21N': {'passenger_capacity': 206, 'mtow': 97000, 'range_km': 7400, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'CRJ9': {'passenger_capacity': 90, 'mtow': 38430, 'range_km': 2945, 'category': 'regional', 'manufacturer': 'Bombardier'},
#     'A319': {'passenger_capacity': 140, 'mtow': 64000, 'range_km': 6850, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'A333': {'passenger_capacity': 277, 'mtow': 242000, 'range_km': 11750, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B38M': {'passenger_capacity': 180, 'mtow': 82019, 'range_km': 6570, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'BCS3': {'passenger_capacity': 145, 'mtow': 67132, 'range_km': 6297, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'B77W': {'passenger_capacity': 396, 'mtow': 351535, 'range_km': 15690, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'B772': {'passenger_capacity': 314, 'mtow': 299370, 'range_km': 15600, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'AT76': {'passenger_capacity': 70, 'mtow': 23000, 'range_km': 1523, 'category': 'turboprop', 'manufacturer': 'ATR'},
#     'B788': {'passenger_capacity': 242, 'mtow': 227930, 'range_km': 13620, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'B789': {'passenger_capacity': 296, 'mtow': 254011, 'range_km': 14140, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'BCS1': {'passenger_capacity': 130, 'mtow': 60350, 'range_km': 5920, 'category': 'narrow-body', 'manufacturer': 'Airbus'},
#     'B737': {'passenger_capacity': 124, 'mtow': 62831, 'range_km': 4700, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A332': {'passenger_capacity': 278, 'mtow': 233000, 'range_km': 13450, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'E190': {'passenger_capacity': 100, 'mtow': 51800, 'range_km': 4445, 'category': 'regional', 'manufacturer': 'Embraer'},
#     'B739': {'passenger_capacity': 177, 'mtow': 79015, 'range_km': 5950, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A359': {'passenger_capacity': 325, 'mtow': 280000, 'range_km': 15000, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B763': {'passenger_capacity': 218, 'mtow': 186880, 'range_km': 11400, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'B39M': {'passenger_capacity': 210, 'mtow': 82019, 'range_km': 6570, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A343': {'passenger_capacity': 300, 'mtow': 276500, 'range_km': 13270, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B752': {'passenger_capacity': 200, 'mtow': 115680, 'range_km': 7222, 'category': 'narrow-body', 'manufacturer': 'Boeing'},
#     'A310': {'passenger_capacity': 220, 'mtow': 164000, 'range_km': 8050, 'category': 'wide-body', 'manufacturer': 'Airbus'},
#     'B773': {'passenger_capacity': 365, 'mtow': 299370, 'range_km': 13750, 'category': 'wide-body', 'manufacturer': 'Boeing'},
#     'C56X': {'passenger_capacity': 9, 'mtow': 9220, 'range_km': 3889, 'category': 'business', 'manufacturer': 'Cessna'},
#     'E290': {'passenger_capacity': 100, 'mtow': 57300, 'range_km': 4620, 'category': 'regional', 'manufacturer': 'Embraer'}
# }
#
# # Function to extract aircraft-specific features
# def extract_aircraft_features(df):
#     # Mapping the features from the dictionary based on aircraft_type
#     df['passenger_capacity'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('passenger_capacity', np.nan))
#     # passenger_capacity: Estimated number of passengers that the aircraft can carry.
#
#     df['mtow'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('mtow', np.nan))
#     # mtow: Maximum TakeOff Weight (MTOW) in kilograms, representing the heaviest weight at which the aircraft is certified to take off.
#
#     df['range_km'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('range_km', np.nan))
#     # range_km: The maximum range in kilometers that the aircraft can fly with a full load of fuel.
#
#     df['aircraft_category'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('category', 'unknown'))
#     # aircraft_category: The category of the aircraft (e.g., narrow-body, wide-body, regional), indicating its size and typical use.
#
#     df['aircraft_manufacturer'] = df['aircraft_type'].map(lambda x: aircraft_features.get(x, {}).get('manufacturer', 'unknown'))
#     # aircraft_manufacturer: The manufacturer of the aircraft (e.g., Airbus, Boeing, Embraer).
#
#     # Creating new features based on these mappings
#     df['estimated_payload'] = df['mtow'] - (df['passenger_capacity'] * 100)  # Simplified payload estimate
#     # estimated_payload: A simplified estimate of the payload capacity, calculated as MTOW minus an average weight per passenger (assumed to be 100 kg per passenger).
#
#     # Additional features
#     df['range_to_mtow_ratio'] = df['range_km'] / df['mtow']  # Range-to-MTOW Ratio
#     # range_to_mtow_ratio: Ratio of the aircraft's range to its MTOW, indicating the efficiency of the aircraft in terms of distance per unit of weight.
#
#     df['passenger_density'] = df['passenger_capacity'] / df['mtow']  # Passenger Density
#     # passenger_density: The number of passengers per unit of MTOW, showing how optimized the aircraft is for passenger transport versus other uses (like cargo).
#
#     df['range_efficiency'] = df['range_km'] / (df['mtow'] / 1000)  # Range Efficiency
#     # range_efficiency: The efficiency of the aircraft’s range per tonne of MTOW, highlighting how far the aircraft can fly per unit of its weight.
#
#     df['is_high_range'] = df['range_km'].apply(lambda x: 1 if x > 10000 else 0)  # Binary high range indicator
#     # is_high_range: A binary feature indicating if the aircraft is considered long-range (1 if the range is greater than 10,000 km).
#
#     df['is_high_capacity'] = df['passenger_capacity'].apply(lambda x: 1 if x > 300 else 0)  # Binary high capacity indicator
#     # is_high_capacity: A binary feature indicating if the aircraft is high-capacity (1 if it can carry more than 300 passengers).
#
#     return df
#
# # Applying the function to enhance challenge and submission sets
# cleaned_challenge_set = extract_aircraft_features(cleaned_challenge_set)
# cleaned_submission_set = extract_aircraft_features(cleaned_submission_set)
#
# # Display the first few rows of the updated challenge set for review
# cleaned_challenge_set.T

# %%
# Load the GlobalAirportDatabase.txt into a DataFrame
columns_global = ['ICAO', 'IATA', 'Airport Name', 'City/Town', 'Country', 
                  'Latitude Degrees', 'Latitude Minutes', 'Latitude Seconds', 'Latitude Direction',
                  'Longitude Degrees', 'Longitude Minutes', 'Longitude Seconds', 'Longitude Direction',
                  'Altitude', 'Latitude Decimal Degrees', 'Longitude Decimal Degrees']
global_airports = pd.read_csv('./extra_data/GlobalAirportDatabase.txt', sep=':', header=None, names=columns_global)

# Select relevant columns including Altitude (ICAO, Latitude Decimal Degrees, Longitude Decimal Degrees, Altitude)
global_airports = global_airports[['ICAO', 'Latitude Decimal Degrees', 'Longitude Decimal Degrees', 'Altitude']]

# Load the airports.dat file (assuming previous naming and structure)
columns_openflights = ['Airport ID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 
                       'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 
                       'Type', 'Source']
openflights_airports = pd.read_csv('./extra_data/airports.dat', header=None, names=columns_openflights)

# Select relevant columns including Altitude (ICAO, Latitude Decimal Degrees, Longitude Decimal Degrees, Altitude)
openflights_airports = openflights_airports[['ICAO', 'Latitude', 'Longitude', 'Altitude']]
openflights_airports.rename(columns={'Latitude': 'Latitude Decimal Degrees', 
                                     'Longitude': 'Longitude Decimal Degrees'}, inplace=True)

# Concatenate both datasets, removing duplicates based on ICAO codes
airports = pd.concat([global_airports, openflights_airports]).drop_duplicates(subset=['ICAO'])

# Display the combined dataset to verify the merge
airports.head()
# Out:
#    ICAO  Latitude Decimal Degrees  Longitude Decimal Degrees  Altitude
# 0  AYGA                    -6.082                    145.392      1610
# 1  AYLA                     0.000                      0.000         0
# 2  AYMD                    -5.207                    145.789         7
# 3  AYMH                    -5.826                    144.296      1643
# 4  AYNZ                    -6.570                    146.726        73

# %%
# Backup
backup_challenge_set = cleaned_challenge_set.copy()

# Merge airports data to cleaned_challenge_set for both departure (adep) and arrival (ades) airports

# Merge for adep (departure airport)
cleaned_challenge_set = pd.merge(
    cleaned_challenge_set, airports, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
cleaned_challenge_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
cleaned_challenge_set = pd.merge(
    cleaned_challenge_set, airports, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
cleaned_challenge_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True
)

# Display the transposed DataFrame to confirm the correct columns are retained
cleaned_challenge_set.T
# Out:
#                                           0       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                              154.0
#
#                                           1       \
# adep                                        LEBL
# ades                                        KMIA
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           2       \
# adep                                        ESSA
# ades                                        KORD
# aircraft_type                               A333
# wtc                                            H
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                               38.0
# ICAO_ades                                   KORD
# Latitude_ades                             41.979
# Longitude_ades                           -87.904
# Altitude_ades                              204.0
#
#                                           3       \
# adep                                        LSZH
# ades                                        KPHL
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   KPHL
# Latitude_ades                             39.872
# Longitude_ades                           -75.241
# Altitude_ades                               12.0
#
#                                           4       \
# adep                                        EIDW
# ades                                        EGLL
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               74.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           5       \
# adep                                        ENGM
# ades                                        LEAL
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                              208.0
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                               44.0
#
#                                           6       \
# adep                                        EGAC
# ades                                        EGLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                5.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           7       \
# adep                                        LTFM
# ades                                        LYBE
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LYBE
# Latitude_ades                             44.818
# Longitude_ades                            20.309
# Altitude_ades                              103.0
#
#                                           8       \
# adep                                        KLAX
# ades                                        LTFM
# aircraft_type                               B789
# wtc                                            H
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                               39.0
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                              325.0
#
#                                           9       ...  \
# adep                                        LTFM  ...
# ades                                        LTAC  ...
# aircraft_type                               A321  ...
# wtc                                            M  ...
# airline         6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                          ...  ...
# Altitude_adep                              325.0  ...
# ICAO_ades                                   LTAC  ...
# Latitude_ades                             40.128  ...
# Longitude_ades                            32.995  ...
# Altitude_ades                              953.0  ...
#
#                                           368361  \
# adep                                        LIRF
# ades                                        EBBR
# aircraft_type                               A320
# wtc                                            M
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   EBBR
# Latitude_ades                             50.902
# Longitude_ades                             4.499
# Altitude_ades                               57.0
#
#                                           368362  \
# adep                                        EGLL
# ades                                        LSZH
# aircraft_type                               A21N
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                              432.0
#
#                                           368363  \
# adep                                        LTFM
# ades                                        LIMC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LIMC
# Latitude_ades                             45.631
# Longitude_ades                             8.728
# Altitude_ades                              234.0
#
#                                           368364  \
# adep                                        LSZH
# ades                                        LGTS
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   LGTS
# Latitude_ades                              40.52
# Longitude_ades                            22.971
# Altitude_ades                                7.0
#
#                                           368365  \
# adep                                        EDDV
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                               56.0
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                              183.0
#
#                                           368366  \
# adep                                        LFPG
# ades                                        KMIA
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           368367  \
# adep                                        LTFM
# ades                                        EDDB
# aircraft_type                               A21N
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   EDDB
# Latitude_ades                              52.38
# Longitude_ades                            13.523
# Altitude_ades                               48.0
#
#                                           368368  \
# adep                                        EDDL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               45.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           368369  \
# adep                                        LFPG
# ades                                        EIDW
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           368370
# adep                                        LEMD
# ades                                        KJFK
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              610.0
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                4.0
#
# [78 rows x 368371 columns]

# %%
# Count missing values for each column in the cleaned_challenge_set DataFrame
missing_values = cleaned_challenge_set.isnull().sum()

# Identify columns with missing values
columns_with_missing = missing_values[missing_values > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
# Assuming 'adep' and 'ades' are the columns where ICAO codes are merged
missing_icaos_adep = cleaned_challenge_set[cleaned_challenge_set['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades = cleaned_challenge_set[cleaned_challenge_set['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos = set(missing_icaos_adep).union(set(missing_icaos_ades))

# Count the number of unique ICAO codes missing
unique_missing_count = len(unique_missing_icaos)

unique_missing_count, unique_missing_icaos
# Out:
# (9, {'HSSK', 'LFTM', 'LTFG', 'LTFO', 'UCFM', 'UTFF', 'VGHS', 'VOGO', 'ZMCK'})

# %%
challenge_set['taxiout_time'].iloc[827]
# Out:
# 12.0

# %%
cleaned_challenge_set['taxiout_time'].iloc[827]
# Out:
# 12.0

# %%
# Display rows in the DataFrame that have missing values in any column
rows_with_missing_values = cleaned_challenge_set[cleaned_challenge_set.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_values.T
# Out:
#                                           1       \
# adep                                        LEBL
# ades                                        KMIA
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           4       \
# adep                                        EIDW
# ades                                        EGLL
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               74.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           5       \
# adep                                        ENGM
# ades                                        LEAL
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                              208.0
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                               44.0
#
#                                           6       \
# adep                                        EGAC
# ades                                        EGLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                5.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           7       \
# adep                                        LTFM
# ades                                        LYBE
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LYBE
# Latitude_ades                             44.818
# Longitude_ades                            20.309
# Altitude_ades                              103.0
#
#                                           8       \
# adep                                        KLAX
# ades                                        LTFM
# aircraft_type                               B789
# wtc                                            H
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                               39.0
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                              325.0
#
#                                           9       \
# adep                                        LTFM
# ades                                        LTAC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LTAC
# Latitude_ades                             40.128
# Longitude_ades                            32.995
# Altitude_ades                              953.0
#
#                                           12      \
# adep                                        ESSA
# ades                                        ESMS
# aircraft_type                               CRJ9
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                               38.0
# ICAO_ades                                   ESMS
# Latitude_ades                              55.53
# Longitude_ades                            13.371
# Altitude_ades                               72.0
#
#                                           13      \
# adep                                        LSGG
# ades                                        EKCH
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                              431.0
# ICAO_ades                                   EKCH
# Latitude_ades                             55.618
# Longitude_ades                            12.656
# Altitude_ades                                6.0
#
#                                           14      ...  \
# adep                                        LTAT  ...
# ades                                        LTAC  ...
# aircraft_type                               B738  ...
# wtc                                            M  ...
# airline         6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                          ...  ...
# Altitude_adep                              862.0  ...
# ICAO_ades                                   LTAC  ...
# Latitude_ades                             40.128  ...
# Longitude_ades                            32.995  ...
# Altitude_ades                              953.0  ...
#
#                                           368358  \
# adep                                        LTFM
# ades                                        LEBL
# aircraft_type                               A21N
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LEBL
# Latitude_ades                             41.297
# Longitude_ades                             2.078
# Altitude_ades                                4.0
#
#                                           368359  \
# adep                                        LSGG
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                              431.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           368360  \
# adep                                        EBBR
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               57.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           368361  \
# adep                                        LIRF
# ades                                        EBBR
# aircraft_type                               A320
# wtc                                            M
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   EBBR
# Latitude_ades                             50.902
# Longitude_ades                             4.499
# Altitude_ades                               57.0
#
#                                           368363  \
# adep                                        LTFM
# ades                                        LIMC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LIMC
# Latitude_ades                             45.631
# Longitude_ades                             8.728
# Altitude_ades                              234.0
#
#                                           368364  \
# adep                                        LSZH
# ades                                        LGTS
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   LGTS
# Latitude_ades                              40.52
# Longitude_ades                            22.971
# Altitude_ades                                7.0
#
#                                           368365  \
# adep                                        EDDV
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                               56.0
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                              183.0
#
#                                           368366  \
# adep                                        LFPG
# ades                                        KMIA
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                3.0
#
#                                           368369  \
# adep                                        LFPG
# ades                                        EIDW
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                              120.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           368370
# adep                                        LEMD
# ades                                        KJFK
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              610.0
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                4.0
#
# [78 rows x 201279 columns]

# %%
# Applying the same transformations for submission_set as described for challenge_set

# Backup
backup_submission_set = cleaned_submission_set.copy()

# Filter updated_airports to include only ICAO codes present in cleaned_submission_set (adep and ades)
relevant_icaos_submission = cleaned_submission_set['adep'].unique().tolist() + cleaned_submission_set['ades'].unique().tolist()
filtered_airports_submission = airports[airports['ICAO'].isin(relevant_icaos_submission)]

# Merge airports data to submission_set for both departure (adep) and arrival (ades) airports
# Merge for adep (departure airport)
cleaned_submission_set = pd.merge(
    cleaned_submission_set, filtered_airports_submission, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
cleaned_submission_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
cleaned_submission_set = pd.merge(
    cleaned_submission_set, filtered_airports_submission, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
cleaned_submission_set.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True
)

cleaned_submission_set.T
# Out:
#                                           0       \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                              251.0
#
#                                           1       \
# adep                                        EBBR
# ades                                        KJFK
# aircraft_type                               A333
# wtc                                            H
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                               57.0
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                4.0
#
#                                           2       \
# adep                                        KMIA
# ades                                        EGLL
# aircraft_type                               B77W
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                3.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           3       \
# adep                                        EGCN
# ades                                        LEAL
# aircraft_type                               B38M
# wtc                                            M
# airline         3922524069809ac4326134429751e26f
# ...                                          ...
# Altitude_adep                               55.0
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                               44.0
#
#                                           4       \
# adep                                        EIDW
# ades                                        LFLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               74.0
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                              251.0
#
#                                           5       \
# adep                                        LTFJ
# ades                                        LTAC
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   LTAC
# Latitude_ades                             40.128
# Longitude_ades                            32.995
# Altitude_ades                              953.0
#
#                                           6       \
# adep                                        EGLL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           7       \
# adep                                        LSZH
# ades                                        EDDH
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                              432.0
# ICAO_ades                                   EDDH
# Latitude_ades                              53.63
# Longitude_ades                             9.988
# Altitude_ades                               17.0
#
#                                           8       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                               25.0
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                              154.0
#
#                                           9       ...  \
# adep                                        LEMD  ...
# ades                                        EIDW  ...
# aircraft_type                               A320  ...
# wtc                                            M  ...
# airline         a73f82288988b79be490c6322f4c32ed  ...
# ...                                          ...  ...
# Altitude_adep                              610.0  ...
# ICAO_ades                                   EIDW  ...
# Latitude_ades                             53.421  ...
# Longitude_ades                             -6.27  ...
# Altitude_ades                               74.0  ...
#
#                                           105781  \
# adep                                        BKPR
# ades                                        LSGG
# aircraft_type                               BCS3
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                             1789.0
# ICAO_ades                                   LSGG
# Latitude_ades                             46.238
# Longitude_ades                             6.109
# Altitude_ades                              431.0
#
#                                           105782  \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                              251.0
#
#                                           105783  \
# adep                                        KORD
# ades                                        EGLL
# aircraft_type                               B789
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                              204.0
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                               25.0
#
#                                           105784  \
# adep                                        KJFK
# ades                                        LEBL
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   LEBL
# Latitude_ades                             41.297
# Longitude_ades                             2.078
# Altitude_ades                                4.0
#
#                                           105785  \
# adep                                        KSFO
# ades                                        EIDW
# aircraft_type                               A333
# wtc                                            H
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                               74.0
#
#                                           105786  \
# adep                                        LTFJ
# ades                                        EKCH
# aircraft_type                               B38M
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              312.0
# ICAO_ades                                   EKCH
# Latitude_ades                             55.618
# Longitude_ades                            12.656
# Altitude_ades                                6.0
#
#                                           105787  \
# adep                                        LOWW
# ades                                        KIAD
# aircraft_type                               B763
# wtc                                            H
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                              183.0
# ICAO_ades                                   KIAD
# Latitude_ades                             38.944
# Longitude_ades                           -77.456
# Altitude_ades                               96.0
#
#                                           105788  \
# adep                                        LTFM
# ades                                        LSZH
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                              325.0
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                              432.0
#
#                                           105789  \
# adep                                        EHAM
# ades                                        EDDF
# aircraft_type                               A320
# wtc                                            M
# airline         f502877cab405652cf0dd70c2213e730
# ...                                          ...
# Altitude_adep                               -3.0
# ICAO_ades                                   EDDF
# Latitude_ades                             50.026
# Longitude_ades                             8.543
# Altitude_ades                              111.0
#
#                                           105790
# adep                                        UBBB
# ades                                        LTFM
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                4.0
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                              325.0
#
# [78 rows x 105791 columns]

# %%
# Count missing values for each column in the submission_set_updated DataFrame
missing_values_submission = cleaned_submission_set.isnull().sum()

# Identify columns with missing values
columns_with_missing_submission = missing_values_submission[missing_values_submission > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
missing_icaos_adep_submission = cleaned_submission_set[cleaned_submission_set['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades_submission = cleaned_submission_set[cleaned_submission_set['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos_submission = set(missing_icaos_adep_submission).union(set(missing_icaos_ades_submission))

# Count the number of unique ICAO codes missing
unique_missing_count_submission = len(unique_missing_icaos_submission)

unique_missing_count_submission, unique_missing_icaos_submission
# Out:
# (6, {'LTFG', 'LTFO', 'UCFM', 'UTFF', 'VOGO', 'ZMCK'})

# %%
# Coordinates for the given ICAO codes

new_airports = {
    'ICAO': ['CYHZ', 'EDDE', 'KDAB', 'KRFD', 'LIPO', 'LTAP', 'HSSK', 'LFTM', 'LTFG', 
             'LTFO', 'UCFM', 'UTFF', 'VGHS', 'VOGO', 'ZMCK'],
    'Latitude Decimal Degrees': [44.8800, 50.9798, 29.1799, 42.1954, 45.4289, 40.0714, 
                                 15.5895, 40.9769, 36.2994, 38.7262, 43.0613, 40.3581, 
                                 23.8433, 15.3808, 48.1357],
    'Longitude Decimal Degrees': [-63.5086, 10.9581, -81.0581, -89.0972, 10.3306, 32.5644, 
                                  32.5532, 28.8146, 32.3006, 30.6015, 74.4776, 71.7450, 
                                  90.3978, 73.8314, 114.6460],
    'Altitude': [145, 316, 11, 224, 109, 535, 386, 35, 28, 1003, 627, 577, 8, 56, 751]
}

# Convert new airports data to DataFrame
new_airports_df = pd.DataFrame(new_airports)

# Append the new rows to the existing DataFrame
updated_airports = pd.concat([airports, new_airports_df], ignore_index=True)

updated_airports = updated_airports.drop_duplicates(subset=['ICAO'])

# %%
# Filter updated_airports to include only ICAO codes present in df (adep and ades)
relevant_icaos_challenge = backup_challenge_set['adep'].unique().tolist() + backup_challenge_set['ades'].unique().tolist()
filtered_airports_challenge = updated_airports[updated_airports['ICAO'].isin(relevant_icaos_challenge)]

# Merge airports data to cleaned_challenge_set for both departure (adep) and arrival (ades) airports
# Merge for adep (departure airport)
challenge_set_updated = pd.merge(
    backup_challenge_set, filtered_airports_challenge, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
challenge_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
challenge_set_updated = pd.merge(
    challenge_set_updated, filtered_airports_challenge, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
challenge_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True)


# Display the transposed DataFrame to confirm the correct columns are retained
challenge_set_updated.T
# Out:
#                                           0       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                                154
#
#                                           1       \
# adep                                        LEBL
# ades                                        KMIA
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                  3
#
#                                           2       \
# adep                                        ESSA
# ades                                        KORD
# aircraft_type                               A333
# wtc                                            H
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                                 38
# ICAO_ades                                   KORD
# Latitude_ades                             41.979
# Longitude_ades                           -87.904
# Altitude_ades                                204
#
#                                           3       \
# adep                                        LSZH
# ades                                        KPHL
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                432
# ICAO_ades                                   KPHL
# Latitude_ades                             39.872
# Longitude_ades                           -75.241
# Altitude_ades                                 12
#
#                                           4       \
# adep                                        EIDW
# ades                                        EGLL
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 74
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           5       \
# adep                                        ENGM
# ades                                        LEAL
# aircraft_type                               A20N
# wtc                                            M
# airline         8be5c854fd664bcb97fb543339f74770
# ...                                          ...
# Altitude_adep                                208
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                                 44
#
#                                           6       \
# adep                                        EGAC
# ades                                        EGLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                  5
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           7       \
# adep                                        LTFM
# ades                                        LYBE
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   LYBE
# Latitude_ades                             44.818
# Longitude_ades                            20.309
# Altitude_ades                                103
#
#                                           8       \
# adep                                        KLAX
# ades                                        LTFM
# aircraft_type                               B789
# wtc                                            H
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                 39
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                                325
#
#                                           9       ...  \
# adep                                        LTFM  ...
# ades                                        LTAC  ...
# aircraft_type                               A321  ...
# wtc                                            M  ...
# airline         6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                          ...  ...
# Altitude_adep                                325  ...
# ICAO_ades                                   LTAC  ...
# Latitude_ades                             40.128  ...
# Longitude_ades                            32.995  ...
# Altitude_ades                                953  ...
#
#                                           368361  \
# adep                                        LIRF
# ades                                        EBBR
# aircraft_type                               A320
# wtc                                            M
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   EBBR
# Latitude_ades                             50.902
# Longitude_ades                             4.499
# Altitude_ades                                 57
#
#                                           368362  \
# adep                                        EGLL
# ades                                        LSZH
# aircraft_type                               A21N
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                                432
#
#                                           368363  \
# adep                                        LTFM
# ades                                        LIMC
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   LIMC
# Latitude_ades                             45.631
# Longitude_ades                             8.728
# Altitude_ades                                234
#
#                                           368364  \
# adep                                        LSZH
# ades                                        LGTS
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                                432
# ICAO_ades                                   LGTS
# Latitude_ades                              40.52
# Longitude_ades                            22.971
# Altitude_ades                                  7
#
#                                           368365  \
# adep                                        EDDV
# ades                                        LOWW
# aircraft_type                               E195
# wtc                                            M
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                                 56
# ICAO_ades                                   LOWW
# Latitude_ades                              48.11
# Longitude_ades                             16.57
# Altitude_ades                                183
#
#                                           368366  \
# adep                                        LFPG
# ades                                        KMIA
# aircraft_type                               B788
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                120
# ICAO_ades                                   KMIA
# Latitude_ades                             25.793
# Longitude_ades                           -80.291
# Altitude_ades                                  3
#
#                                           368367  \
# adep                                        LTFM
# ades                                        EDDB
# aircraft_type                               A21N
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   EDDB
# Latitude_ades                              52.38
# Longitude_ades                            13.523
# Altitude_ades                                 48
#
#                                           368368  \
# adep                                        EDDL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 45
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           368369  \
# adep                                        LFPG
# ades                                        EIDW
# aircraft_type                               A21N
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                120
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           368370
# adep                                        LEMD
# ades                                        KJFK
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                610
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                  4
#
# [78 rows x 368371 columns]

# %%
# Count missing values for each column in the cleaned_challenge_set DataFrame
missing_values = challenge_set_updated.isnull().sum()

# Identify columns with missing values
columns_with_missing = missing_values[missing_values > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
# Assuming 'adep' and 'ades' are the columns where ICAO codes are merged
missing_icaos_adep = challenge_set_updated[challenge_set_updated['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades = challenge_set_updated[challenge_set_updated['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos = set(missing_icaos_adep).union(set(missing_icaos_ades))

# Count the number of unique ICAO codes missing
unique_missing_count = len(unique_missing_icaos)

unique_missing_count, unique_missing_icaos
# Out:
# (0, set())

# %%
# Display rows in the DataFrame that have missing values in any column
rows_with_missing_values = challenge_set_updated[challenge_set_updated.isnull().any(axis=1)]

# Display the rows with missing values
rows_with_missing_values
# Out:
#         adep  ades aircraft_type wtc                           airline  \
# 1       LEBL  KMIA          B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 4       EIDW  EGLL          A21N   M  a73f82288988b79be490c6322f4c32ed
# 5       ENGM  LEAL          A20N   M  8be5c854fd664bcb97fb543339f74770
# 6       EGAC  EGLL          A320   M  a73f82288988b79be490c6322f4c32ed
# 7       LTFM  LYBE          B738   M  6351ec1b849adacc0cbb3b1313d8d39b
# ...      ...   ...           ...  ..                               ...
# 368364  LSZH  LGTS          A320   M  2d5def0a5a844b343ba1b7cc9cb28fa9
# 368365  EDDV  LOWW          E195   M  5d407cb11cc29578cc3e292e743f5393
# 368366  LFPG  KMIA          B788   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 368369  LFPG  EIDW          A21N   M  a73f82288988b79be490c6322f4c32ed
# 368370  LEMD  KJFK          B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1
#
#         taxiout_time  flown_distance            tow  track_variation_ARR_100  \
# 1               13.0            4193  185441.000000               179.318890
# 4               14.0             305   70318.447226                      NaN
# 5               27.0            1434   57721.000000               129.426353
# 6               10.0             295   56818.000000               156.984462
# 7               25.0             458   60678.000000                17.706362
# ...              ...             ...            ...                      ...
# 368364           9.0             782   64826.000000                38.212132
# 368365           8.0             416   40868.000000                70.340447
# 368366          21.0            4046  163438.000000               174.768738
# 368369          12.0             466   72611.161024                48.439184
# 368370          16.0            3213  195373.000000                      NaN
#
#         track_variation_DEP_40  ...        MTOW_kg        MALW_kg  ICAO  \
# 1                     8.910306  ...  297556.352000  213188.240000  LEBL
# 4                   174.928513  ...   94999.854888   79199.884752  EIDW
# 5                    22.836441  ...   78999.850680   67399.688872  ENGM
# 6                    82.098135  ...   78000.133912   65999.903960  EGAC
# 7                   178.849514  ...   79015.726400   66349.169800  LTFM
# ...                        ...  ...            ...            ...   ...
# 368364                     NaN  ...   78000.133912   65999.903960  LSZH
# 368365                0.167177  ...   52290.085760   45800.091424  EDDV
# 368366                5.640549  ...  227929.980000  172364.960000  LFPG
# 368369                     NaN  ...   94999.854888   79199.884752  LFPG
# 368370                0.612683  ...  297556.352000  213188.240000  LEMD
#
#         Latitude_adep  Longitude_adep  Altitude_adep  ICAO_ades  \
# 1           41.297000        2.078000              4       KMIA
# 4           53.421000       -6.270000             74       EGLL
# 5           60.194000       11.100000            208       LEAL
# 6           54.618000       -5.873000              5       EGLL
# 7           41.275278       28.751944            325       LYBE
# ...               ...             ...            ...        ...
# 368364      47.465000        8.549000            432       LGTS
# 368365      52.461000        9.685000             56       LOWW
# 368366      49.013000        2.550000            120       KMIA
# 368369      49.013000        2.550000            120       EIDW
# 368370      40.472000       -3.561000            610       KJFK
#
#         Latitude_ades  Longitude_ades  Altitude_ades
# 1              25.793         -80.291              3
# 4              51.477          -0.461             25
# 5              38.282          -0.558             44
# 6              51.477          -0.461             25
# 7              44.818          20.309            103
# ...               ...             ...            ...
# 368364         40.520          22.971              7
# 368365         48.110          16.570            183
# 368366         25.793         -80.291              3
# 368369         53.421          -6.270             74
# 368370         40.640         -73.779              4
#
# [201229 rows x 78 columns]

# %%
# Applying the same transformations for submission_set as described for challenge_set

# Filter updated_airports to include only ICAO codes present in df (adep and ades)
relevant_icaos_submission = backup_submission_set['adep'].unique().tolist() + backup_submission_set['ades'].unique().tolist()
filtered_airports_submission = updated_airports[updated_airports['ICAO'].isin(relevant_icaos_submission)]

# Merge airports data to submission_set for both departure (adep) and arrival (ades) airports
# Merge for adep (departure airport)
submission_set_updated = pd.merge(
    backup_submission_set, filtered_airports_submission, 
    how='left', left_on='adep', right_on='ICAO', 
    suffixes=('_adep', '')
)

# Rename latitude, longitude, and altitude columns for adep correctly
submission_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_adep', 
        'Longitude Decimal Degrees': 'Longitude_adep',
        'Altitude': 'Altitude_adep'
    }, 
    inplace=True
)

# Merge for ades (arrival airport)
submission_set_updated = pd.merge(
    submission_set_updated, filtered_airports_submission, 
    how='left', left_on='ades', right_on='ICAO', 
    suffixes=('', '_ades')
)

# Rename latitude, longitude, and altitude columns for ades correctly
submission_set_updated.rename(
    columns={
        'Latitude Decimal Degrees': 'Latitude_ades', 
        'Longitude Decimal Degrees': 'Longitude_ades',
        'Altitude': 'Altitude_ades'
    }, 
    inplace=True
)

submission_set_updated.T
# Out:
#                                           0       \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                                251
#
#                                           1       \
# adep                                        EBBR
# ades                                        KJFK
# aircraft_type                               A333
# wtc                                            H
# airline         bdeeef3a675587d530de70a25d7118d2
# ...                                          ...
# Altitude_adep                                 57
# ICAO_ades                                   KJFK
# Latitude_ades                              40.64
# Longitude_ades                           -73.779
# Altitude_ades                                  4
#
#                                           2       \
# adep                                        KMIA
# ades                                        EGLL
# aircraft_type                               B77W
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                  3
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           3       \
# adep                                        EGCN
# ades                                        LEAL
# aircraft_type                               B38M
# wtc                                            M
# airline         3922524069809ac4326134429751e26f
# ...                                          ...
# Altitude_adep                                 55
# ICAO_ades                                   LEAL
# Latitude_ades                             38.282
# Longitude_ades                            -0.558
# Altitude_ades                                 44
#
#                                           4       \
# adep                                        EIDW
# ades                                        LFLL
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 74
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                                251
#
#                                           5       \
# adep                                        LTFJ
# ades                                        LTAC
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   LTAC
# Latitude_ades                             40.128
# Longitude_ades                            32.995
# Altitude_ades                                953
#
#                                           6       \
# adep                                        EGLL
# ades                                        EIDW
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           7       \
# adep                                        LSZH
# ades                                        EDDH
# aircraft_type                               A320
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                                432
# ICAO_ades                                   EDDH
# Latitude_ades                              53.63
# Longitude_ades                             9.988
# Altitude_ades                                 17
#
#                                           8       \
# adep                                        EGLL
# ades                                        EICK
# aircraft_type                               A320
# wtc                                            M
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                 25
# ICAO_ades                                   EICK
# Latitude_ades                             51.843
# Longitude_ades                            -8.492
# Altitude_ades                                154
#
#                                           9       ...  \
# adep                                        LEMD  ...
# ades                                        EIDW  ...
# aircraft_type                               A320  ...
# wtc                                            M  ...
# airline         a73f82288988b79be490c6322f4c32ed  ...
# ...                                          ...  ...
# Altitude_adep                                610  ...
# ICAO_ades                                   EIDW  ...
# Latitude_ades                             53.421  ...
# Longitude_ades                             -6.27  ...
# Altitude_ades                                 74  ...
#
#                                           105781  \
# adep                                        BKPR
# ades                                        LSGG
# aircraft_type                               BCS3
# wtc                                            M
# airline         2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                          ...
# Altitude_adep                               1789
# ICAO_ades                                   LSGG
# Latitude_ades                             46.238
# Longitude_ades                             6.109
# Altitude_ades                                431
#
#                                           105782  \
# adep                                        LTFJ
# ades                                        LFLL
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   LFLL
# Latitude_ades                             45.726
# Longitude_ades                             5.091
# Altitude_ades                                251
#
#                                           105783  \
# adep                                        KORD
# ades                                        EGLL
# aircraft_type                               B789
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                204
# ICAO_ades                                   EGLL
# Latitude_ades                             51.477
# Longitude_ades                            -0.461
# Altitude_ades                                 25
#
#                                           105784  \
# adep                                        KJFK
# ades                                        LEBL
# aircraft_type                               B772
# wtc                                            H
# airline         5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   LEBL
# Latitude_ades                             41.297
# Longitude_ades                             2.078
# Altitude_ades                                  4
#
#                                           105785  \
# adep                                        KSFO
# ades                                        EIDW
# aircraft_type                               A333
# wtc                                            H
# airline         a73f82288988b79be490c6322f4c32ed
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   EIDW
# Latitude_ades                             53.421
# Longitude_ades                             -6.27
# Altitude_ades                                 74
#
#                                           105786  \
# adep                                        LTFJ
# ades                                        EKCH
# aircraft_type                               B38M
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                312
# ICAO_ades                                   EKCH
# Latitude_ades                             55.618
# Longitude_ades                            12.656
# Altitude_ades                                  6
#
#                                           105787  \
# adep                                        LOWW
# ades                                        KIAD
# aircraft_type                               B763
# wtc                                            H
# airline         5d407cb11cc29578cc3e292e743f5393
# ...                                          ...
# Altitude_adep                                183
# ICAO_ades                                   KIAD
# Latitude_ades                             38.944
# Longitude_ades                           -77.456
# Altitude_ades                                 96
#
#                                           105788  \
# adep                                        LTFM
# ades                                        LSZH
# aircraft_type                               A321
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                325
# ICAO_ades                                   LSZH
# Latitude_ades                             47.465
# Longitude_ades                             8.549
# Altitude_ades                                432
#
#                                           105789  \
# adep                                        EHAM
# ades                                        EDDF
# aircraft_type                               A320
# wtc                                            M
# airline         f502877cab405652cf0dd70c2213e730
# ...                                          ...
# Altitude_adep                                 -3
# ICAO_ades                                   EDDF
# Latitude_ades                             50.026
# Longitude_ades                             8.543
# Altitude_ades                                111
#
#                                           105790
# adep                                        UBBB
# ades                                        LTFM
# aircraft_type                               B738
# wtc                                            M
# airline         6351ec1b849adacc0cbb3b1313d8d39b
# ...                                          ...
# Altitude_adep                                  4
# ICAO_ades                                   LTFM
# Latitude_ades                          41.275278
# Longitude_ades                         28.751944
# Altitude_ades                                325
#
# [78 rows x 105791 columns]

# %%
# Count missing values for each column in the submission_set_updated DataFrame
missing_values_submission = submission_set_updated.isnull().sum()

# Identify columns with missing values
columns_with_missing_submission = missing_values_submission[missing_values_submission > 0]

# Specifically count the unique missing ICAO codes by examining columns related to ICAO information
missing_icaos_adep_submission = submission_set_updated[submission_set_updated['Latitude_adep'].isnull()]['adep'].unique()
missing_icaos_ades_submission = submission_set_updated[submission_set_updated['Latitude_ades'].isnull()]['ades'].unique()

# Combine both lists to find unique ICAO codes missing in both 'adep' and 'ades'
unique_missing_icaos_submission = set(missing_icaos_adep_submission).union(set(missing_icaos_ades_submission))

# Count the number of unique ICAO codes missing
unique_missing_count_submission = len(unique_missing_icaos_submission)

unique_missing_count_submission, unique_missing_icaos_submission
# Out:
# (0, set())

# %%
# Function to calculate actual distance between airports using Haversine formula
def calculate_actual_distance(df):
    # Convert degrees to radians
    lat1 = np.radians(df['Latitude_adep'])
    lon1 = np.radians(df['Longitude_adep'])
    lat2 = np.radians(df['Latitude_ades'])
    lon2 = np.radians(df['Longitude_ades'])
    
    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    radius_earth_km = 6371  # Earth radius in kilometers
    df['actual_distance'] = radius_earth_km * c
    
    # Additional features
    df['altitude_difference'] = df['Altitude_ades'] - df['Altitude_adep']  # Vertical distance
    df['bearing'] = np.degrees(np.arctan2(np.sin(dlon) * np.cos(lat2), 
                                           np.cos(lat1) * np.sin(lat2) - 
                                           np.sin(lat1) * np.cos(lat2) * np.cos(dlon)))  # Bearing
    
    df['bearing'] = (df['bearing'] + 360) % 360  # Normalize bearing to 0-360 degrees
    df['elevation_gradient'] = df['altitude_difference'] / df['actual_distance']  # Altitude change per km
    
    return df

# Apply the actual distance calculation and additional features to the challenge set
challenge_set_updated = calculate_actual_distance(challenge_set_updated)
challenge_set_updated = challenge_set_updated.drop(['ICAO', 'ICAO_ades'], axis=1)

# Apply the actual distance calculation and additional features to the submission set
submission_set_updated = calculate_actual_distance(submission_set_updated)
submission_set_updated = submission_set_updated.drop(['ICAO', 'ICAO_ades'], axis=1)

# %%
challenge_set_updated.T
# Out:
#                                                0       \
# adep                                             EGLL
# ades                                             EICK
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                     154
# actual_distance                            555.164898
# altitude_difference                               129
# bearing                                    277.346455
# elevation_gradient                           0.232363
#
#                                                1       \
# adep                                             LEBL
# ades                                             KMIA
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                       3
# actual_distance                           7544.863035
# altitude_difference                                -1
# bearing                                    285.530704
# elevation_gradient                          -0.000133
#
#                                                2       \
# adep                                             ESSA
# ades                                             KORD
# aircraft_type                                    A333
# wtc                                                 H
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Altitude_ades                                     204
# actual_distance                           6855.624802
# altitude_difference                               166
# bearing                                    305.643136
# elevation_gradient                           0.024214
#
#                                                3       \
# adep                                             LSZH
# ades                                             KPHL
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                      12
# actual_distance                           6459.885397
# altitude_difference                              -420
# bearing                                    296.005451
# elevation_gradient                          -0.065017
#
#                                                4       \
# adep                                             EIDW
# ades                                             EGLL
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      25
# actual_distance                            448.923048
# altitude_difference                               -49
# bearing                                    116.445141
# elevation_gradient                           -0.10915
#
#                                                5       \
# adep                                             ENGM
# ades                                             LEAL
# aircraft_type                                    A20N
# wtc                                                 M
# airline              8be5c854fd664bcb97fb543339f74770
# ...                                               ...
# Altitude_ades                                      44
# actual_distance                           2570.426742
# altitude_difference                              -164
# bearing                                    203.829766
# elevation_gradient                          -0.063803
#
#                                                6       \
# adep                                             EGAC
# ades                                             EGLL
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      25
# actual_distance                            502.584003
# altitude_difference                                20
# bearing                                    131.803893
# elevation_gradient                           0.039794
#
#                                                7       \
# adep                                             LTFM
# ades                                             LYBE
# aircraft_type                                    B738
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                     103
# actual_distance                            790.539429
# altitude_difference                              -222
# bearing                                    302.700411
# elevation_gradient                          -0.280821
#
#                                                8       \
# adep                                             KLAX
# ades                                             LTFM
# aircraft_type                                    B789
# wtc                                                 H
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                     325
# actual_distance                          11002.355884
# altitude_difference                               286
# bearing                                     24.367089
# elevation_gradient                           0.025994
#
#                                                9       ...  \
# adep                                             LTFM  ...
# ades                                             LTAC  ...
# aircraft_type                                    A321  ...
# wtc                                                 M  ...
# airline              6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                               ...  ...
# Altitude_ades                                     953  ...
# actual_distance                            379.701883  ...
# altitude_difference                               628  ...
# bearing                                    108.236772  ...
# elevation_gradient                           1.653929  ...
#
#                                                368361  \
# adep                                             LIRF
# ades                                             EBBR
# aircraft_type                                    A320
# wtc                                                 M
# airline              bdeeef3a675587d530de70a25d7118d2
# ...                                               ...
# Altitude_ades                                      57
# actual_distance                           1171.335841
# altitude_difference                                53
# bearing                                    332.262955
# elevation_gradient                           0.045247
#
#                                                368362  \
# adep                                             EGLL
# ades                                             LSZH
# aircraft_type                                    A21N
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Altitude_ades                                     432
# actual_distance                            788.345953
# altitude_difference                               407
# bearing                                    120.930202
# elevation_gradient                           0.516271
#
#                                                368363  \
# adep                                             LTFM
# ades                                             LIMC
# aircraft_type                                    A321
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                     234
# actual_distance                            1682.22032
# altitude_difference                               -91
# bearing                                    293.444038
# elevation_gradient                          -0.054095
#
#                                                368364  \
# adep                                             LSZH
# ades                                             LGTS
# aircraft_type                                    A320
# wtc                                                 M
# airline              2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                               ...
# Altitude_ades                                       7
# actual_distance                           1384.862343
# altitude_difference                              -425
# bearing                                    118.608849
# elevation_gradient                           -0.30689
#
#                                                368365  \
# adep                                             EDDV
# ades                                             LOWW
# aircraft_type                                    E195
# wtc                                                 M
# airline              5d407cb11cc29578cc3e292e743f5393
# ...                                               ...
# Altitude_ades                                     183
# actual_distance                            687.443083
# altitude_difference                               127
# bearing                                    131.991329
# elevation_gradient                           0.184743
#
#                                                368366  \
# adep                                             LFPG
# ades                                             KMIA
# aircraft_type                                    B788
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                       3
# actual_distance                           7371.510894
# altitude_difference                              -117
# bearing                                    282.661191
# elevation_gradient                          -0.015872
#
#                                                368367  \
# adep                                             LTFM
# ades                                             EDDB
# aircraft_type                                    A21N
# wtc                                                 M
# airline              6351ec1b849adacc0cbb3b1313d8d39b
# ...                                               ...
# Altitude_ades                                      48
# actual_distance                           1686.504718
# altitude_difference                              -277
# bearing                                    322.204001
# elevation_gradient                          -0.164245
#
#                                                368368  \
# adep                                             EDDL
# ades                                             EIDW
# aircraft_type                                    A320
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      74
# actual_distance                             915.12942
# altitude_difference                                29
# bearing                                    290.097453
# elevation_gradient                            0.03169
#
#                                                368369  \
# adep                                             LFPG
# ades                                             EIDW
# aircraft_type                                    A21N
# wtc                                                 M
# airline              a73f82288988b79be490c6322f4c32ed
# ...                                               ...
# Altitude_ades                                      74
# actual_distance                             784.92987
# altitude_difference                               -46
# bearing                                    311.966635
# elevation_gradient                          -0.058604
#
#                                                368370
# adep                                             LEMD
# ades                                             KJFK
# aircraft_type                                    B772
# wtc                                                 H
# airline              5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                               ...
# Altitude_ades                                       4
# actual_distance                           5762.301327
# altitude_difference                              -606
# bearing                                    294.723106
# elevation_gradient                          -0.105166
#
# [80 rows x 368371 columns]

# %%
# List of categorical columns to analyze
categorical_columns = ['aircraft_type', 
                       'wtc', 
                       'airline',
                       'offblock_hour',
                       'offblock_minute', 
                       'offblock_day_of_week',
                       'offblock_month',
                       'offblock_week_of_year', 
                       'offblock_season', 
                       'arrival_hour',
                       'arrival_minute',
                       'is_offblock_weekend',
                       'is_offblock_rush_hour',
                       'flight_duration_category',                       
                       'adep_region', 
                       'ades_region', 
                       'same_country_flight',
                       'same_region_flight',                        
                       'flight_direction',
                       'is_intercontinental',
                       'Manufacturer',
                       'Model_FAA',
                       'Physical_Class_Engine',
                       'FAA_Weight']

# Calculate the number of unique values for each categorical column efficiently
unique_variations = challenge_set_updated[categorical_columns].nunique()

# Display the number of variations for each categorical variable
unique_variations
# Out:
# aircraft_type               30
# wtc                          2
# airline                     29
# offblock_hour               24
# offblock_minute             60
# offblock_day_of_week         7
# offblock_month              12
# offblock_week_of_year       52
# offblock_season              4
# arrival_hour                24
# arrival_minute              60
# is_offblock_weekend          2
# is_offblock_rush_hour        2
# flight_duration_category     4
# adep_region                  7
# ades_region                  7
# same_country_flight          2
# same_region_flight           2
# flight_direction             3
# is_intercontinental          2
# Manufacturer                 7
# Model_FAA                   30
# Physical_Class_Engine        2
# FAA_Weight                   3
# dtype: int64

# %%
# Extract airports from both datasets
challenge_airports = set(challenge_set_updated['adep']).union(set(challenge_set_updated['ades']))
submission_airports = set(submission_set_updated['adep']).union(set(submission_set_updated['ades']))

# Find airports in challenge_set_updated that are not in submission_set_updated
airports_only_in_challenge = challenge_airports - submission_airports

# Find airports in submission_set_updated that are not in challenge_set_updated
airports_only_in_submission = submission_airports - challenge_airports

# Display the results
print("Airports in challenge_set_updated that are not in submission_set_updated:")
print(airports_only_in_challenge)

print("\nAirports in submission_set_updated that are not in challenge_set_updated:")
print(airports_only_in_submission)
# Out:
# Airports in challenge_set_updated that are not in submission_set_updated:
# {'HAAB', 'USSS', 'UTNU', 'LTAS', 'GMTA', 'CYFB', 'LJMB', 'EYKA', 'VVTS', 'KNYL', 'VTBS', 'LEZG', 'UGSB', 'WADD', 'LCRA', 'DBBB', 'VNKT', 'GCXO', 'LFTM', 'LEGR', 'CYYT', 'LFCR', 'LTFC', 'HSSK', 'WMKK', 'FZAA', 'TNCA', 'EDLW', 'LFRH', 'KOMA', 'KPAE', 'RPLL', 'LRBS', 'VGHS', 'GMFK', 'OPIS', 'LIEA', 'EPMO', 'CYUL', 'EDSB', 'EFOU', 'EDFH', 'EGJJ', 'UKHH', 'OMDW', 'RKSI', 'SBGR', 'FIMP', 'FAOR', 'LFTW', 'KGSP', 'HCMM', 'KFLL', 'DGAA', 'OMAA', 'LPAZ', 'EDLV', 'FCPP', 'SVMI', 'LGBL', 'KTUL', 'EFKI', 'LIMJ', 'LECH', 'UTTT', 'TBPB', 'DNMM', 'FNLU', 'UTSB', 'OPKC', 'LDRI', 'EGHL', 'LXGB', 'EPKT', 'LTCU'}
#
# Airports in submission_set_updated that are not in challenge_set_updated:
# {'EFET', 'KDAB', 'ESKN', 'RJTT', 'KRFD', 'LKMT', 'DAOO', 'HHAS', 'MMPR', 'LKTB', 'LTCM', 'LFBH', 'LEAB'}

# %%
# Clustering based on geographical coordinates for challenge_set_updated

# Extract coordinates for adep and ades
adep_coords = challenge_set_updated[['Latitude_adep', 'Longitude_adep']].values
ades_coords = challenge_set_updated[['Latitude_ades', 'Longitude_ades']].values

# Combine all coordinates for clustering
combined_coords = np.vstack((adep_coords, ades_coords))

# Calculate inertia for each k value in the specified range
inertia = []
k_range = range(1, 50)  # Testing cluster sizes from 1 to 50

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(combined_coords)
    inertia.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.figure(figsize=(10, 6))
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia (Sum of Squared Distances)')
plt.title('Elbow Method for Optimal k')
plt.grid(True)
plt.show()
        
# Automatically determining the optimal k using the "elbow" point
# Finding the point where the reduction in inertia slows down significantly
optimal_k = 1  # Default to 1 cluster if no elbow is detected
threshold_ratio = 0.01  # Define a threshold for identifying the elbow point

# Checking for the point where inertia reduction starts to slow down
for i in range(1, len(inertia) - 1):
    if (inertia[i - 1] - inertia[i]) > (inertia[i] - inertia[i + 1]) * threshold_ratio:
        optimal_k = i + 1
        break

# %%
# Apply K-means clustering on combined coordinates
kmeans_geo = KMeans(n_clusters=20, random_state=42)  
kmeans_geo.fit(combined_coords)

# Assign cluster labels back to adep and ades separately
adep_geo_labels = kmeans_geo.predict(adep_coords)
ades_geo_labels = kmeans_geo.predict(ades_coords)

# Map cluster labels to the original dataframe
challenge_set_updated['adep_geo_cluster'] = adep_geo_labels
challenge_set_updated['ades_geo_cluster'] = ades_geo_labels

# %%
# Clustering based on geographical coordinates for submission_set_updated

# Extract coordinates for adep and ades from submission_set_updated
adep_coords_submission = submission_set_updated[['Latitude_adep', 'Longitude_adep']].values
ades_coords_submission = submission_set_updated[['Latitude_ades', 'Longitude_ades']].values

# Assign cluster labels back to adep and ades separately for submission_set_updated
adep_geo_labels_submission = kmeans_geo.predict(adep_coords_submission)
ades_geo_labels_submission = kmeans_geo.predict(ades_coords_submission)

# Map cluster labels to the submission_set_updated dataframe
submission_set_updated['adep_geo_cluster'] = adep_geo_labels_submission
submission_set_updated['ades_geo_cluster'] = ades_geo_labels_submission

# %%
# Automatically identify categorical variables in the DataFrame
categorical_columns_auto = challenge_set_updated.select_dtypes(include=['object', 'category']).columns.tolist()

# Calculate the number of unique values for each automatically identified categorical column
unique_variations_auto = challenge_set_updated[categorical_columns_auto].nunique()

# Display the identified categorical variables and their number of unique variations
unique_variations_auto
# Out:
# adep                        459
# ades                        366
# aircraft_type                30
# wtc                           2
# airline                      29
# offblock_season               4
# flight_duration_category      4
# adep_region                   7
# ades_region                   7
# flight_direction              3
# Manufacturer                  7
# Model_FAA                    30
# Physical_Class_Engine         2
# FAA_Weight                    3
# dtype: int64

# %%
# Calculate the number of unique values for each categorical column efficiently
unique_variations = challenge_set_updated[categorical_columns].nunique()

# Display the number of variations for each categorical variable
unique_variations
# Out:
# aircraft_type               30
# wtc                          2
# airline                     29
# offblock_hour               24
# offblock_minute             60
# offblock_day_of_week         7
# offblock_month              12
# offblock_week_of_year       52
# offblock_season              4
# arrival_hour                24
# arrival_minute              60
# is_offblock_weekend          2
# is_offblock_rush_hour        2
# flight_duration_category     4
# adep_region                  7
# ades_region                  7
# same_country_flight          2
# same_region_flight           2
# flight_direction             3
# is_intercontinental          2
# Manufacturer                 7
# Model_FAA                   30
# Physical_Class_Engine        2
# FAA_Weight                   3
# dtype: int64

# %%
# Summary statistics of the challenge set
challenge_summary = challenge_set_updated.describe()

# Check for missing values
missing_values = challenge_set_updated.isnull().sum()

# Correlation matrix to check relationships between numerical features
correlation_matrix = challenge_set_updated.corr(numeric_only=True)

# Plotting the correlation matrix
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Challenge Set')
plt.show()

# Display the summary statistics and missing values
challenge_summary, missing_values
# Out:
# (        taxiout_time  flown_distance            tow  track_variation_ARR_100  \
#  count  368371.000000   368371.000000  368371.000000            344953.000000
#  mean       13.509003     1022.422902   79511.807653                74.451965
#  std         5.757031     1128.832563   53280.808626                57.408515
#  min         1.000000       19.000000   14944.000000                 0.000000
#  25%        10.000000      338.000000   55836.000000                24.303922
#  50%        12.000000      648.000000   63852.000000                59.945523
#  75%        16.000000     1114.000000   73756.000000               124.180948
#  max        90.000000     7272.000000  351327.000000               180.000000
#
#         track_variation_DEP_40  track_variation_ENR  \
#  count           308844.000000        339923.000000
#  mean                70.607768            32.640811
#  std                 53.305970            28.915224
#  min                  0.000000             0.000000
#  25%                 25.523426            10.098077
#  50%                 57.510864            27.069933
#  75%                114.296709            46.032811
#  max                180.000000           179.925209
#
#         average_vertical_rate_ARR_100  average_vertical_rate_DEP_40  \
#  count                  344950.000000                 308843.000000
#  mean                    -1214.532871                   2218.441553
#  std                      1257.372074                   1728.012090
#  min                   -116470.787234                 -22391.562095
#  25%                     -1393.579890                   1947.452687
#  50%                     -1197.617822                   2173.308958
#  75%                      -984.500952                   2426.087868
#  max                     31131.539229                 154417.926724
#
#         average_vertical_rate_ENR  average_airspeed_ARR_100  ...  \
#  count              339921.000000             344767.000000  ...
#  mean                  211.096244                151.161274  ...
#  std                   696.082900                 21.160686  ...
#  min               -100246.382353                 -0.853312  ...
#  25%                    38.383349                140.552221  ...
#  50%                   124.301405                151.848103  ...
#  75%                   296.363422                162.683419  ...
#  max                 54730.315789                922.343740  ...
#
#         Altitude_adep  Latitude_ades  Longitude_ades  Altitude_ades  \
#  count  368371.000000  368371.000000   368371.000000  368371.000000
#  mean      155.922524      48.626453        5.779804     148.424561
#  std       192.744705       7.271241       24.177429     166.710265
#  min        -4.000000     -23.432000     -122.375000      -4.000000
#  25%        25.000000      41.297000        2.550000      25.000000
#  50%        74.000000      49.013000        9.222000      74.000000
#  75%       234.000000      53.421000       16.570000     208.000000
#  max      6400.000000      69.725000      140.386000    2835.000000
#
#         actual_distance  altitude_difference        bearing  \
#  count    368371.000000        368371.000000  368371.000000
#  mean       1792.372943            -7.497963     185.739711
#  std        2038.392985           249.061685     108.707829
#  min          32.122875         -6075.000000       0.112606
#  25%         554.323655          -138.000000      96.124865
#  50%        1112.227042            -2.000000     188.997460
#  75%        1957.775162           129.000000     294.557833
#  max       12289.405460          2510.000000     359.913734
#
#         elevation_gradient  adep_geo_cluster  ades_geo_cluster
#  count       368371.000000     368371.000000     368371.000000
#  mean            -0.008356          8.658651          8.633967
#  std              0.376606          5.764872          5.738586
#  min             -7.182588          0.000000          0.000000
#  25%             -0.109150          4.000000          4.000000
#  50%             -0.001320          7.000000          7.000000
#  75%              0.099872         14.000000         14.000000
#  max              6.201988         19.000000         19.000000
#
#  [8 rows x 68 columns],
#  adep                   0
#  ades                   0
#  aircraft_type          0
#  wtc                    0
#  airline                0
#                        ..
#  altitude_difference    0
#  bearing                0
#  elevation_gradient     0
#  adep_geo_cluster       0
#  ades_geo_cluster       0
#  Length: 82, dtype: int64)

# %%
# Function to rearrange the dataframe so that the target variable 'tow' is the last column
def rearrange_columns(df):
    # Moving 'tow' to the last position
    columns = [col for col in df.columns if col != 'tow'] + ['tow']
    df = df[columns]
    return df

# Remove some categorical columns
# mmaximo: I am not removing 'adep' and 'ades' anymore so I can use them to imput missing values
new_columns_to_remove = ['actual_distance']
# new_columns_to_remove = ['adep', 'ades', 'actual_distance']
challenge_set_updated = remove_columns(challenge_set_updated, new_columns_to_remove)
submission_set_updated = remove_columns(submission_set_updated, new_columns_to_remove)

# Apply One-Hot Encoding to the training set
# challenge_set_updated = pd.get_dummies(challenge_set_updated, columns=categorical_columns, drop_first=True)

# Apply One-Hot Encoding to the test set
# submission_set_updated = pd.get_dummies(submission_set_updated, columns=categorical_columns, drop_first=True)

# Align the test set columns with the training set columns
# Identify missing columns and create a DataFrame with those columns set to zero
missing_cols = set(challenge_set_updated.columns) - set(submission_set_updated.columns)
missing_cols_df = pd.DataFrame(0, index=submission_set_updated.index, columns=list(missing_cols))

# Concatenate the missing columns DataFrame with the test set
submission_set_updated = pd.concat([submission_set_updated, missing_cols_df], axis=1)

# Drop extra columns in the test set that are not in the training set
extra_cols = set(submission_set_updated.columns) - set(challenge_set_updated.columns)
submission_set_updated.drop(columns=list(extra_cols), inplace=True)

# Reorder the columns of the test set to match the training set
submission_set_updated = submission_set_updated[challenge_set_updated.columns]

# Rearrange columns
challenge_set_updated = rearrange_columns(challenge_set_updated)
submission_set_updated = rearrange_columns(submission_set_updated)

# %%
missing_cols
# Out:
# set()

# %%
extra_cols
# Out:
# set()

# %%
challenge_set_updated.T
# Out:
#                                               0       \
# adep                                            EGLL
# ades                                            EICK
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   277.346455
# elevation_gradient                          0.232363
# adep_geo_cluster                                   5
# ades_geo_cluster                                  14
# tow                                          54748.0
#
#                                               1       \
# adep                                            LEBL
# ades                                            KMIA
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   285.530704
# elevation_gradient                         -0.000133
# adep_geo_cluster                                   3
# ades_geo_cluster                                  13
# tow                                         185441.0
#
#                                               2       \
# adep                                            ESSA
# ades                                            KORD
# aircraft_type                                   A333
# wtc                                                H
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   305.643136
# elevation_gradient                          0.024214
# adep_geo_cluster                                   9
# ades_geo_cluster                                   1
# tow                                         230396.0
#
#                                               3       \
# adep                                            LSZH
# ades                                            KPHL
# aircraft_type                                   B788
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   296.005451
# elevation_gradient                         -0.065017
# adep_geo_cluster                                  19
# ades_geo_cluster                                   1
# tow                                         157615.0
#
#                                               4       \
# adep                                            EIDW
# ades                                            EGLL
# aircraft_type                                   A21N
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   116.445141
# elevation_gradient                          -0.10915
# adep_geo_cluster                                  14
# ades_geo_cluster                                   5
# tow                                     70318.447226
#
#                                               5       \
# adep                                            ENGM
# ades                                            LEAL
# aircraft_type                                   A20N
# wtc                                                M
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   203.829766
# elevation_gradient                         -0.063803
# adep_geo_cluster                                  17
# ades_geo_cluster                                   3
# tow                                          57721.0
#
#                                               6       \
# adep                                            EGAC
# ades                                            EGLL
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   131.803893
# elevation_gradient                          0.039794
# adep_geo_cluster                                  14
# ades_geo_cluster                                   5
# tow                                          56818.0
#
#                                               7       \
# adep                                            LTFM
# ades                                            LYBE
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   302.700411
# elevation_gradient                         -0.280821
# adep_geo_cluster                                   4
# ades_geo_cluster                                  18
# tow                                          60678.0
#
#                                               8       \
# adep                                            KLAX
# ades                                            LTFM
# aircraft_type                                   B789
# wtc                                                H
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    24.367089
# elevation_gradient                          0.025994
# adep_geo_cluster                                   6
# ades_geo_cluster                                   4
# tow                                         235632.0
#
#                                               9       ...  \
# adep                                            LTFM  ...
# ades                                            LTAC  ...
# aircraft_type                                   A321  ...
# wtc                                                M  ...
# airline             6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                              ...  ...
# bearing                                   108.236772  ...
# elevation_gradient                          1.653929  ...
# adep_geo_cluster                                   4  ...
# ades_geo_cluster                                   4  ...
# tow                                          73571.0  ...
#
#                                               368361  \
# adep                                            LIRF
# ades                                            EBBR
# aircraft_type                                   A320
# wtc                                                M
# airline             bdeeef3a675587d530de70a25d7118d2
# ...                                              ...
# bearing                                   332.262955
# elevation_gradient                          0.045247
# adep_geo_cluster                                  11
# ades_geo_cluster                                   8
# tow                                     61804.035897
#
#                                               368362  \
# adep                                            EGLL
# ades                                            LSZH
# aircraft_type                                   A21N
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   120.930202
# elevation_gradient                          0.516271
# adep_geo_cluster                                   5
# ades_geo_cluster                                  19
# tow                                          72756.0
#
#                                               368363  \
# adep                                            LTFM
# ades                                            LIMC
# aircraft_type                                   A321
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.444038
# elevation_gradient                         -0.054095
# adep_geo_cluster                                   4
# ades_geo_cluster                                  19
# tow                                          73571.0
#
#                                               368364  \
# adep                                            LSZH
# ades                                            LGTS
# aircraft_type                                   A320
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   118.608849
# elevation_gradient                          -0.30689
# adep_geo_cluster                                  19
# ades_geo_cluster                                  18
# tow                                          64826.0
#
#                                               368365  \
# adep                                            EDDV
# ades                                            LOWW
# aircraft_type                                   E195
# wtc                                                M
# airline             5d407cb11cc29578cc3e292e743f5393
# ...                                              ...
# bearing                                   131.991329
# elevation_gradient                          0.184743
# adep_geo_cluster                                   7
# ades_geo_cluster                                   2
# tow                                          40868.0
#
#                                               368366  \
# adep                                            LFPG
# ades                                            KMIA
# aircraft_type                                   B788
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   282.661191
# elevation_gradient                         -0.015872
# adep_geo_cluster                                   8
# ades_geo_cluster                                  13
# tow                                         163438.0
#
#                                               368367  \
# adep                                            LTFM
# ades                                            EDDB
# aircraft_type                                   A21N
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   322.204001
# elevation_gradient                         -0.164245
# adep_geo_cluster                                   4
# ades_geo_cluster                                   7
# tow                                          78707.0
#
#                                               368368  \
# adep                                            EDDL
# ades                                            EIDW
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   290.097453
# elevation_gradient                           0.03169
# adep_geo_cluster                                   8
# ades_geo_cluster                                  14
# tow                                         62942.75
#
#                                               368369  \
# adep                                            LFPG
# ades                                            EIDW
# aircraft_type                                   A21N
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   311.966635
# elevation_gradient                         -0.058604
# adep_geo_cluster                                   8
# ades_geo_cluster                                  14
# tow                                     72611.161024
#
#                                               368370
# adep                                            LEMD
# ades                                            KJFK
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   294.723106
# elevation_gradient                         -0.105166
# adep_geo_cluster                                  16
# ades_geo_cluster                                   1
# tow                                         195373.0
#
# [81 rows x 368371 columns]

# %%
submission_set_updated.T
# Out:
#                                               0       \
# adep                                            LTFJ
# ades                                            LFLL
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.477205
# elevation_gradient                         -0.030154
# adep_geo_cluster                                   4
# ades_geo_cluster                                  12
# tow                                              NaN
#
#                                               1       \
# adep                                            EBBR
# ades                                            KJFK
# aircraft_type                                   A333
# wtc                                                H
# airline             bdeeef3a675587d530de70a25d7118d2
# ...                                              ...
# bearing                                   291.395141
# elevation_gradient                         -0.009004
# adep_geo_cluster                                   8
# ades_geo_cluster                                   1
# tow                                              NaN
#
#                                               2       \
# adep                                            KMIA
# ades                                            EGLL
# aircraft_type                                   B77W
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    43.036806
# elevation_gradient                          0.003095
# adep_geo_cluster                                  13
# ades_geo_cluster                                   5
# tow                                              NaN
#
#                                               3       \
# adep                                            EGCN
# ades                                            LEAL
# aircraft_type                                   B38M
# wtc                                                M
# airline             3922524069809ac4326134429751e26f
# ...                                              ...
# bearing                                   178.644825
# elevation_gradient                         -0.006508
# adep_geo_cluster                                   5
# ades_geo_cluster                                   3
# tow                                              NaN
#
#                                               4       \
# adep                                            EIDW
# ades                                            LFLL
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   131.790949
# elevation_gradient                          0.149765
# adep_geo_cluster                                  14
# ades_geo_cluster                                  12
# tow                                              NaN
#
#                                               5       \
# adep                                            LTFJ
# ades                                            LTAC
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   104.173834
# elevation_gradient                          1.983765
# adep_geo_cluster                                   4
# ades_geo_cluster                                   4
# tow                                              NaN
#
#                                               6       \
# adep                                            EGLL
# ades                                            EIDW
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   301.052709
# elevation_gradient                           0.10915
# adep_geo_cluster                                   5
# ades_geo_cluster                                  14
# tow                                              NaN
#
#                                               7       \
# adep                                            LSZH
# ades                                            EDDH
# aircraft_type                                   A320
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                       7.8847
# elevation_gradient                         -0.598866
# adep_geo_cluster                                  19
# ades_geo_cluster                                   7
# tow                                              NaN
#
#                                               8       \
# adep                                            EGLL
# ades                                            EICK
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   277.346455
# elevation_gradient                          0.232363
# adep_geo_cluster                                   5
# ades_geo_cluster                                  14
# tow                                              NaN
#
#                                               9       ...  \
# adep                                            LEMD  ...
# ades                                            EIDW  ...
# aircraft_type                                   A320  ...
# wtc                                                M  ...
# airline             a73f82288988b79be490c6322f4c32ed  ...
# ...                                              ...  ...
# bearing                                   352.849559  ...
# elevation_gradient                         -0.368588  ...
# adep_geo_cluster                                  16  ...
# ades_geo_cluster                                  14  ...
# tow                                              NaN  ...
#
#                                               105781  \
# adep                                            BKPR
# ades                                            LSGG
# aircraft_type                                   BCS3
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   294.105445
# elevation_gradient                         -1.085058
# adep_geo_cluster                                  18
# ades_geo_cluster                                  12
# tow                                              NaN
#
#                                               105782  \
# adep                                            LTFJ
# ades                                            LFLL
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.477205
# elevation_gradient                         -0.030154
# adep_geo_cluster                                   4
# ades_geo_cluster                                  12
# tow                                              NaN
#
#                                               105783  \
# adep                                            KORD
# ades                                            EGLL
# aircraft_type                                   B789
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    47.859294
# elevation_gradient                         -0.028218
# adep_geo_cluster                                   1
# ades_geo_cluster                                   5
# tow                                              NaN
#
#                                               105784  \
# adep                                            KJFK
# ades                                            LEBL
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    62.377552
# elevation_gradient                               0.0
# adep_geo_cluster                                   1
# ades_geo_cluster                                   3
# tow                                              NaN
#
#                                               105785  \
# adep                                            KSFO
# ades                                            EIDW
# aircraft_type                                   A333
# wtc                                                H
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                    33.907846
# elevation_gradient                          0.008554
# adep_geo_cluster                                   6
# ades_geo_cluster                                  14
# tow                                              NaN
#
#                                               105786  \
# adep                                            LTFJ
# ades                                            EKCH
# aircraft_type                                   B38M
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   329.024194
# elevation_gradient                         -0.150159
# adep_geo_cluster                                   4
# ades_geo_cluster                                   7
# tow                                              NaN
#
#                                               105787  \
# adep                                            LOWW
# ades                                            KIAD
# aircraft_type                                   B763
# wtc                                                H
# airline             5d407cb11cc29578cc3e292e743f5393
# ...                                              ...
# bearing                                   300.682568
# elevation_gradient                         -0.012142
# adep_geo_cluster                                   2
# ades_geo_cluster                                   1
# tow                                              NaN
#
#                                               105788  \
# adep                                            LTFM
# ades                                            LSZH
# aircraft_type                                   A321
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   300.085737
# elevation_gradient                          0.061473
# adep_geo_cluster                                   4
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               105789  \
# adep                                            EHAM
# ades                                            EDDF
# aircraft_type                                   A320
# wtc                                                M
# airline             f502877cab405652cf0dd70c2213e730
# ...                                              ...
# bearing                                   132.448927
# elevation_gradient                          0.311654
# adep_geo_cluster                                   8
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               105790
# adep                                            UBBB
# ades                                            LTFM
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    279.85055
# elevation_gradient                          0.179499
# adep_geo_cluster                                  15
# ades_geo_cluster                                   4
# tow                                              NaN
#
# [81 rows x 105791 columns]

# %%
total_dataset = pd.concat([challenge_set_updated, submission_set_updated])
total_dataset.T
# Out:
#                                               0       \
# adep                                            EGLL
# ades                                            EICK
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   277.346455
# elevation_gradient                          0.232363
# adep_geo_cluster                                   5
# ades_geo_cluster                                  14
# tow                                          54748.0
#
#                                               1       \
# adep                                            LEBL
# ades                                            KMIA
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   285.530704
# elevation_gradient                         -0.000133
# adep_geo_cluster                                   3
# ades_geo_cluster                                  13
# tow                                         185441.0
#
#                                               2       \
# adep                                            ESSA
# ades                                            KORD
# aircraft_type                                   A333
# wtc                                                H
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   305.643136
# elevation_gradient                          0.024214
# adep_geo_cluster                                   9
# ades_geo_cluster                                   1
# tow                                         230396.0
#
#                                               3       \
# adep                                            LSZH
# ades                                            KPHL
# aircraft_type                                   B788
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                   296.005451
# elevation_gradient                         -0.065017
# adep_geo_cluster                                  19
# ades_geo_cluster                                   1
# tow                                         157615.0
#
#                                               4       \
# adep                                            EIDW
# ades                                            EGLL
# aircraft_type                                   A21N
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   116.445141
# elevation_gradient                          -0.10915
# adep_geo_cluster                                  14
# ades_geo_cluster                                   5
# tow                                     70318.447226
#
#                                               5       \
# adep                                            ENGM
# ades                                            LEAL
# aircraft_type                                   A20N
# wtc                                                M
# airline             8be5c854fd664bcb97fb543339f74770
# ...                                              ...
# bearing                                   203.829766
# elevation_gradient                         -0.063803
# adep_geo_cluster                                  17
# ades_geo_cluster                                   3
# tow                                          57721.0
#
#                                               6       \
# adep                                            EGAC
# ades                                            EGLL
# aircraft_type                                   A320
# wtc                                                M
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                   131.803893
# elevation_gradient                          0.039794
# adep_geo_cluster                                  14
# ades_geo_cluster                                   5
# tow                                          56818.0
#
#                                               7       \
# adep                                            LTFM
# ades                                            LYBE
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   302.700411
# elevation_gradient                         -0.280821
# adep_geo_cluster                                   4
# ades_geo_cluster                                  18
# tow                                          60678.0
#
#                                               8       \
# adep                                            KLAX
# ades                                            LTFM
# aircraft_type                                   B789
# wtc                                                H
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    24.367089
# elevation_gradient                          0.025994
# adep_geo_cluster                                   6
# ades_geo_cluster                                   4
# tow                                         235632.0
#
#                                               9       ...  \
# adep                                            LTFM  ...
# ades                                            LTAC  ...
# aircraft_type                                   A321  ...
# wtc                                                M  ...
# airline             6351ec1b849adacc0cbb3b1313d8d39b  ...
# ...                                              ...  ...
# bearing                                   108.236772  ...
# elevation_gradient                          1.653929  ...
# adep_geo_cluster                                   4  ...
# ades_geo_cluster                                   4  ...
# tow                                          73571.0  ...
#
#                                               105781  \
# adep                                            BKPR
# ades                                            LSGG
# aircraft_type                                   BCS3
# wtc                                                M
# airline             2d5def0a5a844b343ba1b7cc9cb28fa9
# ...                                              ...
# bearing                                   294.105445
# elevation_gradient                         -1.085058
# adep_geo_cluster                                  18
# ades_geo_cluster                                  12
# tow                                              NaN
#
#                                               105782  \
# adep                                            LTFJ
# ades                                            LFLL
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   293.477205
# elevation_gradient                         -0.030154
# adep_geo_cluster                                   4
# ades_geo_cluster                                  12
# tow                                              NaN
#
#                                               105783  \
# adep                                            KORD
# ades                                            EGLL
# aircraft_type                                   B789
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    47.859294
# elevation_gradient                         -0.028218
# adep_geo_cluster                                   1
# ades_geo_cluster                                   5
# tow                                              NaN
#
#                                               105784  \
# adep                                            KJFK
# ades                                            LEBL
# aircraft_type                                   B772
# wtc                                                H
# airline             5543e4dc327359ffaf5b9c0e6faaf0e1
# ...                                              ...
# bearing                                    62.377552
# elevation_gradient                               0.0
# adep_geo_cluster                                   1
# ades_geo_cluster                                   3
# tow                                              NaN
#
#                                               105785  \
# adep                                            KSFO
# ades                                            EIDW
# aircraft_type                                   A333
# wtc                                                H
# airline             a73f82288988b79be490c6322f4c32ed
# ...                                              ...
# bearing                                    33.907846
# elevation_gradient                          0.008554
# adep_geo_cluster                                   6
# ades_geo_cluster                                  14
# tow                                              NaN
#
#                                               105786  \
# adep                                            LTFJ
# ades                                            EKCH
# aircraft_type                                   B38M
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   329.024194
# elevation_gradient                         -0.150159
# adep_geo_cluster                                   4
# ades_geo_cluster                                   7
# tow                                              NaN
#
#                                               105787  \
# adep                                            LOWW
# ades                                            KIAD
# aircraft_type                                   B763
# wtc                                                H
# airline             5d407cb11cc29578cc3e292e743f5393
# ...                                              ...
# bearing                                   300.682568
# elevation_gradient                         -0.012142
# adep_geo_cluster                                   2
# ades_geo_cluster                                   1
# tow                                              NaN
#
#                                               105788  \
# adep                                            LTFM
# ades                                            LSZH
# aircraft_type                                   A321
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                   300.085737
# elevation_gradient                          0.061473
# adep_geo_cluster                                   4
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               105789  \
# adep                                            EHAM
# ades                                            EDDF
# aircraft_type                                   A320
# wtc                                                M
# airline             f502877cab405652cf0dd70c2213e730
# ...                                              ...
# bearing                                   132.448927
# elevation_gradient                          0.311654
# adep_geo_cluster                                   8
# ades_geo_cluster                                  19
# tow                                              NaN
#
#                                               105790
# adep                                            UBBB
# ades                                            LTFM
# aircraft_type                                   B738
# wtc                                                M
# airline             6351ec1b849adacc0cbb3b1313d8d39b
# ...                                              ...
# bearing                                    279.85055
# elevation_gradient                          0.179499
# adep_geo_cluster                                  15
# ades_geo_cluster                                   4
# tow                                              NaN
#
# [81 rows x 474162 columns]

# %%
total_dataset.replace(np.inf, np.nan, inplace=True)

# %%
pd.set_option('display.max_rows', None)

print('Showing proportion of NaNs in the total dataset (challenge + submission):')
print(total_dataset.isna().sum()/total_dataset.shape[0])

pd.reset_option('display.max_rows')
# Out:
# Showing proportion of NaNs in the total dataset (challenge + submission):
# adep                             0.000000
# ades                             0.000000
# aircraft_type                    0.000000
# wtc                              0.000000
# airline                          0.000000
# taxiout_time                     0.000000
# flown_distance                   0.000000
# track_variation_ARR_100          0.063478
# track_variation_DEP_40           0.161708
# track_variation_ENR              0.076767
# average_vertical_rate_ARR_100    0.063485
# average_vertical_rate_DEP_40     0.161711
# average_vertical_rate_ENR        0.076771
# average_airspeed_ARR_100         0.063963
# average_airspeed_DEP_40          0.161902
# average_airspeed_ENR             0.076788
# groundspeed_ARR_100              0.063478
# groundspeed_DEP_40               0.161708
# groundspeed_ENR                  0.076767
# wind_distance_ARR_100            0.063362
# wind_distance_DEP_40             0.161495
# wind_distance_ENR                0.076765
# average_temperature_ARR_100      0.063866
# average_temperature_DEP_40       0.161803
# average_temperature_ENR          0.076786
# average_humidity_ARR_100         0.063866
# average_humidity_DEP_40          0.161803
# average_humidity_ENR             0.076786
# specific_energy_ARR_100          0.421021
# specific_energy_DEP_40           0.168069
# specific_energy_ENR              0.079291
# flown_distance_ARR_100           0.063362
# flown_distance_DEP_40            0.161495
# flown_distance_ENR               0.076765
# average_altitude_ARR_100         0.063362
# average_altitude_DEP_40          0.161495
# average_altitude_ENR             0.076765
# specific_energy                  0.169406
# offblock_hour                    0.000000
# offblock_minute                  0.000000
# offblock_day_of_week             0.000000
# offblock_month                   0.000000
# offblock_week_of_year            0.000000
# offblock_season                  0.000000
# arrival_hour                     0.000000
# arrival_minute                   0.000000
# offblock_to_arrival_duration     0.000000
# is_offblock_weekend              0.000000
# is_offblock_rush_hour            0.000000
# taxi_ratio                       0.000000
# flight_speed                     0.000000
# normalized_taxi_ratio            0.000000
# flight_duration_category         0.000000
# speed_per_distance               0.000000
# cumulative_avg_speed             0.000000
# adep_region                      0.000000
# ades_region                      0.000000
# same_country_flight              0.000000
# same_region_flight               0.000000
# flight_direction                 0.000000
# is_intercontinental              0.000000
# Manufacturer                     0.000000
# Model_FAA                        0.000000
# Physical_Class_Engine            0.000000
# Num_Engines                      0.000000
# Approach_Speed_knot              0.000000
# FAA_Weight                       0.000000
# MTOW_kg                          0.000000
# MALW_kg                          0.000000
# Latitude_adep                    0.000000
# Longitude_adep                   0.000000
# Altitude_adep                    0.000000
# Latitude_ades                    0.000000
# Longitude_ades                   0.000000
# Altitude_ades                    0.000000
# altitude_difference              0.000000
# bearing                          0.000000
# elevation_gradient               0.000000
# adep_geo_cluster                 0.000000
# ades_geo_cluster                 0.000000
# tow                              0.223112
# dtype: float64

# %%
num_nans = total_dataset.isna().sum().sum()
columns = total_dataset.columns[total_dataset.isna().sum() > 0]
columns = list(columns)
columns.remove('tow')

cropped_dataset = total_dataset[['adep', 'ades', 'aircraft_type'] + columns]
cropped_dataset.head()

mean_values = cropped_dataset[columns].mean()

print(mean_values)
# Out:
# track_variation_ARR_100          7.449276e+01
# track_variation_DEP_40           7.069564e+01
# track_variation_ENR              3.261855e+01
# average_vertical_rate_ARR_100   -1.215484e+03
# average_vertical_rate_DEP_40     2.220749e+03
# average_vertical_rate_ENR        2.121080e+02
# average_airspeed_ARR_100         1.511868e+02
# average_airspeed_DEP_40          1.557047e+02
# average_airspeed_ENR             2.254129e+02
# groundspeed_ARR_100              1.486833e+02
# groundspeed_DEP_40               1.549602e+02
# groundspeed_ENR                  2.255860e+02
# wind_distance_ARR_100            1.848462e+02
# wind_distance_DEP_40             6.422145e+00
# wind_distance_ENR               -1.308974e+03
# average_temperature_ARR_100      2.640170e+02
# average_temperature_DEP_40       2.671713e+02
# average_temperature_ENR          2.239423e+02
# average_humidity_ARR_100         2.778440e-03
# average_humidity_DEP_40          2.629072e-03
# average_humidity_ENR             1.009892e-04
# specific_energy_ARR_100          2.485118e+04
# specific_energy_DEP_40           1.035590e+05
# specific_energy_ENR              1.401017e+05
# flown_distance_ARR_100           2.114661e+05
# flown_distance_DEP_40            8.309840e+04
# flown_distance_ENR               1.459314e+06
# average_altitude_ARR_100         1.255369e+04
# average_altitude_DEP_40          1.138256e+04
# average_altitude_ENR             3.327598e+04
# specific_energy                  4.310936e+04
# dtype: float64

# %%
grouped_dataset = cropped_dataset.groupby(['adep', 'ades', 'aircraft_type']).median()
grouped_dataset.head()

# print(grouped_dataset.shape[0])
# total_dataset_imputted = total_dataset
# total_dataset_imputted[columns] = grouped_dataset[columns]
# Out:
#                          track_variation_ARR_100  track_variation_DEP_40  \
# adep ades aircraft_type
# BIKF EGCC B38M                        106.962873                1.163446
#           B738                         81.044395              111.183484
#      EGGD B38M                          2.626313               85.339340
#      EGKK B38M                         28.095888               97.143144
#           B738                         27.328421               70.711437
#
#                          track_variation_ENR  average_vertical_rate_ARR_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                     23.900614                   -1295.017024
#           B738                     41.552622                   -1305.371088
#      EGGD B38M                     50.739064                   -1011.200000
#      EGKK B38M                     50.091165                    -952.869912
#           B738                     49.859458                    -909.765388
#
#                          average_vertical_rate_DEP_40  \
# adep ades aircraft_type
# BIKF EGCC B38M                            2213.313208
#           B738                            2422.756534
#      EGGD B38M                            2212.041481
#      EGKK B38M                            2296.594651
#           B738                            2350.985685
#
#                          average_vertical_rate_ENR  average_airspeed_ARR_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                          126.605623                151.851590
#           B738                          510.586700                154.229611
#      EGGD B38M                          493.137522                159.396937
#      EGKK B38M                          135.056865                166.848617
#           B738                          103.776036                133.103852
#
#                          average_airspeed_DEP_40  average_airspeed_ENR  \
# adep ades aircraft_type
# BIKF EGCC B38M                        161.855873            218.058445
#           B738                        156.074817            239.202101
#      EGGD B38M                        148.655209            227.001384
#      EGKK B38M                        148.386683            244.147893
#           B738                        144.025534            235.757647
#
#                          groundspeed_ARR_100  ...  specific_energy_ARR_100  \
# adep ades aircraft_type                       ...
# BIKF EGCC B38M                    147.810309  ...                      NaN
#           B738                    153.433115  ...             33050.360329
#      EGGD B38M                    156.959380  ...             10452.881024
#      EGKK B38M                    142.936505  ...                      NaN
#           B738                    135.057922  ...              6292.469906
#
#                          specific_energy_DEP_40  specific_energy_ENR  \
# adep ades aircraft_type
# BIKF EGCC B38M                    105532.032682        142832.656678
#           B738                    116496.851843        156254.037659
#      EGGD B38M                    104110.500429        166074.447711
#      EGKK B38M                    104783.106874        126285.912989
#           B738                    108914.199982        140529.028668
#
#                          flown_distance_ARR_100  flown_distance_DEP_40  \
# adep ades aircraft_type
# BIKF EGCC B38M                    199133.428340           83025.879760
#           B738                    164696.149215           86756.488492
#      EGGD B38M                      7764.523383           82020.437072
#      EGKK B38M                    243056.094561           86888.963951
#           B738                    210496.571200           86463.011973
#
#                          flown_distance_ENR  average_altitude_ARR_100  \
# adep ades aircraft_type
# BIKF EGCC B38M                 8.054719e+05              12883.216136
#           B738                 1.357355e+06              12846.607843
#      EGGD B38M                 1.370463e+06              14647.890379
#      EGKK B38M                 1.704992e+06               9765.714829
#           B738                 1.263268e+06              10251.180464
#
#                          average_altitude_DEP_40  average_altitude_ENR  \
# adep ades aircraft_type
# BIKF EGCC B38M                      11937.783019          37091.368274
#           B738                      11732.742440          36010.436786
#      EGGD B38M                      10340.962890          35724.085366
#      EGKK B38M                      11512.400107          36446.827604
#           B738                      10994.938650          34416.558291
#
#                          specific_energy
# adep ades aircraft_type
# BIKF EGCC B38M              45546.012878
#           B738              47464.876791
#      EGGD B38M              38377.301934
#      EGKK B38M              42104.301590
#           B738              39593.635846
#
# [5 rows x 31 columns]

# %%
print('Number of NaNs:', total_dataset.isna().sum().sum())
# Out:
# Number of NaNs: 1791956

# %%
mask = (total_dataset['adep'] == 'BIKF') & (total_dataset['ades'] == 'EGCC') & (total_dataset['aircraft_type'] == 'B38M')
total_dataset.loc[mask]
# Out:
#         adep  ades aircraft_type wtc                           airline  \
# 15060   BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
# 105507  BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
#
#         taxiout_time  flown_distance  track_variation_ARR_100  \
# 15060           10.0             931               106.962873
# 105507          10.0             933                      NaN
#
#         track_variation_DEP_40  track_variation_ENR  ...  Altitude_adep  \
# 15060                      NaN             6.217697  ...             53
# 105507                1.163446            41.583531  ...             53
#
#         Latitude_ades  Longitude_ades  Altitude_ades  altitude_difference  \
# 15060          53.354          -2.275             79                   26
# 105507         53.354          -2.275             79                   26
#
#            bearing  elevation_gradient  adep_geo_cluster  ades_geo_cluster  \
# 15060   126.071797            0.015728                14                 5
# 105507  126.071797            0.015728                14                 5
#
#             tow
# 15060   59835.0
# 105507      NaN
#
# [2 rows x 81 columns]

# %%
from tqdm import tqdm

num_elems = grouped_dataset.shape[0] * grouped_dataset.shape[1]
count = 0

for group, row in tqdm(grouped_dataset.iterrows(), total=grouped_dataset.shape[0]):
    adep = group[0]
    ades = group[1]
    aircraft_type = group[2]
    mask = (total_dataset['adep'] == adep) & (total_dataset['ades'] == ades) & (total_dataset['aircraft_type'] == aircraft_type)
    for col, value in row.items():
        if not pd.isna(value):
            total_dataset.loc[mask, col] = total_dataset.loc[mask, col].fillna(value)
# Out:
# 100%|██████████| 9942/9942 [08:10<00:00, 20.27it/s]

# %%
mask = (total_dataset['adep'] == 'BIKF') & (total_dataset['ades'] == 'EGCC') & (total_dataset['aircraft_type'] == 'B38M')
total_dataset.loc[mask]
# Out:
#         adep  ades aircraft_type wtc                           airline  \
# 15060   BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
# 105507  BIKF  EGCC          B38M   M  3922524069809ac4326134429751e26f
#
#         taxiout_time  flown_distance  track_variation_ARR_100  \
# 15060           10.0             931               106.962873
# 105507          10.0             933               106.962873
#
#         track_variation_DEP_40  track_variation_ENR  ...  Altitude_adep  \
# 15060                 1.163446             6.217697  ...             53
# 105507                1.163446            41.583531  ...             53
#
#         Latitude_ades  Longitude_ades  Altitude_ades  altitude_difference  \
# 15060          53.354          -2.275             79                   26
# 105507         53.354          -2.275             79                   26
#
#            bearing  elevation_gradient  adep_geo_cluster  ades_geo_cluster  \
# 15060   126.071797            0.015728                14                 5
# 105507  126.071797            0.015728                14                 5
#
#             tow
# 15060   59835.0
# 105507      NaN
#
# [2 rows x 81 columns]

# %%
print('Number of NaNs:', total_dataset.isna().sum().sum())
# Out:
# Number of NaNs: 416360

# %%
pd.set_option('display.max_rows', None)

print('Showing proportion of NaNs in the total dataset (challenge + submission):')
print(total_dataset.isna().sum()/total_dataset.shape[0])

pd.reset_option('display.max_rows')

columns_with_nan = total_dataset.columns[total_dataset.isna().sum() > 0]
columns_with_nan = list(columns_with_nan)
columns_with_nan.remove('tow')
print(columns_with_nan)
# Out:
# Showing proportion of NaNs in the total dataset (challenge + submission):
# adep                             0.000000
# ades                             0.000000
# aircraft_type                    0.000000
# wtc                              0.000000
# airline                          0.000000
# taxiout_time                     0.000000
# flown_distance                   0.000000
# track_variation_ARR_100          0.001683
# track_variation_DEP_40           0.031253
# track_variation_ENR              0.028794
# average_vertical_rate_ARR_100    0.001683
# average_vertical_rate_DEP_40     0.031253
# average_vertical_rate_ENR        0.028794
# average_airspeed_ARR_100         0.001742
# average_airspeed_DEP_40          0.031283
# average_airspeed_ENR             0.028805
# groundspeed_ARR_100              0.001683
# groundspeed_DEP_40               0.031253
# groundspeed_ENR                  0.028794
# wind_distance_ARR_100            0.001681
# wind_distance_DEP_40             0.031238
# wind_distance_ENR                0.028794
# average_temperature_ARR_100      0.001740
# average_temperature_DEP_40       0.031270
# average_temperature_ENR          0.028805
# average_humidity_ARR_100         0.001740
# average_humidity_DEP_40          0.031270
# average_humidity_ENR             0.028805
# specific_energy_ARR_100          0.007303
# specific_energy_DEP_40           0.031432
# specific_energy_ENR              0.029030
# flown_distance_ARR_100           0.001681
# flown_distance_DEP_40            0.031238
# flown_distance_ENR               0.028794
# average_altitude_ARR_100         0.001681
# average_altitude_DEP_40          0.031238
# average_altitude_ENR             0.028794
# specific_energy                  0.031432
# offblock_hour                    0.000000
# offblock_minute                  0.000000
# offblock_day_of_week             0.000000
# offblock_month                   0.000000
# offblock_week_of_year            0.000000
# offblock_season                  0.000000
# arrival_hour                     0.000000
# arrival_minute                   0.000000
# offblock_to_arrival_duration     0.000000
# is_offblock_weekend              0.000000
# is_offblock_rush_hour            0.000000
# taxi_ratio                       0.000000
# flight_speed                     0.000000
# normalized_taxi_ratio            0.000000
# flight_duration_category         0.000000
# speed_per_distance               0.000000
# cumulative_avg_speed             0.000000
# adep_region                      0.000000
# ades_region                      0.000000
# same_country_flight              0.000000
# same_region_flight               0.000000
# flight_direction                 0.000000
# is_intercontinental              0.000000
# Manufacturer                     0.000000
# Model_FAA                        0.000000
# Physical_Class_Engine            0.000000
# Num_Engines                      0.000000
# Approach_Speed_knot              0.000000
# FAA_Weight                       0.000000
# MTOW_kg                          0.000000
# MALW_kg                          0.000000
# Latitude_adep                    0.000000
# Longitude_adep                   0.000000
# Altitude_adep                    0.000000
# Latitude_ades                    0.000000
# Longitude_ades                   0.000000
# Altitude_ades                    0.000000
# altitude_difference              0.000000
# bearing                          0.000000
# elevation_gradient               0.000000
# adep_geo_cluster                 0.000000
# ades_geo_cluster                 0.000000
# tow                              0.223112
# dtype: float64
# ['track_variation_ARR_100', 'track_variation_DEP_40', 'track_variation_ENR', 'average_vertical_rate_ARR_100', 'average_vertical_rate_DEP_40', 'average_vertical_rate_ENR', 'average_airspeed_ARR_100', 'average_airspeed_DEP_40', 'average_airspeed_ENR', 'groundspeed_ARR_100', 'groundspeed_DEP_40', 'groundspeed_ENR', 'wind_distance_ARR_100', 'wind_distance_DEP_40', 'wind_distance_ENR', 'average_temperature_ARR_100', 'average_temperature_DEP_40', 'average_temperature_ENR', 'average_humidity_ARR_100', 'average_humidity_DEP_40', 'average_humidity_ENR', 'specific_energy_ARR_100', 'specific_energy_DEP_40', 'specific_energy_ENR', 'flown_distance_ARR_100', 'flown_distance_DEP_40', 'flown_distance_ENR', 'average_altitude_ARR_100', 'average_altitude_DEP_40', 'average_altitude_ENR', 'specific_energy']

# %%
for col in columns_with_nan:
    total_dataset[col] = total_dataset[col].fillna(mean_values[col])

print('Number of NaNs (with tow):', total_dataset.isna().sum().sum())
print('Number of NaNs (in tow):', total_dataset['tow'].isna().sum())

challenge_set_updated = total_dataset[~total_dataset['tow'].isna()]
submission_set_updated = total_dataset[total_dataset['tow'].isna()]

print('Number of flights in challenge:', challenge_set_updated.shape[0])
print('Number of flights in submission:', submission_set_updated.shape[0])
# Out:
# Number of NaNs (with tow): 105791
# Number of NaNs (in tow): 105791
# Number of flights in challenge: 368371
# Number of flights in submission: 105791

# %%
challenge_set_updated.to_csv('./data/challenge_set_updated_v9_median.csv', index=False)
submission_set_updated.to_csv('./data/submission_set_updated_v9_median.csv', index=False)

# %% [raw]
# # Summary
# v1: sem ICAO
# v2: sem ICAO mas com lat e lon
# v3: com ICAO e lat e lon
# v4: sem ICAO e lat lon alt
# v5: correcao de alguns erros do v4
# v6: inclusao de features do aircraft type
# v7: correção das features de aircraft type
# v8: v7 plus trajectories
# v9: v8 plus imputation using the (adep, ades, aircraft_type) strategy
